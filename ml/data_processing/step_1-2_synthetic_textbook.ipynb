# %%
import sys

sys.path.append("../../")

from app.common.logger import logger
from app.config.utils import Configuration, init_config
from app.common.llm_clients.openai_client import OpenAILLMClient

from ml.data_processing.prompt import STEP_1_2_SYNTHETIC_TEXTBOOK_PROMPT

# %%
config = Configuration()
init_config(config)
config = config()

# %% [markdown]
# # Data Load & Grouping

# %%
import json
import re

# %%
with open("../data/amr_guide_preprocessed.json", "r", encoding="utf-8") as f:
    arm_guide_preprocessed = json.load(f)

# %%
def group_by_h1(data_list):
    grouped_data = {}

    for item in data_list:
        original_text = item.get("original", "")

        # 정규표현식으로 첫 줄의 대제목(# ...) 추출
        # 예: "# 1. Daily Operating\n## 1.1 ..." -> "# 1. Daily Operating"
        match = re.search(r'^# .+', original_text)

        if match:
            h1_title = match.group(0).strip()
        else:
            # 대제목이 없는 경우 (예외 처리)
            h1_title = "Others"

        if h1_title not in grouped_data:
            grouped_data[h1_title] = []

        grouped_data[h1_title].append(item)

    return grouped_data

def group_by_h2(data_list):
    grouped_data = {}

    for item in data_list:
        original_text = item.get("original", "")

        # 정규표현식으로 두 번째 줄의 중제목(## ...) 추출
        match = re.search(r'^## .+', original_text)

        if match:
            h2_title = match.group(0).strip()
        else:
            # 두 번째 줄의 중제목이 없는 경우 (예외 처리)
            h2_title = "Others"

        if h2_title not in grouped_data:
            grouped_data[h2_title] = []

        grouped_data[h2_title].append(item)

    return grouped_data

# %%
grouped_amr_guide = group_by_h1(arm_guide_preprocessed)

# %%
grouped_amr_guide.keys()
# Out:
# dict_keys(['# 1. Daily Operating', '# 2. Trouble Shooting: Call Assignment', '# 3. Trouble Shooting: Navigation & Obstacle', '# 4. Trouble Shooting: Docking & H/W', '# 5. Trouble Shooting: Model Specific', '# 6. Operational Manual: Control Tools (조작 및 유지보수 매뉴얼)', '# 7. Appendix'])

# %%
# API 전처리 문서 불러오기
with open("../data/step1/HACS_preprocessed.json", "r", encoding="utf-8") as f:
    hacs_preprocessed = json.load(f)

with open("../data/step1/MCS_preprocessed.json", "r", encoding="utf-8") as f:
    mcs_preprocessed = json.load(f)

# 에러 처리 시나리오 전처리 문서 불러오기
with open("../data/step1/error_scenario_preprocessed.json", "r", encoding="utf-8") as f:
    error_scenario_preprocessed = json.load(f)

# %% [markdown]
# # 합성 데이터 생성

# %%
model = "google/gemini-3-pro-preview"
provider = "openrouter"
api_key = config["openrouter"]["api_key"]
params = {
    "max_tokens": 32768,
    "temperature": 0.0
}
llm_client = OpenAILLMClient(model=model, provider=provider, api_key=api_key, params=params)
# Out:
# 2026-01-12 10:55:01.785 | INFO     | app.common.llm_clients.openai_client:_create_clients:57 - Creating OpenRouter client.

# %% [markdown]
# ## 그룹 별 텍스트북 생성

# %%
resuls = []
for k, v in grouped_amr_guide.items():
    context = [x['preprocessed'] for x in v]
    context = f"{k}\n" + "\n".join(context)
    user_prompt = f"""[입력 텍스트]
    {context}"""
    response = llm_client.generate(system_prompt=STEP_1_2_SYNTHETIC_TEXTBOOK_PROMPT, chat_messages=[{"role": "user", "content": user_prompt}])
    result = response.choices[0].message.content
    logger.info(result)

    json_result = {
        'id': k,
        'preprocessed_group': context,
        'textbook': result
    }
    resuls.append(json_result)
# Out:
# 2026-01-02 17:42:55.515 | INFO     | __main__:<module>:9 - # BMA 자동화 시스템 기술 백서: 운영 로직 및 전력 관리 아키텍처
# ## (Technical Whitepaper: Operational Logic and Power Management Architecture in BMA Systems)
#
# **작성자:** 수석 아키텍트 (Chief Architect)
# **문서 등급:** Confidential (Internal Use Only)
# **적용 대상:** 현대자동차그룹 BMA 공정 0.3T/1T AMR 및 WEB ACS 운영 엔지니어
#
# ---
#
# ### 1. 서론 (Introduction)
#
# 본 챕터에서는 BMA(Battery Module Assembly) 공정의 핵심 물류 자원인 AMR(Autonomous Mobile Robot)과 이를 관제하는 상위 시스템 WEB ACS(Activity Control System) 간의 **논리적 상호작용(Logical Interaction)** 및 **전력 관리 메커니즘(Power Management Mechanism)**을 다룬다.
#
# 단순한 조작 절차를 넘어, 시스템이 미션(Mission)을 생성하고 할당하는 알고리즘적 배경과, 리튬이온 배터리 기반의 모빌리티 하드웨어가 전기적 안정성을 유지하기 위해 요구되는 물리적 제약 사항을 공학적 관점에서 심층 분석한다.
#
# ---
#
# ### 2. 미션 디스패칭 아키텍처와 Place Cycle 제어 논리
# #### (Mission Dispatching Architecture & Place Cycle Control Logic)
#
# WEB ACS는 공정 내 수백 개의 노드(Node)와 링크(Link)를 관리하며, 각 위치(Place)의 상태에 따라 AMR에게 작업을 할당한다. 이때 **'Place Cycle'** 설정은 시스템이 물리적 공간을 논리적 가용 자원으로 인식하게 만드는 핵심 인터페이스다.
#
# #### 2.1. 이중 검증 게이트웨이: Logistics와 Run 상태의 상관관계
# ACS 시스템은 AMR에게 미션을 할당하기 전, **AND 논리 게이트**를 통해 해당 목적지의 유효성을 검증한다. 이 검증 과정은 `Logistics` 스위치와 `Run` 상태라는 두 가지 변수에 의해 결정된다.
#
# *   **Logistics (논리적 미션 생성 트리거):**
#     *   **기능:** 시스템 레벨에서의 '미션 생성 허가(Mission Generation Enable)' 비트(Bit)이다.
#     *   **작동 원리:** 이 스위치가 `ON` 상태일 때만 ACS의 스케줄러(Scheduler) 알고리즘이 해당 Place를 유효한 작업 대기열(Queue)에 포함시킨다. 만약 `OFF`라면, 물리적으로 설비가 가동 중이라 하더라도 ACS는 해당 위치로의 이동 명령을 생성하지 않는다. 이는 소프트웨어적인 차단막 역할을 한다.
# *   **Run (물리적 설비 가동 상태):**
#     *   **기능:** 현장 설비(Equipment)의 '물리적 준비 상태(Physical Readiness)'를 나타내는 상태 플래그이다.
#     *   **작동 원리:** `RUNNING` 상태는 해당 위치의 설비가 에러 없이 정상 작동 중이며, AMR과의 인터페이스(도킹, 이재 등)가 가능함을 의미한다.
# *   **논리적 인과관계 (Logical Causality):**
#     *   시스템은 `IF (Logistics == ON) AND (Run == RUNNING) THEN (Dispatch Mission)`의 로직을 수행한다.
#     *   따라서 운영자는 생산 시작 시 반드시 두 변수를 모두 활성화해야 하며, 비가동 시에는 이를 비활성화하여 불필요한 트래픽 생성이나 유령 미션(Ghost Mission) 할당을 방지해야 한다.
#
# #### 2.2. 배치(Batch) 제어 프로세스: Auto ON/OFF 알고리즘
# 대규모 공정에서 개별 Place를 일일이 제어하는 것은 휴먼 에러(Human Error)를 유발할 수 있다. 이를 방지하기 위해 ACS는 **Auto ON/OFF** 기능을 제공한다.
#
# *   **메커니즘:** 이 기능은 `Run` 상태를 마스터 키(Master Key)로 활용한다. 사용자가 Auto 기능을 실행하면, 시스템은 현재 `Run` 상태가 `ON`인 모든 Place를 스캔(Scan)하고, 해당 항목들의 `Logistics` 스위치를 동기화(Synchronization)하여 일괄적으로 `ON`으로 전환한다.
# *   **데이터 흐름:** `User Input (Auto ON)` -> `Query (Select Places where Run=True)` -> `Update (Set Logistics=True)` -> `System Feedback (Ready to Dispatch)`.
# *   이 프로세스는 운영자가 실제 가동 라인과 시스템 설정 간의 불일치(Mismatch)를 최소화하도록 설계되었다.
#
# ---
#
# ### 3. AMR 전력 관리 시스템과 전기화학적 안정성
# #### (AMR Power Management System & Electrochemical Stability)
#
# AMR은 고용량 리튬이온 배터리를 동력원으로 사용하며, BMS(Battery Management System)를 통해 전압과 전류를 제어한다. 전력 관리 규정은 단순한 에너지 절약이 아닌, 배터리 셀(Cell)의 수명 보호와 시스템의 안전한 종료(Graceful Shutdown)를 위해 설계되었다.
#
# #### 3.1. 충전 중 전원 유지의 공학적 이유
# *   **규정:** 충전기에 도킹(Docking)되어 충전 중인 AMR은 절대 전원을 끄지 않는다.
# *   **Why (공학적 배경):**
#     *   **BMS 통신 유지:** 충전 중에는 AMR의 BMS와 충전기(Charger) 간에 지속적인 통신(CAN/Ethernet)이 이루어진다. 이를 통해 배터리의 전압(Voltage), 온도(Temperature), SOC(State of Charge) 정보를 실시간으로 교환하며 CC(Constant Current) 및 CV(Constant Voltage) 모드를 조절한다.
#     *   **냉각 시스템 가동:** 급속 충전 시 발생하는 열을 제어하기 위해 AMR 내부의 냉각 팬(Cooling Fan)이 가동되어야 한다. 전원을 끄면 냉각 시스템이 중단되어 배터리 셀의 열화(Degradation)를 초래할 수 있다.
#
# #### 3.2. 대기 상태(Idle)에서의 Graceful Shutdown 절차
# 충전기 외부에서 대기 중인 AMR은 기생 방전(Parasitic Drain)을 막기 위해 전원을 차단해야 한다. 그러나 즉각적인 전원 차단(Hard Power Off)은 데이터 손실이나 논리적 오류를 유발하므로, 다음과 같은 **순차적 종료 시퀀스**를 준수해야 한다.
#
# 1.  **Call Cancel (미션 반환):** 할당된 미션을 ACS 서버에 반환하여, 다른 로봇이 해당 작업을 수행할 수 있도록 스케줄러를 갱신한다.
# 2.  **Job Cancel (작업 취소):** 로봇 내부의 로컬 컨트롤러(Local Controller)에서 수행 중인 프로세스를 중단하고, 구동 모터 및 액추에이터의 서보(Servo)를 Off 상태로 전환한다.
# 3.  **Power OFF (전원 차단):** 상위 논리 회로가 안전하게 종료된 후, 물리적 전원을 차단한다.
#
# #### 3.3. 장기 보관 시 물리적 격리 (Physical Isolation)
# *   **규정:** 주말 등 장기 정지 시 충전기에서 **200mm 이상** 이격 후 전원을 끈다.
# *   **작동 원리:**
#     *   **갈바닉 절연(Galvanic Isolation) 확보:** 충전 단자와 로봇의 접촉 부위가 장기간 연결되어 있을 경우, 미세한 누설 전류(Leakage Current)가 발생하거나, 충전기 전원 차단 시 배터리에서 충전기 쪽으로 역전류(Reverse Current)가 흐를 위험이 있다.
#     *   200mm의 물리적 거리는 이러한 전기적 경로를 완벽히 차단하여 배터리의 과방전(Deep Discharge)을 방지하는 물리적 안전장치(Fail-safe)이다.
#
# ---
#
# ### 4. 비상 상황 복구 및 하드웨어 보호 메커니즘
# #### (Emergency Recovery & Hardware Protection Mechanism)
#
# #### 4.1. 재가동 시퀀스: Call-Retry를 통한 동기화
# AMR을 재가동할 때 `Power ON` 후 `Call-Retry`를 실행하는 것은 단순한 재시도가 아니다. 이는 **ACS 서버와 AMR 간의 상태 동기화(State Synchronization)** 과정이다.
# *   전원이 꺼져 있던 동안 ACS와 AMR 간의 정보 불일치가 발생할 수 있다. `Call-Retry` 명령은 AMR이 자신의 현재 위치(Localization)와 상태 정보를 ACS에 강제로 푸시(Push)하고, 중단되었던 미션 컨텍스트(Context)를 복원하는 핸드쉐이킹(Handshaking) 절차이다.
#
# #### 4.2. 과전류 보호 회로(OCPD) 작동 및 수동 복구
# *   **현상:** 충전 중인 1T/0.3T AMR을 강제 종료할 경우, 배터리 회로 차단기가 트립(Trip)될 수 있다.
# *   **원인 분석 (Physics):**
#     *   충전 중에는 높은 전류(High Amperage)가 흐르고 있다. 이때 강제로 시스템을 종료하면, 인덕턴스 성분에 의해 급격한 전압 스파이크(Voltage Spike)나 과도 전류(Transient Current)가 발생할 수 있다.
#     *   배터리 내부의 보호 회로(Protection Circuit)는 이를 단락(Short Circuit)이나 심각한 전기적 결함으로 인식하여, 물리적 차단기(Breaker)를 작동시켜 배터리 셀을 보호한다.
# *   **복구 메커니즘:**
#     *   이 상태는 소프트웨어 리셋으로 복구되지 않는 **하드웨어 락(Hardware Lock)** 상태이다.
#     *   따라서 엔지니어는 전면 커버를 제거하고(물리적 접근), 배터리 후면의 차단기 스위치를 직접 조작(Mechanical Reset)하여 회로를 다시 연결해야 한다. 이는 시스템 보호를 위한 최후의 보루가 정상 작동했음을 의미한다.
#
# ---
# **결론:**
# BMA 공정의 안정적인 운영은 WEB ACS의 논리적 설정과 AMR 하드웨어의 물리적 특성을 정확히 이해하는 것에서 시작된다. 운영자는 각 조작 행위가 시스템의 데이터 흐름과 전기적 회로에 미치는 인과관계를 숙지하고, 정의된 프로토콜을 준수하여 시스템의 가용성(Availability)과 안전성(Safety)을 확보해야 한다.
# 2026-01-02 17:43:39.009 | INFO     | __main__:<module>:9 - # BMA 자동화 시스템 기술 백서
# ## Chapter 4. 작업 할당 로직 및 예외 상황 처리 메커니즘 (Task Allocation & Exception Handling)
#
# ### 1. 개요 (Overview)
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 물류 자동화는 ACS(AGV Control System)와 MCS(Material Control System), 그리고 현장의 설비 PLC(Programmable Logic Controller) 간의 정교한 데이터 핸드셰이킹(Handshaking)을 기반으로 작동한다. 본 챕터에서는 AMR(Autonomous Mobile Robot)의 작업 할당(Call Assignment) 프로세스에서 발생하는 논리적 교착 상태(Deadlock)와 통신 불일치 현상을 시스템 아키텍처 관점에서 분석하고, 이에 대한 공학적 해결 원리를 서술한다.
#
# ---
#
# ### 2. ACS 작업 생성 실패의 논리적 원인 분석 (Logic of Call Generation Failure)
#
# ACS 상에서 작업 요청(Call)이 생성되지 않는 현상은 단순한 통신 단절이 아닌, 시스템의 **가용성 검증(Availability Check)** 및 **데이터 무결성(Data Integrity)** 검증 단계에서의 실패를 의미한다.
#
# #### 2.1. 논리적 가용성 플래그 (Logical Availability Flags)
# ACS는 작업을 생성하기 전, 대상 설비(Equipment)와 컨베이어 시스템의 상태를 논리적으로 검증한다. WEB ACS의 `Place Cycle` 설정 메뉴에서 확인되는 **Logistics**와 **RUN** 상태는 시스템의 '논리적 연결됨(Logically Connected)'과 '물리적 가동 중(Physically Running)'을 나타내는 이중 안전장치다.
# *   **메커니즘:** 상위 시스템은 설비로부터 `Heartbeat` 신호를 수신하더라도, `Logistics=ON` 및 `RUN=RUNNING`이라는 두 가지 비트(Bit)가 동시에 `True`일 때만 유효한 작업 노드로 인식한다. 이 중 하나라도 비활성화될 경우, 시스템은 해당 노드를 '격리(Isolation)' 상태로 간주하여 작업 큐(Queue) 생성을 원천 차단한다.
#
# #### 2.2. 데이터 타입 불일치에 의한 프로토콜 거부 (Protocol Rejection by Type Mismatch)
# 설비(EQP)와 AMR 간의 **Call Type** 불일치는 데이터베이스 레벨의 무결성 위반을 초래한다.
# *   **작동 원리:** 설비 PLC가 요청하는 자재의 속성(Call Type)과 AMR이 운송 가능한 자재의 속성(AMR Call Type)은 1:1 또는 N:1로 매핑되어야 한다. WEB ACS의 PLC 탭에서 이 값이 상이할 경우, ACS의 스케줄러(Scheduler)는 "적합한 운송 수단 없음"으로 판단하여 Call 생성을 중단한다. 이는 잘못된 자재가 투입되어 발생할 수 있는 물리적 공정 사고를 예방하기 위한 소프트웨어적 인터록(Interlock)이다.
#
# #### 2.3. HMI 레벨의 인터럽트 (HMI Level Interrupt)
# 설비 HMI(Human-Machine Interface)의 **Call Create Pause** 버튼은 상위 시스템의 로직을 하위 레벨에서 강제로 차단하는 '소프트웨어 인터럽트' 역할을 수행한다.
# *   **인과관계:** 이 버튼이 활성화되면 PLC의 특정 레지스터 값이 변경되어, 자재가 투입 준비 완료 상태(Ready)가 되더라도 상위 ACS로 `Call Request` 트리거를 보내지 않는다. 이는 유지보수나 일시적 라인 정지 시 불필요한 트래픽 생성을 억제한다.
#
# #### 2.4. 작업 스레드 점유 (Task Thread Occupation)
# AMR이 물리적으로는 정지해 있으나 시스템상으로 작업을 할당받지 못하는 경우, **Work Orders** 메뉴의 상태 점검이 필수적이다.
# *   **Deadlock 메커니즘:** AMR의 상태가 `Idle`이 아닌 경우, 이전 작업의 트랜잭션(Transaction)이 정상적으로 종료(Commit)되지 않고 잔존해 있음을 의미한다. 데이터베이스 상에 '유령 작업(Ghost Task)'이 남아있으면, 스케줄러는 해당 AMR을 'Busy' 상태로 인식하여 신규 작업을 할당하지 않는다. 잔존 Work Order의 강제 삭제는 이러한 논리적 점유를 해제하여 리소스를 가용 상태로 복구하는 과정이다.
#
# ---
#
# ### 3. 자재 준비 지연 및 창고 시스템 연동 (Warehouse Integration & Latency)
#
# 자재 준비 지연(Warehouse Delay)은 물리적 물류 흐름과 디지털 정보 흐름의 비동기화(Desynchronization)에서 기인한다.
#
# #### 3.1. 프로세스 지연과 준비 실패의 구분
# *   **Process Delay (준비 지연):** 창고 내부의 스태커 크레인(Stacker Crane)이나 컨베이어의 물리적 이동 시간이 예상보다 길어지는 경우다. 이는 시스템 에러가 아닌 '물리적 병목(Physical Bottleneck)' 현상이다.
# *   **Preparation Fail (준비 실패):** WMS(Warehouse Management System)가 재고 부족(Out of Stock)이나 창고 설비의 하드웨어 에러(Motor Fault, Sensor Error 등)로 인해 출고 명령을 수행할 수 없는 상태다. 이는 즉각적인 유지보수 개입이 필요한 '시스템 예외(System Exception)' 상황이다.
#
# #### 3.2. MCS 로드 명령과 자원 할당의 경합 (Resource Contention)
# MCS 상에 `LOAD` 명령이 존재함에도 로봇이 할당되지 않는 현상은 **자원 경합(Resource Contention)** 또는 **미션 중복(Mission Overlap)**에 기인한다.
# *   **분석:** WEB ACS Mission List에 수동 미션이 선점되어 있거나, 목적지 노드(Destination Node)에 다른 미션이 예약(Reservation)된 경우, 교착 상태 방지 알고리즘에 의해 자동 할당이 보류된다.
# *   **제어 모드 의존성:** AMR은 `AUTO` 모드에서만 MCS의 스케줄링 알고리즘에 반응한다. `MANUAL` 모드는 로컬 제어권이 우선시되므로 중앙 관제 시스템의 명령을 무시(Bypass)하게 설계되어 있다. 따라서 자동 복구 실패 시 AMR의 제어 모드 확인은 필수적인 디버깅 절차다.
#
# ---
#
# ### 4. 경로 대기 및 동적 라우팅 로직 (Way Point Waiting & Dynamic Routing)
#
# AMR이 Way Point(WP)에서 장시간 대기하는 현상은 **동적 라우팅(Dynamic Routing)** 실패 또는 **공간 상호 배제(Spatial Mutual Exclusion)** 로직의 결과다.
#
# #### 4.1. 목적지 점유와 트래픽 제어
# AMR은 충돌 방지를 위해 목적지 노드가 선행 AMR에 의해 점유(Occupied)되어 있거나, 도킹 프로세스가 진행 중일 때 WP에서 대기하도록 프로그래밍되어 있다. 이는 다중 로봇 제어 시스템(Multi-Agent System)의 기본 원칙인 상호 배제(Mutual Exclusion)가 작동하는 정상적인 대기 상태일 수 있다.
#
# #### 4.2. WMS의 위치 결정 지연 (Location Assignment Latency)
# AMR이 WP에 도착했음에도 대기하는 주된 기술적 원인은 창고 시스템(WMS)의 **적재 위치 결정 로직(Decision Logic)** 지연이다.
# *   **데이터 흐름:** AMR(WP 도착 신호) → ACS → MCS → WMS(적재 포트 #1/#2 가용성 판단) → MCS → ACS → AMR(최종 목적지 하달).
# *   **현상:** 이 데이터 체인 중 WMS가 적재 위치(#1 or #2)를 확정하여 리턴하지 않으면, AMR은 다음 이동 명령(Next Move Command)을 수신하지 못해 WP에서 무한 대기(Infinite Loop)하게 된다. 창고 시스템이 수동 모드이거나 위치 정보를 소실(Null Return)한 경우, 보전 담당자를 통한 시스템 리셋이 요구된다.
#
# ---
#
# ### 5. 차종 변경 시의 역물류 프로세스 (Reverse Logistics in Model Changeover)
#
# 차종 변경(Model Change)은 정방향 물류(Forward Logistics)를 중단하고, 라인 내 잔류 자재를 제거하는 역물류(Reverse Logistics) 프로세스를 수반한다.
#
# #### 5.1. 자재별 회수 가능성 (Recoverability by Material Type)
# *   **회수 가능 (BMA/BSA/Battery Cell):** 표준화된 팔레트나 박스 형태의 자재는 AMR의 그리퍼나 컨베이어 인터페이스와 호환되어 자동 회수가 가능하다.
# *   **회수 불가능 (Lower Case - L/C):** L/C 공급 AMR은 공정 특성상 단방향 공급에 최적화되어 있거나, 자재의 부피 및 적재 방식의 특이성으로 인해 역방향 회수 로직이 구현되어 있지 않다. 이는 하드웨어적 제약에 따른 시스템 설계 사양이다.
#
# #### 5.2. 트랜잭션 롤백 시퀀스 (Transaction Rollback Sequence)
# 차종 변경 시 수동 조작 절차는 데이터베이스의 트랜잭션을 안전하게 롤백(Rollback)하는 과정이다.
# 1.  **Call Create Pause 'ON':** 신규 트랜잭션 생성 차단 (Input Blocking).
# 2.  **Call Cancel:** 대기 중인 요청 큐(Queue) 삭제.
# 3.  **Work Reset:** 현재 진행 중인 프로세스 강제 종료 및 초기화.
# 4.  **Unload (Manual/Auto):** 물리적 자재 제거.
# 5.  **Call Create Pause 'OFF':** 시스템 재가동 준비 완료 (System Resume).
#
# 이 순서를 준수하지 않을 경우, 물리적 자재는 제거되었으나 시스템상에는 자재가 존재하는 **데이터 불일치(Data Inconsistency)**가 발생할 수 있다.
#
# ---
#
# ### 6. 미션 소실 시 수동 복구 및 예외 처리 (Manual Recovery & Exception Handling)
#
# 작업자의 실수로 미션이 삭제되어 AMR이 '적재 상태(Loaded)'로 고립된 경우, 시스템은 AMR의 위치와 적재물 정보를 잃어버린 상태가 된다. 이를 복구하기 위해 가상의 시스템 상태를 강제로 주입(Injection)해야 한다.
#
# #### 6.1. 가상 노드를 통한 상태 동기화 (State Synchronization via Virtual Nodes)
# WEB ACS에서의 우클릭 및 `Unload` 명령은 실제 물리적 하역을 수행하는 것이 아니라, 시스템 상의 AMR 상태를 `Loaded`에서 `Empty`로 강제 전환하는 **논리적 리셋(Logical Reset)** 과정이다.
#
# *   **BMA Pallet:** `MW 11`, `MW 21` (적재 상태 노드) 또는 `MW 13`, `MW 213` (공차 상태 노드)와 같은 특정 메모리 워드(Memory Word) 주소에 해당하는 가상 위치를 이용하여 시스템 상태를 동기화한다.
# *   **BMA Parts Box:** `MS25`(회수 포트)와 같은 지정된 회수 노드에서 `Unload` 및 `Unload2` 명령을 수행하여, 복잡한 부품 박스의 데이터 구조를 초기화한다.
# *   **L/C 및 BSA 완제품:** 목표 지점(Destination)에서 논리적 `Unload`를 수행하거나, 지게차를 이용한 물리적 배출 후 시스템 상태를 수동으로 보정한다.
#
# 이러한 수동 복구 절차 후 `Auto Mode`로의 전환은, 초기화된 상태 정보를 바탕으로 AMR이 다시 중앙 관제 시스템의 스케줄링 루프(Scheduling Loop)에 정상적으로 편입되도록 하는 최종 단계다.
# 2026-01-02 17:44:29.770 | INFO     | __main__:<module>:9 - # BMA 자동화 시스템 기술 백서 (Technical Whitepaper)
# ## Chapter 3. 자율주행 내비게이션 아키텍처 및 센서 퓨전 기반 장애물 회피 메커니즘
# **(Autonomous Navigation Architecture & Sensor Fusion based Obstacle Avoidance Mechanism)**
#
# ---
#
# ### 1. 개요 (Overview)
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 물류 자동화는 ACS(Agile Control System)의 글로벌 경로 계획(Global Path Planning)과 AMR(Autonomous Mobile Robot)의 로컬 제어(Local Control)가 유기적으로 결합된 복합 시스템입니다. 본 챕터에서는 0.3T 및 1T AMR이 주행 경로를 생성하고 추종하는 논리적 프로세스와, Lidar 및 3D Camera 센서 퓨전을 통해 구현되는 안전 메커니즘(Safety Mechanism)의 심층적인 작동 원리를 기술합니다. 특히 현장에서 발생하는 주요 에러 코드의 공학적 원인과 시스템의 논리적 대응 절차를 분석하여, 엔지니어가 시스템의 인과관계를 명확히 이해하도록 돕습니다.
#
# ---
#
# ### 2. 내비게이션 알고리즘 및 위치 추정 무결성 (Navigation Algorithm & Localization Integrity)
#
# AMR의 자율 주행은 사전에 정의된 디지털 맵(Digital Map)과 실제 환경 데이터를 실시간으로 대조하는 확률적 모델(Probabilistic Model)에 기반합니다. 이 과정에서 경로 유효성 검증 실패나 위치 추정의 불확실성이 발생할 경우, 시스템은 안전을 위해 즉각적인 예외 처리(Exception Handling) 루틴을 수행합니다.
#
# #### 2.1. 경로 계획의 유효성 검증 및 예외 처리
# **[System Logic: ACS Command Validation Layer]**
#
# ACS는 AMR에게 이동 명령(Move Command)을 하달하기 전, 목적지 노드의 유효성을 검증합니다. 이때 발생하는 **`ACS_ERROR_WHILE_NAVIGATING_THE_ROUTE`**는 단순한 명령 오류가 아니라, **경로 비용 계산(Path Cost Calculation)의 실패**를 의미합니다.
#
# *   **발생 원리 (Mechanism):** ACS의 맵 데이터는 '주행 가능 영역(Costmap defined)'과 '주행 불가 영역(Undefined/White Background)'으로 이진화되어 있습니다. 관리자가 주행 불가 영역을 목적지로 지정할 경우, A* 또는 Dijkstra와 같은 경로 탐색 알고리즘은 목표 지점까지의 유효한 노드 연결(Edge Connection)을 생성할 수 없어 무한 루프나 Null 값을 반환하게 됩니다.
# *   **시스템 대응 (System Response):** 시스템은 이를 치명적 논리 오류로 간주하여 해당 Job을 거부합니다.
# *   **복구 로직 (Recovery Logic):** 자동 복구가 불가능한 논리적 교착 상태이므로, 운영자가 `Job Cancel` 신호를 통해 잘못된 명령 스택을 소거해야 합니다. 이후 JOG 모드를 통해 AMR을 Costmap이 정의된 정상 경로(Colored Line)로 물리적으로 이동시켜, 알고리즘이 다시 유효한 경로 비용을 산출할 수 있는 초기 조건을 형성해야 합니다.
#
# #### 2.2. 경로 추종 오차 및 이탈 감지 (Cross-Track Error Monitoring)
# **[Error Code: 80002 - ERROR_NOT_ON_PATH]**
#
# 1T AMR은 경로 추종 시 설정된 경로와 실제 로봇 위치 간의 수직 거리 오차(Cross-Track Error, XTE)를 실시간으로 모니터링합니다.
#
# *   **발생 원리 (Mechanism):** 로봇의 제어기(Controller)는 매 제어 주기마다 `|Current_Position - Planned_Path|`를 연산합니다. 이 값이 허용 임계값(Threshold)을 초과하면, 로봇은 자신이 제어 불가능한 영역에 있다고 판단합니다. 이는 슬립(Slip) 현상이나 외력에 의한 밀림 등으로 발생할 수 있습니다.
# *   **복구 로직 (Recovery Logic):** 이탈 상태에서는 자율 복귀 경로 생성이 불가능하므로(Unsafe State), `Job Cancel` 후 수동/JOG 조작을 통해 로봇을 허용 오차 범위(정상 경로) 내로 진입시켜야 합니다. 위치가 정상 범위로 수렴하면 `CALL-RETRY` 또는 `AUTO` 모드 전환을 통해 경로 추종 PID 제어 루프를 재활성화합니다.
#
# #### 2.3. 확률적 위치 추정 및 신뢰도 저하 (Probabilistic Localization & Confidence)
# **[Error Code: 80003 - ERROR_CONFIDENCE_LOW]**
#
# AMR은 SLAM(Simultaneous Localization and Mapping) 기술, 특히 입자 필터(Particle Filter)나 그래프 기반 최적화를 통해 자신의 위치를 추정합니다.
#
# *   **발생 원리 (Mechanism):** 라이다 센서가 스캔한 현재의 점군(Point Cloud) 데이터와 저장된 맵 데이터 간의 매칭 확률(Matching Probability)이 임계치 이하로 떨어지는 현상입니다.
#     *   **환경적 요인:** 맵에 없는 미지의 영역 진입 또는 동적 장애물(지게차, 작업자 등)이 고정 지형지물(벽, 기둥)을 장시간 가려 '특징점(Feature)' 추출이 불가능한 경우 발생합니다.
# *   **복구 로직 (Recovery Logic):**
#     1.  **시야 확보:** 센서의 시야(Field of View)를 가리는 장애물을 제거하여 특징점 매칭을 유도합니다.
#     2.  **재수렴(Re-convergence):** 제자리에서 360도 회전을 수행하면 라이다가 전방위 데이터를 수집하여 위치 확률 분포를 갱신, 현재 위치를 재특정할 수 있습니다.
#     3.  **강제 초기화(Initialization):** 자동 수렴 실패 시, ACS의 `Init Position` 명령을 통해 로봇에게 현재의 절대 좌표(Node/Map Icon)와 헤딩(Heading, 0~360도) 값을 강제로 주입(Injection)하여 위치 추정 알고리즘을 리셋합니다.
#
# #### 2.4. 오도메트리 피드백 상실 (Odometry Feedback Loss)
# **[Error Code: 80014 - ERROR_ENCODER_NOT_UPDATE]**
#
# 정밀 주행을 위해서는 바퀴의 회전량을 감지하는 엔코더(Encoder) 데이터가 필수적입니다.
#
# *   **발생 원리 (Mechanism):** 모터 제어기(Motor Driver)가 구동 전류를 인가했음에도 불구하고, 엔코더로부터 펄스(Pulse) 신호 변화가 감지되지 않는 상태입니다. 이는 물리적으로 바퀴가 구속(Stall)되었거나, 엔코더 통신 라인의 단선, 혹은 센서 모듈의 하드웨어적 고장을 의미합니다.
# *   **시스템 대응 (System Response):** 제어기는 이를 '제어 불능 상태'로 판단하여 즉시 모터 전원을 차단(Emergency Stop)합니다.
# *   **복구 로직 (Recovery Logic):** 이는 하드웨어 상태 불일치이므로 소프트웨어 리셋만으로는 해결되지 않을 수 있습니다. `Job Cancel` 후 기체 측면의 물리적 `RESET` 버튼을 눌러 하위 레벨 제어기(Low-level Controller)를 재부팅하고 엔코더 상태를 초기화해야 합니다.
#
# ---
#
# ### 3. 안전 센서 퓨전 및 OSSD 메커니즘 (Safety Sensor Fusion & OSSD Mechanism)
#
# BMA 공정의 AMR은 작업자와의 협동을 전제로 하므로, 국제 안전 규격(ISO 13849-1 등)을 준수하는 하드웨어 기반의 안전 시스템을 탑재하고 있습니다.
#
# #### 3.1. 광학적 특성에 따른 라이다 오인식 (Optical Characteristics & Lidar False Positive)
# **[Error Code: 20014 - Stop due to HOKUYO Lidar obstacle detection]**
#
# HOKUYO 안전 라이다는 ToF(Time of Flight) 방식을 사용하며, 레이저 펄스가 물체에 반사되어 돌아오는 시간을 측정합니다.
#
# *   **발생 원리 (Mechanism):**
#     *   **고반사체 간섭 (High Reflectivity):** 안전콘의 은색 반사판이나 작업자 조끼의 반사 테이프는 입사된 레이저를 광원 방향으로 강하게 반사(Retro-reflection)시킵니다. 이는 수신부 포토다이오드(Photodiode)의 포화(Saturation)를 유발하거나, '블루밍(Blooming)' 현상을 일으켜 실제보다 물체를 더 크게, 혹은 존재하지 않는 위치에 장애물이 있는 것으로 오인하게 만듭니다.
#     *   **센서 오염:** 렌즈 표면의 이물질은 레이저를 산란(Scattering)시켜 신호 대 잡음비(SNR)를 떨어뜨리고, 이를 근거리 장애물로 인식하게 합니다.
# *   **복구 로직 (Recovery Logic):**
#     *   **물리적 이격:** 고반사 물체를 2m 이상 이격시켜 수신 광량을 정상 범위로 낮춥니다.
#     *   **광학적 세척:** 전용 클리너로 렌즈를 닦아 산란 요인을 제거합니다.
#     *   **하드웨어 리셋:** 센서 내부의 에러 레지스터가 래치(Latch)된 경우, `RESET` 버튼 또는 전원 재부팅을 통해 OSSD 상태를 클리어해야 합니다. 지속적인 오류는 센서 모듈 자체의 결함일 수 있으므로 S/V 기술 지원이 필요합니다.
#
# #### 3.2. OSSD 기반 비상 정지 메커니즘 (OSSD Based Emergency Stop)
# **[Error Code: 30020 - OSSD LIDAR ERROR]**
#
# OSSD(Output Signal Switching Device)는 소프트웨어의 개입 없이 센서가 직접 전력 계통을 제어하는 최상위 안전 장치입니다.
#
# *   **작동 원리 (Mechanism):** 라이다가 설정된 안전 영역(Safety Zone) 내에서 물체를 감지하거나 자체 고장(Self-diagnosis fault)을 감지하면, OSSD 신호 라인(Dual Channel)을 Low 상태로 떨어뜨립니다. 이는 모터 구동 회로의 전원을 물리적으로 차단(Cut-off)하여 로봇을 즉시 정지시킵니다.
# *   **데이터 흐름 (Data Flow):** [Obstacle Detection] -> [Lidar Internal Logic] -> [OSSD Signal Low] -> [Safety Relay Open] -> [Motor Power Cut].
# *   **복구 로직 (Recovery Logic):** 장애물 제거 후 `RESET` 버튼을 누르는 행위는 Safety Relay에 다시 전원을 인가하여 OSSD 신호를 High 상태로 복구시키는 과정입니다.
#
# ---
#
# ### 4. 3D 인지 및 동적 환경 상호작용 (3D Perception & Dynamic Environment Interaction)
#
# 2D 라이다의 한계(높이 정보 부재)를 극복하기 위해 3D 카메라가 퓨전(Fusion)되어 입체적인 장애물 감지를 수행합니다.
#
# #### 4.1. 3D 공간 장애물 및 충돌 방지 (Volumetric Obstacle Detection)
# **[Error Code: 80026 - PAUSE_BY_CAMERA_OBSTACLE]**
#
# *   **발생 원리 (Mechanism):** 3D 카메라는 전방 공간을 복셀(Voxel) 단위로 인식합니다. 바닥에 닿아있지 않은 공중의 물체(늘어진 케이블, 돌출된 HMI 패널 등)가 AMR의 충돌 예측 볼륨(Collision Volume) 내에 진입하면 에러를 트리거합니다.
# *   **도킹 시나리오 (Docking Scenario):** 도킹/언도킹 과정에서는 로봇과 설비 간의 간격이 매우 좁아집니다. 이때 금속 설비 표면의 정반사(Specular Reflection)가 3D 카메라에 노이즈(Ghost Object)를 생성하여 `PAUSED_BY_OBSTACLE` 알람을 유발할 수 있습니다.
# *   **복구 로직 (Recovery Logic):**
#     *   **환경 개선:** 상부 장애물(케이블 등)을 제거하거나, 금속 반사면에 비반사 필름을 부착하여 센서 간섭을 차단합니다.
#     *   **수동 탈출:** 도킹 중 장애물 감지로 교착 상태(Deadlock)에 빠진 경우, 자동 알고리즘으로는 충돌 없이 빠져나갈 경로를 계산할 수 없습니다. 따라서 작업자가 수동으로 `Undocking`을 수행하여 로봇을 안전한 공간(Free Space)으로 이동시킨 후, `Call-Retry`를 통해 작업을 재개해야 합니다.
#
# ---
#
# ### 5. 결론 (Conclusion)
#
# BMA 공정의 AMR 시스템 에러는 단순한 고장이 아니라, **불확실한 환경 변수로부터 시스템과 작업자를 보호하기 위한 방어 기제(Defense Mechanism)의 작동**으로 이해해야 합니다. 엔지니어는 각 에러 코드가 의미하는 센서의 물리적 한계와 알고리즘의 논리적 조건을 정확히 파악하고, 제시된 인과관계에 따라 체계적인 트러블슈팅을 수행함으로써 시스템의 가동률(Availability)을 극대화해야 합니다.
# 2026-01-02 17:45:10.686 | INFO     | __main__:<module>:9 - # BMA 자동화 시스템 기술 백서 (Technical Whitepaper)
# ## Chapter 4. 정밀 도킹 시스템의 메커니즘 및 하드웨어 무결성 분석 (Precision Docking Mechanism & H/W Integrity)
#
# ### 1. 개요 (Executive Summary)
#
# BMA(Battery Module Assembly) 공정 내 AMR(Autonomous Mobile Robot)의 운용 효율성은 설비와의 물리적 결합, 즉 **도킹(Docking)**의 정밀도에 의해 결정된다. 도킹 프로세스는 단순한 위치 이동이 아니라, 글로벌 네비게이션(Global Navigation)에서 로컬 퍼셉션(Local Perception)으로 제어권이 이양되는 임계 구간이다.
#
# 본 챕터에서는 AMR의 도킹 시퀀스 중 발생하는 물리적/논리적 불일치 현상을 시스템 아키텍처 관점에서 분석한다. 특히 Lidar 기반의 형상 인식(V-Marker)과 IR 센서 기반의 물리적 체결 확인(Dog Plate) 과정에서 발생하는 에러 코드 **[80018]** 및 **[10015]**의 발생 원리, 센서 데이터 흐름, 그리고 시스템 복구(Recovery)를 위한 FSM(Finite State Machine) 제어 로직을 심층적으로 다룬다.
#
# ---
#
# ### 2. 로컬 퍼셉션과 기하학적 정렬 메커니즘 (Local Perception & Geometric Alignment)
#
# AMR이 도킹 스테이션에 접근할 때, 시스템은 SLAM(Simultaneous Localization and Mapping) 기반의 전역 좌표계에서 Lidar 센서를 활용한 상대 좌표계로 주행 알고리즘을 전환한다. 이 과정에서 핵심적인 역할을 수행하는 것이 **V-마커(V-Marker)**이다.
#
# #### 2.1. V-마커 기반의 형상 인식 알고리즘
# V-마커는 단순한 표식이 아니라, Lidar 센서가 스캔한 포인트 클라우드(Point Cloud) 데이터 내에서 특정한 기하학적 특징(Feature)을 추출하기 위한 기준점(Reference)이다.
#
# *   **작동 원리:** AMR의 메인 컨트롤러는 Lidar로 스캔된 환경 데이터 중 'V'자 형태의 모서리(Corner) 특징점을 추출하고, 이를 사전에 정의된 템플릿과 매칭(Template Matching)하여 로봇의 현재 진입 각도(Heading)와 편차(Lateral Offset)를 계산한다.
# *   **[80018] ERROR_DOCK_NOT_FIND의 발생 메커니즘:**
#     이 에러는 **"예측된 위치(Global Map)"와 "실측된 형상(Local Sensor)" 간의 불일치**에서 기인한다.
#     1.  **좌표 불일치:** 맵 상에 티칭(Teaching)된 도킹 좌표에 도달했음에도 불구하고, Lidar 센서의 유효 탐지 범위(FOV) 내에서 V-마커의 특징점이 검출되지 않을 때 발생한다.
#     2.  **형상 왜곡:** 작업자의 실수로 V-마커를 밟거나 충격을 가해 마커가 물리적으로 변형(비뚤어짐)된 경우, Lidar 알고리즘은 이를 유효한 마커로 인식하지 못하고 노이즈(Noise)로 처리한다. 이는 패턴 매칭 점수(Score)가 임계값 미만으로 떨어지게 하여 도킹 대상을 찾지 못하는 결과를 초래한다.
#
# #### 2.2. 진입 각도(Heading) 제어 및 예외 처리
# 도킹의 성공률은 진입 벡터의 정렬에 달려 있다. AMR이 계산한 진입 경로의 각도가 허용 오차(Tolerance) 범위를 초과할 경우, 물리적 충돌을 방지하기 위해 시스템은 즉시 도킹 프로세스를 중단(Abort)한다. 이는 설비와 로봇 간의 커넥터 파손을 방지하기 위한 **소프트웨어적 안전 인터록(Safety Interlock)**이다.
#
# ---
#
# ### 3. 물리적 체결 검증 시스템 (Physical Verification System)
#
# Lidar가 AMR을 도킹 위치로 유도했다면, 최종적인 체결 완료 여부는 **IR(Infrared) 센서**와 **도그플레이트(Dog Plate)** 간의 상호작용을 통해 검증된다.
#
# #### 3.1. IR 센서와 도그플레이트의 광학적 상호작용
# AMR 하단에 부착된 IR 센서는 적외선을 방출하고, 설비 스토퍼(Stopper)에 장착된 도그플레이트(Dog Plate)에서 반사되어 돌아오는 광량을 측정하여 거리를 감지한다.
#
# *   **[10015] Docking failure due to IR sensor detection failure 분석:**
#     이 에러는 도킹 동작이 완료되었어야 하는 시점에, IR 센서의 신호(Digital Input)가 'High' 또는 'On' 상태로 전환되지 않았음을 의미한다.
#     *   **광학적 경로 차단 및 산란:** 도그플레이트가 파손되거나 표면이 오염된 경우, 적외선의 반사율(Reflectivity)이 저하되어 센서가 임계값 이상의 신호를 수신하지 못한다.
#     *   **설치 높이(Z-axis) 오차:** IR 센서는 특정 초점 거리(Focal Length)를 가진다. 센서의 높이 설정이 부적절하면 초점이 맞지 않아 감지 실패로 이어진다.
#
# #### 3.2. 기종별 센서 퓨전 로직 (Sensor Fusion Logic by Model)
# BMA 공정에는 0.3T와 1T 두 가지 타입의 AMR이 운용되며, 각기 다른 하중과 기구학적 특성에 따라 도킹 완료를 판단하는 센서 로직(Boolean Logic)이 상이하다.
#
# *   **0.3T AMR (단방향 도킹):**
#     *   구조적 특성상 후면 도킹(Rear Docking)만을 지원한다.
#     *   **판단 로직:** 안전 무결성을 위해 **AND 게이트** 로직을 사용한다.
#         $$Docking\_Status = (rear\_docking\_check\_sensor == ON) \land (front\_docking\_check\_sensor2 == ON)$$
#         두 센서가 동시에 활성화되어야만 시스템은 이를 'DOCK OK'로 간주한다.
#
# *   **1T AMR (양방향 도킹):**
#     *   전방 및 후방 진입이 모두 가능하다.
#     *   **판단 로직:** 진입 방향에 따른 **조건부 분기(Conditional Branching)** 로직을 수행한다.
#         *   전방 도킹 시: `front_docking_check_sensor1 == ON`
#         *   후방 도킹 시: `rear_docking_check_sensor == ON`
#
# ---
#
# ### 4. 시스템 복구 전략 및 FSM 제어 (Recovery Strategy & FSM Control)
#
# 에러 발생 시 시스템을 정상 상태로 복귀시키기 위해서는 WEB ACS(Access Control System)를 통한 논리적 상태 제어와 현장 작업자의 물리적 조치가 병행되어야 한다.
#
# #### 4.1. 논리적 상태 복구 (Logical Recovery via ACS)
# ACS 상에서의 조작은 시스템의 **교착 상태(Deadlock)**를 해제하는 과정이다.
#
# 1.  **JOB CANCEL:** 현재 수행 중인 작업 스레드(Thread)를 강제 종료하여 AMR에 할당된 리소스를 해제한다.
# 2.  **ERROR RESET:** PLC 및 상위 제어기의 에러 레지스터(Error Register)를 소거(Clear)한다.
# 3.  **상태 동기화 (State Synchronization):**
#     *   **자동 복구 실패 시 (위치 정상):** 센서 오작동 등으로 인해 실제로는 도킹되었으나 시스템이 인지하지 못한 경우, 강제로 상태를 `After Docking`으로 변경하여 프로세스를 다음 단계로 넘긴다(Bypass).
#     *   **위치 비정상 시:** AMR이 엉뚱한 위치에 있다면, 상태를 `Before Docking`으로 변경하여 재진입을 준비시킨다.
#
# #### 4.2. 물리적 복구 및 재시도 (Physical Recovery & Retry)
# 논리적 리셋만으로 해결되지 않는 물리적 정렬 불량은 수동 조작(Manual Operation)을 통해 해결해야 한다.
#
# *   **Docking-Out 메커니즘:**
#     자동 복구가 불가능할 때, 작업자는 수동(Manual/JOG) 모드로 AMR을 조작하여 도킹 스테이션의 간섭 영역(Interference Zone) 밖으로 완전히 이탈시켜야 한다. 이는 재진입 시 경로 계획(Path Planning) 알고리즘이 초기화된 상태에서 깨끗한 경로를 생성할 수 있도록 하기 위함이다.
# *   **CALL-RETRY:**
#     물리적 위치가 초기화된 후 `CALL-RETRY` 명령을 인가하면, 시스템은 V-마커 탐색부터 시작하는 전체 도킹 시퀀스를 처음부터 다시 수행한다.
#
# ### 5. 결론 및 유지보수 제언
#
# 도킹 실패는 대부분 하드웨어(센서, 마커, 플레이트)의 물리적 변형과 소프트웨어(알고리즘)의 허용 오차 간의 불일치에서 발생한다. 따라서 유지보수 엔지니어는 단순한 에러 리셋을 넘어 다음 사항을 주기적으로 점검해야 한다.
#
# 1.  **V-마커의 기하학적 무결성:** 수직/수평 정렬 상태 및 표면 손상 여부.
# 2.  **IR 센서의 신호 감도:** 도그플레이트와의 거리 및 높이(Height) 캘리브레이션.
# 3.  **환경 노이즈 관리:** Lidar 및 IR 센서에 간섭을 줄 수 있는 외부 광원이나 장애물 제거.
#
# 이러한 체계적인 접근 방식만이 BMA 공정의 가동률(Availability)을 극대화하고 다운타임을 최소화할 수 있다.
# 2026-01-02 17:45:55.350 | INFO     | __main__:<module>:9 - # BMA 공정 자동화 시스템 기술 백서
# ## Chapter 5. 이기종 AMR 운용 시나리오별 예외 처리 및 시스템 복구 메커니즘 (Exception Handling & System Recovery Mechanism)
#
# ### 1. 개요 (Overview)
# 현대자동차그룹 BMA(Battery Module Assembly) 공정은 고중량의 배터리 모듈과 부품 박스를 이송하기 위해 **0.3T Box Conveyor AMR**과 **1T Pallet Lift AMR**이라는 이기종(Heterogeneous) 로봇 군집을 운용한다. 이 시스템의 안정성은 물리적 기구부(Physical Layer), 제어 로직(PLC Layer), 그리고 관제 시스템(ACS/MCS Layer) 간의 정밀한 동기화(Synchronization)에 의존한다.
#
# 본 챕터에서는 각 AMR 모델의 기구적 특성에 따른 에러 발생 원인(Root Cause)을 공학적으로 분석하고, 시스템의 논리적 교착 상태(Logical Deadlock)를 해소하기 위한 데이터 흐름 및 복구 프로세스를 심층적으로 기술한다.
#
# ---
#
# ### 2. 0.3T AMR (Box Conveyor Type): 동적 이송 제어와 논리적 정합성
# 0.3T AMR은 컨베이어 벨트와 도어(Door) 메커니즘을 통해 박스 단위의 자재를 이송한다. 이 과정에서 발생하는 문제는 주로 물리적 마찰에 의한 구동 실패와 시스템 상의 재고 데이터 불일치로 나뉜다.
#
# #### 2.1. 물리적 끼임(Jamming)과 토크 제어 메커니즘
# 컨베이어 구동 중 발생하는 '박스 끼임' 현상은 모터의 부하 전류(Load Current)가 임계치를 초과하거나, 엔코더(Encoder)의 회전수와 지령 속도 간의 오차가 발생할 때 감지된다.
# *   **현상:** 이송 중 박스 끼임 또는 작업 지연 알람 발생.
# *   **복구 로직:** 시스템은 과부하 보호를 위해 모터 전원을 차단(Trip)한다. 작업자가 물리적 장애 요소를 제거한 후, HMI의 **[Main(F1) -> RESUME]** 시퀀스를 입력하는 것은 단순한 재시작이 아니다. 이는 모터 드라이버의 에러 레지스터(Error Register)를 소거(Clear)하고, 중단된 시점의 시퀀스 스텝(Sequence Step)을 다시 호출하여 PID 제어 루프를 재활성화하는 과정이다.
#
# #### 2.2. 도킹 실패와 경로 점유 교착 상태 (Deadlock Resolution)
# AMR이 설비와 도킹(Docking)을 시도하다 실패할 경우, 해당 AMR은 경로를 점유한 채 정지하여 후속 로봇의 이동을 막는 병목(Bottleneck) 현상을 유발한다.
# *   **해결 알고리즘:**
#     1.  **설비 측 리셋:** 설비 HMI의 **[Call Cancel]** 및 **[Call Create Pause ON]**은 설비가 더 이상 해당 미션에 대해 '준비 상태(Ready)'가 아님을 선언하고, 신규 호출 생성을 억제하여 큐(Queue)를 비우는 작업이다.
#     2.  **상태 초기화:** **[Work Reset]**은 설비 PLC와 AMR 간의 통신 핸드셰이킹(Handshaking) 비트를 강제로 `0`으로 초기화하여 통신 타임아웃 루프를 끊는다.
#     3.  **회수 명령:** 이후 AMR을 **MS25(회수 포트)**로 복귀시키는 것은 시스템 상에서 해당 로봇의 위치 점유를 해제하고, 안전 구역(Safe Zone)에서 재가동을 준비시키기 위함이다.
#
# #### 2.3. 다단 적재(2-Row) 미션에서의 데이터 불일치와 동기화
# 0.3T AMR이 2열 공급/회수 미션을 수행할 때, 물리적 적재 상태와 ACS(ACS: Automated Control System) 상의 데이터(Payload Data)가 불일치하면 시스템은 안전을 위해 작업을 중단한다.
#
# *   **시나리오 A: 포트 포화(Port Full)로 인한 공급 실패**
#     *   **원인:** 설비 센서가 포트에 자재가 있음을 감지했으나, AMR은 공급 명령을 받고 진입한 경우 발생. 이는 물리적 센서 값과 상위 시스템의 재고 데이터 간의 레이턴시(Latency) 차이로 발생할 수 있다.
#     *   **복구 메커니즘:**
#         1.  **물리적 차단:** HMI Manual 모드의 **[Close ALL]**은 컨베이어 도어를 강제로 폐쇄하여 주행 중 자재 낙하를 방지하는 하드웨어 인터락(Interlock)을 체결하는 과정이다.
#         2.  **논리적 리셋:** WEB ACS의 **[JOB Cancel]** 및 **[Error Reset]**은 현재 수행 중인 트랜잭션을 롤백(Rollback)시킨다. 이후 **[Call Retry]**를 통해 상위 시스템이 최신 센서 데이터를 기반으로 작업을 재할당하도록 유도한다.
#
# *   **시나리오 B: 부분 작업 완료 (Partial Completion) 후 데이터 보정**
#     *   **원인:** 2단 작업 중 1단만 성공하고 에러가 발생한 경우, AMR은 "작업 중" 상태로 남게 되며, ACS는 여전히 2개의 자재를 모두 가진 것으로 인식할 수 있다.
#     *   **데이터 동기화 (Digital Twin Synchronization):**
#         *   작업자는 WEB ACS의 **Payload Setting**을 수정하여 디지털 트윈 데이터를 물리적 현실과 일치시켜야 한다.
#         *   공급 실패한 자재는 **'1EA – Full'**, 공급 완료된 칸은 **'1EA – None'**으로 설정한다.
#         *   이후 **[JOB Complete]**를 실행하면, 시스템은 해당 미션을 '강제 성공'으로 처리하고 재고 데이터를 업데이트하여 다음 프로세스로 넘어갈 수 있게 한다.
#
# *   **시나리오 C: 회수 미션 중 빈 박스 부재 (Empty Box Missing)**
#     *   **원인:** 회수 포트에 빈 박스가 있다는 정보(Data)를 바탕으로 로봇이 도착했으나, Lidar 또는 근접 센서가 박스를 감지하지 못한 경우.
#     *   **복구:** 설비와 ACS의 작업을 취소한 후, **[Payload All Clear]**를 수행한다. 이는 로봇이 "아무것도 싣지 않았다"는 상태로 논리적 정의를 내리는 것이며, 이를 통해 로봇은 다음 명령을 수신할 수 있는 Idle 상태로 전환된다.
#
# ---
#
# ### 3. 1T AMR (Pallet Lift Type): 고중량 리프팅 역학 및 센서 퓨전
# 1T AMR은 유압 또는 전동 리프트를 사용하여 스키드(Skid)를 들어 올린다. 이 과정에서는 고중량에 의한 구조적 변형과 센서 정밀도 간의 상관관계가 핵심적인 기술적 이슈로 작용한다.
#
# #### 3.1. PLC 신호 타임아웃과 핸드셰이킹 프로토콜
# AMR이 도킹에 성공했음에도 작업이 시작되지 않는 현상은 주로 **PLC Handshaking Protocol**의 실패에서 기인한다.
# *   **메커니즘:** AMR은 도킹 후 `Docking_Complete` 신호를 송출하고, 설비 PLC로부터 `Work_Start` 신호를 대기한다. 특정 시간(Timeout) 내에 응답이 없으면 교착 상태를 방지하기 위해 에러를 발생시킨다.
# *   **조치:** WEB ACS에서 **[After Docking]** 상태로 변경하는 것은, 시스템에게 "로봇은 이미 물리적으로 도킹 위치에 있으니, 주행 단계를 생략하고 즉시 작업(Work) 단계부터 재시도하라"는 명령을 내리는 것이다. 이는 불필요한 주행 시간을 단축하고 통신 시퀀스만 재시작하는 효율적인 복구 전략이다.
#
# #### 3.2. 스키드 변형(Deformation)과 센서 미감지
# 고중량 배터리 모듈을 적재한 스키드는 물리적 하중에 의해 미세하게 휘어질 수 있다(Deflection).
# *   **원인:** 리프트 Up/Down 시, 스키드의 휨으로 인해 AMR의 광학 센서나 근접 센서(Proximity Sensor)의 감지 범위(Detection Zone)를 벗어나는 경우, 시스템은 안전을 위해 동작을 즉시 정지한다.
# *   **복구 프로세스:**
#     1.  **강제 하강:** WEB ACS의 **[Lift down]** 명령을 통해 유압/모터 밸브를 개방하여 리프트를 원점으로 복귀시킨다.
#     2.  **수동 배출:** 센서 오차 범위를 벗어난 스키드는 자동화 설비로 핸들링이 불가능하므로, AMR을 점검 장소로 이동시킨 후 지게차를 이용해 수동으로 라인에서 배출(Reject)한다.
#
# #### 3.3. 센서 I/O 진단 및 인터페이스 신호 점검
# 물리적 센서의 고장인지, 단순한 위치 오차인지 판별하기 위해 엔지니어는 로우 레벨(Low-level) 데이터에 접근해야 한다.
# *   **진단 방법:** WEB ACS의 **Information 탭 -> IO Category**에서 `mobis_1ton_onboard_sensor 1/2` (제품 감지) 및 `mobis_1ton_lift_up/down_sensor` (리프트 상/하한 리미트 스위치)의 비트 상태(ON/OFF)를 실시간으로 모니터링한다.
# *   **인터페이스 신호 복구:** 리프트 동작은 완료되었으나 시스템 상 완료 처리가 안 되는 경우, 이는 장비(EQP) 측의 `Unload REQ / Load REQ` 신호가 끊긴(Drop) 상태이다. 이때는 **PLC Manager Interface**를 통해 수동으로 신호를 트리거(Trigger)하여 논리적 흐름을 이어주어야 한다.
#
# #### 3.4. 잔류 감지 오류 및 센서 재조정
# Unload 작업 중 잔류 감지(Residual Detection) 오류가 발생하면, 실제로는 짐을 내렸으나 센서는 여전히 짐이 있다고 판단할 수 있다.
# *   **조치:** **[Job Complete(강제 완료)]** 및 **[Payload Clear]**를 통해 소프트웨어적으로 "짐 없음" 상태를 확정 짓는다. 이후 해당 AMR은 반드시 점검 장소로 이동하여 센서의 감도(Sensitivity) 및 설치 각도를 재조정(Calibration)해야 한다. 이는 센서의 히스테리시스(Hysteresis) 특성이 변했거나, 외란광(Ambient Light) 등의 노이즈가 원인일 수 있기 때문이다.
#
# ---
#
# ### 4. 결론: 시스템 무결성을 위한 표준 운영 절차 (SOP)
# BMA 공정의 자동화 시스템 복구 절차는 단순히 에러를 끄는 것이 아니라, **[물리적 상태(Physical State)] - [제어 신호(PLC Signal)] - [데이터 상태(ACS Data)]** 의 3요소를 일치시키는 과정이다.
#
# 1.  **설비(Equipment):** `Call Cancel`과 `Work Reset`을 통해 PLC의 시퀀스 메모리를 초기화한다.
# 2.  **관제(ACS):** `Job Cancel`과 `Payload Setting`을 통해 데이터베이스의 트랜잭션 무결성을 확보한다.
# 3.  **로봇(AMR):** `Manual Mode` 조작과 `Sensor Check`를 통해 기구부의 안전을 확보하고 재가동 준비를 마친다.
#
# 모든 수동 조작 및 점검이 완료된 AMR은 반드시 이상 유무를 최종 확인(Verification)한 후 후공정에 투입되어야 하며, 이는 전체 라인의 가동률(Availability)과 직결되는 핵심 원칙이다.
# 2026-01-02 17:46:42.516 | INFO     | __main__:<module>:9 - # BMA 자동화 시스템 기술 백서 (Technical Whitepaper)
# ## Chapter 4. 이기종 제어 시스템 간의 상호 운용성 및 센서 피드백 메커니즘
# **(Interoperability and Sensory Feedback Mechanisms in Heterogeneous Control Systems)**
#
# ---
#
# ### 1. 서론 (Introduction)
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정은 물리적 계층(Physical Layer)의 AMR(Autonomous Mobile Robot)과 논리적 계층(Logical Layer)의 상위 관제 시스템(ACS/MCS), 그리고 제어 계층(Control Layer)의 설비 PLC가 유기적으로 결합된 복합 시스템(Cyber-Physical System)입니다. 본 챕터에서는 단순한 조작 절차를 넘어, 각 시스템 간의 **핸드쉐이킹(Handshaking) 프로토콜**, **센서의 공학적 감지 원리**, 그리고 **예외 상황(Exception Handling)에서의 논리적 인과관계**를 심층적으로 분석합니다. 엔지니어는 이를 통해 시스템의 블랙박스 내부에서 발생하는 데이터 흐름과 물리적 상호작용을 이해해야 합니다.
#
# ---
#
# ### 2. 설비-AMR 인터페이스 제어 논리 및 교착 상태 방지 (EQP-AMR Interface Logic)
#
# 설비(EQP)와 AMR 간의 통신은 비동기적(Asynchronous) 환경에서 결정론적(Deterministic) 동작을 보장해야 합니다. EQP HMI의 제어 도구들은 이러한 통신 과정에서 발생할 수 있는 논리적 교착 상태(Deadlock)나 레이스 컨디션(Race Condition)을 해결하기 위해 설계되었습니다.
#
# #### 2.1. 호출 취소(Call Cancel)와 레지스터 초기화 메커니즘
# `Call Cancel` 기능은 단순히 명령을 철회하는 것이 아니라, PLC 메모리 내의 통신 레지스터를 강제로 소거(Clear)하는 **'상태 리셋(State Reset)'** 과정입니다.
#
# *   **작동 원리:**
#     1.  **트리거:** 운영자가 HMI에서 Call Cancel을 실행.
#     2.  **내부 로직:** PLC는 `Request ID`, `Call Request`, `Call Response`, `Robot Assigned` 비트를 순차적으로 `0`으로 초기화합니다.
#     3.  **필요성:** AMR이 도킹하기 전(Pre-Docking) 단계에서만 유효한 이유는, 도킹 프로세스가 시작되면 설비와 로봇 간의 하드와이어드(Hard-wired) 또는 광통신 인터록이 체결되기 때문입니다. 이 상태에서 논리적 호출만 취소할 경우, 물리적 연결은 유지된 채 논리 링크만 끊어지는 **'고아 상태(Orphaned State)'**가 발생하여 시스템 멈춤을 유발합니다.
# *   **적용 시나리오:**
#     *   **차종 교체(Model Change):** `AUTO`에서 `Manual`로 전환 시, 기존 차종에 대한 호출 ID가 잔존하면 신규 차종의 호출 생성을 방해(Blocking)합니다. 이때 Call Cancel은 잔존 ID를 플러시(Flush)하여 메모리 스택을 비웁니다.
#     *   **재공 불일치:** 라인 재개 시 물리적 재고와 시스템상 재고 데이터(WIP Count)가 불일치할 경우, 잘못 생성된 공급 요청을 삭제하여 물류 병목을 해소합니다.
#
# #### 2.2. 호출 생성 일시 정지(Call Create Pause)와 흐름 제어
# `Call Create Pause`는 설비의 센서가 자재 투입/배출 조건을 만족하더라도(Trigger Condition Met), 상위 시스템으로의 신호 송출을 물리적으로 차단(Gating)하는 기능입니다.
#
# *   **논리적 차이점:** `Call Cancel`이 이미 생성된 트랜잭션을 파괴하는 것이라면, `Call Create Pause`는 트랜잭션 생성 자체를 억제하는 **'게이트 키퍼(Gatekeeper)'** 역할을 수행합니다.
# *   **공학적 적용:**
#     *   **리워크(Rework) 공정:** 불량품 재투입 시, 정상적인 자재 소진 로직에 의해 불필요한 자재 공급 요청이 발생할 수 있습니다. 이를 방지하기 위해 자동 호출 트리거를 마스킹(Masking)합니다.
#     *   **수동 개입 시 안전 확보:** 지게차 작업 등 인간이 개입하는 동안 시스템의 비동기적 호출 생성을 막아, AMR과 작업자 간의 동선 중첩을 원천 차단합니다.
#
# #### 2.3. 우선순위 역전(Priority Inversion) 및 강제 도킹(Forced Docking)
# ACS의 스케줄링 알고리즘은 기본적으로 FIFO(First-In-First-Out) 또는 최적 경로 기반이지만, 현장 상황에 따라 이를 오버라이드(Override)해야 할 때가 있습니다.
#
# *   **Call Priority (인터럽트 요청):** 설비 막힘(Blocking) 발생 시, 해당 설비의 호출에 최상위 가중치를 부여하여 큐(Queue)의 맨 앞으로 이동시킵니다. 이는 1회성 인터럽트(One-shot Interrupt)로 동작하며, 작업 완료 후 시스템은 즉시 표준 스케줄링 로직으로 복귀합니다.
# *   **Forced Docking (유효성 검사 우회):**
#     *   **정상 로직:** 설비의 `Call Type`과 AMR의 `Job Type`이 일치하는지 비트 단위로 비교(Bitwise Comparison)하여, 불일치 시 도킹을 거부합니다.
#     *   **강제 로직:** 긴급 지원이나 라인 간 교차 투입 시, 이 비교 로직을 바이패스(Bypass)하여 물리적 도킹을 승인합니다.
#     *   **주의사항:** BSA #1라인에서 #2라인으로 전환 시, 반드시 기존 라인의 잔존 신호를 `Call Cancel`로 소거해야 합니다. 그렇지 않으면 두 라인의 신호가 중첩되어 **'이중 할당(Double Assignment)'** 오류가 발생합니다.
#
# ---
#
# ### 3. 자율주행 시스템의 예외 처리 및 신호 무결성 (AMR Navigation & Signal Integrity)
#
# AMR의 자율주행은 정밀한 위치 추정(Localization)과 상위 시스템과의 끊임없는 통신에 의존합니다.
#
# #### 3.1. 작업 취소(Job Cancel)와 도킹 시점의 임계성
# WEB ACS를 통한 `JOB CANCEL` 명령은 AMR의 미션 큐를 삭제합니다. 그러나 이 명령의 실행 시점은 시스템 안정성에 치명적인 영향을 미칩니다.
#
# *   **Docking-OUT 완료 후 실행 원칙:**
#     *   도킹 중(Docking-IN/Busy)에는 AMR과 설비 간의 광통신 또는 근거리 무선 통신을 통해 I/O 신호가 실시간으로 교환됩니다(예: E-Stop 연동, 컨베이어 구동 신호).
#     *   이 과정에서 강제로 Job을 취소하면, PLC는 통신 두절을 감지하고 **'Interface Error'**를 발생시킵니다. 이는 단순 에러가 아니라, 설비와 로봇 양쪽의 안전 회로가 트립(Trip)되는 현상입니다.
#     *   따라서 반드시 물리적/논리적 연결이 해제된 `Docking-OUT` 상태 확인 후 명령을 실행해야 합니다.
#
# #### 3.2. 수동 조작(Manual Jog)과 서보 제어
# AMR이 위치를 잃거나(Delocalization) 장애물에 갇혔을 때, `Unlock` 기능을 통해 제어권을 자동(Auto)에서 수동(Manual)으로 전환합니다. 이는 서보 모터의 위치 제어 루프(Position Control Loop)를 해제하고, 작업자의 입력에 따라 속도 제어(Velocity Control) 모드로 구동함을 의미합니다. 복구 후 `CALL-RETRY`는 중단된 시퀀스의 포인터를 찾아 자동화 루프를 재개시키는 명령어입니다.
#
# ---
#
# ### 4. 센서 시스템의 물리학적 특성 및 캘리브레이션 (Sensor Physics & Calibration)
#
# BMA 공정의 신뢰성은 센서 데이터의 정확도에 좌우됩니다. 각 센서는 고유의 물리적 검출 원리를 가지며, 이에 따른 정밀한 튜닝이 요구됩니다.
#
# #### 4.1. 광학식 제품 감지 센서 (Photoelectric Sensors)
# AMR 차상에는 FESTO사의 `SOEG-RTH-M18-PS-K-2L` (확산 반사형) 모델이 사용됩니다.
#
# *   **작동 원리:** 발광부에서 쏘아진 빛이 물체(배터리 모듈/SKID)에 반사되어 수광부로 돌아오는 광량을 측정합니다.
# *   **히스테리시스(Hysteresis)와 감지 높이:**
#     *   **Cone Type (BMA/BSA SKID):** 권장 높이 **20~25mm**. 이 센서는 배경 억제(Background Suppression) 기능이 제한적일 수 있습니다. 만약 높이를 **100mm 초과**로 설정하면, 리프트 하강 시 바닥면(Floor)을 제품으로 오인하는 **'허위 양성(False Positive)'** 신호가 발생합니다.
#     *   **Attach Type (Type B):** 권장 높이 **5mm**. 감지 거리가 매우 짧게 설정된 이유는 난반사에 의한 노이즈를 최소화하고, 대상 물체의 유무만을 명확히 판별하기 위함입니다.
# *   **상태 표시:** 녹색 LED(전원/대기)와 노란색 LED(출력/감지)의 조합을 통해 센서의 동작 상태(N.O/N.C) 및 안정 영역 진입 여부를 시각적으로 판별합니다.
#
# #### 4.2. 유도형 근접 센서 (Inductive Proximity Sensors)
# 리프트 및 도킹 감지에는 FESTO `SIEH-M12B` 및 AUTONICS `PRT12-8DN2`가 사용됩니다.
#
# *   **작동 원리:** 센서 전면부에서 고주파 자기장을 형성하고, 금속 물체(검출체)가 접근할 때 발생하는 와전류(Eddy Current) 손실을 감지하여 스위칭합니다.
# *   **정밀 튜닝 (Gap Control):**
#     *   **리프트 센서:** 검출체(프레임)와의 거리를 **2mm**로 유지해야 합니다. 이는 자기장의 유효 검출 범위(Sensing Distance) 내에서 가장 안정적인 신호 대 잡음비(SNR)를 확보하는 거리입니다.
#     *   **Up/Down 스트로크:** Down 센서 기준 Up 센서까지 **100mm** 간격은 리프트의 기계적 스트로크와 일치해야 하며, 이를 벗어날 경우 리프트 모터의 과부하(Overload)나 위치 결정 실패를 유발합니다.
#
# ---
#
# ### 5. 인프라스트럭처와 기하학적 인식 (Infrastructure & Geometric Recognition)
#
# AMR은 주변 환경의 특징점(Feature)을 인식하여 자신의 위치를 계산합니다.
#
# #### 5.1. V-Marker와 Lidar SLAM
# V-Marker는 단순한 반사판이 아니라, AMR의 Lidar 센서가 인식하는 **기하학적 랜드마크(Geometric Landmark)**입니다.
#
# *   **인식 메커니즘:** AMR의 네비게이션 알고리즘은 스캔된 포인트 클라우드(Point Cloud) 데이터와 사전에 정의된 V-Marker의 형상 템플릿을 매칭합니다.
# *   **변형의 영향:** 작업자의 충격으로 V-Marker의 각도가 틀어지면, 템플릿 매칭 점수(Matching Score)가 하락하여 AMR은 도킹 위치를 특정하지 못하고 배회하거나 정지합니다.
#
# #### 5.2. 도그플레이트(Dog Plate)와 물리적 정렬 확인
# 도그플레이트는 도킹의 최종 단계에서 기구적 정렬을 확정하고 센서를 트리거하는 물리적 인터페이스입니다.
#
# *   **에러 코드 10015 (센서 미감지):** 도킹 동작은 완료되었으나, 도그플레이트가 센서 감지 범위(Sensing Area)에 들어오지 않았음을 의미합니다. 이는 AMR의 정차 위치 오차(Navigation Error) 또는 도그플레이트의 기구적 변형(Mechanical Deformation)에 기인합니다. 따라서 단순 재시도보다는 플레이트의 위치 교정 및 파손 여부 점검이 선행되어야 합니다.
#
# ---
#
# **결론:** BMA 공정의 안정적인 운영은 HMI의 논리적 제어, AMR의 통신 프로토콜 준수, 그리고 센서 하드웨어의 정밀한 물리적 세팅이 삼위일체를 이룰 때 달성됩니다. 운영자와 엔지니어는 각 에러 코드와 현상 이면에 존재하는 이러한 시스템적 인과관계를 파악하여 근본적인 원인을 해결해야 합니다.
# 2026-01-02 17:47:30.891 | INFO     | __main__:<module>:9 - # BMA/BSA 자동화 시스템 아키텍처 및 제어 로직 기술 백서
# ## (Technical Whitepaper: BMA/BSA Automation System Architecture & Control Logic)
#
# **작성자:** 수석 아키텍트 (Chief Architect)
# **문서 등급:** 대외비 (Confidential)
# **적용 공정:** 현대자동차그룹 BMA/BSA Manufacturing Line
#
# ---
#
# ## 1. 서론: 통합 제어 시스템의 계층적 구조 (Hierarchical Control Architecture)
#
# BMA(Battery Module Assembly) 및 BSA(Battery System Assembly) 공정은 단순한 물리적 조립을 넘어, 데이터와 물류가 실시간으로 동기화되는 **CPS(Cyber-Physical System)** 환경입니다. 본 시스템은 최상위 관리 시스템인 **MCS**와 **WMS**, 중간 제어 계층인 **ACS**, 그리고 현장 제어 계층인 **PLC**와 **AMR**이 유기적으로 결합된 다층 구조(Multi-layered Architecture)를 갖습니다.
#
# ### 1.1 데이터 흐름과 제어 권한의 위계 (Data Topology)
# 시스템의 안정성을 보장하기 위해 제어 권한은 엄격한 위계 구조를 따릅니다.
#
# *   **MCS (Material Control System):** 공정의 '두뇌'에 해당합니다. 생산 계획에 따라 부품 소요량을 예측하고, 하위 시스템에 작업(Job)을 할당합니다. MCS는 직접 장비를 제어하지 않고, **PLC**와의 통신을 통해 트리거(Trigger) 신호를 수신하여 **ACS**에 물류 명령을 하달하는 **이벤트 기반(Event-Driven)** 아키텍처를 채택하고 있습니다.
# *   **ACS (AMR Control System - Web ACS):** 자율주행 로봇(AMR) 군집을 관리하는 '관제탑'입니다. MCS로부터 할당받은 작업을 수행하기 위해 최적의 경로(Path Planning)를 연산하고, 다수의 AMR 간 트래픽을 중재(Arbitration)하며, 실시간 위치 및 상태를 모니터링합니다.
# *   **PLC (Programmable Logic Controller):** 물리적 장비(EQP)를 제어하는 '신경망'입니다. 센서(Sensor)로부터 입력된 아날로그/디지털 신호를 밀리초(ms) 단위의 스캔 타임(Scan Time) 내에 처리하여 모터, 밸브, 리프트 등의 액추에이터를 결정론적(Deterministic)으로 제어합니다.
# *   **WMS (Warehouse Management System):** 재고의 정합성을 보장합니다. MS(Material Storage), MW(Module Warehouse), SC(System Complete) 등 각 창고 구역의 입출고 트랜잭션을 관리하며, 물리적 재고 위치와 전산 재고를 동기화합니다.
#
# ---
#
# ## 2. 공정 역학 및 물류 흐름 (Process Dynamics & Material Flow)
#
# 배터리 제조 공정은 에너지 밀도가 높은 셀(Cell)을 다루므로, 물리적 충격 방지와 정밀한 위치 제어가 필수적입니다. 물류 흐름은 에너지 단위의 결합 과정에 따라 다음과 같이 구성됩니다.
#
# 1.  **Cell to Module (BMA 공정):**
#     *   **CS (BMA CELL):** 가장 기본 단위인 배터리 셀이 투입되는 시점입니다.
#     *   **MC (BMA):** 셀들이 결합되어 모듈(Module) 형태를 갖추는 핵심 조립 구역입니다.
#     *   **MW (Module Warehouse):** 완성된 모듈이 BSA 공정으로 넘어가기 전, 버퍼(Buffer) 역할을 수행하는 자동 창고입니다.
# 2.  **Module to System (BSA 공정):**
#     *   **BP (BSA):** 모듈들이 **L/C (Lower Case)** 위에 안착되어 최종 시스템으로 조립됩니다.
#     *   **LWR CASE (LL):** 배터리 팩의 하부 하우징으로, 구조적 강성을 담당합니다.
#     *   **SC (System Complete):** 조립이 완료된 배터리 시스템이 보관되는 최종 단계입니다.
# 3.  **Support Logistics:**
#     *   **MS (Material Storage):** 부품 공급의 원천입니다.
#     *   **SKID RETURN (RC):** 물류 순환의 핵심인 스키드(Skid)를 회수하여 재투입하는 루프(Loop) 시스템입니다.
#
# ---
#
# ## 3. 자율주행 로봇(AMR)의 메커니즘 및 운영 로직
#
# AMR은 단순한 운송 수단이 아니라, 공정 간의 '동기화'를 담당하는 능동적 에이전트입니다. 적재물의 특성에 따라 두 가지 타입으로 운용됩니다.
#
# ### 3.1 0.3T AMR (Box Conveyor Type)
# *   **작동 원리:** 상단에 컨베이어 벨트가 장착되어 있어, 설비(EQP)의 컨베이어와 도킹(Docking) 시 속도와 위치를 동기화하여 박스(Box) 단위의 자재를 이송합니다.
# *   **핵심 기술:** 설비와의 정밀한 정렬(Alignment)이 요구되며, 이송 시 진동을 최소화하여 셀(Cell) 손상을 방지합니다.
#
# ### 3.2 1T AMR (Pallet Lift Type)
# *   **작동 원리:** 고중량의 팔렛트(PLT)나 스키드(SKID)를 들어 올리는 리프트(Lift) 메커니즘을 탑재하고 있습니다.
# *   **핵심 기술:** 무게 중심(Center of Gravity) 변화에 따른 주행 안정성 확보와, 리프트 상하 구동 시의 유압/전동 제어 정밀도가 핵심입니다.
#
# ---
#
# ## 4. 결함 허용 시스템 및 예외 처리 전략 (Fault Tolerance & Exception Handling)
#
# 자동화 시스템에서 에러는 피할 수 없는 변수입니다. 따라서 시스템은 에러 발생 시 **교착 상태(Deadlock)**를 방지하고, 최단 시간 내에 정상 상태로 복귀(Recovery)하기 위한 다단계 로직을 내장하고 있습니다.
#
# ### 4.1 트래픽 제어 및 교착 상태 해결 (Traffic & Deadlock Resolution)
# 다수의 AMR이 좁은 경로에서 운용될 때, 창고(Warehouse) 측의 지연이나 병목 현상으로 인해 AMR이 주행 경로 상에서 고립되는 경우가 발생합니다.
#
# *   **논리적 인과관계:** [창고 문제 발생] -> [AMR 경로 점유 및 정지] -> [후속 AMR 진입 불가 (Traffic Jam)]
# *   **해결 메커니즘:**
#     1.  **Job Cancel (자원 점유 해제):** 작업자는 ACS 상에서 해당 AMR의 작업을 취소하여, 시스템이 해당 로봇에 할당한 논리적 점유권(Token)을 해제합니다.
#     2.  **Physical Relocation (물리적 회피):** AMR을 주행 경로 밖으로 수동 이동시켜 물리적 병목을 해소합니다.
#     3.  **State Restoration (상태 복원):** 창고 문제가 해결되면, AMR을 다시 경로로 복귀시키고 상태를 **'Before Docking'**으로 재설정합니다. 이는 AMR의 상태 머신(State Machine)을 초기 진입 단계로 리셋하여, 중단된 시점부터 논리적 오류 없이 프로세스를 재개하기 위함입니다.
#
# ### 4.2 0.3T AMR 도킹 에러 복구 프로토콜 (3-Stage Recovery Logic)
# 도킹(Docking)은 AMR과 설비 간의 물리적/통신적 결합이 일어나는 가장 불안정한 단계입니다. 시스템은 에러의 심각도에 따라 3단계의 복구 절차를 수행합니다.
#
# #### 1단계: 일시적 통신/센서 오류 (Transient Error)
# *   **현상:** 도킹 상태는 물리적으로 정상(Docking OK)이나, 소프트웨어적 에러가 발생한 경우.
# *   **조치:** **RESUME** 명령을 통해 일시적인 패킷 손실이나 타임아웃을 무시하고 프로세스를 재개합니다.
#
# #### 2단계: 로직 불일치 (Logic Mismatch) - 1차 초기화
# *   **현상:** RESUME 실패 시. 설비와 AMR 간의 시퀀스 스텝이 어긋난 상태입니다.
# *   **조치:**
#     1.  **EQP Work Reset:** 설비 측의 PLC 시퀀스를 초기화합니다.
#     2.  **AMR Reset Sequence:** Job Cancel -> Error Reset -> Door Close.
#     3.  **State Sync:** AMR 상태를 **'After Docking'**으로 강제 설정하여, 설비가 작업을 완료했다고 인식하게 함으로써 다음 프로세스로 넘어가도록 유도합니다.
#
# #### 3단계: 시스템 비동기화 (System Desynchronization) - 2차 완전 초기화
# *   **현상:** 1차 초기화 실패 시. 상위 시스템(MCS)과 현장 설비 간의 데이터 정합성이 깨진 상태입니다.
# *   **조치 (심층 분석):**
#     1.  **Call Create Pause (ON):** **가장 중요한 단계**입니다. 복구 작업 중 MCS가 새로운 자재 보충 요청(Call)을 생성하지 못하도록 막아, '복구 중 추가 명령 유입'으로 인한 논리적 충돌(Race Condition)을 방지합니다.
#     2.  **Call Cancel & Work Reset:** 기존에 발행된 잘못된 요청을 삭제하고 설비를 리셋합니다.
#     3.  **Conditional Recovery (조건부 복구):**
#         *   **작업 전(Before Work):** 공급 미션은 회수 포트(MS25)로, 회수 미션은 복귀(Go Back)로 변경하여 안전하게 라인을 비웁니다.
#         *   **작업 중(In Work):** 박스 유무를 센서로 재확인합니다.
#             *   **Empty Box:** MS25에서 언로딩(Unload) 후 복귀. (빈 박스 회수 로직)
#             *   **Full Box / Nothing:** 즉시 복귀(Go Back). (실물 자재가 있거나 아예 없는 경우, 공정 투입 부적합으로 판단하여 창고로 회송)
#     4.  **Call Create Pause (OFF):** 모든 조치가 완료되면 Pause를 해제하여 정상적인 생산 요청을 다시 수신합니다.
#
# ### 4.3 1T AMR (Pallet Lift) 예외 처리 로직
# 1T AMR은 고중량물을 다루므로, **제품(SKID)의 유무**와 **에러의 원천(설비 vs 창고)**에 따라 대응 로직이 분기됩니다.
#
# 1.  **SKID 존재 시 (Load State):**
#     *   **위험 요소:** 리프트가 상승한 상태에서 에러 발생 시 전복 위험이 있습니다.
#     *   **조치:** 리프트를 하강(초기화)하여 무게 중심을 낮춘 후, 설비와 AMR을 리셋하고 **'After Docking'** 상태로 전환하여 잔여 프로세스를 수행합니다.
# 2.  **SKID 부재 시 (Unload State):**
#     *   **설비(Product Line) 문제:** 설비 센서 오작동 등으로 인한 경우, **Call Create Pause**를 걸고 설비 로직을 리셋하여 허위 호출을 제거합니다.
#     *   **창고(Warehouse) 문제:** WMS 상의 재고 데이터와 실제 물리적 상태가 불일치하는 경우입니다. 이는 자동 복구가 불가능한 치명적 오류(Critical Error)로 간주하여, 즉시 보전반(Maintenance Team)을 호출해 수동으로 데이터를 보정해야 합니다.
#
# ### 4.4 센서 퓨전 및 하드웨어 점검 (Sensor Fusion & H/W Check)
# 도킹 실패나 자동 복구 불가 시, 이는 단순 소프트웨어 문제가 아니라 물리적 센서(Lidar, IR, Camera 등)의 오염이나 고장일 가능성이 높습니다.
# *   **V-Marker 인식 실패:** AMR은 설비에 부착된 반사판(V-Marker)을 Lidar로 스캔하여 정밀 위치를 보정합니다. 도킹 실패 시 이 마커의 손상 여부나 센서 렌즈의 오염을 우선적으로 점검해야 합니다 ([4.1 도킹 실패] 및 [5.2 센서 점검] 참조).
#
# ---
#
# ## 5. 결론 (Conclusion)
#
# 본 BMA/BSA 자동화 시스템은 MCS-ACS-PLC로 이어지는 견고한 데이터 파이프라인과, 0.3T/1T AMR의 특화된 기구학적 설계를 바탕으로 구축되었습니다. 특히, 다단계 에러 복구 시나리오(Resume -> Reset -> Full Initialization)와 **Call Create Pause**와 같은 트래픽 제어 기법은 시스템의 가동률(Availability)을 극대화하고 다운타임을 최소화하는 핵심 기술입니다. 엔지니어는 단순한 매뉴얼 준수를 넘어, 이러한 시스템의 논리적 인과관계를 이해하고 상황에 맞는 최적의 트러블 슈팅을 수행해야 합니다.

# %%
import json

with open("amr_guide_textbook.json", "w", encoding="utf-8") as f:
    json.dump(resuls, f, ensure_ascii=False, indent=4)

# %%
with open("../data/amr_guide_textbook.json", "r", encoding="utf-8") as f:
    resuls = json.load(f)

# %% [markdown]
# ## 단락 별 텍스트북 생성

# %%
from ml.data_processing.prompt import SYNTHETIC_SPECIFIC_PROMPT

# %%
for i, x in enumerate(arm_guide_preprocessed):
    context = x['preprocessed']
    user_prompt = f"""챕터 번호는 없어도 돼.

[입력 텍스트]
{context}"""
    logger.info(user_prompt)
    response = llm_client.generate(system_prompt=STEP_1_2_SYNTHETIC_TEXTBOOK_PROMPT, chat_messages=[{"role": "user", "content": user_prompt}])
    result = response.choices[0].message.content
    logger.info(result)
    json_result = {
        'id': i,
        'preprocessed_group': context,
        'textbook': result
    }
    resuls.append(json_result)
    logger.info(f"{len(resuls)} 텍스트북 생성 완료")
# Out:
# 2026-01-05 14:49:46.809 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# WEB ACS의 Place Cycle 설정 시, AMR이 미션을 수신하고 동작하기 위해서는 Logistics 스위치와 Run 상태가 모두 ON으로 활성화되어야 한다.
#
# WEB ACS의 Place Cycle 설정 절차는 오른쪽 톱니바퀴 아이콘 클릭 후 Place Cycle 메뉴를 선택하고, 검색창에서 제어할 Place 이름을 검색하여 Logistics 스위치와 Run 상태를 각각 ON과 RUNNING으로 전환하는 순서로 진행한다.
#
# Place Cycle의 Logistics 기능은 시스템이 미션을 생성하고 AMR이 이를 수신하여 수행하도록 활성화하는 장치이며, 생산 가동 중에는 반드시 ON, 비가동 또는 종업 시에는 OFF 상태를 유지해야 한다.
#
# Place Cycle의 RUN 상태는 가동 중인 생산 라인에서 필수적으로 활성화해야 하는 항목이며, 대부분의 운영 상황에서 상시 ON 상태를 유지한다.
#
# 생산 시작 전에는 Place Cycle의 Logistics와 Run 버튼을 ON으로 활성화하고, 생산 완료 후에는 해당 버튼들을 OFF로 변경하는 것을 운영 규칙으로 한다.
# 2026-01-05 14:50:21.377 | INFO     | __main__:<module>:10 - # WEB ACS 기반의 Place Cycle 제어 논리와 미션 디스패칭(Mission Dispatching) 메커니즘
#
# ## 1. 서론: BMA 공정 내 노드(Node) 관리의 중요성
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 자동화 시스템에서 **WEB ACS(Automated Control System)**는 수십 대의 AMR(Autonomous Mobile Robot)과 설비 간의 물류 흐름을 조율하는 중앙 관제탑 역할을 수행한다. 이때, 공장 내의 물리적 위치(Station)를 논리적 객체로 추상화한 것이 바로 **'Place'**이며, 이 Place의 가동 상태를 정의하는 것이 **'Place Cycle'**이다.
#
# 단순히 로봇을 특정 위치로 보내는 것이 아니라, 해당 위치가 현재 물류를 수용할 수 있는지, 시스템적으로 미션을 생성해도 되는지를 판단하는 것은 전체 시스템의 **결정론적(Deterministic) 동작**을 보장하기 위해 필수적이다. 본 챕터에서는 WEB ACS 상에서 Place Cycle을 구성하는 핵심 파라미터인 **Logistics**와 **Run** 상태의 공학적 의미와, 이들이 AMR의 미션 수신 프로세스에 미치는 논리적 인과관계를 심층 분석한다.
#
# ---
#
# ## 2. 이중 제어 레이어(Dual-Layer Control): Logistics와 Run의 상관관계
#
# WEB ACS의 Place Cycle 설정은 단일 신호가 아닌, **Logistics**와 **Run**이라는 두 가지 독립적인 변수의 **논리적 곱(AND Condition)**에 의해 작동한다. 이는 시스템의 안전성과 운영 유연성을 확보하기 위한 이중 잠금 장치(Double Interlock) 설계 사상을 반영한다.
#
# ### 2.1. Logistics: 미션 생성 및 할당의 게이트키퍼 (Mission Generator)
# **Logistics** 스위치는 시스템의 **스케줄러(Scheduler) 레벨**에서 작동하는 파라미터다.
# *   **작동 원리:** Logistics가 **ON** 상태일 때, ACS의 중앙 알고리즘은 해당 Place를 '유효한 물류 목적지'로 인식한다. 즉, 상위 시스템(MES/MCS)에서 작업 지시가 내려오거나 설비에서 호출 신호가 발생했을 때, 이를 실제 AMR이 수행해야 할 '미션(Mission)'으로 변환하여 큐(Queue)에 등록하는 권한을 부여한다.
# *   **비활성화 시 메커니즘:** 만약 Logistics가 **OFF**라면, 물리적으로 설비가 가동 중이라 하더라도 ACS는 해당 위치로 향하는 어떠한 미션도 생성하지 않는다. 이는 AMR이 불필요하게 유휴 설비로 이동하거나, 유지보수 중인 구역으로 진입하여 교착 상태(Deadlock)를 유발하는 것을 원천적으로 차단한다.
#
# ### 2.2. Run: 노드 실행 상태 및 가용성 검증 (Execution Availability)
# **Run** 상태는 해당 Place의 **실행 레벨(Execution Level)**을 관장한다.
# *   **작동 원리:** **RUNNING** 상태는 해당 Place가 물리적으로 AMR을 받아들일 준비가 되었으며, 내부 로직(예: 도착 확인, 적재/이재 시퀀스 등)이 활성화되어 있음을 의미한다. 이는 생산 라인이 가동 중(Active)일 때 필수적으로 요구되는 상태 값이다.
# *   **상시 가동의 필요성:** BMA 공정의 특성상 연속적인 흐름 생산이 이루어지므로, 대부분의 운영 상황에서 Run 상태는 상시 **ON**을 유지하여 시스템의 응답 지연(Latency)을 최소화해야 한다.
#
# ---
#
# ## 3. 데이터 흐름과 시스템 설정 프로세스 (Data Flow & Configuration)
#
# 신입 엔지니어는 WEB ACS 인터페이스 뒤에서 발생하는 데이터의 흐름을 이해해야 한다. 운영자가 UI를 통해 설정을 변경할 때, 백엔드에서는 다음과 같은 절차로 시스템 상태가 갱신된다.
#
# 1.  **파라미터 접근 (Access):** 운영자가 WEB ACS 우측 상단의 설정(톱니바퀴 아이콘) 메뉴를 통해 `Place Cycle`에 진입하는 것은, 시스템의 **글로벌 구성 데이터베이스(Global Configuration DB)**에 접근하는 과정이다.
# 2.  **타겟팅 (Targeting):** 검색창을 통해 특정 `Place` 이름을 쿼리(Query)하는 과정은 수백 개의 노드 중 제어 대상의 고유 ID(UUID)를 필터링하는 단계다.
# 3.  **상태 천이 (State Transition):**
#     *   **Logistics → ON:** 미션 디스패처(Mission Dispatcher) 프로세스에 해당 노드의 인터럽트 처리를 허용하라는 플래그(Flag)를 세트한다.
#     *   **Run → RUNNING:** 해당 노드의 상태 머신(State Machine)을 'Idle'에서 'Active'로 전환한다.
# 4.  **동기화 (Synchronization):** 변경된 설정값은 실시간으로 네트워크를 통해 대기 중인 AMR 군집(Fleet)에 브로드캐스팅되거나, AMR이 다음 미션을 요청할 때 참조된다.
#
# ---
#
# ## 4. 운영 시나리오별 시스템 거동 및 프로토콜
#
# 시스템의 안정성을 위해 생산 주기(Production Lifecycle)에 따른 엄격한 운영 규칙이 적용된다. 이는 인간의 개입 실수(Human Error)를 방지하고 시스템 리소스를 최적화하기 위함이다.
#
# ### 4.1. 생산 시작 전 (Startup Sequence)
# *   **Action:** Logistics와 Run 버튼을 모두 **ON**으로 활성화.
# *   **Mechanism:** 시스템은 '콜드 스타트(Cold Start)' 상태에서 벗어나 모든 노드를 '수신 대기(Listening)' 상태로 전환한다. 이때부터 설비 PLC로부터의 I/O 신호가 유효한 트리거로 인정받아 AMR 미션으로 전환되기 시작한다.
# *   **Why:** 만약 둘 중 하나라도 OFF 상태라면, AMR은 미션을 수신하지 못하고 대기 장소(Waiting Position)에서 무한 대기하게 되며, 이는 전체 라인의 병목(Bottleneck) 현상을 초래한다.
#
# ### 4.2. 생산 가동 중 (Runtime)
# *   **Action:** Logistics **ON**, Run **RUNNING** 유지.
# *   **Mechanism:** 실시간으로 발생하는 수천 건의 트랜잭션을 처리한다. AMR은 지속적으로 미션을 할당받고 이동한다.
#
# ### 4.3. 생산 종료 및 비가동 시 (Shutdown Sequence)
# *   **Action:** Logistics와 Run 버튼을 **OFF**로 비활성화.
# *   **Mechanism:**
#     1.  **Logistics OFF:** 더 이상 새로운 미션이 큐(Queue)에 쌓이지 않도록 차단한다(Cut-off).
#     2.  **Run OFF:** 해당 Place의 논리적 전원을 차단하여, 잔여 미션이나 오작동으로 인한 AMR의 진입 시도를 거부한다.
# *   **Why:** 생산이 종료된 후에도 설정이 ON으로 남아있을 경우, 센서 오작동이나 잔류 신호(Ghost Signal)로 인해 AMR이 빈 라인으로 출동하는 '유령 미션'이 발생할 수 있다. 이는 배터리 전력 낭비뿐만 아니라, 다음 날 시업 점검 시 AMR이 엉뚱한 위치에 가 있는 혼선을 야기한다.
#
# ## 5. 결론
#
# WEB ACS의 **Place Cycle** 설정은 단순한 스위치 조작이 아니다. 이는 BMA 공정의 물리적 가동 여부를 논리적 데이터 흐름으로 변환하는 **디지털 트윈(Digital Twin)의 동기화 과정**이다.
#
# 엔지니어는 **"Logistics는 미션의 생성 권한, Run은 노드의 실행 준비 상태"**라는 개념을 명확히 인지하고, 두 조건이 모두 충족(AND Logic)되었을 때만 AMR이 물리적으로 움직인다는 원칙을 이해해야 한다. 이러한 엄격한 상태 관리는 고속으로 움직이는 자율주행 로봇 시스템의 예측 가능성과 안전성을 보장하는 핵심 기반이다.
# 2026-01-05 14:50:21.378 | INFO     | __main__:<module>:17 - 8 텍스트북 생성 완료
# 2026-01-05 14:50:21.379 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# WEB ACS의 Place Cycle 설정 메뉴에서 AUTO ON/OFF 기능을 실행하면 RUN이 활성화된 항목에 대해 Logistics를 자동으로 ON/OFF 하며, 사용자는 실제 가동 라인의 RUN 상태가 ON인지 확인하여 사용하지 않는 장소의 RUN을 OFF로 설정해야 한다.
# 2026-01-05 14:50:56.627 | INFO     | __main__:<module>:10 - # WEB ACS 기반의 동적 물류 제어 메커니즘: Place Cycle 및 가동 상태 동기화 프로토콜
#
# ## 1. 서론: BMA 공정 내 물류 오케스트레이션의 핵심
# 현대자동차그룹의 BMA(Battery Module Assembly) 공정은 다수의 AMR(Autonomous Mobile Robot)과 설비가 유기적으로 연동되는 복합 시스템입니다. 이 시스템의 중추 신경망 역할을 수행하는 **WEB ACS(Automated Control System)**는 단순한 모니터링 도구를 넘어, 공정의 가동 현황(Physical Status)을 물류 흐름(Logical Flow)으로 변환하는 핵심 알고리즘을 내장하고 있습니다.
#
# 본 기술 백서에서는 WEB ACS의 **Place Cycle 설정 메뉴** 내 **AUTO ON/OFF 기능**이 수행하는 논리적 연산 과정과, 이에 따른 **RUN 상태** 및 **Logistics(물류 가용성)** 간의 상관관계를 시스템 아키텍처 관점에서 심층 분석합니다. 또한, 자동화 로직의 한계점을 보완하기 위한 운영자의 개입(Human-in-the-loop)이 시스템 안정성에 미치는 공학적 중요성을 서술합니다.
#
# ---
#
# ## 2. AUTO ON/OFF 알고리즘의 작동 원리 및 데이터 흐름
#
# ### 2.1. 논리적 인과관계 (Logical Causality)
# WEB ACS 내 'Place Cycle'은 AMR이 주행해야 할 경로(Path)와 작업 지점(Node)의 순서를 정의하는 토폴로지(Topology) 데이터입니다. 여기서 **AUTO ON/OFF** 기능은 운영자가 수동으로 각 공정의 물류 투입 여부를 결정하는 비효율을 제거하기 위해 설계된 **상태 동기화(State Synchronization) 알고리즘**입니다.
#
# 이 기능이 실행될 때 시스템 내부에서는 다음과 같은 논리적 연쇄 반응이 발생합니다:
#
# 1.  **트리거(Trigger):** 운영자가 Place Cycle 메뉴에서 AUTO ON/OFF 기능을 활성화.
# 2.  **상태 스캔(State Scanning):** ACS 서버는 데이터베이스 또는 메모리 레지스터에 정의된 모든 공정(Place) 항목의 **RUN 비트(Bit)** 상태를 전수 조사(Polling)합니다.
# 3.  **조건부 연산(Conditional Operation):**
#     *   **IF [RUN Status == Active(ON)]:** 해당 공정이 물리적으로 가동 중임을 의미하므로, 시스템은 즉시 해당 지점의 **Logistics 플래그**를 **ON**으로 전환합니다. 이는 AMR의 라우팅 테이블(Routing Table)에 해당 노드를 '진입 가능' 상태로 등록하는 것을 의미합니다.
#     *   **ELSE [RUN Status == Inactive(OFF)]:** 해당 공정이 정지 상태이거나 비가동 중임을 의미하므로, **Logistics 플래그**를 **OFF**로 전환합니다. 이는 AMR의 경로 탐색 알고리즘에서 해당 노드를 배제(Exclusion)시켜 불필요한 진입을 원천 차단합니다.
#
# ### 2.2. 시스템 아키텍처 관점의 데이터 흐름
# 이 과정은 **설비 제어 레이어(PLC)**와 **상위 관제 레이어(ACS)** 간의 데이터 정합성을 유지하는 핵심 메커니즘입니다. 'RUN' 상태는 설비의 물리적 전원 및 가동 준비 완료 신호를 대변하며, 'Logistics'는 AMR 관제 시스템의 논리적 허가 신호를 대변합니다. AUTO ON/OFF 기능은 이 두 레이어 사이의 **미들웨어(Middleware) 로직**으로 작용하여, 물리적 설비가 준비되지 않은 상태에서 논리적 물류 명령이 하달되는 '명령 불일치(Command Mismatch)' 오류를 방지합니다.
#
# ---
#
# ## 3. 운영자 개입의 필요성: 물리적 상태와 디지털 트윈의 정합성 확보
#
# ### 3.1. 자동화의 한계와 휴먼 에러 방지
# 비록 AUTO ON/OFF 기능이 RUN 상태에 따라 Logistics를 자동으로 제어하지만, 시스템은 **'RUN 상태가 참(True)인가?'**라는 디지털 값만을 신뢰합니다. 만약 실제 현장(Physical World)에서는 설비가 고장 났거나 유지보수 중임에도 불구하고, 시스템 상의 RUN 설정이 여전히 ON으로 남아있다면 치명적인 논리적 오류가 발생합니다.
#
# 이를 방지하기 위해 엔지니어는 다음의 절차를 반드시 수행해야 합니다:
#
# 1.  **실제 가동 라인 검증 (Physical Verification):** 운영자는 WEB ACS 화면상의 데이터에만 의존하지 않고, 실제 BMA 라인의 설비가 가동 가능한 상태인지 육안 또는 CCTV 등을 통해 교차 검증해야 합니다.
# 2.  **비가동 구역의 강제 차단 (Manual Override):** 사용하지 않는 장소(Unused Place)의 RUN 상태가 ON으로 되어 있다면, 이를 수동으로 **OFF**로 설정해야 합니다.
#
# ### 3.2. 미조치 시 발생 가능한 공학적 문제 (Failure Scenario)
# 만약 실제로는 가동하지 않는 라인의 RUN 상태를 ON으로 방치하고 AUTO ON/OFF를 실행할 경우, 다음과 같은 연쇄적인 시스템 장애가 발생합니다:
#
# *   **유령 경로 생성 (Phantom Path Generation):** ACS는 해당 비가동 라인을 '가용 라인'으로 인식하여 Logistics를 ON으로 활성화합니다.
# *   **AMR 교착 상태 (Deadlock):** AMR은 작업 지시를 받고 해당 라인으로 이동하지만, 설비와의 핸드쉐이킹(Handshaking)이 불가능하거나 물리적 작업이 수행되지 않아 무한 대기 상태에 빠지게 됩니다.
# *   **전체 물류 효율 저하 (Throughput Degradation):** 한 대의 AMR이 비가동 라인에 묶이게 되면, 후속 AMR들의 경로를 막거나(Blocking), 가용 자원(AMR 대수)이 감소하여 전체 공정의 사이클 타임(Cycle Time)이 지연됩니다.
#
# ---
#
# ## 4. 결론
#
# WEB ACS의 Place Cycle 내 **AUTO ON/OFF 기능**은 설비의 가동 상태(RUN)와 물류 흐름 허가(Logistics)를 연동시키는 **동적 라우팅 제어(Dynamic Routing Control)**의 핵심 기술입니다. 이 기능은 시스템의 자동화 수준을 높여주지만, 그 기반이 되는 데이터(RUN 상태)의 무결성은 전적으로 운영자의 정확한 현장 확인 및 설정 관리에 달려 있습니다.
#
# 따라서 엔지니어는 **[물리적 현장 확인] -> [시스템 RUN 상태 최신화] -> [AUTO ON/OFF 실행]**이라는 표준 운영 절차(SOP)를 준수함으로써, 불필요한 물류 정체를 예방하고 BMA 공정의 가동 효율(Availability)을 극대화해야 합니다.
# 2026-01-05 14:50:56.630 | INFO     | __main__:<module>:17 - 9 텍스트북 생성 완료
# 2026-01-05 14:50:56.631 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# 1. 충전기에 도킹되어 충전 중인 AMR은 충전 상태를 유지해야 하며 절대로 전원을 끄지 않는다.
#
# 2. 충전기 외부에 위치하여 미션 대기 중인 AMR은 전원을 꺼야 하며, 종료 시 WEB ACS에서 해당 AMR을 선택하여 Call Cancel(미션 반환 및 대기), Job Cancel, Power OFF를 순차적으로 실행한다.
#
# 3. 주말 및 공휴일 등 장기 정지 시에는 모든 AMR의 남은 임무를 완료하거나 삭제한 후, 충전기에서 200mm 이상 분리하여 전원을 끈다.
#
# 4. 작업 재개를 위해 AMR을 가동하는 경우, WEB ACS에서 해당 AMR을 선택하여 Power ON을 누른 후 Call-Retry를 실행한다.
# 2026-01-05 14:51:36.044 | INFO     | __main__:<module>:10 - # BMA 공정 내 자율주행 로봇(AMR)의 전력 관리 및 운영 생명주기 프로토콜 (Energy Management Protocols and Operational Lifecycle)
#
# ## 1. 서론: 전력 관리의 시스템적 중요성
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 효율성은 물류의 혈관 역할을 하는 AMR(Autonomous Mobile Robot)의 가동률(Availability)에 의해 결정된다. AMR의 전력 관리는 단순한 배터리 충·방전의 문제를 넘어, **ACS(AMR Control System)**와의 데이터 동기화, **BMS(Battery Management System)**의 전기화학적 안정성, 그리고 공정 전체의 **교착 상태(Deadlock)** 방지를 위한 핵심 아키텍처 요소이다. 본 장에서는 AMR의 충전, 대기, 장기 정지, 그리고 재가동 시나리오에 따른 시스템적 거동 원리와 엔지니어링 메커니즘을 심층 분석한다.
#
# ---
#
# ## 2. 충전 도킹 상태에서의 시스템 무결성 유지 (Charging State Integrity)
#
# ### 2.1. 충전 중 전원 유지의 전기화학적/논리적 배경
# **[Fact 1]**에 따르면, 충전기에 도킹(Docking)되어 충전 프로세스가 진행 중인 AMR은 절대 전원을 차단해서는 안 되며, 'Power ON' 상태를 유지해야 한다. 이는 다음과 같은 공학적 이유에 기인한다.
#
# 1.  **BMS의 능동적 셀 밸런싱(Active Cell Balancing):** 리튬이온 배터리 팩은 충전 중에 각 셀(Cell) 간의 전압 편차를 맞추는 밸런싱 작업이 수행된다. 이 과정에서 전원이 강제 차단될 경우, 특정 셀의 과전압(Over-voltage) 또는 불균형 상태가 고착화되어 배터리 수명(SOH, State of Health)에 치명적인 영향을 미친다.
# 2.  **충전기와 AMR 간의 핸드쉐이킹(Handshaking) 유지:** 충전은 단순히 전력을 밀어 넣는 행위가 아니라, 충전기(Charger)와 로봇(AMR)이 CAN 통신 또는 Ethernet을 통해 전압(V), 전류(A), 온도(T) 데이터를 실시간으로 교환하는 **피드백 제어 루프(Feedback Control Loop)** 과정이다. 전원 차단 시 통신 링크가 끊기며 충전기는 이를 '비정상 이탈'로 간주, 아크(Arc) 발생 방지를 위해 급격히 출력을 차단하게 되는데, 이 과정에서 서지(Surge) 전압이 발생하여 로봇 내부의 전장 회로(DC-DC 컨버터 등)를 손상시킬 수 있다.
# 3.  **열 관리 시스템(Thermal Management):** 고전류 충전 시 발생하는 열을 식히기 위해 AMR 내부의 냉각 팬(Cooling Fan)이 가동된다. 전원 차단은 냉각 시스템의 정지를 의미하며, 잔열(Residual Heat)로 인한 소자 손상을 초래할 수 있다.
#
# ---
#
# ## 3. 미션 대기 상태의 유휴 자원 관리 (Idle Resource Management)
#
# ### 3.1. 유휴 AMR의 전원 차단 논리
# **[Fact 2]**는 충전기 외부에 위치한 대기(Idle) 상태의 AMR은 전원을 꺼야 함을 명시한다. 이는 대기 전력(Standby Power) 소모로 인한 배터리 심방전(Deep Discharge)을 방지하기 위함이다. AMR은 구동 모터가 정지해 있더라도, Lidar 센서, 메인 컨트롤러(IPC), 통신 모듈이 지속적으로 전력을 소비하므로, 물리적 작업이 없는 경우 전원을 차단하여 에너지 효율을 극대화해야 한다.
#
# ### 3.2. Graceful Shutdown 시퀀스: 논리적 연결 해제
# 전원을 끄는 과정은 물리적 스위치를 내리는 것으로 시작되지 않는다. 시스템의 데이터 무결성을 위해 **WEB ACS**를 통한 순차적 종료 절차(Graceful Shutdown)가 필수적이다.
#
# 1.  **Call Cancel (미션 반환 및 대기):**
#     *   **Why:** 상위 제어 시스템(ACS/MCS)은 해당 AMR을 '가용 자원(Available Resource)'으로 인식하고 있다. 물리적 전원을 먼저 끄면, 서버는 로봇이 통신 두절(Disconnection)된 것으로 판단하여 에러를 발생시키거나, 존재하지 않는 로봇에게 명령을 내리는 **'고아 프로세스(Orphan Process)'**가 생성된다.
#     *   **Mechanism:** Call Cancel 명령은 ACS의 스케줄러(Scheduler)에게 "이 로봇은 더 이상 작업을 수행할 수 없음"을 알리고, 할당된 논리적 점유권을 해제한다.
#
# 2.  **Job Cancel (작업 버퍼 소거):**
#     *   **Why:** 로봇 내부 메모리(RAM)에 잔존할 수 있는 미수행 명령(Pending Jobs)을 삭제한다. 이를 수행하지 않고 재부팅할 경우, 로봇이 켜지자마자 과거의(이미 유효하지 않은) 명령을 수행하려다 충돌 사고가 발생할 수 있다.
#
# 3.  **Power OFF (물리적 차단):**
#     *   **Mechanism:** 논리적 연결이 모두 안전하게 해제된 후, 최종적으로 메인 릴레이(Main Relay)를 개방(Open)하여 배터리와 전장 시스템 간의 연결을 물리적으로 차단한다.
#
# ---
#
# ## 4. 장기 정지 시의 물리적 격리 및 안전 프로토콜 (Long-term Storage Protocol)
#
# ### 4.1. 잔여 임무 처리와 데이터베이스 정합성
# **[Fact 3]**에 따라 주말 및 공휴일 등 장기 정지 시에는 모든 잔여 임무를 완료하거나 삭제해야 한다. 이는 ACS 데이터베이스의 트랜잭션(Transaction)을 닫기 위함이다. 미완료된 임무가 DB에 남아있을 경우, 휴무 후 시스템 재가동 시 수십 대의 로봇이 동시에 오래된 명령을 처리하려 하여 네트워크 트래픽 폭주(Broadcast Storm)나 논리적 충돌을 야기할 수 있다.
#
# ### 4.2. 200mm 이격(Separation)의 공학적 의미
# 충전기에서 AMR을 **200mm 이상 분리**한 후 전원을 끄는 규정은 단순한 위치 이동이 아니라, 다음과 같은 물리적/센서 공학적 안전장치이다.
#
# 1.  **전기적 절연(Galvanic Isolation) 확보:** 충전 접점(Contact Pad)과 로봇의 집전 장치가 물리적으로 닿아 있는 상태에서 장기간 방치될 경우, 접점 부식이나 미세 전류 누설이 발생할 수 있다. 200mm 이격은 완벽한 공기 절연(Air Gap)을 보장한다.
# 2.  **Lidar 센서의 최소 감지 거리(Minimum Range):** 대부분의 2D Safety Lidar는 센서 표면 바로 앞(약 0~100mm 구간)에 불감대(Blind Spot)를 가진다. 너무 가깝게 주차된 상태에서 재기동할 경우, 로봇이 충전기를 장애물로 인식하지 못하고 전진하여 충돌할 위험이 있다. 200mm는 센서가 전방의 충전기를 명확한 '장애물'로 인식할 수 있는 안전 거리이다.
# 3.  **재기동 시 위치 추정(Localization) 오차 방지:** 로봇이 충전기 구조물에 완전히 밀착되어 있으면, Lidar가 스캔할 수 있는 특징점(Feature)이 제한되어 초기 위치 추정(Initial Pose Estimation)에 실패할 확률이 높아진다.
#
# ---
#
# ## 5. 시스템 재가동 및 네트워크 재진입 (System Initialization & Reintegration)
#
# ### 5.1. Power ON과 부팅 시퀀스
# **[Fact 4]**의 작업 재개 절차는 휴면 상태의 하드웨어를 깨우고 네트워크에 재진입시키는 과정이다.
# *   **WEB ACS에서의 Power ON:** 이는 원격 웨이크업(Remote Wake-up) 신호 또는 현장 작업자에 의한 물리적 버튼 인가를 의미한다. 전원이 인가되면 AMR은 **POST(Power On Self Test)**를 수행하여 모터 드라이버, 센서, 배터리 상태를 점검하고 OS를 로드한다.
#
# ### 5.2. Call-Retry: 상태 머신(State Machine)의 동기화
# 단순히 전원을 켜는 것만으로는 로봇이 자동으로 작업을 시작하지 않는다. **Call-Retry** 실행은 다음과 같은 필수적인 논리적 핸드쉐이킹을 수행한다.
#
# 1.  **Heartbeat 재개:** AMR이 ACS 서버에 "나는 정상적으로 부팅되었으며 통신 가능하다"는 신호(Heartbeat)를 전송한다.
# 2.  **위치 동기화:** 로봇이 현재 자신의 좌표(x, y, theta)를 서버에 보고하고, 서버상의 로봇 위치 정보와 일치하는지 검증한다.
# 3.  **작업 할당 요청:** "현재 대기 중(Idle)" 상태임을 알리고, ACS의 스케줄러로부터 새로운 작업(Job)을 수신할 준비가 되었음을 선언한다.
#
# 이 과정을 통해 AMR은 물리적인 '기계 덩어리'에서 시스템의 통제를 받는 '지능형 에이전트'로 전환되어 BMA 공정의 물류 흐름에 복귀하게 된다.
# 2026-01-05 14:51:36.045 | INFO     | __main__:<module>:17 - 10 텍스트북 생성 완료
# 2026-01-05 14:51:36.045 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# 충전기가 도킹된 상태에서 1T/0.3T AMR을 강제로 종료하여 과전류 보호용 배터리 회로 차단기가 작동했을 경우, 자동 복구 실패 시 AMR 전면 커버를 제거하고 배터리를 분리한 뒤 배터리 뒷면의 차단기 스위치를 수동으로 켜서 전원 상태를 복구한다.
# 2026-01-05 14:51:55.390 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: 전력 관리 및 하드웨어 보호 메커니즘
#
# ## 1. 서론: AMR 전력 시스템의 안정성 설계
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 핵심 물류 자원인 1T 및 0.3T AMR(Autonomous Mobile Robot)은 고효율 리튬 계열 배터리 시스템을 기반으로 구동된다. 이 시스템은 단순한 에너지 저장 장치를 넘어, BMS(Battery Management System)와 연동된 정교한 전력 분배 유닛(PDU: Power Distribution Unit)을 통해 모터 구동, 센서 처리, 통신 모듈에 필요한 전력을 안정적으로 공급한다.
#
# 본 장에서는 충전 도킹(Docking) 상태에서 발생할 수 있는 비정상적인 전원 차단 시나리오와, 이에 대응하는 하드웨어 레벨의 과전류 보호 메커니즘(Overcurrent Protection Mechanism), 그리고 물리적 복구 절차의 공학적 원리를 심층적으로 다룬다.
#
# ## 2. 충전 중 강제 종료와 과도 응답(Transient Response) 현상
#
# ### 2.1. 충전 도킹 상태의 전기적 특성
# AMR이 충전 스테이션에 도킹되어 있을 때, 로봇 내부의 전력 회로는 외부 전원(Grid Power)으로부터 정류된 DC 전압을 받아들이는 '수동적 부하(Passive Load)' 상태이자, 동시에 배터리를 충전하는 '능동적 싱크(Active Sink)' 상태가 된다. 이때 충전기와 배터리 사이에는 수십 암페어(A) 이상의 대전류가 흐르는 폐회로(Closed Loop)가 형성된다.
#
# ### 2.2. 강제 종료 시의 역기전력 및 서지(Surge) 발생
# 정상적인 종료 절차(Graceful Shutdown)는 충전 전류를 서서히 감소(Ramp-down)시킨 후 릴레이를 개방하지만, 물리적 버튼이나 비상 정지 등을 통한 **강제 종료(Forced Shutdown)**는 이 흐름을 즉각적으로 절단한다.
#
# 전기 회로 이론에 따르면, 인덕턴스 성분이 존재하는 회로에서 전류의 급격한 변화($di/dt$)는 필연적으로 높은 역기전력(Back EMF)을 유발한다.
# $$ V = L \cdot \frac{di}{dt} $$
# 이 수식에 의해, 충전 중 강제 종료는 순간적으로 시스템의 정격 전압을 초과하는 과도 전압(Transient Voltage)과 돌입 전류(Inrush Current)를 발생시킨다. 이러한 전기적 충격(Surge)은 AMR 내부의 민감한 전자 부품(PCB, 모터 드라이버 등)을 파괴할 위험이 있다.
#
# ## 3. 배터리 회로 차단기(Circuit Breaker)의 보호 로직
#
# ### 3.1. 과전류 보호 메커니즘 (OCP)
# AMR의 배터리 팩에는 이러한 전기적 충격으로부터 셀(Cell)과 전장 부품을 보호하기 위해 물리적인 **회로 차단기(Circuit Breaker)**가 내장되어 있다. 강제 종료로 인해 허용치를 초과하는 과전류(Overcurrent)가 감지되면, 차단기 내부의 바이메탈(Bimetal)이나 전자기 코일이 작동하여 물리적으로 회로를 개방(Trip)한다. 이는 퓨즈(Fuse)와 달리 재사용이 가능한 보호 장치이나, 트립(Trip) 상태에서는 배터리의 출력이 완전히 차단되므로 AMR은 전원 불능(Blackout) 상태에 빠지게 된다.
#
# ### 3.2. 자동 복구 실패의 원인
# 일반적으로 BMS는 일시적인 오류에 대해 소프트웨어적인 리셋을 시도한다. 그러나 물리적 차단기가 트립된 경우, 이는 소프트웨어 제어 범위를 벗어난 하드웨어적 단락(Open Circuit) 상태이므로, 시스템의 자동 복구(Auto-Recovery) 로직이 작동하지 않는다. 즉, 전력 선로 자체가 물리적으로 끊어진 상태이므로 외부에서의 기계적 개입 없이는 전원을 복구할 수 없다.
#
# ## 4. 하드웨어 레벨의 수동 복구 절차 및 공학적 유의사항
#
# 자동 복구가 불가능한 상황(차단기 트립)에서 엔지니어는 다음과 같은 절차를 통해 시스템을 정상화해야 한다. 이 과정은 단순한 스위치 조작이 아니라, 잔류 전하 방전 및 회로 안정화를 포함한 일련의 공학적 조치이다.
#
# ### 4.1. 물리적 접근 및 전원 분리 (Isolation)
# *   **AMR 전면 커버 제거:** 내부 배터리 팩에 접근하기 위해 하우징을 분해한다.
# *   **배터리 커넥터 분리:** 차단기를 리셋하기 전, 부하(Load) 측과의 연결을 완전히 끊어야 한다. 이는 차단기 복구 순간 발생할 수 있는 2차적인 스파크나 서지 전압이 메인보드로 유입되는 것을 방지하기 위한 필수적인 **절연(Isolation)** 조치이다.
#
# ### 4.2. 차단기 수동 리셋 (Manual Reset)
# *   **배터리 후면 스위치 조작:** 배터리 팩 후면에 위치한 차단기 스위치를 물리적으로 'ON' 위치로 전환한다. 이 행위는 개방되었던 접점을 기계적으로 다시 연결하여 전위차를 형성할 준비를 마치는 것이다.
#
# ### 4.3. 시스템 재기동 및 검증
# 배터리 커넥터를 다시 연결하고 전원을 인가하면, BMS는 초기화 시퀀스(Initialization Sequence)를 수행한다. 이때 전압, 전류, 온도가 정상 범위인지 체크한 후 메인 릴레이를 닫아 시스템에 전력을 공급한다. 엔지니어는 이 과정에서 다시 과전류 알람이 발생하지 않는지 모니터링하여, 강제 종료로 인한 영구적인 하드웨어 손상이 없었음을 최종 검증해야 한다.
#
# ---
# **결론:** 충전 중 강제 종료는 시스템에 심각한 전기적 스트레스를 주는 행위이다. 배터리 차단기의 작동은 최후의 안전장치(Fail-Safe)가 성공적으로 동작했음을 의미하며, 수동 복구 절차는 이러한 안전장치를 해제하고 시스템을 정상 궤도로 돌려놓는 정밀한 유지보수 과정이다.
# 2026-01-05 14:51:55.391 | INFO     | __main__:<module>:17 - 11 텍스트북 생성 완료
# 2026-01-05 14:51:55.392 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# 1. ACS 상에서 Call이 생성되지 않을 경우, WEB ACS의 Place Cycle 설정 메뉴에서 해당 설비 또는 컨베이어의 Logistics와 RUN 상태가 모두 ON 및 RUNNING으로 활성화되어 있는지 확인한다.
#
# 2. ACS 상에서 Call이 생성되지 않을 경우, WEB ACS의 PLC 탭에서 설비(EQP) 또는 컨베이어의 Call Type 값과 AMR의 Call Type 값이 일치하는지 대조하고, 값이 다를 경우 설비 또는 컨베이어의 Call Type을 올바른 값으로 수정한다.
#
# 3. ACS 상에서 Call이 생성되지 않을 경우, 설비 HMI(EQP HMI) 화면 우측의 Call Create Pause 버튼이 활성화되어 콜 생성을 차단하고 있는지 확인한다.
#
# 4. ACS 상에서 Call이 생성되지 않을 경우, WEB ACS의 Work Orders 메뉴에서 해당 AMR의 상태가 Idle인지 확인하고, 이전 작업이 남아있어 자동 복구가 실패한 경우 해당 Work Order를 삭제한다.
# 2026-01-05 14:52:34.048 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: ACS 태스크 생성 로직 및 예외 처리 메커니즘
# **Technical Whitepaper: Logic Architecture of Task Generation and Dispatching in BMA Automation**
#
# ---
#
# ## 1. 서론: 결정론적 태스크 스케줄링의 개요
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 물류 자동화는 ACS(Automated Control System)를 중추로 하여 AMR(Autonomous Mobile Robot), 설비(Equipment), 그리고 상위 관제 시스템 간의 유기적인 데이터 동기화에 의존한다. 이 시스템의 핵심은 **'Call(작업 요청)'**이 생성되는 과정에 있으며, 이는 단순한 신호 전달이 아닌 다층적인 논리 게이트(Logic Gate)와 상태 검증(State Validation)을 통과해야만 실행되는 결정론적(Deterministic) 프로세스다.
#
# 본 챕터에서는 ACS 상에서 Call이 생성되지 않는 현상을 시스템 아키텍처 관점에서 분석하고, 각 레이어(Layer)별 데이터 흐름과 논리적 인과관계를 심층적으로 기술한다.
#
# ---
#
# ## 2. 논리적/물리적 가용성 검증 (Availability Validation)
# ### 2.1 Place Cycle의 이중 검증 메커니즘 (Logistics & RUN)
# ACS가 특정 설비나 컨베이어로부터 작업 요청을 수신하고 이를 실제 AMR에 할당하기 위해서는, 해당 노드(Node)가 논리적, 물리적으로 '가용 상태'임이 선행되어야 한다. WEB ACS의 **Place Cycle** 설정은 이러한 가용성을 판단하는 최상위 게이트 역할을 수행한다.
#
# *   **Logistics (논리적 흐름 제어):** 이는 소프트웨어 레벨의 스위치로, 해당 설비가 전체 물류 네트워크 토폴로지(Topology) 상에서 활성화되어 있는지를 정의한다. 설비가 물리적으로 정상이라 하더라도, 공정 밸런싱이나 유지보수를 위해 시스템적으로 격리(Isolation)해야 할 경우 Logistics 상태는 OFF가 된다.
# *   **RUN (물리적 운전 상태):** 이는 설비의 실제 가동 여부를 나타내는 하드웨어 레벨의 상태 플래그다. 설비 제어기(PLC)로부터 수신된 Heartbeat 신호나 Operation Status가 'Running'일 때만 활성화된다.
#
# **[작동 원리 및 인과관계]**
# ACS의 디스패칭 알고리즘은 `IF (Logistics == ON) AND (RUN == RUNNING) THEN Create_Call`이라는 **AND 논리 연산**을 수행한다. 두 조건 중 하나라도 만족하지 못할 경우(False), 시스템은 해당 설비를 '비가용(Unavailable)'으로 간주하여 Call 생성 프로세스를 즉시 중단한다. 이는 준비되지 않은 설비로 AMR이 이동하여 발생할 수 있는 대기 시간(Idle Time) 증가나 병목 현상을 원천적으로 차단하기 위한 방어 로직이다.
#
# ---
#
# ## 3. 이기종 시스템 간 데이터 무결성 및 프로토콜 동기화
# ### 3.1 Call Type 매핑과 핸드쉐이킹 (PLC ↔ ACS ↔ AMR)
# BMA 공정에는 다양한 사양의 AMR(예: 0.3T, 1T 등)과 설비가 혼재되어 있다. 따라서 설비가 요청하는 작업의 성격과 이를 수행할 AMR의 제원(Capability)이 정확히 일치해야 한다. 이 일치 여부를 판단하는 핵심 파라미터가 **Call Type**이다.
#
# *   **데이터 흐름(Data Flow):**
#     1.  **Source (설비/컨베이어):** PLC 레지스터에 정의된 Call Type 값(Integer 또는 String)을 상위 시스템으로 송출한다.
#     2.  **Middleware (ACS):** 수신된 Call Type 값을 데이터베이스 내의 AMR Fleet 설정과 대조한다.
#     3.  **Target (AMR):** 해당 Call Type을 수행할 수 있는 AMR 그룹을 필터링한다.
#
# **[작동 원리 및 인과관계]**
# WEB ACS의 PLC 탭에서 확인되는 **EQP(설비) Call Type**과 **AMR Call Type** 간의 불일치(Mismatch)는 프로토콜 레벨의 통신 오류를 야기한다. 예를 들어, 설비는 'Type A(고중량 배터리 모듈)'를 요청했으나, 시스템에 가용한 AMR이 'Type B(경량 부품)'로 설정되어 있다면, ACS는 물리적 호환성 문제(적재 하중 초과, 트레이 규격 불일치 등)를 방지하기 위해 Call 생성을 거부한다. 이는 단순한 설정 오류가 아니라, 공정 안전을 보장하기 위한 **데이터 무결성(Data Integrity) 검증 실패**로 해석해야 한다. 따라서 엔지니어는 두 시스템 간의 파라미터 매핑 테이블을 수정하여 논리적 연결 고리를 복구해야 한다.
#
# ---
#
# ## 4. 휴먼 인터페이스(HMI)에 의한 우선 제어권 (Override Control)
# ### 4.1 Call Create Pause의 신호 우선순위
# 자동화 시스템이라 하더라도 운영자(Operator)의 판단이나 현장 상황에 따른 수동 개입(Manual Intervention)은 최우선 순위를 가져야 한다. 설비 HMI(EQP HMI)에 존재하는 **Call Create Pause** 버튼은 이러한 수동 오버라이드(Override) 기능을 수행한다.
#
# **[작동 원리 및 인과관계]**
# 이 기능은 시스템 아키텍처 상에서 **'Hard Interlock'**으로 동작한다. 앞서 언급한 Logistics나 RUN 상태가 모두 정상이라 하더라도, HMI로부터 `Pause == True` 신호가 인가되면 ACS의 스케줄러는 모든 논리 연산을 무시하고 Call 생성을 강제로 차단(Block)한다.
# 이는 다음과 같은 상황에서 필수적이다:
# *   설비 내부의 자재 걸림(Jam) 발생 시.
# *   작업자가 설비 유지보수를 위해 접근할 때 안전 확보.
# *   후공정의 버퍼(Buffer)가 가득 차서 일시적인 유량 제어(Flow Control)가 필요할 때.
#
# 따라서 Call이 생성되지 않을 때, 시스템 로그 상의 에러가 없다면 이는 시스템 오류가 아니라 운영자의 의도적인 개입(Pause 활성화)이 시스템에 정상적으로 반영된 결과임을 인지해야 한다.
#
# ---
#
# ## 5. 리소스 할당 및 교착 상태(Deadlock) 해결
# ### 5.1 Work Order의 생명주기(Lifecycle)와 좀비 프로세스 처리
# ACS는 각 AMR에게 작업을 할당할 때 **Work Order(작업 지시서)**라는 객체를 생성하여 관리한다. 하나의 AMR은 특정 시점에 하나의 Work Order만 처리할 수 있는 단일 스레드(Single-threaded)적 성격을 갖는다.
#
# *   **정상적인 상태 전이:** `Idle (대기)` → `Assigned (할당)` → `Running (수행)` → `Complete (완료)` → `Idle (대기)`
# *   **교착 상태(Deadlock) 발생:** 통신 단절, 센서 오류, 또는 예기치 않은 프로세스 종료로 인해 AMR이 물리적으로는 작업을 마쳤으나, 시스템 상의 상태값(State)이 `Idle`로 복귀하지 못하고 이전 작업 정보(Residual Data)를 유지하는 경우가 발생한다.
#
# **[작동 원리 및 인과관계]**
# WEB ACS의 Work Orders 메뉴에서 AMR의 상태가 `Idle`이 아닌 경우, ACS 스케줄러는 해당 로봇을 '작업 중(Busy)'으로 인식하여 새로운 Call을 할당하지 않는다. 특히 자동 복구(Auto-Recovery) 로직이 실패하여 남겨진 **'좀비 Work Order'**는 시스템 리소스를 점유하며 새로운 태스크의 진입을 막는 블로킹(Blocking) 요소가 된다.
# 이때 엔지니어가 해당 Work Order를 강제로 삭제(Force Delete)하는 행위는, 꼬여버린 상태 머신(State Machine)을 초기화(Reset)하여 AMR을 다시 가용 리소스 풀(Resource Pool)로 반환시키는 **논리적 리셋(Logical Reset)** 과정이다. 이를 통해 AMR의 상태는 `Null` 또는 `Unknown`에서 다시 `Idle`로 천이(Transition)되며, 비로소 새로운 Call을 수신할 준비를 마치게 된다.
# 2026-01-05 14:52:34.049 | INFO     | __main__:<module>:17 - 12 텍스트북 생성 완료
# 2026-01-05 14:52:34.050 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# AMR이 할당되지 않고 대기하는 자재 준비 지연(Warehouse Delay) 발생 시, 작업자는 WEB ACS의 Mission 탭에서 Status를 통해 작업 상태를 확인한다.
#
# 자재 준비 지연(Warehouse Delay) 상황에서 창고 내 부품 준비가 늦어지는 경우(Process Delay), 작업자는 창고 내 부품 준비 지연 여부를 점검한다.
#
# 자재 준비 지연(Warehouse Delay) 상황에서 창고 내 부품 준비가 실패한 경우(Preparation Fail), 작업자는 부품 재고 부족 여부 및 창고 설비의 에러 상태를 확인한다.
# 2026-01-05 14:53:07.595 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템의 자재 동기화 및 지연 처리 메커니즘 (Material Synchronization & Latency Management)
#
# ## 1. 서론: AMR과 창고 관리 시스템 간의 상호운용성
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 효율성은 자재 창고(Warehouse)와 생산 라인 간의 정밀한 물류 동기화에 의존합니다. AMR(Autonomous Mobile Robot)은 단순히 자재를 운반하는 운송 수단이 아니라, 상위 관제 시스템(ACS: Autonomous Control System) 및 창고 관리 시스템(WMS/MCS)과 실시간으로 데이터를 교환하는 **사이버-물리 시스템(Cyber-Physical System)**의 말단 노드(Edge Node)입니다.
#
# 본 기술 백서는 자재 불출 과정에서 발생하는 **'자재 준비 지연(Warehouse Delay)'** 현상을 시스템 아키텍처 관점에서 분석하고, 이에 따른 **'공정 지연(Process Delay)'**과 **'준비 실패(Preparation Fail)'**의 논리적 인과관계 및 데이터 흐름을 심층적으로 기술합니다.
#
# ---
#
# ## 2. 미션 디스패칭(Mission Dispatching)과 상태 모니터링 아키텍처
#
# ### 2.1. 자원 할당 최적화 알고리즘 (Resource Allocation Logic)
# 일반적으로 AMR은 ACS로부터 미션(Mission)을 수신하면 즉시 이동을 시작합니다. 그러나 **자재 준비 지연(Warehouse Delay)** 상태는 시스템의 **디스패처(Dispatcher) 알고리즘**이 의도적으로 AMR 할당을 보류(Pending)한 상태를 의미합니다.
#
# *   **작동 원리:** ACS는 WMS(Warehouse Management System)로부터 "자재 출고 준비 완료(Ready to Pick)" 신호를 수신하기 전까지는 해당 미션을 수행할 AMR을 지정하지 않습니다. 이는 준비되지 않은 포트(Port)로 로봇을 미리 보내 발생할 수 있는 **병목 현상(Bottleneck)**과 **교착 상태(Deadlock)**를 방지하기 위한 선제적 로직입니다.
# *   **데이터 시각화 (WEB ACS):** 이 과정에서 발생하는 모든 트랜잭션은 **WEB ACS**의 **Mission 탭**에 실시간으로 기록됩니다. **Status** 필드는 단순한 텍스트가 아니라, 시스템 내부의 **유한 상태 머신(FSM: Finite State Machine)**이 현재 어느 단계(State)에 머물러 있는지를 나타내는 지표입니다. 작업자가 이를 확인하는 행위는 백엔드 로직의 교착 여부를 판단하는 첫 번째 디버깅 절차입니다.
#
# ---
#
# ## 3. 프로세스 지연(Process Delay)의 공학적 분석
#
# ### 3.1. 비동기 프로세스와 타임아웃 메커니즘
# **자재 준비 지연(Warehouse Delay)**이라는 대분류 하에서, **Process Delay**는 창고 내부의 물리적 설비(Stacker Crane, Conveyor 등)가 작동 중이나, 예상된 **사이클 타임(Cycle Time)**을 초과하는 경우 발생합니다.
#
# *   **발생 메커니즘:** WMS는 자재 불출 명령을 내린 후, 특정 시간(Time Window) 내에 출고 포트의 센서(Photoelectric Sensor 등)가 자재 감지를 트리거(Trigger)할 것을 기대합니다. 그러나 설비의 노후화, 일시적인 통신 지연, 또는 다량의 불출 명령으로 인한 큐(Queue) 적체로 인해 물리적 이동이 지연될 수 있습니다.
# *   **시스템 반응:** ACS는 WMS로부터 "Processing(처리 중)"이라는 상태 값을 지속적으로 수신하지만, "Complete(완료)" 플래그가 수신되지 않는 상태가 지속됩니다. 이는 시스템 오류(Fault)가 아닌 **지연(Latency)** 상태이므로, 시스템은 에러를 발생시키지 않고 대기 모드를 유지합니다.
# *   **운영적 대응:** 작업자가 창고 내 부품 준비 지연 여부를 점검해야 하는 이유는, 이것이 소프트웨어적 버그가 아니라 **물리적 물류 흐름의 정체**에서 기인하기 때문입니다.
#
# ---
#
# ## 4. 준비 실패(Preparation Fail)와 예외 처리 (Exception Handling)
#
# ### 4.1. 논리적 데이터 불일치와 물리적 하드웨어 오류
# **Preparation Fail**은 Process Delay와 달리, 시스템이 해당 미션을 수행할 수 없음을 확정적으로 판단한 **터미널 스테이트(Terminal State)**입니다. 이는 크게 두 가지 공학적 원인으로 분류됩니다.
#
# #### A. 데이터 정합성 오류 (Data Integrity Error) - 부품 재고 부족
# *   **원리:** ERP(Enterprise Resource Planning)나 WMS 상의 전산 재고(Logical Stock)와 실제 창고 내 물리적 재고(Physical Stock) 간의 불일치(Discrepancy)가 발생한 경우입니다.
# *   **데이터 흐름:** WMS가 특정 Bin(적재 위치)으로 크레인을 보냈으나, 해당 위치의 **로드 셀(Load Cell)**이나 **비전 센서**가 빈 팔레트(Empty Pallet)를 감지하면, WMS는 ACS에게 **NACK(Negative Acknowledgement)** 신호와 함께 "재고 없음" 코드를 반환합니다.
# *   **결과:** ACS는 즉시 해당 미션을 'Fail' 처리하고, AMR 할당을 영구적으로 취소하여 헛된 주행(Dead Run)을 방지합니다.
#
# #### B. 설비 제어 시스템 오류 (Equipment Control Fault)
# *   **원리:** 창고 자동화 설비(AS/RS)를 제어하는 PLC(Programmable Logic Controller) 레벨에서 하드웨어적인 에러가 발생한 경우입니다. 서보 모터의 과부하(Overload), 인버터 트립(Trip), 또는 통신 모듈의 단선 등이 원인이 될 수 있습니다.
# *   **인과관계:** 설비가 물리적으로 움직일 수 없는 상태이므로, 아무리 시간을 대기해도 자재는 출고 포트에 도달할 수 없습니다. 따라서 시스템은 즉시 에러 상태를 전파(Propagate)합니다.
# *   **운영적 대응:** 작업자가 "창고 설비의 에러 상태"를 확인하는 것은, 상위 시스템(ACS)이 수신한 에러 코드가 실제 하드웨어의 어떤 물리적 결함(센서 오작동, 모터 고장 등)에서 기인했는지를 현장에서 검증(Verification)하는 절차입니다.
#
# ---
#
# ## 5. 결론
# BMA 공정의 **Warehouse Delay** 관리는 단순한 기다림이 아니라, **ACS(관제)-WMS(창고)-AMR(로봇)** 간의 복잡한 핸드쉐이킹(Handshaking) 프로토콜의 결과물입니다.
# **Process Delay**는 물리적 처리 속도의 한계(Throughput Limit)를, **Preparation Fail**은 데이터의 불일치나 하드웨어의 고장(Hard Failure)을 의미합니다. 작업자는 WEB ACS의 Status 정보를 통해 이러한 시스템 내부의 논리적 판단 결과를 역추적하여, 소프트웨어적 대기 상태인지 물리적 개입이 필요한 고장 상태인지를 정확히 식별해야 합니다.
# 2026-01-05 14:53:07.598 | INFO     | __main__:<module>:17 - 13 텍스트북 생성 완료
# 2026-01-05 14:53:07.599 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# MCS 상에서 LOAD 명령이 존재함에도 로봇 할당이 되지 않을 경우, WEB ACS의 Mission List를 통해 AMR에 수동 미션이 설정되어 있거나 목적지에 이미 다른 미션이 할당되어 자동 미션 수행이 불가능한 상태인지 확인해야 한다.
#
# 자동 복구 실패 시, WEB ACS의 AMR Info 메뉴에서 해당 AMR이 AUTO 모드로 설정되어 있는지 확인해야 하며, AMR이 AUTO 모드일 때만 MCS 미션을 정상적으로 수행할 수 있다.
# 2026-01-05 14:53:44.528 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: AMR 관제 로직과 자원 할당의 결정론적 메커니즘
# **(Technical Whitepaper: Deterministic Mechanisms of AMR Dispatching and Resource Allocation in BMA Automation)**
#
# ---
#
# ### 1. 서론: MCS와 ACS 간의 명령 동기화 및 자원 경합
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 물류 자동화는 상위 제어 시스템인 **MCS(Material Control System)**와 하위 실행 시스템인 **ACS(AMR Control System)** 간의 정밀한 핸드쉐이킹(Handshaking)을 기반으로 작동한다. 이 계층 구조에서 MCS는 전체 공정의 자재 흐름을 관장하는 '두뇌' 역할을 하며, ACS는 실제 물리적 자원인 **AMR(Autonomous Mobile Robot)** 군집을 제어하는 '신경망' 역할을 수행한다.
#
# 본 장에서는 MCS가 `LOAD` 명령을 하달했음에도 불구하고, 물리적 실행 주체인 AMR이 할당(Dispatching)되지 않는 현상을 시스템 아키텍처 관점에서 분석하고, 이에 대한 논리적 인과관계와 데이터 흐름을 심층적으로 기술한다.
#
# ---
#
# ### 2. 자원 할당 실패(Dispatching Failure)의 논리적 원인 분석
#
# MCS 상에서 `LOAD` 명령(Command)이 큐(Queue)에 존재함에도 불구하고, ACS가 특정 AMR을 해당 작업에 할당하지 못하는 현상은 단순한 통신 오류가 아니다. 이는 시스템이 **교착 상태(Deadlock)**나 **물리적 충돌(Collision)**을 방지하기 위해 설계된 **'자원 점유 및 우선순위 로직(Resource Reservation & Priority Logic)'**이 정상적으로 작동하고 있다는 반증이기도 하다.
#
# #### 2.1. 수동 미션에 의한 인터럽트와 우선순위 역전 (Priority Inversion)
# ACS의 스케줄링 알고리즘은 기본적으로 MCS로부터 수신된 자동화 명령을 처리하도록 설계되어 있다. 그러나 **WEB ACS**의 `Mission List`에 **수동 미션(Manual Mission)**이 설정되어 있는 경우, 시스템은 이를 최상위 우선순위(Highest Priority) 인터럽트로 간주한다.
#
# *   **작동 원리:** 엔지니어가 유지보수나 긴급 조작을 위해 WEB ACS를 통해 특정 AMR에 수동 명령을 입력하면, 해당 AMR의 **작업 레지스터(Task Register)**는 수동 미션으로 즉시 점유(Lock)된다.
# *   **결과:** MCS가 아무리 `LOAD` 명령을 송출하더라도, ACS의 디스패처(Dispatcher)는 해당 AMR을 '가용 자원(Available Resource)' 목록에서 제외한다. 이는 자동 명령이 수동 조작을 덮어써서 발생할 수 있는 안전 사고를 방지하기 위한 **논리적 차단(Logical Block)** 메커니즘이다.
#
# #### 2.2. 목적지 노드 점유와 경로 계획의 배타성 (Spatial Resource Contention)
# AMR의 자율 주행은 공장 바닥을 수학적 그래프(Graph) 모델로 변환한 **토폴로지 맵(Topology Map)** 위에서 이루어진다. MCS가 지시한 목적지(Destination Node)에 이미 다른 미션이 할당되어 있다는 것은, 해당 공간 자원이 **'예약(Reserved)'** 상태임을 의미한다.
#
# *   **공학적 배경:** 다중 로봇 제어 시스템(Multi-Agent System)에서 두 대 이상의 로봇이 동일한 좌표나 노드를 동시에 점유하는 것은 물리적 충돌을 의미한다. 따라서 ACS의 경로 계획(Path Planning) 알고리즘은 선행 미션이 완료되어 해당 노드의 점유가 해제(Release)될 때까지 후행 미션의 할당을 보류한다.
# *   **데이터 흐름:**
#     1.  MCS `LOAD` 명령 수신.
#     2.  ACS가 목적지 노드의 상태 비트(State Bit) 검사.
#     3.  `Node_Status == OCCUPIED` 또는 `RESERVED`일 경우, 할당 로직은 대기(Wait) 상태로 전환.
#     4.  이 과정에서 운영자는 겉보기에 로봇이 할당되지 않는 현상을 목격하게 된다.
#
# ---
#
# ### 3. 시스템 상태 머신(State Machine)과 오토 모드의 무결성
#
# 시스템의 자동 복구(Auto-recovery) 기능이 실패하거나, 미션 수행이 근본적으로 불가능한 경우, 엔지니어는 시스템의 가장 기초적인 상태(State)인 **운전 모드(Operation Mode)**를 검증해야 한다.
#
# #### 3.1. AUTO 모드와 MCS 명령 수락의 인과관계
# BMA 공정의 모든 AMR은 **유한 상태 머신(Finite State Machine, FSM)**에 따라 동작한다. 여기서 **AUTO 모드**는 단순한 스위치 설정이 아니라, AMR이 외부 관제 시스템(MCS/ACS)의 제어 신호를 수락하고 처리할 준비가 되었음을 알리는 **'통신 및 제어 권한 위임(Control Authority Delegation)'** 상태를 의미한다.
#
# *   **논리적 게이트(Logical Gate):** ACS와 AMR 간의 통신 프로토콜에는 명령 수락을 위한 전제 조건(Pre-condition)으로 `Mode == AUTO`라는 논리적 게이트가 존재한다.
# *   **데이터 흐름 및 차단:**
#     *   **Case 1 (AUTO 모드):** MCS 명령 패킷 도달 → AMR 내부 컨트롤러가 모드 비트 확인(`1`: AUTO) → 명령 파싱 및 구동 모터 제어 시작.
#     *   **Case 2 (MANUAL/TEACHING 모드):** MCS 명령 패킷 도달 → AMR 내부 컨트롤러가 모드 비트 확인(`0`: Not AUTO) → **명령 패킷 폐기(Drop) 또는 NACK(Negative Acknowledge) 응답 전송.**
#
# #### 3.2. WEB ACS를 통한 상태 검증 및 복구 절차
# 자동 복구 시도가 실패했다는 것은 소프트웨어적인 리셋(Soft Reset)만으로는 해결되지 않는 하드웨어적 상태 불일치가 존재함을 시사한다. 이때 엔지니어는 **WEB ACS**의 `AMR Info` 메뉴를 통해 해당 로봇의 실시간 상태 데이터를 확인해야 한다.
#
# *   **진단 메커니즘:** WEB ACS는 현장의 AMR로부터 주기적인 **Heartbeat 신호**와 상태 패킷을 수신하여 시각화한다. 만약 AMR이 수동 조작 중이거나 에러 상태로 인해 AUTO 모드가 해제된 경우, MCS의 어떠한 미션도 물리적 구동으로 이어지지 않는다.
# *   **결론:** 따라서 MCS 미션의 정상적인 수행을 위해서는 AMR의 로컬 제어기가 반드시 AUTO 모드로 설정되어 있어야 하며, 이는 중앙 관제 시스템이 개별 로봇에 대한 **결정론적 제어(Deterministic Control)**를 수행하기 위한 필수 불가결한 조건이다.
# 2026-01-05 14:53:44.530 | INFO     | __main__:<module>:17 - 14 텍스트북 생성 완료
# 2026-01-05 14:53:44.531 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# AMR이 Way Point(WP)에서 장시간 대기하는 현상은 목적지 점유 상태 또는 창고 시스템의 로직 문제로 인해 발생한다.
#
# 자동 복구 실패 시, 목적지 위치에 이미 도킹 중이거나 작업을 수행 중인 선행 AMR이 있는지 확인하여 후속 AMR의 대기 원인을 파악한다.
#
# 수동 조작이 필요한 경우, 창고 시스템이 수동 모드이거나 목적지 위치 정보를 제공하지 못할 때는 창고 보전 담당자에게 연락하여 조치를 취한다.
#
# AMR이 Way Point(WP)에 도착했음에도 창고 시스템에서 적재 위치(#1 또는 #2)를 결정하여 지정해주지 않으면 AMR은 해당 위치에서 지속적으로 대기한다.
# 2026-01-05 14:54:20.713 | INFO     | __main__:<module>:10 - # BMA 공정 내 AMR 자율 주행 및 관제 시스템의 상호 운용성 분석: Way Point(WP) 대기 메커니즘과 예외 처리 로직
#
# ## 1. 서론: 물류 자동화의 결정적 노드(Critical Node)로서의 Way Point
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 물류 자동화 시스템에서 AMR(Autonomous Mobile Robot)의 주행은 단순한 좌표 이동의 연속이 아니다. 특히 **Way Point(WP)**는 단순한 경유지가 아니라, AMR의 로컬 제어기(Local Controller)와 상위 관제 시스템(ACS/WCS) 간의 **데이터 동기화(Data Synchronization) 및 의사결정(Decision Making)이 이루어지는 임계 구역(Critical Section)**으로 정의된다.
#
# 본 챕터에서는 AMR이 WP에 도착한 후 발생하는 장시간 대기 현상(Long-term Idle State)을 시스템 아키텍처 관점에서 분석하고, 목적지 할당 로직의 실패 원인과 이에 따른 물리적/논리적 인과관계를 심층적으로 기술한다.
#
# ---
#
# ## 2. 목적지 할당 알고리즘과 교착 상태(Deadlock)의 역학
#
# ### 2.1. 동적 라우팅(Dynamic Routing)과 슬롯 할당 로직
# AMR이 WP에 도달했을 때, 시스템은 정적인 경로를 따르는 것이 아니라 실시간 상황에 기반한 동적 라우팅을 수행한다. 입력된 사실(Fact)에 따르면, AMR은 WP 도착 시점에서 창고 시스템으로부터 **적재 위치(#1 또는 #2)** 중 하나를 할당받아야 한다.
#
# 이 과정은 다음과 같은 논리적 시퀀스로 작동한다:
# 1.  **Trigger (이벤트 발생):** AMR이 WP 좌표 반경(Tolerance) 내에 진입하면, AMR은 상위 시스템에 `Arrived_at_WP` 신호를 송신한다.
# 2.  **Processing (상태 연산):** 창고 시스템은 현재 적재 위치 #1과 #2의 **가용성(Availability)**을 평가한다. 이는 해당 슬롯의 센서 데이터, 작업 스케줄, 선행 AMR의 점유 상태 등을 종합하여 판단한다.
# 3.  **Assignment (자원 할당):** 최적의 위치(예: #1)가 결정되면 시스템은 AMR에게 `Target_Node: #1`이라는 지령을 하달한다.
#
# ### 2.2. 대기 현상의 근본 원인: 할당 로직의 타임아웃
# AMR이 WP에서 지속적으로 대기하는 현상은 위 3단계 중 **Assignment 단계의 결락(Missing)** 또는 **지연(Latency)**에서 기인한다. 창고 시스템이 적재 위치(#1 또는 #2)를 결정하여 패킷을 전송하지 않으면, AMR의 내부 상태 머신(State Machine)은 `Moving` 상태로 전이되지 못하고 `Idle/Wait` 상태를 유지한다. 이는 안전을 위한 **Fail-Safe 설계**의 일환으로, 목적지가 확정되지 않은 상태에서의 임의 주행을 원천 차단하여 충돌 사고를 방지하기 위함이다.
#
# ---
#
# ## 3. 물리적 점유와 논리적 점유의 불일치 (Physical vs. Logical Occupancy)
#
# ### 3.1. 자원 경합(Resource Contention)과 선행 AMR
# 자동 복구 실패 시 확인해야 할 가장 중요한 물리적 변수는 **선행 AMR의 존재 여부**이다. 이는 컴퓨터 공학적 관점에서 **상호 배제(Mutual Exclusion, Mutex)** 원칙과 직결된다.
#
# *   **논리적 점유(Logical Occupancy):** 시스템 데이터베이스 상에서 해당 위치(#1 또는 #2)가 '사용 중(Busy)'으로 마킹된 상태.
# *   **물리적 점유(Physical Occupancy):** 실제 공간에 선행 AMR이 도킹 중이거나 작업을 수행 중인 상태.
#
# 만약 선행 AMR이 작업을 마치고 물리적으로는 이탈했으나, 통신 지연이나 센서 오류로 인해 시스템 상에서 '점유 해제(Release)' 신호가 처리되지 않았다면, 후속 AMR은 물리적 공간이 비어있음에도 불구하고 WP에서 무한 대기하게 된다. 반대로, 시스템은 비어있다고 판단했으나 실제로는 선행 AMR이 고장으로 멈춰 있다면, 후속 AMR의 Lidar 센서나 Safety Zone이 장애물을 감지하여 주행을 차단한다. 따라서 엔지니어는 이 두 가지 점유 상태의 일치 여부를 반드시 검증해야 한다.
#
# ---
#
# ## 4. 시스템 모드 종속성과 데이터 흐름(Data Flow) 단절
#
# ### 4.1. 수동 모드(Manual Mode)에 의한 제어권 이양
# 창고 시스템이 **수동 모드**로 전환된 경우, 자동화 로직(Auto-Logic)의 실행 루프가 중단된다. 이 상태에서 상위 시스템은 AMR로부터 `Arrived_at_WP` 요청을 수신하더라도, 이에 대한 응답(Response)인 목적지 좌표를 생성하지 않는다.
#
# 이는 시스템 아키텍처 상 **제어권(Control Authority)**이 알고리즘에서 인간 운영자(Human Operator)에게로 이양되었음을 의미한다. 수동 모드에서는 안전상의 이유로 모든 자동 할당 프로세스가 바이패스(Bypass)되거나 차단(Block)되도록 설계되어 있다. 따라서 AMR은 상위 제어기로부터 유효한 데이터 패킷(Valid Payload)을 수신할 때까지 대기 모드를 유지할 수밖에 없다.
#
# ### 4.2. 목적지 정보 소실(Null Destination)과 예외 처리
# 창고 시스템이 정상적인 자동 모드임에도 불구하고 목적지 정보를 제공하지 못하는 경우는 **데이터 무결성(Data Integrity)** 문제로 볼 수 있다.
# *   **재고 데이터 오류:** 적재할 자재 정보가 DB에서 누락된 경우.
# *   **설비 인터페이스 에러:** 창고 설비(Stacker Crane 등)와 관제 시스템 간의 통신 두절(Disconnection).
#
# 이러한 경우 시스템은 AMR에게 잘못된 목적지를 주는 것보다 **'지령 없음(No Command)'** 상태를 유지하는 것이 전체 공정의 꼬임(Gridlock)을 방지하는 데 유리하다.
#
# ---
#
# ## 5. 결론 및 대응 프로토콜: Human-in-the-loop
#
# AMR이 WP에서 장시간 대기하는 현상은 단순한 오류가 아니라, **불확실한 상황에서 시스템의 엔트로피를 증가시키지 않기 위한 방어적 기제(Defensive Mechanism)**이다.
#
# 엔지니어는 다음의 인과 사슬을 이해하고 대응해야 한다:
# 1.  **현상:** AMR WP 대기 지속.
# 2.  **1차 원인 분석 (System Logic):** 창고 시스템이 적재 위치(#1/#2) 할당 로직을 수행하지 않음.
# 3.  **2차 원인 분석 (Physical/Mode):** 선행 AMR에 의한 자원 점유(Deadlock) 또는 창고 시스템의 수동 모드 전환.
# 4.  **조치 (Action):** 자동 복구(Auto-Recovery)가 불가능한 경우, 이는 소프트웨어 로직의 범위를 벗어난 물리적/운영적 예외 상황임을 의미한다. 따라서 **창고 보전 담당자**에게 연락하여 시스템 모드를 정상화하거나, 물리적 장애 요소를 제거하는 **인적 개입(Human-in-the-loop)**을 통해 데이터 흐름을 재개시켜야 한다.
# 2026-01-05 14:54:20.715 | INFO     | __main__:<module>:17 - 15 텍스트북 생성 완료
# 2026-01-05 14:54:20.716 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# 차종 변경 시 BMA 부품, BSA용 공급, 배터리 셀 공급 프로세스의 AMR은 자재 회수가 가능하지만, Lower Case(L/C) 공급 AMR은 자재를 회수할 수 없다.
#
# 차종 변경 시작 시 수동 조작이 필요한 경우, 설비 HMI에서 Call Create Pause를 'ON'으로 설정한 후 Call Cancel과 Work Reset을 순차적으로 실행한다.
#
# 차종 변경 완료 후 작업을 재개하는 경우, 설비 HMI에서 Call Create Pause를 'OFF'로 설정한다.
#
# 이미 로드된 자재를 작업자가 수동으로 회수하는 경우, 설비 HMI에서 Call Create Pause 'ON', Call Cancel, Work Reset을 실행한 뒤 지게차나 카트를 이용해 수동으로 언로드(Unload)하고 Call Create Pause를 'OFF'로 변경한다.
#
# 이미 로드된 자재를 AMR 및 설비를 통해 자동으로 회수하는 경우, 자재를 NG 처리하여 배출 포트로 이동시킨 후 설비 HMI에서 'Call Priority' 버튼을 눌러 AMR을 호출하여 창고로 배출한다.
# 2026-01-05 14:55:04.847 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: 차종 변경(Model Change) 시 자재 흐름 제어 및 예외 처리 메커니즘
#
# ## 1. 개요 (Overview)
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정은 다차종 혼류 생산을 지원하는 유연 생산 시스템(FMS, Flexible Manufacturing System)을 기반으로 설계되었다. 그러나 차종 변경(Model Change) 시점에서는 기존 차종의 잔여 자재를 라인에서 제거(Clearance)하고 신규 차종의 자재를 투입하는 과정에서 물리적, 논리적 제약 사항이 발생한다.
#
# 본 챕터에서는 차종 변경 시 AMR(Autonomous Mobile Robot)과 설비 간의 상호작용, 특히 **Lower Case(L/C) 공급 공정의 기구학적 비가역성**과 이를 해결하기 위한 **제어 시스템(HMI/PLC)의 논리적 시퀀스(Logical Sequence)**를 심층 분석한다. 또한, 잔여 자재 회수를 위한 수동 및 자동 프로세스의 아키텍처적 차이와 그 작동 원리를 공학적 관점에서 서술한다.
#
# ---
#
# ## 2. 자재 회수의 기구학적 제약과 AMR 운용 특성
#
# ### 2.1. 공정별 자재 회수 가능성 분석 (Reversibility Analysis)
# BMA 공정 내 물류 흐름은 기본적으로 공급(Supply) 방향으로 최적화되어 있으나, 차종 변경 시에는 역방향(Reverse) 물류가 요구된다. 이때 AMR의 하드웨어 특성과 이송 메커니즘에 따라 회수 가능 여부가 결정된다.
#
# *   **회수 가능 그룹 (BMA 부품, BSA 공급, 배터리 셀):**
#     이 공정의 AMR들은 트레이(Tray)나 매거진(Magazine) 단위의 소형/중형 자재를 취급한다. 이송 메커니즘은 양방향 컨베이어 혹은 리프트 방식을 채택하고 있어, 설비와의 핸드쉐이킹(Handshaking) 프로토콜만 역으로 수행하면 물리적인 자재 회수(Retrieval)가 가능하다. 즉, 투입 포트가 곧 배출 포트의 역할을 겸할 수 있는 **양방향 토폴로지(Bidirectional Topology)**를 갖는다.
#
# *   **회수 불가능 그룹 (Lower Case 공급 AMR):**
#     **Lower Case(L/C)**는 배터리 모듈의 하부 하우징으로, 중량물이며 부피가 크다. L/C 공급 AMR과 도킹하는 설비의 투입부는 중력이나 체인 구동에 의한 **단방향(Unidirectional) 진입 메커니즘**으로 설계되어 있다.
#     *   **Why?** 중량물의 경우 역방향 구동 시 모터 부하 및 기구적 정렬(Alignment) 유지가 어렵고, 안전상의 이유로 Back-stop 메커니즘이 적용되는 경우가 많다.
#     *   **Result:** 따라서 L/C 공급 AMR은 자재를 설비에 안착(Docking & Drop)시킨 이후에는 물리적으로 다시 자재를 집어 올릴 수 없는 **비가역적(Irreversible) 상태**가 된다. 이는 시스템 설계 단계에서 정의된 하드웨어적 제약 사항이다.
#
# ---
#
# ## 3. 제어 로직의 상태 전이와 인터락 해제 (State Transition & Interlock Release)
#
# 차종 변경 시 시스템은 '생산 모드(Production Mode)'에서 '전환 모드(Transition Mode)'로 변경되어야 한다. 이 과정에서 운영자는 HMI(Human Machine Interface)를 통해 PLC의 내부 레지스터를 조작하여 논리적 흐름을 제어한다.
#
# ### 3.1. 명령 생성 중단 (Call Create Pause: ON)
# *   **기능:** 상위 관제 시스템(ACS/MCS)에서 하위 설비로 내려오는 신규 자재 요청(Call) 생성 로직을 차단한다.
# *   **작동 원리:** PLC 내의 자재 요청 생성 트리거(Trigger) 비트를 마스킹(Masking) 처리한다. 이 기능이 활성화('ON')되면, 설비 내 자재가 소진되더라도 추가적인 AMR 호출 신호가 발생하지 않는다. 이는 차종 변경 중 구형 자재가 추가로 투입되는 것을 방지하는 **유입 차단(Inflow Blocking)** 단계이다.
#
# ### 3.2. 요청 취소 및 작업 리셋 (Call Cancel & Work Reset)
# 이미 생성되어 대기 큐(Queue)에 존재하는 명령들을 소거하는 단계이다.
# *   **Call Cancel:** 현재 실행 중이지 않은 대기 상태의 미션(Mission)들을 삭제한다. ACS의 스케줄러 테이블에서 해당 설비와 관련된 펜딩(Pending) 작업들을 제거하여, 불필요한 트래픽을 방지한다.
# *   **Work Reset:** 설비 PLC의 **유한 상태 머신(FSM, Finite State Machine)**을 초기화한다. 현재 진행 중이던 시퀀스(Step)를 강제로 종료하고, 에러 플래그나 임시 데이터 레지스터를 '0'으로 클리어(Clear)하여, 새로운 차종 데이터를 받아들일 준비 상태(Ready State)로 복귀시킨다.
#
# ### 3.3. 작업 재개 (Call Create Pause: OFF)
# 차종 변경 설정이 완료된 후, 마스킹 해제 신호를 인가한다. 이때부터 PLC는 변경된 차종 ID(Model ID)를 기반으로 새로운 자재 요청 신호를 ACS로 송출하기 시작하며, 정상적인 생산 사이클이 재개된다.
#
# ---
#
# ## 4. 잔여 자재 처리 프로세스: 수동 vs 자동 (Material Recovery Protocols)
#
# 이미 설비 내부로 로드(Load)된 자재를 제거하는 방법은 **물리적 접근(수동)**과 **논리적 우회(자동)** 두 가지 방식으로 나뉜다.
#
# ### 4.1. 수동 회수 프로세스 (Manual Unload)
# 작업자가 물리적으로 개입해야 하는 경우(예: L/C AMR의 회수 불가 특성 또는 설비 고장 시), 시스템은 안전을 위해 완벽한 정지 상태를 유지해야 한다.
#
# 1.  **논리적 격리:** `Call Create Pause 'ON'` → `Call Cancel` → `Work Reset`을 순차적으로 실행하여 설비와 AMR의 자동 운전을 비활성화한다. 이는 작업자가 설비 영역(Safety Zone)에 진입했을 때 기계가 불시에 작동하는 것을 막는 **논리적 안전 펜스(Logical Safety Fence)** 역할을 한다.
# 2.  **물리적 회수:** 지게차나 카트 등 외부 장비를 이용하여 자재를 언로드한다. 이때 설비의 센서는 자재가 제거됨을 감지(Sensor Falling Edge)하지만, `Work Reset` 상태이므로 이를 에러로 인식하지 않고 대기한다.
# 3.  **시스템 복귀:** 작업 완료 후 `Call Create Pause 'OFF'`를 입력하면, 시스템은 초기 상태에서 다시 시작하며 신규 자재를 요청한다.
#
# ### 4.2. 자동 회수 프로세스: 가상 불량 처리 (Automatic Recovery via Virtual NG)
# AMR 및 설비를 이용해 자동으로 자재를 빼내고 싶지만, 정상적인 '회수(Return)' 로직을 사용할 수 없는 경우(예: 단방향 물류 라인), 시스템은 **"정상 자재를 불량품(NG)으로 위장"**시키는 논리적 우회(Logic Bypass) 기법을 사용한다.
#
# 1.  **NG 처리 (Virtual Defect Assignment):**
#     *   운영자는 HMI를 통해 해당 자재의 상태 비트(Status Bit)를 'OK'에서 'NG(No Good)'로 강제 변경한다.
#     *   **Why?** 설비 로직 상, '생산 완료된 제품'은 다음 공정으로 이동하지만, '불량품'은 별도의 배출 포트(Discharge Port)로 이동하도록 프로그래밍되어 있기 때문이다. 이를 통해 역방향 이동이 불가능한 하드웨어 제약을 우회하여, **순방향(Forward) 흐름을 유지하면서 자재를 라인 밖으로 배출**할 수 있다.
#
# 2.  **배출 포트 이동 및 우선 호출 (Priority Call):**
#     *   자재가 NG 배출 포트에 도착하면, HMI에서 `Call Priority` 버튼을 활성화한다.
#     *   **작동 원리:** 일반적인 자재 요청은 FIFO(First-In-First-Out) 방식으로 처리되지만, `Priority` 신호는 ACS 스케줄러의 최상위 인터럽트(Interrupt)로 작용한다. 이는 차종 변경 시간을 단축하기 위해 배출용 AMR을 최우선으로 배차(Dispatching)하게 만든다.
#
# 3.  **창고 배출:**
#     *   호출된 AMR은 해당 자재를 수령하여 창고(Warehouse)나 NG 스테이션으로 이송한다. 시스템 입장에서 이 자재는 '불량'으로 기록되지만, 물리적으로는 온전한 자재이므로 창고 입고 후 재고 관리 시스템(WMS)에서 상태를 '정상'으로 갱신하는 후처리 과정이 수반된다.
#
# ## 5. 결론 (Conclusion)
#
# BMA 공정의 차종 변경 시나리오는 단순한 자재 교체가 아니라, **하드웨어의 기구학적 제약(L/C의 비가역성)**과 **소프트웨어의 상태 제어(Pause/Reset)**가 정교하게 맞물려 돌아가는 과정이다. 엔지니어는 각 버튼 조작이 PLC 레지스터와 ACS 스케줄러에 미치는 영향을 정확히 이해해야 하며, 특히 자동 회수가 불가능한 상황에서 'NG 처리'를 통한 논리적 우회 기법을 적절히 활용하여 라인 가동 중단(Downtime)을 최소화해야 한다.
# 2026-01-05 14:55:04.850 | INFO     | __main__:<module>:17 - 16 텍스트북 생성 완료
# 2026-01-05 14:55:04.851 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# 작업자의 실수로 AMR의 미션이 삭제되어 적재물을 실은 상태로 정지한 경우, WEB ACS에서 해당 AMR을 수동 모드(Manual Mode)로 전환한 후 적재물 종류에 따라 다음과 같이 조치한다.
#
# 1. BMA Pallet 적재 시, 자동 복구 실패 시 WEB ACS에서 MW 11, MW 21(Loaded) 또는 MW 13, MW 213(Empty) 위치를 우클릭하여 Unload를 실행한 후 자동 모드(Auto Mode)로 전환한다.
# 2. BMA Parts Box 적재 시, 수동 조작이 필요한 경우 WEB ACS에서 MS25(회수 포트)를 우클릭하여 Unload 및 Unload2를 선택한 후 자동 모드(Auto Mode)로 전환한다.
# 3. L/C 및 BSA 완제품 적재 시, 수동 조작이 필요한 경우 WEB ACS에서 목표 지점을 우클릭하여 Unload를 실행하고 자동 모드(Auto Mode)로 전환하거나 지게차를 이용하여 수동으로 배출한다.
# 2026-01-05 14:55:44.886 | INFO     | __main__:<module>:10 - # BMA 공정 자동화 시스템 기술 백서
# ## Section 4.3: 예외 상황 발생 시 미션 복구 및 교착 상태(Deadlock) 해결 메커니즘
#
# ### 1. 개요 (Overview)
#
# BMA(Battery Module Assembly) 공정 내 물류 흐름은 ACS(Advanced Control System)와 AMR(Autonomous Mobile Robot) 간의 실시간 데이터 동기화에 의해 제어된다. 그러나 운영 과정에서 작업자의 인적 오류(Human Error)로 인해 실행 중인 미션(Mission)이 강제 삭제되는 상황이 발생할 수 있다.
#
# 이 경우, AMR은 물리적으로는 적재물(Payload)을 파지하고 있으나, 논리적으로는 목적지(Destination) 데이터를 상실한 **'고립 상태(Orphan State)'**에 빠지게 된다. 이는 시스템 상에서 해당 로봇이 유휴(Idle) 상태로 인식되거나, 반대로 점유(Busy) 상태임에도 다음 명령을 수행할 수 없는 논리적 교착 상태(Logical Deadlock)를 유발한다.
#
# 본 챕터에서는 이러한 미션 소실 상황에서 시스템의 정합성(Integrity)을 유지하고, 적재물의 종류(Pallet, Parts Box, 완제품)에 따라 최적화된 복구 로직(Recovery Logic)이 어떻게 수행되는지 아키텍처 관점에서 기술한다.
#
# ---
#
# ### 2. 제어 권한 이양 및 상태 동기화 (Control Authority Transfer)
#
# 미션이 삭제된 AMR은 자율 주행을 위한 경로(Path Planning) 데이터를 잃게 되므로, 안전을 위해 즉시 정지(Fail-Safe Stop)한다. 이때 시스템 복구를 위한 첫 번째 단계는 제어 권한을 스케줄러(Scheduler)에서 운영자(Operator)로 이양하는 것이다.
#
# *   **수동 모드(Manual Mode) 전환의 공학적 의미:**
#     WEB ACS 상에서의 수동 모드 전환은 AMR의 제어 루프(Control Loop)에서 상위 관제 시스템의 자동 할당 알고리즘을 배제(Bypass)하는 것을 의미한다. 이는 로봇이 불완전한 데이터로 인해 예측 불가능한 거동을 하는 것을 방지하고, 운영자가 직접 개입하여 논리적 에러를 수정할 수 있는 '관리자 권한(Supervisory Control)'을 활성화하는 절차다.
#
# ---
#
# ### 3. 적재물 유형별 복구 시나리오 및 데이터 흐름 (Recovery Scenarios & Data Flow)
#
# 적재물의 물리적 특성과 공정 내 위치(Topology)에 따라 복구 프로토콜은 상이하게 적용된다. 각 시나리오는 AMR 내부 PLC와 ACS 간의 통신 프로토콜을 기반으로 설계되었다.
#
# #### 3.1. BMA Pallet 적재 시: 가상 노드 할당을 통한 강제 배출
#
# BMA Pallet 공정에서 미션이 삭제된 경우, 시스템은 로봇의 현재 위치와 적재 상태를 기반으로 가상의 목표 노드(Virtual Target Node)를 재설정해야 한다.
#
# *   **논리적 위치 정의 (Logical Node Definition):**
#     *   **MW 11, MW 21 (Loaded State):** 적재물이 존재하는 상태에서의 목표 노드 레지스터.
#     *   **MW 13, MW 213 (Empty State):** 공(Empty) Pallet 회수 또는 이동을 위한 노드 레지스터.
#     *   이러한 `MW(Map Waypoint)` 코드는 단순한 좌표가 아니라, 공정 맵(Map) 상에서 로봇이 작업을 수행할 수 있는 유효한 '논리적 정류장'을 의미한다.
#
# *   **Unload 명령의 시퀀스 (Sequence of Unload Command):**
#     1.  **명령 주입 (Injection):** 운영자가 WEB ACS에서 해당 위치(MW xx)를 우클릭하여 `Unload`를 실행하면, ACS는 AMR에게 "현재 위치를 목적지로 간주하고 하역 시퀀스를 수행하라"는 오버라이드 신호(Override Signal)를 전송한다.
#     2.  **PLC 동작:** AMR 내부 PLC는 주행 모터(Traction Motor)를 잠그고(Lock), 리프트 또는 컨베이어 모터를 구동하여 적재물을 배출한다.
#     3.  **상태 초기화:** 배출이 완료되면 로봇의 센서(Photo sensor 등)가 적재물 없음을 감지하고, 로봇의 상태 비트(State Bit)를 `Loaded`에서 `Empty`로 갱신한다.
#
# *   **자동 모드 복귀:** 모든 물리적 작업이 완료된 후 `Auto Mode`로 전환하면, 스케줄러는 해당 로봇을 다시 '가용 자원(Available Resource)'으로 인식하여 대기열(Queue)에 있는 새로운 미션을 할당한다.
#
# #### 3.2. BMA Parts Box 적재 시: 전용 회수 포트를 통한 다단 제어
#
# 부품 박스(Parts Box)는 Pallet에 비해 크기가 작고 정밀한 도킹이 요구되므로, 임의의 위치가 아닌 지정된 회수 포트(Recovery Port)를 통해 복구가 이루어진다.
#
# *   **MS25 (회수 포트)의 역할:**
#     `MS(Machine Station) 25`는 공정 라인 내에서 에러가 발생한 자재를 안전하게 회수하기 위해 설계된 버퍼 존(Buffer Zone)이다. 이곳은 물리적 가이드나 센서 인터락(Interlock)이 갖춰져 있어 수동 조작 시의 충돌 위험을 최소화한다.
#
# *   **Unload 및 Unload2의 순차적 실행 (Sequential Execution):**
#     단순 `Unload` 명령 하나로 처리하지 않고 `Unload`와 `Unload2`를 선택적으로 혹은 순차적으로 수행하는 이유는 AMR의 하역 메커니즘이 다단(Multi-stage)으로 구성되어 있기 때문이다.
#     *   **Unload:** 1차적으로 도킹 래치(Latch)를 해제하거나 이송 컨베이어를 예비 구동하는 단계.
#     *   **Unload2:** 실제 적재물을 외부로 밀어내거나(Push), 외부 설비와의 핸드쉐이킹(Handshaking)을 완료하는 단계.
#     이러한 분할 실행은 기구적 잼(Mechanical Jam)을 방지하고, 자재가 불완전하게 배출되어 낙하하는 사고를 예방하기 위한 안전 로직이다.
#
# #### 3.3. L/C 및 BSA 완제품 적재 시: 하이브리드 복구 전략
#
# L/C(Low Converter) 및 BSA(Battery System Assembly) 완제품은 고중량(High Payload)이며 고가의 자산이다. 따라서 소프트웨어적 복구와 물리적 장비(지게차)를 이용한 하드웨어적 복구를 병행하는 하이브리드 전략을 취한다.
#
# *   **소프트웨어적 복구 (ACS Unload):**
#     목표 지점(Target Point)에 이미 도달했거나 근접한 경우, ACS 상에서 `Unload` 명령을 통해 정상적인 공정 흐름을 마무리 짓는다. 이는 데이터의 연속성을 유지하는 가장 이상적인 방법이다.
#
# *   **하드웨어적 복구 (Manual Forklift Operation):**
#     AMR이 설비와 설비 사이의 전이 구간(Transition Zone)에서 멈추거나, 소프트웨어 명령에 응답하지 않는 경우(통신 음영 등), 지게차를 이용한 물리적 배출이 수행된다.
#     *   **Why Forklift?** 배터리 모듈의 무게로 인해 작업자가 직접 이송하는 것은 불가능하며, AMR의 리프트만으로는 안전한 하역이 어려운 위치일 수 있다.
#     *   **데이터 정합성 후처리:** 지게차로 제품을 강제 배출한 경우, ACS는 여전히 로봇이 짐을 싣고 있다고 판단할 수 있다. 따라서 물리적 배출 후 반드시 시스템 상에서 해당 로봇의 재고 데이터(Inventory Data)를 소거(Clear)하고 `Auto Mode`로 전환해야 데이터 불일치(Data Discrepancy)를 방지할 수 있다.
#
# ---
#
# ### 4. 결론 (Conclusion)
#
# 작업자의 실수로 인한 미션 삭제는 단순한 조작 오류처럼 보이지만, 시스템 내부적으로는 **[경로 데이터 소실] -> [Fail-Safe 정지] -> [논리적 교착 상태]**로 이어지는 복합적인 문제를 야기한다.
#
# 현대자동차그룹 BMA 공정의 자동화 시스템은 이러한 상황에 대비하여, **WEB ACS를 통한 제어 권한의 유연한 변경(Auto/Manual)**과 **적재물 특성에 따른 세분화된 배출 로직(MW/MS 코드 기반의 Unload 시퀀스)**을 갖추고 있다. 이를 통해 예외 상황 발생 시에도 공정 전체의 셧다운(Shutdown) 없이, 해당 노드만 국소적으로 복구하여 가동률(Availability)을 극대화한다.
# 2026-01-05 14:55:44.888 | INFO     | __main__:<module>:17 - 17 텍스트북 생성 완료
# 2026-01-05 14:55:44.889 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# ACS_ERROR_WHILE_NAVIGATING_THE_ROUTE 오류는 WEB ACS 상에서 관리자가 AMR에 Move 명령을 내릴 때 목적지 지점이 정상 주행 경로가 아닌 주행 불가 영역(흰색 배경)으로 지정될 경우 발생한다.
#
# 자동 복구 실패 시, WEB ACS 상단의 Job Cancel 버튼을 클릭하여 현재 작업을 취소해야 한다.
#
# 수동 조작이 필요한 경우, JOG 모드를 활성화하여 AMR을 정상 주행 경로(색상이 있는 라인) 위로 이동시켜야 한다.
#
# AMR이 정상 경로 위에 위치하면, 다시 일반 경로 상의 지점을 목적지로 선택하여 Move 명령을 실행한다.
# 2026-01-05 14:56:18.047 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: 자율주행 경로 계획 및 예외 처리 메커니즘
#
# ## 1. 서론: 경로 계획(Path Planning)의 알고리즘적 기초와 무결성
#
# 현대자동차그룹 BMA 공정 내 도입된 AMR(Autonomous Mobile Robot) 시스템은 단순한 점 대 점(Point-to-Point) 이동이 아닌, 정밀하게 정의된 **위상학적 지도(Topological Map)** 기반의 자율 주행을 수행한다. 이 시스템의 핵심은 관제 시스템(ACS/MCS)이 하달한 목적지 좌표가 로봇이 물리적으로 주행 가능한 영역(Navigable Area) 내에 존재하는지를 검증하는 **경로 유효성 검사(Path Validation)** 프로세스에 있다.
#
# 본 장에서는 경로 생성 실패 시 발생하는 `ACS_ERROR_WHILE_NAVIGATING_THE_ROUTE` 에러의 기술적 배경을 분석하고, 이를 해결하기 위한 논리적/물리적 복구 절차(Recovery Procedure)의 공학적 원리를 상세히 기술한다.
#
# ---
#
# ## 2. 에러 발생 메커니즘: `ACS_ERROR_WHILE_NAVIGATING_THE_ROUTE`
#
# ### 2.1. 공간 데이터의 추상화와 주행 불가 영역
# ACS(Automated Control System)의 WEB 인터페이스 상에서 시각화되는 맵은 크게 두 가지 영역으로 구분된다.
# 1.  **정상 주행 경로(Colored Line):** AMR이 SLAM(Simultaneous Localization and Mapping) 알고리즘을 통해 자기 위치를 인식하고, 글로벌 경로 계획(Global Path Planning)을 수립할 수 있도록 사전에 정의된 **노드(Node)와 엣지(Edge)의 집합**이다.
# 2.  **주행 불가 영역(White Background):** 맵 데이터 상에서 '장애물(Obstacle)'로 정의되거나, 경로 비용(Cost)이 무한대로 설정된 **미정의 공간(Undefined Space)**이다.
#
# ### 2.2. 경로 생성 알고리즘의 실패 원리
# 관리자가 WEB ACS를 통해 AMR에 `Move` 명령을 내리면, 시스템은 현재 로봇의 위치($P_{start}$)와 목표 지점($P_{goal}$) 사이의 최적 경로를 탐색한다(주로 A* 또는 Dijkstra 알고리즘 변형 사용).
#
# 이때, 관리자가 실수로 **주행 불가 영역(흰색 배경)**을 $P_{goal}$로 지정할 경우, 경로 계획 알고리즘은 목표 지점의 **비용 지도(Cost Map)** 값을 조회한다. 해당 좌표가 '이동 불가능(Non-traversable)'으로 마킹되어 있거나 위상학적 그래프와 연결성이 끊겨 있을 경우, 알고리즘은 유효한 경로 해(Solution)를 도출할 수 없다.
#
# 이 논리적 연산 실패는 즉시 예외(Exception) 처리되며, 시스템은 `ACS_ERROR_WHILE_NAVIGATING_THE_ROUTE`라는 에러 코드를 반환하여 운영자에게 "목표 좌표가 주행 알고리즘의 허용 범위를 벗어났음"을 알린다.
#
# ---
#
# ## 3. 시스템 복구 전략: 논리적 리셋과 물리적 보정
#
# 이 에러는 하드웨어 고장이 아닌 **논리적 명령 오류**에 해당하므로, 시스템의 상태(State)를 초기화하고 로봇의 물리적 위치를 보정하는 두 단계의 절차가 요구된다.
#
# ### 3.1. 논리적 교착 상태 해제 (Job Cancel)
# 잘못된 좌표가 입력된 상태에서 시스템은 해당 명령을 수행하기 위해 지속적으로 경로 재탐색(Re-planning)을 시도하거나, 에러 상태(Error State)에 락(Lock)이 걸리게 된다. 자동 복구(Auto Recovery) 기능이 실패한다는 것은 소프트웨어적인 재시도만으로는 불가능한 영역(Unreachable Area)임을 의미한다.
#
# 따라서 운영자는 WEB ACS 상단의 **[Job Cancel]** 버튼을 클릭하여 다음의 내부 로직을 수행해야 한다:
# 1.  **명령 큐(Command Queue) 플러시(Flush):** 현재 수행 불가능한 `Move` 명령을 메모리에서 강제 삭제한다.
# 2.  **상태 머신 리셋:** AMR과 ACS의 통신 상태를 '에러(Error)'에서 '대기(Idle)' 상태로 전환하여 새로운 명령을 수신할 준비를 마친다.
#
# ### 3.2. 물리적 위치 보정 (Manual JOG Operation)
# 논리적 리셋이 완료되었더라도, 만약 AMR이 관성이나 이전의 잘못된 주행 시도로 인해 경로를 이탈해 있다면 자율 주행을 재개할 수 없다. AMR의 자율 주행 엔진은 **"로봇이 정의된 경로(Colored Line) 상의 허용 오차 범위 내에 위치할 때"**만 활성화되도록 안전 설계(Fail-safe)가 되어 있기 때문이다.
#
# 따라서 운영자는 **수동 조작(JOG 모드)**을 활성화하여 다음의 공학적 조치를 취해야 한다:
# *   **수동 제어(Manual Override):** 자율 주행 알고리즘의 개입을 차단하고, 운영자가 모터의 구동을 직접 제어하여 로봇을 이동시킨다.
# *   **경로 복귀(Return to Path):** 로봇을 **정상 주행 경로(색상이 있는 라인)** 위로 물리적으로 이동시킨다. 이는 로봇의 LiDAR나 카메라 센서가 맵 상의 특징점(Feature)을 다시 포착하고, 자신의 위치 확률 분포(Localization Probability)를 수렴시키기 위함이다.
#
# ### 3.3. 정상 운용 재개
# AMR이 정상 경로(Colored Line) 위에 위치하여 자기 위치 인식(Localization) 신뢰도가 확보되면, 시스템은 다시 자율 주행 준비 상태가 된다. 이때 운영자는 **일반 경로 상의 유효한 지점**을 목적지로 선택하여 `Move` 명령을 재발행함으로써, 중단되었던 물류 흐름을 정상화한다.
#
# ---
#
# ## 4. 결론 및 요약
#
# `ACS_ERROR_WHILE_NAVIGATING_THE_ROUTE`는 시스템의 결함이 아니라, **정의되지 않은 공간으로의 이동 명령을 차단하는 방어적 로직**의 결과이다. 엔지니어는 이 에러가 발생했을 때 단순한 재시작이 아닌, **[명령 취소(Job Cancel) -> 수동 경로 복귀(JOG to Path) -> 유효 명령 재발행(Re-command)]**이라는 일련의 인과적 절차를 준수해야 한다. 이는 자율주행 시스템의 데이터 무결성을 유지하고, 예측 불가능한 영역에서의 로봇 오작동을 방지하는 필수적인 운영 프로토콜이다.
# 2026-01-05 14:56:18.050 | INFO     | __main__:<module>:17 - 18 텍스트북 생성 완료
# 2026-01-05 14:56:18.051 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# 1T AMR이 물리적으로 지정된 주행 경로를 벗어난 상태에서 주행을 시도할 경우 [80002] ERROR_NOT_ON_PATH가 발생한다.
#
# 자동 복구 실패 시, WEB ACS에서 Job Cancel을 클릭하여 작업을 취소한 후 현장에서 1T AMR을 수동 또는 JOG 조작을 통해 정상 주행 경로 내부로 이동시킨다.
#
# 수동 조작이 완료된 후에는 WEB ACS에서 CALL-RETRY 버튼을 클릭하거나 1T AMR의 모드를 AUTO로 전환하여 작업을 재개한다.
# 2026-01-05 14:56:51.342 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: 자율주행 로봇의 경로 이탈 메커니즘 및 복구 프로토콜
#
# ## 1. 서론: 자율주행 시스템의 위치 인식과 경로 추종
#
# ...
#
# ### 4.2. EQP와 HMI의 상호작용
# **EQP(Equipment)**는 물리적인 조립, 용접, 검사를 수행하는 장비 본체를 의미하며, 그 내부는 PLC와 서보 모터, 로봇 암 등으로 구성됩니다.
#
# *   **인간-기계 인터페이스 (EQP HMI):** 작업자는 **EQP HMI(Human-Machine Interface)**를 통해 장비 내부의 보이지 않는 데이터에 접근합니다. HMI는 PLC의 메모리 주소를 시각화하여 터치 패널에 표시합니다. 작업자가 HMI에서 'Start' 버튼을 누르면, 이는 PLC의 특정 비트를 '1'로 변경(Write)하는 통신 행위이며, PLC는 이 변화를 감지하여 물리적 구동을 시작합니다.
#
# ---
#
# ## 5. 품질 관리 로직: OK와 NG의 결정론
#
# 자동화 시스템에서 품질 판정은 모호함이 없는 이진(Binary) 논리를 따릅니다.
#
# *   **상태 판정 알고리즘:** 센서 데이터나 비전 검사 결과가 사전에 설정된 임계값(Threshold) 범위 내에 들어오면 시스템은 해당 제품이나 장비 상태를 **OK(Good)**로 마킹합니다. 반면, 범위를 벗어나면 즉시 **NG(Not Good)** 플래그를 세웁니다.
# *   **인과적 대응:**
#     *   **OK 신호:** 다음 공정으로의 이송 컨베이어를 가동하거나, AMR에게 이송 명령을 하달합니다.
#     *   **NG 신호:** 즉시 라인을 정지시키거나(Interlock), 불량품을 별도의 배출구(Reject Station)로 분기시키는 로직을 수행합니다. 이는 불량품이 후속 공정으로 유입되어 더 큰 비용 손실을 초래하는 것을 방지하는 **Fail-Safe** 설계의 일환입니다.
#
# ---
#
# **결론적으로**, BMA/BSA 공정은 MCS의 계획, ACS의 물류 제어, PLC의 실시간 연산, 그리고 AMR과 EQP의 물리적 구동이 유기적으로 결합된 시스템입니다. 엔지니어는 단순한 에러 코드의 확인을 넘어, 이러한 데이터의 흐름과 물리적 인과관계를 입체적으로 파악하여 시스템을 운영해야 합니다.
# 2026-01-05 15:23:28.930 | INFO     | __main__:<module>:17 - 61 텍스트북 생성 완료
# 2026-01-05 15:23:28.931 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# 도킹 전 트래픽 발생 시 창고(Warehouse) 문제로 인해 AMR이 이동 중 멈추거나 경로가 막힌 경우, 수동 조작이 필요한 상황에서 작업자는 AMR의 Job Cancel을 실행하고 AMR을 주행 경로 밖으로 이동시킨 후, 창고 문제가 해결되면 다시 AMR을 주행 경로 안으로 복귀시켜 상태를 Before Docking으로 변경한다.
# 2026-01-05 15:23:49.064 | INFO     | __main__:<module>:10 - BMA 공정 자동화 시스템 기술 백서 (Technical Whitepaper)
#
# ---
#
# ### **교착 상태(Deadlock) 회피 및 예외적 트래픽 제어 메커니즘: 도킹 전 단계(Pre-Docking Phase)를 중심으로**
#
# **개요 (Overview)**
#
# BMA(Battery Module Assembly) 공정 내 물류 흐름은 고도로 정밀한 시공간적 동기화(Spatio-temporal Synchronization)를 전제로 설계된다. 특히 AMR(Autonomous Mobile Robot)이 목표 스테이션에 진입하여 물리적 결합을 시도하는 '도킹(Docking)' 단계 직전은 시스템의 병목 현상이 발생하기 가장 쉬운 임계 구간이다. 본 절에서는 창고(Warehouse) 시스템의 비정상적 상태나 물리적 장애물로 인해 AMR의 주행 경로(Path planning)가 차단되었을 때 발생하는 트래픽 혼잡(Traffic Congestion) 상황을 공학적으로 분석하고, 이를 해소하기 위한 수동 개입(Manual Intervention) 및 시스템 복구 프로토콜의 논리적 타당성을 서술한다.
#
# #### **1. 트래픽 발생의 인과 관계 및 시스템적 영향 (Causality of Traffic Congestion)**
#
# AMR의 자율 주행 알고리즘은 기본적으로 동적 장애물 회피(Dynamic Obstacle Avoidance) 기능을 포함하고 있으나, 공정 내 도킹 구역은 협소한 공간 특성상 회피 기동이 제한되는 '단일 경로(Single Path)' 구간이 많다.
#
# *   **창고(Warehouse) 시스템과의 연동성:** AMR은 상위 관제 시스템(ACS/MCS)으로부터 지령을 받아 창고 입출고 포트로 이동한다. 이때 창고 설비의 기계적 오류나 재고 데이터 불일치로 인해 입고 대기열(Queue)이 해소되지 않을 경우, 후속 AMR들은 목표 지점에 도달하지 못한 채 주행 경로 상에서 정지하게 된다.
# *   **교착 상태(Deadlock)의 형성:** 다수의 AMR이 좁은 통로에서 연쇄적으로 정지하면, 로컬 경로 계획(Local Path Planning) 알고리즘만으로는 해결 불가능한 교착 상태에 빠진다. 이는 단순히 로봇이 멈추는 것을 넘어, 전체 공정의 사이클 타임(Cycle Time)을 지연시키는 치명적인 결과를 초래한다. 따라서 시스템은 자동 복구가 불가능하다고 판단될 때, 운영자의 개입을 요청하는 예외 처리 루틴(Exception Handling Routine)으로 전환된다.
#
# #### **2. 작업 취소(Job Cancel) 및 물리적 격리 (Physical Isolation)**
#
# 교착 상태를 해소하기 위한 첫 번째 단계는 시스템의 논리적 연결을 끊고 물리적 공간을 확보하는 것이다.
#
# *   **Job Cancel의 논리적 의미:** 운영자가 실행하는 'Job Cancel' 명령은 단순한 정지가 아니다. 이는 상위 관제 시스템(ACS)과 해당 AMR 간에 맺어진 '작업 할당 세션(Task Assignment Session)'을 강제로 종료(Terminate)하는 행위다. 이 명령이 수행되면 AMR은 현재 수행 중이던 미션 데이터(목표 좌표, 적재 정보 등)를 초기화하고, 관제 시스템은 해당 로봇을 '유휴(Idle)' 상태로 인식하여 트래픽 계산에서 제외한다.
# *   **경로 이탈(Off-Path)의 필요성:** 논리적 연결이 끊긴 AMR은 여전히 물리적으로 주행 경로를 점유하고 있다. 후속 차량의 통행을 보장하고 창고 문제 해결을 위한 작업 공간을 확보하기 위해, 운영자는 수동 조작(Manual Control)을 통해 AMR을 주행 경로 밖의 안전 구역(Safety Zone)으로 이동시켜야 한다. 이는 네트워크상의 데이터 흐름을 정리함과 동시에 물리적 병목을 해소하는 이중적 조치이다.
#
# #### **3. 시스템 복구 및 상태 재동기화 (System Recovery & Resynchronization)**
#
# 창고 측의 문제가 해결(예: 설비 리셋, 장애물 제거)된 후, AMR을 다시 자동화 공정에 투입하기 위해서는 정교한 상태 복구 절차가 요구된다.
#
# *   **물리적 복귀(Physical Return):** AMR을 다시 주행 경로 안으로 진입시키는 과정이다. 이때 중요한 것은 AMR의 위치 인식 센서(Lidar/Camera)가 자신의 위치를 정확히 파악할 수 있는 '특징점(Feature Point)'이 풍부한 구역으로 복귀시켜야 한다는 점이다. 이는 SLAM(Simultaneous Localization and Mapping) 알고리즘이 로봇의 전역 좌표(Global Coordinate)를 신속하게 재계산하도록 돕는다.
# *   **상태 변경(State Transition) - Before Docking:** 물리적 복귀만으로는 시스템이 자동으로 작업을 재개하지 않는다. 운영자는 AMR의 상태를 명시적으로 **'Before Docking'**으로 변경해야 한다.
#     *   **Why 'Before Docking'?** 이 상태 값은 AMR의 제어권이 수동 모드에서 다시 시스템의 자동 제어 모드로 넘어갔음을 알리는 트리거(Trigger) 역할을 한다. 또한, 시스템에게 "이 로봇은 도킹 직전 단계까지의 미션을 이미 수행했거나, 수행할 준비가 되었으므로 즉시 도킹 시퀀스를 시작하라"는 논리적 플래그(Flag)를 전달한다.
#     *   **재진입 로직:** 'Before Docking' 상태가 입력되면, AMR은 현재 위치에서 도킹 스테이션까지의 잔여 경로를 재계산하고, 관제 시스템은 해당 로봇을 다시 트래픽 관리 네트워크에 등록하여 작업을 재개한다.
#
# **결론 (Conclusion)**
#
# 도킹 전 트래픽 발생 시 수행되는 일련의 수동 조작 절차는 단순한 임시방편이 아니다. 이는 **[논리적 세션 종료(Job Cancel)] -> [물리적 공간 확보(Move Out)] -> [환경 정상화] -> [물리적 복귀(Move In)] -> [논리적 상태 재설정(Set to Before Docking)]**으로 이어지는 체계적인 '장애 복구 알고리즘(Failover Algorithm)'의 인간 개입 버전이다. 엔지니어는 이 절차를 통해 자동화 시스템의 한계를 보완하고, 공정의 연속성을 유지할 수 있다.
# 2026-01-05 15:23:49.066 | INFO     | __main__:<module>:17 - 62 텍스트북 생성 완료
# 2026-01-05 15:23:49.067 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# 0.3T AMR(Box Conveyor)이 도킹 후 에러를 발생시켰으나 도킹 상태가 정상(Docking OK)인 경우, 작업자는 0.3T AMR HMI 메인 화면에서 RESUME 버튼을 클릭하여 복구를 시도한다.
#
# 자동 복구 실패 시, 0.3T AMR의 1차 초기화를 위해 설비의 Work Reset을 수행한 후 AMR의 Job Cancel, Error Reset, Door Close를 순차적으로 진행하고 상태를 After Docking으로 변경한다.
#
# 1차 초기화 후에도 문제가 해결되지 않을 경우, 0.3T AMR의 2차 완전 초기화를 위해 설비의 Call Create Pause를 ON으로 설정하고 Call Cancel 및 Work Reset을 수행하며, AMR의 Job Cancel과 Error Reset을 실행한다.
#
# 2차 완전 초기화 후 작업 전 단계(Before Work)에서 수동 조작이 필요한 경우, 0.3T AMR의 상태를 After Docking으로 설정하고 공급 미션은 MS25(회수 포트)로, 회수 미션은 복귀(Go back)로 지정한 뒤 설비 라인을 점검하고 Call Create Pause를 OFF로 전환한다.
#
# 2차 완전 초기화 후 작업 중 단계(In Work)에서 수동 조작이 필요한 경우, 0.3T AMR의 박스 위치 점검과 도어 닫기를 수행한 후 Payload 값을 수동으로 설정한다.
#
# 작업 중 단계에서 0.3T AMR에 적재된 박스가 빈 박스(Empty Box)인 경우, MS25 Unload를 수행하고 Auto 모드로 전환하여 복귀 절차를 진행한다.
#
# 작업 중 단계에서 0.3T AMR에 실물 박스가 적재되어 있거나 박스가 없는 경우(Full Box or Nothing), 즉시 창고 복귀(Go Back)를 수행하고 설비의 Call Create Pause를 OFF로 변경하여 라인을 재개한다.
# 2026-01-05 15:24:34.565 | INFO     | __main__:<module>:10 - # BMA 공정 내 0.3T AMR 도킹 시퀀스 및 예외 상황 복구 메커니즘에 관한 심층 분석
# **Deep Analysis on Docking Sequence and Exception Recovery Mechanism of 0.3T AMR in BMA Process**
#
# ---
#
# ## 1. 서론: 이종 시스템 간 핸드쉐이킹(Handshaking)과 비동기적 오류의 본질
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 물류 자동화 핵심인 0.3T AMR(Box Conveyor Type)은 물리적 공간에서의 이동뿐만 아니라, 상위 관제 시스템(ACS/MCS) 및 설비 PLC와의 끊임없는 데이터 교환을 통해 작동한다. 특히 AMR이 설비와 물리적으로 결합하는 **도킹(Docking)** 단계는 기구적 정밀도와 통신 프로토콜의 정합성(Integrity)이 동시에 요구되는 임계 구역(Critical Section)이다.
#
# 본 챕터에서는 0.3T AMR이 도킹 프로세스 중 겪을 수 있는 논리적 교착 상태(Deadlock)와 이를 해소하기 위한 단계별 복구 전략(Resume, 1st/2nd Initialization)의 공학적 원리를 규명한다. 단순한 에러 소거가 아닌, 시스템의 **상태 머신(State Machine) 동기화** 관점에서 복구 절차를 재해석한다.
#
# ---
#
# ## 2. 과도 응답 오류와 상태 재동기화 (Transient Error & Resynchronization)
#
# ### 2.1. 현상 분석: 물리적 도킹 성공과 논리적 에러의 괴리
# 0.3T AMR이 설비와 도킹을 완료하여 물리적 정렬(Alignment)이 완벽하고 센서(Lidar 또는 Magnetic Guide) 상으로도 `Docking OK` 신호가 확인되었음에도 불구하고, 시스템이 에러를 송출하는 현상은 주로 **통신 레이턴시(Latency)**나 **신호 디바운싱(Debouncing)** 실패에 기인한다.
#
# *   **발생 원리:** AMR과 설비 PLC 간의 핸드쉐이킹 과정에서, 설비의 `Ready` 신호와 AMR의 `In-Position` 신호가 교차 검증되어야 하는 타임 윈도우(Time Window) 내에 패킷 손실이나 일시적 노이즈가 발생할 경우, 안전 로직(Safety Logic)은 이를 '불확실한 상태'로 간주하여 에러를 트리거한다.
# *   **복구 메커니즘 (RESUME):** 운영자가 HMI의 `RESUME` 버튼을 클릭하는 행위는 단순한 재시작이 아니다. 이는 PLC와 AMR의 통신 버퍼를 플러시(Flush)하지 않고, 현재의 센서 값을 기반으로 **상태 검증 로직(State Validation Logic)을 재수행(Re-polling)**하도록 강제하는 인터럽트 신호다. 즉, 물리적 상태가 정상이므로 논리적 상태를 물리적 상태에 맞춰 동기화시키는 과정이다.
#
# ---
#
# ## 3. 1차 초기화: 로컬 제어권 회수 및 강제 상태 천이 (Local Reset & State Transition)
#
# `RESUME`을 통한 재동기화가 실패했다는 것은 일시적 통신 오류를 넘어, AMR 내부의 태스크 매니저(Task Manager)와 설비 PLC의 시퀀스가 서로 다른 단계(Step)를 가리키고 있는 **시퀀스 불일치(Sequence Mismatch)** 상태임을 의미한다. 이때는 `1차 초기화`를 통해 양측의 시퀀스를 강제로 정렬해야 한다.
#
# ### 3.1. 설비와 로봇의 순차적 리셋 (Sequential Reset)
# *   **설비 Work Reset:** 우선적으로 설비 측의 작업을 리셋한다. 이는 설비가 AMR에게 자재를 이재(Transfer)하거나 신호를 보내려는 시도를 중단시켜, AMR이 독립적으로 제어 가능한 상태(Idle)가 되도록 **인터락(Interlock)을 해제**하는 과정이다.
# *   **AMR Job Cancel & Error Reset:** 이후 AMR의 잔여 작업(Job)을 취소하여 메모리 상의 주행 경로 및 작업 큐(Queue)를 소거한다. 이는 로봇을 논리적인 '무부하(No Operation)' 상태로 만든다.
#
# ### 3.2. 물리적 안전 확보와 상태 강제 할당
# *   **Door Close:** 에러 상태에서 개방되었을 수 있는 도어를 닫는 것은 단순한 정리가 아니다. 이는 AMR의 주행 안전 회로(Safety Circuit)를 폐쇄(Close)하여, 다음 명령 시 즉각적인 모터 구동이 가능하도록 **하드웨어적 준비(Ready)**를 마치는 단계다.
# *   **State: After Docking:** 시스템은 AMR의 상태를 강제로 `After Docking`으로 변경한다. 이는 도킹 진입(Docking In)이나 작업 중(In Work) 단계에서 꼬여버린 로직을 건너뛰고, "이미 도킹 후 작업이 끝난 상태"라고 시스템에 선언함으로써, 다음 시퀀스(출차 또는 복귀)로 넘어가기 위한 **논리적 바이패스(Logical Bypass)** 기법이다.
#
# ---
#
# ## 4. 2차 완전 초기화: 글로벌 트래픽 격리 및 미션 재할당 (Global Isolation & Mission Reassignment)
#
# 1차 초기화로도 해결되지 않는 경우, 이는 해당 AMR뿐만 아니라 상위 관제 시스템(ACS)의 할당 로직까지 얽혀있는 심각한 교착 상태다. 따라서 `2차 완전 초기화`는 개별 로봇을 넘어 **전체 라인의 트래픽 흐름(Traffic Flow)** 관점에서 접근해야 한다.
#
# ### 4.1. 호출 생성 차단 (Call Create Pause ON)의 중요성
# 이 단계의 핵심은 `Call Create Pause`를 `ON`으로 설정하는 것이다.
# *   **Why?** 문제가 발생한 AMR을 초기화하는 동안, ACS가 해당 설비나 로봇에게 새로운 작업(Call)을 지속적으로 할당하려 하면 **경쟁 상태(Race Condition)**가 발생한다.
# *   **Mechanism:** 신규 호출 생성을 차단함으로써, 해당 구역을 논리적으로 **격리(Isolation)**시킨다. 이는 네트워크상의 '방화벽'과 유사한 역할로, 오류가 전파되거나 복구 중인 로봇에 중복 명령이 하달되는 것을 원천 봉쇄한다.
#
# ### 4.2. 완전 소거 (Call Cancel & Work Reset)
# 격리된 상태에서 `Call Cancel`과 `Work Reset`을 수행하는 것은, 상위 시스템(MCS/ACS)에 등록된 해당 로봇의 모든 트랜잭션 ID를 삭제하는 **하드 리셋(Hard Reset)**이다. 이는 데이터베이스 상에서 해당 작업 건을 완전히 들어내어, 시스템이 해당 로봇을 '새로운 가용 자원'으로 인식하게 만든다.
#
# ---
#
# ## 5. 수동 조작 시나리오별 동역학적/논리적 대응 전략
#
# 2차 초기화 후, AMR은 자신의 위치나 적재 상태에 대한 정보(Context)를 소실한 상태일 수 있다. 따라서 엔지니어는 현재의 물리적 상황(작업 전/중, 박스 유무)에 따라 AMR의 **페이로드(Payload) 파라미터**와 **목적지 노드(Node)**를 재설정해야 한다.
#
# ### 5.1. 작업 전(Before Work) 단계의 경로 최적화
# 작업을 수행하기 전 에러가 발생했다면, 자재의 흐름을 결정해야 한다.
# *   **MS25 (회수 포트) vs. Go Back:**
#     *   시스템은 수동 조작 시 `After Docking` 상태를 부여하여 로봇이 즉시 이동 가능하게 한다.
#     *   이때 공급 미션은 `MS25`로 지정되는데, 이는 공정 라인에 투입되지 못한 자재를 회수 포트로 보내는 **예외 처리 경로(Exception Path)**다.
#     *   회수 미션은 `Go Back`으로 지정하여, 불필요한 자재 이동 없이 대기 장소로 복귀시켜 가동률(Availability)을 확보한다.
# *   **라인 재개:** 모든 조치 후 `Call Create Pause`를 `OFF`로 전환하여, 격리되었던 트래픽 제어권을 다시 활성화한다.
#
# ### 5.2. 작업 중(In Work) 단계와 페이로드(Payload) 데이터 무결성
# 작업 도중 에러가 발생했다면, 가장 중요한 것은 **'AMR이 현재 무엇을 들고 있는가?'**를 시스템에 알리는 것이다.
# *   **Payload 수동 설정의 공학적 의미:** AMR의 주행 알고리즘은 적재 중량에 따라 가감속 프로파일(Acceleration Profile)과 제동 거리(Braking Distance)를 다르게 계산한다. 초기화로 인해 Payload 값이 `0` 또는 `Null`이 된 상태에서 실물 박스를 싣고 주행하면, 관성 모멘트(Moment of Inertia) 불일치로 인해 정지 정확도가 떨어지거나 전복 사고가 발생할 수 있다. 따라서 박스 유무를 육안 확인 후 Payload 값을 수동 입력하여 **데이터 무결성(Data Integrity)**을 복구해야 한다.
#
# ### 5.3. 적재 상태에 따른 분기 로직 (Branching Logic)
# *   **Empty Box (빈 박스)인 경우:**
#     *   빈 박스는 공정상 가치가 없거나 회수 용기일 가능성이 높다. 따라서 `MS25 Unload`를 수행하여 라인 밖으로 배출하고, `Auto` 모드로 전환하여 스스로 복귀하도록 한다. 이는 **폐루프(Closed Loop) 자재 순환**을 유지하기 위함이다.
# *   **Full Box or Nothing (실물 박스 또는 없음)인 경우:**
#     *   실물 박스가 있거나 아예 없는 경우, 불확실성을 제거하기 위해 즉시 `Go Back`을 수행한다.
#     *   실물 박스가 있는 상태에서의 `Go Back`은 자재의 재투입이나 품질 검사를 위한 창고 복귀를 의미하며, 박스가 없는 경우의 `Go Back`은 다음 작업을 위한 빠른 가용성 확보를 의미한다.
#     *   이 과정은 설비의 `Call Create Pause`를 `OFF`로 변경하여 전체 라인의 **택트 타임(Takt Time)** 손실을 최소화하는 것으로 마무리된다.
#
# ---
#
# ## 6. 결론
#
# 0.3T AMR의 에러 복구 절차는 단순한 버튼 조작의 나열이 아니다. 이는 **(1) 센서와 로직의 재동기화(Resume), (2) 로컬 제어기의 상태 강제 천이(1st Init), (3) 글로벌 트래픽 격리 및 트랜잭션 소거(2nd Init)**로 이어지는 계층적 방어 전략(Layered Defense Strategy)이다. 엔지니어는 각 단계에서 발생하는 데이터의 흐름과 물리적 기구부의 상태 변화를 정확히 이해함으로써, 시스템의 가동 중단(Downtime)을 최소화하고 BMA 공정의 연속성을 보장할 수 있다.
# 2026-01-05 15:24:34.566 | INFO     | __main__:<module>:17 - 63 텍스트북 생성 완료
# 2026-01-05 15:24:34.567 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# 1T AMR(Pallet Lift)의 도킹 성공 후 제품(SKID)이 있는 상태에서 트러블 슈팅이 해결되지 않을 경우, 설비 PLC 및 센서를 점검하고 1T AMR의 리프트를 작업 전 상태로 상하 구동하여 초기화한 뒤 설비 Work Reset과 AMR의 Job Cancel, Error Reset, After Docking 설정을 순차적으로 수행한다.
#
# 1T AMR(Pallet Lift)의 도킹 성공 후 제품(SKID)이 없는 상태에서 설비(Product Line) 측 문제로 에러가 발생한 경우, 설비의 Call Create Pause를 활성화하고 Call Cancel과 Work Reset을 수행한 뒤 AMR의 Job Cancel, Error Reset, After Docking 처리를 거쳐 라인 점검 후 Call Create Pause를 해제한다.
#
# 1T AMR(Pallet Lift)의 도킹 성공 후 제품(SKID)이 없는 상태에서 창고(Warehouse) 측 문제로 에러가 발생한 경우, 수동 조작이 필요한 상황으로 간주하여 보전반을 호출한다.
#
# 1T AMR(Pallet Lift)의 도킹 상태 확인 결과 도킹에 실패한 경우, [4.1. 도킹 실패 및 센서 에러] 섹션에 명시된 조치 절차를 수행한다.
#
# 1T AMR(Pallet Lift)의 도킹 성공 후 제품(SKID)이 감지되었으나 자동 복구에 실패하여 AMR 센서 이상이 확인된 경우, [5.2 센서 점검] 가이드에 따라 조치한다.
# 2026-01-05 15:25:16.748 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: 1T AMR(Pallet Lift) 예외 처리 및 복구 메커니즘
#
# ## 1. 서론: 이종 시스템 간의 핸드쉐이킹(Handshaking)과 상태 동기화
#
# BMA(Battery Module Assembly) 공정의 효율성은 물류의 혈관 역할을 하는 AMR(Autonomous Mobile Robot)과 각 공정 설비(Equipment) 간의 정밀한 협업에 달려 있습니다. 특히 1T급 고하중 Pallet Lift AMR은 물리적인 리프팅(Lifting) 동작과 논리적인 작업 지시(Job Order)가 결합된 복합 시스템입니다.
#
# 본 챕터에서는 AMR이 설비와 도킹(Docking)을 성공적으로 수행한 시점, 즉 **'물리적 결합'이 완료된 상태에서 발생하는 예외 상황(Exception)**들을 다룹니다. 이때 발생하는 에러는 단순한 기계적 고장이 아니라, 상위 관제 시스템(ACS/MCS), 설비 PLC, 그리고 AMR 내부 컨트롤러 간의 **상태 불일치(State Mismatch)**에서 기인하는 경우가 많습니다. 따라서 복구 절차는 물리적 기구의 초기화와 논리적 신호의 동기화를 순차적으로 수행하여 시스템의 무결성을 확보하는 데 목적이 있습니다.
#
# ---
#
# ## 2. 적재 상태(Loaded State)에서의 교착 상태(Deadlock) 해결 알고리즘
#
# ### 2.1. 물리적/논리적 복합 에러의 발생 메커니즘
# 1T AMR이 도킹에 성공하고 제품(SKID)을 적재하고 있는 상황은 시스템적으로 가장 민감한 상태입니다. AMR은 수백 kg에 달하는 배터리 모듈을 리프트 상부에 얹고 있으며, 이는 AMR의 무게 중심(Center of Gravity)과 관성 모멘트에 변화를 줍니다.
#
# 이 상태에서 트러블 슈팅이 실패한다는 것은, AMR 내부의 주행 제어기(Navigation Controller)와 리프트 제어기(Lift Controller) 간의 통신이 두절되었거나, 설비 PLC와의 인터락(Interlock) 신호가 'High' 상태로 고착(Latching)되었음을 의미합니다.
#
# ### 2.2. 리프트 구동을 통한 센서 재보정 (Sensor Recalibration)
# 복구의 첫 단계로 **'리프트를 작업 전 상태로 상하 구동하여 초기화'**하는 과정이 필수적입니다. 이는 단순한 기계적 움직임이 아닙니다.
# *   **엔코더(Encoder) 영점 보정:** 리프트 모터의 위치 제어 엔코더 값이 노이즈로 인해 틀어졌을 가능성을 배제하기 위해, 물리적 리미트 스위치(Limit Switch)를 다시 트리거하여 Z축의 절대 좌표를 재설정합니다.
# *   **하중 분산 확인:** 리프트를 상하로 구동함으로써 SKID가 AMR의 상판에 올바르게 안착되었는지, 편하중(Unbalanced Load)으로 인한 모터 과부하가 없는지 전류 센서 값을 통해 간접적으로 검증합니다.
#
# ### 2.3. 순차적 논리 리셋 (Sequential Logical Reset)
# 물리적 초기화 후에는 **[설비 Work Reset] → [AMR Job Cancel] → [Error Reset] → [After Docking]**의 순서로 논리적 복구를 수행합니다. 이 순서는 데이터 흐름의 인과관계에 기반합니다.
# 1.  **설비 Work Reset:** 설비 PLC가 가지고 있는 '작업 중' 상태를 해제하여, 설비가 AMR을 붙잡고 있는 논리적 족쇄(Interlock)를 풉니다.
# 2.  **AMR Job Cancel:** 상위 시스템(MCS)으로부터 할당받은 작업 ID(Task ID)를 소거하여, AMR이 더 이상 잘못된 명령을 수행하려 시도하지 않도록 합니다.
# 3.  **Error Reset & After Docking:** 내부 에러 레지스터를 비우고(Clear), AMR의 상태를 '도킹 완료 직후'의 대기 상태로 강제 천이(State Transition)시킵니다.
#
# > **Note:** 만약 제품이 감지되었으나 자동 복구에 실패하고, AMR 자체 센서(예: 포토 센서, 근접 센서)의 하드웨어적 이상이 확인될 경우, 소프트웨어 리셋은 무의미합니다. 이 경우 **[5.2 센서 점검]** 가이드에 따라 하드웨어 교체 또는 배선 점검을 수행해야 합니다.
#
# ---
#
# ## 3. 공(Empty) 상태에서의 설비 및 창고 측 에러 처리 프로토콜
#
# AMR이 도킹에 성공했으나 제품(SKID)이 없는 상태, 즉 '픽업(Pick-up) 직전' 또는 '언로딩(Unloading) 직후'의 에러는 발생 원인이 **설비(Product Line)**냐 **창고(Warehouse)**냐에 따라 대응 로직이 완전히 분리됩니다.
#
# ### 3.1. 설비(Product Line) 측 문제: 호출 신호 제어 (Call Signal Throttling)
# 설비 라인에서 에러가 발생한 경우, 가장 큰 위험은 고장 난 설비가 계속해서 AMR을 호출(Call)하는 **'좀비 콜(Zombie Call)'** 현상입니다. 이를 방지하기 위해 다음과 같은 방어 로직이 작동합니다.
#
# 1.  **Call Create Pause 활성화:** 이는 네트워크 레벨에서의 '차단(Blocking)' 동작입니다. 설비 PLC가 ACS/MCS로 보내는 작업 요청 신호 생성을 일시적으로 중단시켜, 불필요한 트래픽과 추가적인 AMR 배차를 막습니다.
# 2.  **Call Cancel & Work Reset:** 이미 생성된 잘못된 호출을 취소하고 설비의 상태를 초기화합니다.
# 3.  **AMR 복구 (Job Cancel -> Error Reset -> After Docking):** AMR을 대기 상태로 되돌립니다.
# 4.  **라인 점검 후 Pause 해제:** 설비의 물리적/소프트웨어적 문제가 완전히 해결된 것이 확인된 후에만 `Call Create Pause`를 해제하여 정상적인 물류 흐름을 재개합니다.
#
# ### 3.2. 창고(Warehouse) 측 문제: 인적 개입(Human-in-the-loop)의 필요성
# 반면, 창고 측에서 발생한 에러는 자동 복구를 시도하지 않고 **'보전반 호출(Manual Intervention)'**을 원칙으로 합니다. 그 이유는 다음과 같습니다.
# *   **WMS 데이터 무결성:** 창고는 WMS(Warehouse Management System)와 연동되어 재고(Inventory) 데이터를 관리합니다. 현장에서 임의로 리셋을 수행할 경우, 실물은 없는데 전산상에는 재고가 존재하는 **'유령 재고(Phantom Inventory)'** 문제가 발생할 수 있습니다.
# *   **비정형 환경:** 창고는 라인 설비보다 환경 변화(적재물의 틀어짐, 파렛트 파손 등)가 심해, 센서만으로는 상황을 완벽히 인지하기 어렵습니다. 따라서 엔지니어의 인지적 판단이 필요한 영역으로 분류됩니다.
#
# ---
#
# ## 4. 도킹 실패 및 정밀 주행(Navigation) 오류
#
# AMR이 도킹 위치에 도달했으나, 최종적으로 **도킹 실패(Docking Failure)** 판정을 받는 경우는 주로 위치 인식(Localization)의 오차에서 기인합니다.
#
# *   **원인 분석:** 1T AMR은 라이다(LiDAR)와 바닥의 QR/V-Marker 등을 융합하여 위치를 추정합니다. 도킹 실패는 AMR의 실제 위치와 맵(Map) 상의 좌표 간 오차가 허용 공차(Tolerance, 통상 ±10mm 이내)를 벗어났음을 의미합니다.
# *   **대응:** 이 경우 무리한 재진입은 설비와의 충돌을 유발할 수 있으므로, 즉시 정지 후 **[4.1. 도킹 실패 및 센서 에러]** 섹션의 절차를 따릅니다. 이는 주로 주변 환경의 변화(장애물 등)로 인한 라이다 매칭률 저하를 점검하는 과정을 포함합니다.
#
# ---
#
# ## 5. 결론
#
# 1T AMR의 에러 조치 프로세스는 단순한 '재부팅'이 아닙니다. 이는 **물리적 기구의 안전 확보(Safety)**, **상위 시스템과의 데이터 동기화(Synchronization)**, 그리고 **공정 전체의 흐름 제어(Flow Control)**가 유기적으로 연결된 공학적 알고리즘입니다. 엔지니어는 각 조치 단계가 시스템 아키텍처 내에서 어떤 레이어(Layer)를 건드리고 있는지 명확히 이해하고 작업을 수행해야 합니다.
# 2026-01-05 15:25:16.750 | INFO     | __main__:<module>:17 - 64 텍스트북 생성 완료

# %%
with open("amr_guide_textbook_merged.json", "w", encoding="utf-8") as f:
    json.dump(resuls, f, ensure_ascii=False, indent=4)

# %%
for i, x in enumerate(acs_alarm_preprocessed):
    context = x['preprocessed']
    user_prompt = f"""챕터 번호는 없어도 돼.

[입력 텍스트]
{context}"""
    logger.info(user_prompt)
    response = llm_client.generate(system_prompt=STEP_1_2_SYNTHETIC_TEXTBOOK_PROMPT, chat_messages=[{"role": "user", "content": user_prompt}])
    result = response.choices[0].message.content
    logger.info(result)

    json_result = {
        'id': i,
        'preprocessed_group': context,
        'textbook': result
    }
    result2.append(json_result)
    logger.info(f"{len(result2)} 텍스트북 생성 완료")
# Out:
# 2026-01-05 15:26:36.122 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# BMA 공정 AMR의 [10000] RFID 감지 안됨(RFID not detected) 경고는 주행 경로상의 RFID 태그 인식이 불가능한 상태를 의미한다. **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 AMR의 정지 위치를 확인하고 RFID 리더기와 태그의 정렬 상태를 점검해야 한다.
#
# BMA 공정 AMR의 [10001] 리프트 미션 실패(Lift mission fail) 경고는 팔레트 상하강 동작이 지정된 시간 내에 완료되지 않았음을 나타낸다. **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 리프트 구동부의 기계적 간섭 여부를 확인한 후 HMI를 통해 리프트 위치를 초기화해야 한다.
#
# BMA 공정 AMR의 [10002] 턴테이블 미션 실패(Turntable mission fail) 경고는 상단 턴테이블의 회전 동작이 정상 범위 내에서 종료되지 않았을 때 발생한다. **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 턴테이블의 회전 반경 내 이물질을 제거하고 수동 모드에서 원점 복귀를 수행해야 한다.
#
# BMA 공정 AMR의 [10003] 도킹 중 장애물 감지(Obstacle detected during docking) 경고는 설비 진입 및 도킹 과정에서 안전 센서가 물체를 감지하여 주행이 중단된 상태를 의미한다. **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 도킹 경로상의 장애물을 제거한 후 주행 재개 버튼을 조작해야 한다.
#
# BMA 공정 AMR의 [10004] 거치대 도킹 실패(Wing docking fail) 경고는 AMR이 윙(Wing) 타입 거치대와의 물리적 결합 위치 정밀도 확보에 실패했음을 나타낸다. **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 거치대의 정위치 이탈 여부를 확인하고 AMR을 후진시킨 후 재도킹을 시도해야 한다.
# 2026-01-05 15:27:30.743 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: AMR 미션 크리티컬 에러와 복구 메커니즘 분석
# **Technical Whitepaper: Mission Critical Errors & Recovery Mechanisms in BMA AMR Systems**
#
# ---
#
# ## 1. 서론: 결정론적 시스템에서의 예외 처리 (Exception Handling in Deterministic Systems)
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정 내 AMR(Autonomous Mobile Robot)은 단순한 운송 수단이 아닌, 상위 관제 시스템(ACS/MCS)과 실시간으로 데이터를 교환하며 물리적 작업을 수행하는 **사이버-물리 시스템(CPS)**의 핵심 에지(Edge) 디바이스입니다.
#
# 본 챕터에서는 AMR 운용 중 발생하는 주요 미션 실패 코드([10000] ~ [10004])를 시스템 아키텍처 관점에서 재해석합니다. 단순한 현상 서술을 넘어, 각 에러가 발생하는 공학적 원인(Root Cause), 센서 및 액추에이터의 상호작용, 그리고 시스템이 자동 복구(Auto-Recovery)에 실패하여 수동 개입(Manual Intervention)을 요구하게 되는 논리적 임계점에 대해 심층적으로 기술합니다.
#
# ---
#
# ## 2. 위치 추정 및 내비게이션 정합성 상실 (Localization Integrity Loss)
#
# ### 2.1. [10000] RFID 감지 안됨 (RFID not detected)
# **[현상]** 주행 경로상에 매설된 RFID 태그를 AMR이 인식하지 못하고 지나치거나, 인식 범위 내에서 신호를 획득하지 못함.
#
# **[아키텍처 및 작동 원리 분석]**
# AMR의 자율 주행은 기본적으로 휠 엔코더(Wheel Encoder)와 IMU(관성측정장치)를 이용한 추측 항법(Dead Reckoning)에 의존하지만, 이는 주행 거리가 누적될수록 오차(Drift)가 발생합니다. 이를 보정하기 위해 바닥에 매설된 RFID 태그는 **절대 좌표(Absolute Coordinate)** 기준점 역할을 수행합니다.
#
# 1.  **트리거 메커니즘:** AMR의 내비게이션 알고리즘은 맵 데이터(Map Data)에 정의된 좌표 $(x, y)$ 근방에 도달하면 RFID 리더기를 활성화(Active) 상태로 전환하고 태그의 고유 ID를 스캔합니다.
# 2.  **실패 원인 (Physics):**
#     *   **전자기적 간섭:** BMA 공정 내 고전압 케이블이나 모터 구동부에서 발생하는 노이즈가 RF 신호의 S/N비(Signal-to-Noise Ratio)를 저하시킨 경우.
#     *   **기구적 오차:** AMR의 횡방향(Lateral) 주행 오차가 리더기의 안테나 감지 패턴(Antenna Lobe) 범위를 벗어난 경우.
#     *   **타이밍 불일치:** AMR의 주행 속도가 태그의 데이터 전송 속도(Baud rate) 대비 과도하게 빨라 핸드쉐이킹(Handshaking)이 완료되기 전 통신 영역을 이탈한 경우.
# 3.  **논리적 교착 상태:** 시스템은 "특정 좌표 도달 시 태그 ID $N$이 읽혀야 한다"는 조건을 만족하지 못했으므로, 현재의 추측 항법 위치 데이터를 신뢰할 수 없는 상태(Unreliable Localization)로 간주합니다. 이는 안전을 위해 즉각적인 주행 중단(Halt)으로 이어집니다.
#
# **[복구 프로토콜의 공학적 의미]**
# 자동 재시도(Retry)가 불가능한 이유는 AMR이 자신의 정확한 위치를 '모르는' 상태에서 이동하는 것이 충돌 위험을 야기하기 때문입니다.
# *   **운영자 개입:** 운영자가 AMR의 물리적 위치를 확인하고 리더기와 태그를 정렬하는 행위는, 시스템의 **위치 추정 오차(Estimation Error)를 0으로 강제 리셋(Hard Reset)**하여 내비게이션 알고리즘의 신뢰도를 회복시키는 과정입니다.
#
# ---
#
# ## 3. 키네마틱 액추에이션 및 피드백 제어 실패 (Kinematic Actuation & Feedback Control Failure)
#
# ### 3.1. [10001] 리프트 미션 실패 (Lift mission fail)
# **[현상]** 배터리 모듈 팔레트의 상하강(Z축) 동작이 타임아웃(Timeout) 내에 완료되지 않음.
#
# **[아키텍처 및 작동 원리 분석]**
# 리프트 시스템은 모터(또는 유압)의 구동력과 엔코더/리미트 스위치(Limit Switch)의 피드백을 통한 **폐루프 제어(Closed-loop Control)** 시스템입니다.
#
# 1.  **제어 로직:** PLC는 리프트 모터에 구동 명령을 내리고, 동시에 타이머(Timer)를 시작합니다. 정상적인 경우, 상한(Upper) 또는 하한(Lower) 리미트 스위치로부터 신호(Signal 1)가 입력되면 모터를 정지하고 미션 완료를 선언합니다.
# 2.  **실패 원인 (Physics):**
#     *   **기계적 부하:** 리프트 가이드 레일의 마찰력 증가나 배터리 모듈의 하중이 모터의 정격 토크(Rated Torque)를 초과하여 구동 속도가 저하된 경우.
#     *   **센서 오류:** 물리적으로는 도달했으나, 리미트 스위치의 접점 불량이나 단선으로 인해 PLC가 완료 신호를 수신하지 못한 경우.
# 3.  **타임아웃 메커니즘:** 안전을 위해 설정된 $T_{max}$ 시간 내에 완료 신호가 없으면, 시스템은 이를 기구적 끼임(Jamming)이나 모터 과부하로 판단하여 전원을 차단하고 [10001] 에러를 송출합니다.
#
# **[복구 프로토콜의 공학적 의미]**
# *   **운영자 개입:** 기계적 간섭(Interference) 확인은 모터 소손을 방지하기 위한 필수 절차입니다. HMI를 통한 **위치 초기화(Position Initialization)**는 PLC 내부의 리프트 상태 레지스터를 초기값으로 되돌려, 불확실한 중간 위치(Intermediate Position)에서 발생할 수 있는 급발진이나 낙하 사고를 방지합니다.
#
# ### 3.2. [10002] 턴테이블 미션 실패 (Turntable mission fail)
# **[현상]** 상단 턴테이블의 회전(Theta축) 동작이 목표 각도에 도달하지 못하거나 정해진 시간 내에 종료되지 않음.
#
# **[아키텍처 및 작동 원리 분석]**
# 턴테이블은 배터리 모듈의 적재 방향을 변경하기 위한 회전체로, 관성 모멘트(Moment of Inertia)가 큰 부하를 제어해야 합니다.
#
# 1.  **제어 로직:** 서보 모터나 스텝 모터를 통해 특정 펄스(Pulse) 수만큼 회전을 지시합니다. 목표 각도 도달 여부는 엔코더 값이나 포지션 센서의 ON/OFF 상태로 판별합니다.
# 2.  **실패 원인 (Physics):**
#     *   **회전 반경 간섭:** 배터리 모듈이 정위치에 안착되지 않아 회전 시 주변 설비나 AMR 차체와 충돌하여 물리적으로 회전이 저지된 경우(Stall).
#     *   **백래시(Backlash) 및 기어 마모:** 동력 전달 기어의 유격으로 인해 모터는 회전했으나 실제 턴테이블이 목표 각도까지 도달하지 못한 경우.
# 3.  **시스템 반응:** 모터 드라이버는 과전류(Over-current)나 위치 오차(Position Error)가 임계치를 넘으면 보호 모드로 진입하며 PLC에 에러 플래그를 전송합니다.
#
# **[복구 프로토콜의 공학적 의미]**
# *   **운영자 개입:** 이물질 제거는 물리적 구속(Constraint)을 해제하는 과정입니다. **수동 모드 원점 복귀(Homing)**는 틀어진 회전축의 0점(Zero Point)을 센서를 통해 다시 찾아내어, 다음 공정 설비와의 도킹 시 각도 불일치로 인한 대형 사고를 예방하는 재보정(Recalibration) 절차입니다.
#
# ---
#
# ## 4. 안전 인터록 및 정밀 도킹 다이내믹스 (Safety Interlocks & Precision Docking Dynamics)
#
# ### 4.1. [10003] 도킹 중 장애물 감지 (Obstacle detected during docking)
# **[현상]** 설비 진입 및 도킹 시퀀스 수행 중 안전 센서(LiDAR, Safety Bumper 등)가 물체를 감지하여 비상 정지함.
#
# **[아키텍처 및 작동 원리 분석]**
# 도킹 과정은 AMR과 설비 간의 간격이 최소화되는 구간이므로, 충돌 위험이 가장 높습니다. 이 단계에서 안전 시스템은 **PL-d (Performance Level d)** 등급 이상의 높은 신뢰성을 요구합니다.
#
# 1.  **센싱 메커니즘:** LiDAR 센서는 ToF(Time of Flight) 방식을 이용해 주변 환경을 스캐닝하며, 도킹 모드에서는 평소 주행보다 더 좁고 정밀한 **보호 필드(Protective Field)**를 활성화합니다.
# 2.  **트리거 로직:** 보호 필드 내에 설정된 임계값(Threshold) 이상의 반사 신호가 감지되면, Safety PLC는 즉시 모터 구동부의 전력을 차단하는 **STO(Safe Torque Off)** 기능을 하드웨어적으로 트리거합니다. 이는 소프트웨어 연산 지연을 배제한 즉각적인 물리적 제동입니다.
# 3.  **실패 원인 (Physics):** 실제 장애물 외에도, 설비의 반사판 오염, 급격한 조도 변화, 또는 설비 구조물의 돌출부가 센서의 허용 오차 범위 내로 침범했을 때 발생할 수 있습니다.
#
# **[복구 프로토콜의 공학적 의미]**
# *   **운영자 개입:** 장애물 제거 후 주행 재개 버튼을 누르는 것은 Safety PLC에 걸려 있는 **래치(Latch) 상태를 해제(Reset)**하는 행위입니다. 시스템은 장애물이 제거되었음을 센서만으로 100% 확신할 수 없도록 설계되어 있으므로(센서 고장 가능성), 반드시 인간의 육안 확인(Human Verification)을 거쳐야만 STO가 해제되도록 안전 로직이 구성되어 있습니다.
#
# ### 4.2. [10004] 거치대 도킹 실패 (Wing docking fail)
# **[현상]** 윙(Wing) 타입 거치대와의 물리적 결합 시도 중 위치 정밀도(Position Accuracy) 확보 실패.
#
# **[아키텍처 및 작동 원리 분석]**
# 윙 도킹은 전력 충전이나 기구적 고정을 위해 AMR의 커넥터/래치와 스테이션의 수신부가 물리적으로 결합(Mating)하는 과정입니다.
#
# 1.  **정밀 제어 로직:** AMR은 비전 센서(V-Marker 인식)나 라인 센서를 통해 미세 주행(Micro-navigation) 모드로 진입합니다. 이때 허용되는 위치 오차는 수 mm 이내입니다.
# 2.  **실패 원인 (Physics):**
#     *   **기하학적 불일치:** 거치대가 충격 등으로 인해 원래 위치에서 미세하게 틀어졌거나(Displacement), AMR의 진입 각도(Heading Angle)가 허용 공차(Tolerance)를 벗어난 경우.
#     *   **결합력 부족:** 도킹 시 발생하는 기계적 저항을 이겨내지 못하고 휠이 미끄러지거나(Slip), 도킹 완료 센서(Proximity Sensor)가 활성화되지 않은 경우.
# 3.  **시스템 반응:** 도킹 시도 횟수 초과 또는 위치 보정 알고리즘의 수렴 실패 시, 시스템은 무리한 진입이 커넥터 파손을 유발할 수 있다고 판단하여 동작을 중단합니다.
#
# **[복구 프로토콜의 공학적 의미]**
# *   **운영자 개입:** AMR을 후진(Back-off)시키는 것은 **진입 벡터(Approach Vector)를 초기화**하는 것입니다. 잘못된 각도로 진입한 상태에서는 제자리 회전만으로 보정이 불가능하므로, 물리적 공간을 확보한 뒤 처음부터 다시 정렬(Re-alignment) 과정을 수행하여 기하학적 정합성을 확보해야 합니다.
#
# ---
#
# ## 5. 결론 (Conclusion)
#
# BMA 공정의 AMR 시스템에서 발생하는 [10000]~[10004] 에러 코드는 단순한 고장이 아니라, 시스템의 **물리적 한계(Physical Constraints)와 안전 무결성(Safety Integrity)을 보호하기 위한 방어 기제**입니다.
#
# 자동 복구가 실패하는 지점은 소프트웨어 알고리즘이 해결할 수 없는 물리적 불일치(센서 오차, 기구적 간섭, 안전 위협)가 발생한 임계점입니다. 따라서 엔지니어는 각 에러 코드 이면에 존재하는 **센서-제어기-액추에이터 간의 인과관계(Causality)**를 명확히 이해하고, 매뉴얼에 따른 조작이 단순한 버튼 누르기가 아닌 시스템의 상태(State)를 정상 궤도로 복귀시키는 공학적 절차임을 인지해야 합니다.
# 2026-01-05 15:27:30.743 | INFO     | __main__:<module>:18 - 8 텍스트북 생성 완료
# 2026-01-05 15:27:30.744 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# BMA 공정 AMR의 [10005] 충전 도킹 실패(Charge docking fail) 알람은 로봇이 충전 스테이션과의 물리적 결합에 실패했음을 의미한다. **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 로봇의 위치를 재조정하고 충전 단자의 정렬 상태를 확인해야 한다.
#
# BMA 공정 AMR의 [10006] 도킹아웃 중 충돌 방지 대기중(Waiting for collision protection during docking out) 상태는 로봇이 도킹 해제 후 이동 경로 상의 장애물을 감지하여 일시 정지한 상황을 나타낸다.
#
# BMA 공정 AMR의 [10007] 도킹 비정상 완료 감지됨(Docking completion WARN) 알람은 도킹 프로세스는 종료되었으나 센서 데이터가 정상 범위를 벗어난 불완전한 결합 상태임을 의미한다. **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 로봇과 스테이션의 도킹 상태를 육안으로 점검하고 재도킹을 수행해야 한다.
#
# BMA 공정 AMR의 [10008] 설비 인터락으로 인한 정지 상태(Stop-state due to facility interlocks)는 상위 제어 시스템이나 주변 설비로부터 정지 신호를 수신하여 로봇의 구동이 차단된 상태이다.
#
# BMA 공정 AMR의 [10009] 도킹 인지 실패(Docking shape recognition fail) 알람은 로봇의 비전 센서나 레이저 스캐너가 도킹 스테이션의 형상을 식별하지 못할 때 발생한다. **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 도킹 스테이션 마커의 오염 상태를 확인하고 센서의 이물질을 제거해야 한다.
# 2026-01-05 15:28:13.038 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: AMR 도킹 메커니즘 및 예외 처리 아키텍처
# **Technical Whitepaper: AMR Docking Mechanisms and Exception Handling Architecture in BMA Process**
#
# ---
#
# ## 1. 서론: 정밀 도킹 시스템의 공학적 중요성
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정에서 AMR(Autonomous Mobile Robot)은 단순한 물류 이송 수단을 넘어, 공정 간의 동기화를 책임지는 핵심 링크(Link) 역할을 수행한다. 특히 배터리 모듈의 중량과 전압 특성을 고려할 때, AMR의 충전 및 도킹(Docking) 프로세스는 마이크로미터(µm) 단위의 정밀 제어와 밀리초(ms) 단위의 통신 동기화가 요구되는 고난도 작업이다.
#
# 본 챕터에서는 AMR 운용 중 발생하는 주요 알람 코드([10005] ~ [10009])를 중심으로, 시스템이 물리적 환경을 인지하고 제어하는 **논리적 메커니즘(Logical Mechanism)**과 **데이터 흐름(Data Flow)**, 그리고 각 상황에서의 **공학적 인과관계**를 심층 분석한다.
#
# ---
#
# ## 2. 도킹 진입 및 형상 인식 알고리즘 (Docking Approach & Recognition)
#
# AMR이 충전 스테이션이나 작업 스테이션에 접근할 때, 가장 먼저 수행되는 프로세스는 목표 지점의 '인지'이다. 이 과정은 로봇의 위치 추정(Localization)과 환경 매핑(Mapping) 기술이 결합된 형태로 이루어진다.
#
# ### 2.1. [10009] 도킹 인지 실패 (Docking shape recognition fail)
# **[현상 분석]**
# 이 알람은 AMR의 내비게이션 컨트롤러가 비전 센서(Vision Sensor) 또는 2D/3D 라이다(Lidar)를 통해 수집한 포인트 클라우드(Point Cloud) 데이터에서 사전에 정의된 도킹 스테이션의 기하학적 형상(Shape)을 매칭하지 못했을 때 발생한다.
#
# **[작동 원리 및 인과관계]**
# 1.  **스캔 및 필터링:** AMR은 도킹 예상 지점에 접근하여 고해상도 스캔을 수행한다. 이때 센서는 반사된 레이저의 시간차(ToF: Time of Flight)나 이미지의 패턴을 분석한다.
# 2.  **패턴 매칭 알고리즘:** 수집된 데이터는 내부 메모리에 저장된 '레퍼런스 템플릿(Reference Template)'과 비교된다. 이 과정에서 V-Marker의 각도, 반사판(Reflector)의 강도(Intensity), 스테이션의 윤곽선이 허용 오차 범위 내에 들어와야 한다.
# 3.  **실패 트리거:** 만약 스테이션 마커에 오일 미스트(Oil Mist)나 먼지가 흡착되어 난반사가 발생하거나, 주변 조명의 간섭으로 인해 신호 대 잡음비(SNR)가 낮아지면 알고리즘은 매칭 신뢰도(Confidence Score)를 임계값 이하로 떨어뜨린다.
# 4.  **시스템 반응:** 로봇은 부정확한 좌표로 진입하여 발생할 수 있는 물리적 충돌을 방지하기 위해 즉시 정지하고 [10009] 알람을 송출한다.
#
# **[복구 메커니즘]**
# 시스템의 자동 재시도(Retry) 로직이 실패하여 수동 조작이 요구되는 경우, 이는 단순한 소프트웨어 리셋으로 해결될 수 없는 **물리적 신호 왜곡(Physical Signal Distortion)** 상태임을 시사한다. 따라서 운영자는 센서 표면과 마커의 오염을 제거하여 광학적 경로(Optical Path)를 복원해야 한다.
#
# ---
#
# ## 3. 물리적 결합 및 충전 핸드쉐이킹 (Physical Coupling & Handshaking)
#
# 형상 인식이 완료되면 AMR은 정밀 주행 모드로 전환하여 물리적 도킹을 시도한다. 이 단계에서는 기구학적 정렬과 전기적 연결이 동시에 이루어져야 한다.
#
# ### 3.1. [10005] 충전 도킹 실패 (Charge docking fail)
# **[현상 분석]**
# 로봇이 목표 좌표에 도달하여 도킹 동작을 수행했으나, 충전 스테이션과의 물리적 결합이 확정되지 않은 상태이다. 이는 기구적 체결 실패 또는 전기적 접촉 불량을 포괄한다.
#
# **[작동 원리 및 인과관계]**
# 1.  **접촉 시도:** AMR은 미세 구동을 통해 충전 단자(Contact Plate)에 접근한다. 이때 모터의 토크(Torque) 변화를 감지하여 물리적 접촉 여부를 1차 판단한다.
# 2.  **전기적 핸드쉐이킹:** 물리적 접촉 후, BMS(Battery Management System)와 충전기는 파일럿 신호(Pilot Signal)를 교환한다.
# 3.  **실패 트리거:**
#     *   **기구적 요인:** 바닥의 평탄도 문제나 로봇 서스펜션의 노후화로 인해 단자의 높이가 맞지 않아(Misalignment) 접촉 면적이 확보되지 않는 경우.
#     *   **전기적 요인:** 접촉 저항이 높아 전압 강하(Voltage Drop)가 발생하거나, 통신 타임아웃이 발생할 경우.
# 4.  **시스템 반응:** 충전 회로 보호를 위해 릴레이(Relay)를 차단하고 [10005] 알람을 발생시킨다.
#
# **[복구 메커니즘]**
# 자동 복구 실패 시, 운영자의 개입은 로봇의 **기구학적 좌표(Kinematic Coordinate)를 재설정**하는 과정이다. 로봇을 수동으로 이동시켜 정렬 상태를 물리적으로 보정한 후, 시스템이 영점(Zero Position)을 다시 인식하도록 유도해야 한다.
#
# ### 3.2. [10007] 도킹 비정상 완료 감지됨 (Docking completion WARN)
# **[현상 분석]**
# 도킹 프로세스 자체는 종료(Finish) 플래그가 섰으나, 센서 데이터가 '완벽한 성공'을 보증하지 못하는 **경계 상태(Marginal State)**이다.
#
# **[작동 원리 및 인과관계]**
# 1.  **논리적 모순:** 예를 들어, 충전 전류는 정상적으로 흐르기 시작했으나(전기적 성공), 로봇의 위치 센서는 정지 허용 범위를 약간 벗어난 값(기구적 경고)을 가리키는 경우 발생한다.
# 2.  **안전 마진(Safety Margin):** 시스템은 이를 즉각적인 에러(Error)로 처리하여 공정을 멈추기보다는, 경고(Warning)로 분류하여 상위 시스템에 보고한다. 그러나 장기적으로는 접점 부위의 발열이나 커넥터 손상을 유발할 수 있다.
# 3.  **시스템 반응:** 공정 효율을 위해 가동은 유지하되, [10007] 코드를 띄워 잠재적 위험을 알린다.
#
# **[복구 메커니즘]**
# 자동 복구가 불가능하다는 것은 센서 데이터의 불일치(Discrepancy)가 해소되지 않았음을 의미한다. 운영자는 육안 점검을 통해 로봇이 비스듬하게 도킹되었는지, 혹은 센서 자체가 드리프트(Drift) 되었는지를 판단하고 재도킹을 통해 데이터 정합성을 확보해야 한다.
#
# ---
#
# ## 4. 도킹 해제 및 동적 안전 제어 (Undocking & Dynamic Safety)
#
# 도킹 해제(Docking Out)는 정지 상태(Static)에서 이동 상태(Dynamic)로 전환되는 과정으로, 관성 및 주변 환경 변화에 가장 취약한 순간이다.
#
# ### 4.1. [10006] 도킹아웃 중 충돌 방지 대기중 (Waiting for collision protection during docking out)
# **[현상 분석]**
# AMR이 스테이션에서 후진하거나 빠져나오는 과정에서, 안전 센서(Safety Lidar/Bumper)가 장애물을 감지하여 주행을 '일시 정지(Pause)'한 상태이다. 이는 에러라기보다 **안전 기능의 정상 작동(Safety Function Activation)**으로 해석해야 한다.
#
# **[작동 원리 및 인과관계]**
# 1.  **사각지대 모니터링:** 도킹 스테이션 주변은 구조물로 인해 시야가 제한적이다. AMR은 도킹 해제 시 안전 감지 영역(Safety Zone)을 최대로 확장한다.
# 2.  **동적 감지:** 이동 경로 상에 작업자, 다른 AMR, 또는 적재물이 감지되면, Safety PLC는 모터 드라이버에 STO(Safe Torque Off) 신호를 보내 즉시 구동을 차단한다.
# 3.  **대기 상태:** 장애물이 제거되면 시스템은 자동으로 주행을 재개하려 시도하지만, 감지 상태가 지속되면 [10006] 상태를 유지하며 대기한다.
#
# ---
#
# ## 5. 상위 시스템 통합 제어 및 인터락 (System Integration & Interlocks)
#
# AMR은 독립적인 개체가 아니라, 전체 공장 자동화 시스템(Factory Automation System)의 일부로 작동한다.
#
# ### 5.1. [10008] 설비 인터락으로 인한 정지 상태 (Stop-state due to facility interlocks)
# **[현상 분석]**
# AMR 자체에는 하드웨어적 결함이 없으나, 외부 요인에 의해 구동이 강제로 차단된 상태이다. 이는 **제어 권한의 위계(Hierarchy of Control)**에서 상위 시스템이나 연동 설비가 AMR의 동작을 제한(Veto)했음을 의미한다.
#
# **[작동 원리 및 인과관계]**
# 1.  **신호 교환(Handshaking):** AMR은 이동 전 ACS(Activity Control System) 또는 MCS(Material Control System)와 통신하며 이동 허가(Permission)를 요청한다.
# 2.  **인터락 조건:**
#     *   **설비 동기화:** 목적지 설비가 아직 준비되지 않았거나(Not Ready), 도어가 열리지 않은 경우.
#     *   **안전 구역:** 화재 경보가 발생했거나, 해당 구역의 라이트 커튼(Light Curtain)이 침범되어 전체 라인이 비상 정지(EMG Stop)된 경우.
# 3.  **논리적 차단:** PLC 로직 상 `Move_Enable` 비트가 `False`로 전환되면, AMR은 현재 위치에서 대기 모드로 전환되고 [10008] 코드를 출력한다.
#
# **[시스템적 함의]**
# 이 알람은 시스템이 **교착 상태(Deadlock)**나 **연쇄 충돌**을 방지하기 위해 정상적으로 방어 기제를 작동하고 있음을 보여준다. 해결을 위해서는 AMR이 아닌, 인터락을 유발한 주변 설비나 상위 시스템의 상태를 점검해야 한다.
# 2026-01-05 15:28:13.039 | INFO     | __main__:<module>:18 - 9 텍스트북 생성 완료
# 2026-01-05 15:28:13.039 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# BMA 공정 AMR의 [10010] 알람은 도킹 프로세스 중 장애물 감지를 위한 3D 카메라와의 통신 연결이 실패했음을 의미한다.
#
# BMA 공정 AMR의 [10011] 알람은 도킹 시작 지점의 위치 오차가 허용 범위를 초과하여 발생한 경고 상태를 나타낸다.
#
# BMA 공정 AMR의 [10012] 알람은 도킹용 IR 센서가 감지되지 않아 시스템이 자동으로 도킹을 재시도하고 있는 상태를 의미한다.
#
# BMA 공정 AMR의 [10013] 알람은 설정된 제한 시간 내에 도킹 완료 신호가 수신되지 않아 도킹 시간 초과가 발생했음을 의미한다.
#
# BMA 공정 AMR의 [10014] 알람은 도킹 경로 상에서 장애물이 감지되어 주행이 일시 정지된 상태를 나타낸다.
# 2026-01-05 15:28:53.473 | INFO     | __main__:<module>:10 - # BMA 공정 내 AMR 도킹 정밀 제어 및 예외 처리 메커니즘 (Precision Control and Exception Handling Mechanisms for AMR Docking in BMA Processes)
#
# ## 1. 서론: 도킹 프로세스의 공학적 중요성
# 현대자동차그룹의 BMA(Battery Module Assembly) 공정에서 AMR(Autonomous Mobile Robot)의 도킹(Docking) 단계는 단순한 물류 이송의 종료가 아닌, 설비와 로봇 간의 물리적, 정보적 결합이 이루어지는 가장 임계(Critical)적인 구간입니다. 수백 킬로그램에 달하는 배터리 모듈을 이재(Transfer)하기 위해서는 밀리미터(mm) 단위의 정밀도가 요구되며, 이 과정에서 발생할 수 있는 모든 변수는 시스템의 안전 무결성 등급(Safety Integrity Level)에 따라 엄격하게 통제되어야 합니다. 본 백서는 AMR 도킹 시퀀스에서 발생하는 주요 알람 코드([10010] ~ [10014])를 통해, 시스템이 어떻게 오차를 감지하고 안전을 확보하는지 그 아키텍처를 심층 분석합니다.
#
# ---
#
# ## 2. 센서 네트워크 무결성 및 통신 레이어 분석
#
# ### [10010] 3D 카메라 통신 인터페이스 실패 (Communication Link Failure)
# **현상:** 도킹 프로세스 진입 시, 장애물 감지 및 심도(Depth) 측정을 담당하는 3D 카메라와의 연결이 소실됨.
#
# **기술적 분석 (Technical Analysis):**
# AMR의 도킹 구간은 설비와 로봇이 근접하는 공간이므로, 2D Lidar의 평면 스캔만으로는 돌출된 구조물이나 공중에 떠 있는 장애물을 감지하는 데 한계가 있습니다. 이를 보완하기 위해 3D 카메라(Stereo Vision 또는 ToF 방식)가 사용됩니다.
# 알람 **[10010]**은 물리적 센서 고장보다는 **데이터 링크 레이어(Data Link Layer) 또는 전송 레이어(Transport Layer)**에서의 핸드쉐이킹(Handshaking) 실패를 의미합니다.
#
# 1.  **Heartbeat 메커니즘:** 상위 제어기(Main Controller)는 3D 카메라에 주기적으로 상태 확인 신호(Heartbeat)를 전송합니다.
# 2.  **Timeout 발생:** 설정된 주기(예: 100ms) 내에 카메라로부터 ACK 신호가 수신되지 않거나, 패킷 손실률이 임계치를 초과할 경우 시스템은 이를 '통신 두절'로 간주합니다.
# 3.  **Fail-Safe 동작:** 시각 정보(Vision Data)가 없는 상태에서의 주행은 'Blind Navigation'으로 간주되어 위험하므로, 시스템은 즉시 도킹 시퀀스를 차단(Interlock)하고 해당 알람을 트리거합니다. 이는 USB 대역폭 포화나 이더넷 케이블의 노이즈 간섭으로 인해 발생할 수 있습니다.
#
# ---
#
# ## 3. 기구학적 위치 제어와 오차 보정
#
# ### [10011] 초기 진입 위치 오차 초과 (Initial Pose Deviation)
# **현상:** 도킹 시작 지점(Pre-docking Station)에 도착한 AMR의 좌표가 허용 공차(Tolerance) 범위를 벗어남.
#
# **작동 원리 (Mechanism):**
# AMR은 SLAM(Simultaneous Localization and Mapping) 또는 QR 코드를 통해 자신의 위치를 추정(Localization)합니다. 도킹을 시작하기 위해서는 로봇의 중심점 $(x, y)$과 헤딩 각도 $(\theta)$가 설비가 요구하는 진입 벡터와 일치해야 합니다.
#
# *   **오차 산출 로직:** $\Delta E = \sqrt{(x_{target} - x_{actual})^2 + (y_{target} - y_{actual})^2}$
# *   **각도 오차:** $\Delta \theta = |\theta_{target} - \theta_{actual}|$
#
# 알람 **[10011]**은 이 $\Delta E$ 또는 $\Delta \theta$ 값이 기구학적으로 보정 불가능한 수준(예: ±10mm 또는 ±2도 초과)일 때 발생합니다. 이 상태에서 도킹을 강행할 경우, AMR의 컨베이어와 설비의 컨베이어가 물리적으로 어긋나 배터리 모듈의 낙하(Drop)나 잼(Jam) 현상을 유발할 수 있습니다. 따라서 시스템은 진입 자체를 불허하고, 운영자에게 수동 개입이나 재위치(Relocalization) 명령을 요구하게 됩니다.
#
# ---
#
# ## 4. 광학 유도 시스템과 피드백 루프
#
# ### [10012] IR 센서 미감지 및 자동 재시도 (IR Signal Loss & Auto-Retry Logic)
# **현상:** 정밀 도킹을 위한 적외선(IR) 가이드 신호가 감지되지 않아, 시스템이 위치를 재조정하는 상태.
#
# **심층 분석 (Deep Dive):**
# Lidar나 카메라는 환경 인식에는 유리하지만, 도킹 직전의 'Last Mile' 정밀 유도에는 적외선(IR) 센서가 주로 사용됩니다. 설비 측의 IR 송신부(Transmitter)와 AMR 측의 수신부(Receiver)가 일직선상(Line of Sight)에 놓여야 합니다.
#
# 1.  **신호 강도(RSSI) 분석:** AMR은 수신된 IR 신호의 강도와 패턴을 분석하여 설비의 정중앙을 찾습니다.
# 2.  **재시도 알고리즘 (Retry Algorithm):** 알람 **[10012]**는 단순한 에러가 아니라, 시스템의 **자율 복구(Self-Healing) 프로세스**가 작동 중임을 나타냅니다.
#     *   *조건:* IR 신호가 노이즈로 인해 왜곡되거나 감지되지 않음.
#     *   *동작:* AMR은 현재 위치에서 후진(Back-off)하여 시야각(FOV)을 확보한 뒤, 다시 진입 경로를 탐색하는 루틴을 수행합니다.
#     *   *의의:* 이는 즉각적인 정지보다는 로봇 스스로 문제를 해결하려는 지능형 제어의 일환입니다. 단, 재시도 횟수가 설정값(예: 3회)을 초과하면 영구적인 에러로 전환됩니다.
#
# ---
#
# ## 5. 동적 장애물 감지와 안전 인터록
#
# ### [10014] 경로 상 장애물 감지 및 주행 정지 (Obstacle Detection & Safety Stop)
# **현상:** 도킹 경로(Trajectory) 상에 이물질이나 작업자가 감지되어 주행이 일시 정지됨.
#
# **안전 메커니즘 (Safety Mechanism):**
# 이 알람은 [10010]과 달리 센서는 정상 작동 중이며, 실제로 물리적인 위험 요소를 감지했을 때 발생합니다.
#
# 1.  **보호 영역(Protective Field)의 가변성:** AMR은 속도에 따라 안전 레이저 스캐너(Safety Laser Scanner)의 감지 영역을 동적으로 조절합니다. 도킹 중에는 저속이므로 감지 영역이 좁고 정밀해집니다.
# 2.  **STO (Safe Torque Off):** 장애물이 '정지 영역(Stop Zone)' 내에서 감지되면, 안전 PLC는 즉시 모터 드라이버의 전력을 차단하는 STO 기능을 트리거합니다. 이는 소프트웨어적인 정지가 아닌 하드웨어 레벨의 강제 차단으로, 관성에 의한 충돌까지 방지합니다.
# 3.  **자동 복귀 대기:** 장애물이 제거되면 센서는 이를 인지하고, 시스템은 다시 주행 가능 상태(Ready to Move)로 전환됩니다. 즉, [10014]는 에러라기보다는 **안전 기능의 정상적인 개입** 상태입니다.
#
# ---
#
# ## 6. 시계열 로직과 교착 상태 방지
#
# ### [10013] 도킹 시간 초과 (Docking Process Timeout)
# **현상:** 도킹 시작 후 설정된 제한 시간(Time Limit) 내에 완료 신호가 수신되지 않음.
#
# **논리적 인과관계 (Logical Causality):**
# 모든 자동화 시퀀스에는 교착 상태(Deadlock)를 방지하기 위한 **와치독 타이머(Watchdog Timer)**가 존재합니다. 도킹 프로세스는 `[진입] -> [정렬] -> [도킹 완료] -> [핸드쉐이크]`의 순차적인 상태 머신(State Machine)으로 구성됩니다.
#
# 1.  **타이머 트리거:** 도킹 시퀀스가 시작되는 순간(T=0), 내부 타이머가 카운트를 시작합니다.
# 2.  **지연 요인:** 바퀴의 미세한 슬립(Slip), 통신 지연, 기구적 마찰 등으로 인해 로봇이 목표 지점에 도달하지 못하고 제자리에서 미세 조정을 반복하는 경우가 발생할 수 있습니다.
# 3.  **강제 종료:** 만약 $T_{current} > T_{limit}$ (예: 60초)가 되면, 시스템은 무한 루프에 빠진 것으로 간주합니다. 배터리 소모와 모터 과열을 방지하고, 전체 공정의 병목(Bottleneck) 현상을 막기 위해 시스템은 작업을 강제 중단하고 **[10013]** 알람을 송출합니다. 이는 상위 관제 시스템(ACS)에 "해당 로봇은 자력으로 도킹을 완료할 수 없으니 관리자의 개입이 필요함"을 알리는 신호입니다.
# 2026-01-05 15:28:53.475 | INFO     | __main__:<module>:18 - 10 텍스트북 생성 완료
# 2026-01-05 15:28:53.475 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# BMA 공정 AMR의 [10015] 에러는 도킹 과정에서 IR 센서가 감지되지 않아 최종적으로 도킹에 실패했음을 의미한다.
#
# BMA 공정 AMR의 [10016] 경고는 충전 도킹 중 충전 센서가 감지되지 않아 도킹을 재시도하고 있는 상태를 나타낸다.
#
# BMA 공정 AMR의 [10017] 에러는 PLC(Programmable Logic Controller)가 리셋되었으나 진행 중인 작업(Job)이 정상적으로 취소되지 않았을 때 발생한다. **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 제어 시스템을 통해 잔여 작업을 강제로 종료하거나 초기화해야 한다.
#
# BMA 공정 AMR의 [10018] 정보는 설정된 충전 허용 시간을 초과하여 충전 타임아웃이 발생했음을 알린다.
#
# BMA 공정 AMR의 [20000] 정보는 주행 중 장애물 발생이나 경로 이탈로 인해 시스템이 주행 경로를 재생성하고 있는 상태를 의미한다.
# 2026-01-05 15:29:34.963 | INFO     | __main__:<module>:10 - # BMA 공정 자동화 시스템 기술 백서: AMR 제어 로직 및 예외 처리 메커니즘
# **Technical Whitepaper: AMR Control Logic & Exception Handling in Battery Module Assembly**
#
# ---
#
# ## 1. 서론: 정밀 제어와 시스템 안정성
# 현대자동차그룹의 BMA(Battery Module Assembly) 공정은 고중량의 배터리 모듈을 다루는 환경 특성상, AMR(Autonomous Mobile Robot)의 정밀한 주행 능력과 상위 제어 시스템(PLC/ACS) 간의 완벽한 동기화를 요구한다. 본 챕터에서는 AMR 운용 중 발생하는 주요 상태 코드(Status Code)와 에러(Error)를 단순한 '고장'이 아닌, **시스템 아키텍처(System Architecture)**, **센서 퓨전(Sensor Fusion)**, 그리고 **논리적 인과관계(Logical Causality)** 관점에서 심층 분석한다. 이를 통해 엔지니어는 시스템이 예외 상황을 어떻게 감지하고, 어떤 논리적 판단을 거쳐 안전 모드(Fail-safe)로 진입하는지 이해할 수 있다.
#
# ---
#
# ## 2. 정밀 도킹 시스템과 센서 피드백 루프 (Precision Docking & Sensor Feedback Loop)
#
# BMA 공정 내 AMR의 도킹(Docking) 작업은 일반 주행과 달리 밀리미터(mm) 단위의 정밀도를 요구하는 고난이도 시퀀스다. 이 과정에서 시스템은 SLAM(Simultaneous Localization and Mapping) 기반의 글로벌 위치 인식에서, 근거리 센서(IR, Vision 등)를 활용한 로컬 정렬 모드로 제어 권한을 이양(Handover)한다.
#
# ### 2.1. IR 센서 기반의 도킹 실패 메커니즘 [Error 10015]
# **[10015] 에러**는 AMR이 도킹 스테이션에 접근을 시도했으나, 최종 단계에서 **IR(Infrared) 센서 신호의 핸드쉐이킹(Handshaking)이 실패**하여 프로세스가 강제 종료된 상태를 정의한다.
#
# *   **작동 원리 (Mechanism):** AMR이 도킹 스테이션의 수 cm 이내로 진입하면, 로봇과 스테이션 간의 IR 송수신기가 서로를 인식(Line-of-Sight)해야 한다. 이는 물리적 접촉 이전에 정렬(Alignment)의 정확성을 검증하는 'Pre-contact' 단계다.
# *   **발생 원인 분석 (Root Cause Analysis):**
#     1.  **광학적 간섭:** 주변 조명이나 반사 재질로 인한 IR 신호의 노이즈(Signal-to-Noise Ratio 저하).
#     2.  **기하학적 오차:** AMR의 진입 각도(Yaw)나 횡방향(Lateral) 오차가 허용 공차(Tolerance)를 벗어나 IR 빔이 수신부(Receiver)에 도달하지 못함.
# *   **시스템 로직:** 시스템은 정해진 시간($T_{dock}$) 내에 유효한 IR 패턴이 수신되지 않으면, 물리적 충돌을 방지하기 위해 모터 구동을 즉시 차단하고 [10015] 에러를 송출한다. 이는 설비와 로봇의 하드웨어 파손을 막기 위한 능동적 안전장치다.
#
# ### 2.2. 충전 도킹의 재시도 알고리즘과 히스테리시스 [Warning 10016]
# **[10016] 경고**는 충전 도킹 시퀀스 중 **접촉 센서(Contact Sensor) 또는 충전 단자의 전압 감지 실패**로 인해 시스템이 **재시도(Retry) 루프**에 진입했음을 나타낸다.
#
# *   **논리적 흐름 (Logical Flow):**
#     1.  **접근:** AMR이 충전 스테이션에 접근하여 도킹을 시도한다.
#     2.  **검증 실패:** 충전 패드 접촉 시 기대되는 전기적 신호(Continuity)가 감지되지 않음.
#     3.  **재시도 로직 (Retry Logic):** 시스템은 즉시 에러를 띄우는 대신, 일시적으로 후진(Back-off) 후 재진입을 시도한다. 이는 미세한 기구적 유격이나 단자의 산화막 등으로 인한 일시적 접촉 불량을 해소하기 위한 알고리즘이다.
# *   **엔지니어링 관점:** 이 경고는 '실패'가 아닌 '보정 중'인 상태다. 제어기는 정해진 횟수($N_{retry}$)만큼 재시도를 수행하며, 이 과정에서 PID 제어기의 이득(Gain) 값을 미세 조정하여 정렬 정밀도를 높이려 시도한다.
#
# ---
#
# ## 3. 제어 시스템 간 동기화 및 상태 관리 (System Synchronization & State Management)
#
# AMR은 단독으로 작동하지 않으며, 상위 PLC 및 ACS(AMR Control System)와 끊임없이 통신하며 작업(Job)을 수행한다. 이 통신 과정에서의 상태 불일치는 심각한 논리적 오류를 야기할 수 있다.
#
# ### 3.1. PLC 리셋과 좀비 프로세스(Zombie Process) 처리 [Error 10017]
# **[10017] 에러**는 상위 제어기인 **PLC가 리셋(Power Cycle 또는 Logic Reset)되었음에도 불구하고, AMR 내부의 작업 큐(Job Queue)에 이전 작업이 잔존**하여 발생하는 상태 불일치(State Desynchronization) 현상이다.
#
# *   **인과관계 (Chain of Causality):**
#     1.  **조건:** AMR이 작업을 수행 중인 상황에서 PLC가 비정상 종료 후 재기동됨.
#     2.  **트리거:** PLC는 초기화되어 'Idle' 상태가 되었으나, AMR은 여전히 'Busy' 상태로 남아 있음.
#     3.  **충돌:** PLC가 새로운 명령을 내리거나 상태를 확인하려 할 때, AMR은 기존 작업의 완료 신호를 기다리는 교착 상태(Deadlock)에 빠짐.
# *   **복구 메커니즘의 한계:** 일반적인 통신 재연결로는 이 논리적 모순을 해결할 수 없다. 시스템의 자동 복구(Auto-recovery) 시도가 실패할 경우, 이는 **'좀비 작업(Zombie Job)'**이 되어 시스템 리소스를 점유한다.
# *   **대응 프로토콜:** 운영자는 ACS 또는 관제 UI를 통해 강제적으로 작업 취소(Job Cancel) 명령을 전송하여 AMR의 상태 레지스터를 초기화(Flush)해야 한다. 이는 제어권의 무결성을 회복하기 위한 필수적인 수동 개입 절차다.
#
# ---
#
# ## 4. 에너지 관리 및 배터리 안전 로직 (Energy Management & Safety)
#
# 리튬이온 배터리를 사용하는 AMR은 화재 예방과 배터리 수명 관리를 위해 엄격한 충전 프로파일을 따른다.
#
# ### 4.1. 충전 타임아웃과 열폭주 방지 [Info 10018]
# **[10018] 정보**는 설정된 **최대 충전 허용 시간($T_{max\_charge}$)을 초과**했음에도 목표 전압(Target Voltage)이나 전류(Cut-off Current)에 도달하지 못했을 때 발생한다.
#
# *   **공학적 배경 (Engineering Background):** 정상적인 CC-CV(Constant Current - Constant Voltage) 충전 곡선에서 배터리는 예측 가능한 시간 내에 완충되어야 한다.
# *   **타임아웃의 의미:** 시간이 초과되었다는 것은 배터리 셀의 내부 저항(Internal Resistance) 증가, 충전 효율 저하, 또는 충전 회로의 누설 전류 발생 가능성을 시사한다.
# *   **안전 로직 (Fail-safe):** 시스템은 이를 단순 지연으로 보지 않고, 잠재적인 **열폭주(Thermal Runaway)** 위험으로 간주하여 충전 프로세스를 강제 중단(Cut-off)한다. 이는 하드웨어 보호를 위한 최우선 논리다.
#
# ---
#
# ## 5. 자율 주행과 동적 경로 계획 (Autonomous Navigation & Dynamic Path Planning)
#
# BMA 공정은 작업자와 지게차, 타 설비가 혼재된 동적 환경(Dynamic Environment)이다. AMR은 고정된 레일이 아닌, 실시간으로 변화하는 환경에 적응해야 한다.
#
# ### 5.1. 실시간 장애물 회피와 경로 재생성 [Info 20000]
# **[20000] 정보**는 AMR의 **로컬 플래너(Local Planner)**가 주행 중 장애물을 감지하거나 경로 이탈(Path Deviation)을 확인하여, **새로운 궤적(Trajectory)을 연산 중인 상태**를 의미한다.
#
# *   **작동 원리 (How it works):**
#     1.  **감지:** Lidar 센서가 전방의 미확인 물체(Dynamic Obstacle)를 포인트 클라우드(Point Cloud) 형태로 인식한다.
#     2.  **비용 지도 업데이트:** 내비게이션 스택의 코스트맵(Costmap) 상에서 해당 위치의 주행 비용(Cost)을 무한대로 설정한다.
#     3.  **알고리즘 수행:** A* 또는 D* Lite와 같은 경로 탐색 알고리즘이 장애물을 우회하는 최적의 경로를 실시간으로 다시 계산(Replanning)한다.
# *   **시스템 상태:** 이 코드는 에러가 아니라, AMR이 환경 변화에 **지능적으로 대응하고 있음**을 나타내는 정상적인 상태 정보이다. 다만, 이 상태가 지속되면 병목 현상이 발생할 수 있으므로 관제 시스템은 해당 구역의 혼잡도를 모니터링해야 한다.
# 2026-01-05 15:29:34.965 | INFO     | __main__:<module>:18 - 11 텍스트북 생성 완료
# 2026-01-05 15:29:34.965 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# BMA 공정 AMR의 주행 시스템에서 발생하는 [20001] 에러는 현재 위치에서 목적지까지의 주행 경로 생성이 불가능한 상태를 의미한다.
#
# BMA 공정 AMR의 주행 시스템에서 발생하는 [20002] 에러는 일시적인 주행 제한이 설정되어 로봇의 이동이 차단된 상태를 나타낸다.
#
# BMA 공정 AMR의 주행 시스템에서 발생하는 [20003] 에러는 구동부 바퀴의 슬립(Slip) 현상이 감지되어 정상적인 주행 토크 전달이 어려운 상태를 의미한다.
#
# BMA 공정 AMR의 주행 시스템에서 발생하는 [20004] 상태는 주행 경로 상에 장애물이 감지되어 로봇이 안전을 위해 대기 중인 정보성 알림이다.
#
# BMA 공정 AMR의 주행 시스템에서 발생하는 [20005] 에러는 주행 제어 시스템 내부의 일반적인 경고(WARN) 상황이 발생했음을 의미한다.
# 2026-01-05 15:30:18.328 | INFO     | __main__:<module>:10 - # BMA 공정 자율주행 로봇(AMR)의 내비게이션 아키텍처 및 주행 제어 예외 처리 메커니즘 분석
#
# **작성자:** BMA 자동화 시스템 수석 아키텍트
# **문서 분류:** Technical Whitepaper / Navigation Control Subsystem
#
# ---
#
# ## 1. 개요 (Overview)
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정 내 도입된 AMR(Autonomous Mobile Robot)은 단순한 물류 이송 장치를 넘어, 복잡한 환경 변수 속에서 최적의 경로를 연산하고 스스로의 상태를 진단하는 지능형 에이전트입니다. 본 챕터에서는 AMR의 주행 제어 시스템(Navigation Control System)에서 발생하는 주요 상태 코드(20001~20005)를 중심으로, 로봇이 환경을 인지하고 경로를 생성하며 운동학적(Kinematic) 제어를 수행하는 내부 로직과 데이터 흐름을 심층적으로 분석합니다.
#
# 우리는 단순한 에러 코드의 정의를 넘어, **ACS(Agile Control System)**와 **AMR 로컬 컨트롤러** 간의 상호작용, 그리고 물리적 센서 데이터가 논리적 판단으로 변환되는 엔지니어링 메커니즘을 규명할 것입니다.
#
# ---
#
# ## 2. 경로 계획 및 토폴로지 무결성 (Path Planning & Topology Integrity)
#
# AMR의 자율 주행은 주어진 공간을 노드(Node)와 링크(Link)로 정의한 토폴로지 맵(Topology Map) 위에서 수행됩니다. 이 과정에서 발생하는 예외 상황은 주로 그래프 이론(Graph Theory)에 기반한 경로 탐색 알고리즘의 실패나 상위 관제 시스템의 개입에 기인합니다.
#
# ### 2.1. [20001] 경로 생성 실패 (Path Planning Failure)
# **[정의]** 현재 위치(Current Pose)에서 목표 위치(Target Goal)까지의 유효한 주행 경로를 생성할 수 없는 상태.
#
# **[메커니즘 및 인과관계 분석]**
# 이 에러는 AMR의 **Global Path Planner**가 A* 알고리즘 혹은 Dijkstra 알고리즘을 수행하는 과정에서 발생합니다.
# 1.  **초기화:** 상위 시스템(ACS/MCS)으로부터 목적지 좌표 $(x, y, \theta)$가 수신되면, AMR은 현재 자신의 위치를 시작 노드로, 목적지를 종료 노드로 설정합니다.
# 2.  **비용 함수(Cost Function) 연산:** 로봇은 맵 데이터베이스를 참조하여 이동 가능한 경로의 비용을 계산합니다. 이때, 물리적인 벽뿐만 아니라 '가상의 벽(Virtual Wall)'이나 '금지 구역(No-Go Zone)'도 무한대의 비용(Infinite Cost)으로 처리됩니다.
# 3.  **예외 발생 트리거:**
#     *   **고립된 노드(Isolated Node):** 현재 로봇이 위치한 노드와 목적지 노드 사이에 연결된 링크가 물리적/논리적으로 단절된 경우.
#     *   **맵 불일치(Map Discrepancy):** SLAM(Simultaneous Localization and Mapping)을 통해 인식된 현재 위치가 사전에 정의된 주행 가능 영역(Free Space)을 벗어난 경우(예: 로봇이 수동 조작으로 맵 밖으로 이동됨).
# 4.  **결과:** 알고리즘은 수렴하지 못하고 '경로 없음(Null Path)'을 반환하며, 시스템은 이를 [20001] 에러로 플래그(Flag) 처리하여 대기 상태로 전환합니다. 이는 로봇이 미지의 영역으로 진입하여 발생할 수 있는 충돌 사고를 방지하기 위한 논리적 안전장치입니다.
#
# ### 2.2. [20002] 주행 제한 및 교착 상태 방지 (Motion Restriction & Deadlock Prevention)
# **[정의]** 일시적인 주행 제한 설정으로 인한 이동 차단 상태.
#
# **[메커니즘 및 인과관계 분석]**
# [20001]이 로봇 내부의 연산 실패라면, [20002]는 **상위 관제 시스템(Fleet Management System)** 혹은 **외부 로직**에 의한 의도적인 제어 개입(Intervention)입니다.
# 1.  **트래픽 제어(Traffic Control):** BMA 공정은 다수의 AMR이 협업하는 환경입니다. 교차로(Intersection)나 병목 구간에서 교착 상태(Deadlock)를 방지하기 위해 관제 시스템은 특정 로봇에게 '일시 정지(Hold)' 신호를 보냅니다.
# 2.  **동적 구역 설정:** 유지보수나 긴급 상황으로 인해 특정 구역이 '일시적 차단 구역(Temporary Blocked Zone)'으로 설정될 수 있습니다.
# 3.  **로직 수행:** AMR의 주행 제어기는 목적지가 설정되어 있더라도, `Motion_Enable` 비트가 `False`로 마스킹(Masking) 되어 있는지 확인합니다. 이 비트가 비활성화된 경우, 로봇은 모터에 토크를 인가하지 않고 [20002] 코드를 송출하며 대기합니다. 이는 물리적 고장이 아닌, 시스템 전체의 흐름 효율성을 위한 **운영적 대기 상태**입니다.
#
# ---
#
# ## 3. 운동학적 제어 및 마찰공학 (Kinematics & Tribology)
#
# AMR의 이동은 바퀴와 지면 사이의 마찰력에 의존합니다. 정밀한 제어를 위해서는 모터의 회전수와 실제 이동 거리 간의 동기화가 필수적입니다.
#
# ### 3.1. [20003] 구동부 슬립 감지 (Wheel Slip Detection)
# **[정의]** 구동 휠의 회전량 대비 실제 이동 거리가 일치하지 않는 슬립(Slip) 현상 감지.
#
# **[메커니즘 및 인과관계 분석]**
# 이 에러는 **오도메트리(Odometry)**와 **관성 항법(Inertial Navigation)** 간의 데이터 융합(Sensor Fusion) 과정에서 발생하는 불일치를 진단합니다.
# 1.  **데이터 수집:**
#     *   **내부 센서:** 휠에 부착된 엔코더(Encoder)는 모터의 회전수($RPM$)를 측정하여 이론적인 이동 거리($D_{enc}$)를 계산합니다.
#     *   **외부 센서:** IMU(관성측정장치)의 가속도계와 자이로스코프, 그리고 Lidar의 스캔 매칭(Scan Matching)을 통해 실제 이동 거리($D_{act}$)와 회전각을 계측합니다.
# 2.  **비교 및 판단:** 제어 알고리즘은 실시간으로 두 값의 차이($\Delta = |D_{enc} - D_{act}|$)를 모니터링합니다.
# 3.  **물리적 원인:** 바닥에 유막(Oil), 물기, 혹은 이물질이 존재하여 마찰 계수($\mu$)가 급격히 낮아지거나, 로봇이 허용 하중을 초과하여 급가속할 때 휠은 헛돌게 됩니다.
# 4.  **트리거 및 안전 동작:** $\Delta$ 값이 사전에 설정된 임계값(Threshold)을 초과하면, 시스템은 이를 '슬립'으로 판정하고 [20003] 에러를 발생시킵니다. 동시에 **트랙션 제어(Traction Control)** 로직이 개입하여 모터 출력을 강제로 차단하거나 감속시켜, 로봇이 제어 불능 상태(Spin-out)에 빠지거나 위치 추정(Localization)을 상실하는 것을 방지합니다.
#
# ---
#
# ## 4. 인지 시스템 및 안전 레이어 (Perception & Safety Layer)
#
# BMA 공정은 작업자와 로봇이 공존하는 공간이므로, 충돌 방지를 위한 인지 시스템이 최우선으로 동작합니다.
#
# ### 4.1. [20004] 장애물 감지 및 대기 (Obstacle Detection & Wait)
# **[정의]** 주행 경로 상 장애물 감지로 인한 안전 대기 상태 (정보성 알림).
#
# **[메커니즘 및 인과관계 분석]**
# 이 코드는 에러(Error)라기보다는 시스템이 정상적으로 **안전 기능(Safety Function)**을 수행하고 있음을 나타내는 상태 정보입니다.
# 1.  **센싱(Sensing):** AMR 전후방에 장착된 2D/3D Lidar 센서는 주행 방향으로 레이저 펄스를 방사하여 ToF(Time of Flight) 방식으로 거리를 측정합니다.
# 2.  **동적 안전 필드(Dynamic Safety Field):** 로봇의 현재 속도($v$)에 비례하여 감지 영역(Protective Field)의 크기가 가변적으로 설정됩니다. 속도가 빠를수록 제동 거리가 길어지므로 감지 영역은 전방으로 길어집니다.
# 3.  **판단 로직:** 설정된 안전 필드 내에 포인트 클라우드(Point Cloud) 데이터가 감지되면(예: 작업자의 발, 적재된 자재 등), 상위 제어기는 즉시 **속도 프로파일(Velocity Profile)**을 0으로 수렴하도록 제어합니다.
# 4.  **결과:** 로봇은 정지 후 장애물이 사라질 때까지 대기하며 [20004] 상태를 유지합니다. 장애물이 제거되면 별도의 리셋 없이 자동으로 주행을 재개합니다. 이는 **PL(Performance Level) d 등급** 이상의 안전 규격을 만족하기 위한 필수적인 거동입니다.
#
# ---
#
# ## 5. 시스템 무결성 모니터링 (System Integrity Monitoring)
#
# ### 5.1. [20005] 주행 제어 시스템 일반 경고 (General System Warning)
# **[정의]** 주행 제어 시스템 내부의 일반적인 경고(WARN) 상황 발생.
#
# **[메커니즘 및 인과관계 분석]**
# [20005]는 치명적인 결함(Fatal Error)은 아니지만, 시스템의 안정성을 저해할 수 있는 잠재적 요소를 알리는 포괄적인 경고 코드입니다.
# 1.  **모니터링 대상:** CPU 부하율, 메모리 점유율, 내부 통신 버스(CAN/EtherCAT)의 간헐적인 패킷 손실, 혹은 비주기적인 센서 노이즈 등이 포함됩니다.
# 2.  **워치독(Watchdog) 메커니즘:** 시스템 내부의 헬스 체크(Health Check) 데몬이 백그라운드에서 실행되며, 각 모듈의 응답 시간을 측정합니다.
# 3.  **트리거:** 특정 모듈의 응답이 예상보다 지연되거나(Latency), 센서 데이터의 신뢰도(Confidence Score)가 일시적으로 하락했지만 주행 자체는 가능한 수준일 때 이 경고가 발생합니다.
# 4.  **대응:** 시스템은 이 이벤트를 로그(Log)에 기록하고 운영자에게 알림을 주지만, 로봇을 즉시 정지시키지는 않습니다(Fail-Operational). 단, 이 경고가 지속될 경우 상위 에러로 전이될 수 있으므로 예방 정비의 지표로 활용됩니다.
#
# ---
#
# ## 6. 결론 (Conclusion)
#
# BMA 공정 AMR의 주행 시스템 에러 코드(20001~20005)는 단순한 고장 신호가 아닙니다. 이는 **경로 계획(S/W) - 관제(Network) - 운동학(Physics) - 인지(Sensor) - 시스템 리소스(H/W)**의 각 레이어가 유기적으로 상호작용하며, 비정상 상황에서 시스템을 안전한 상태(Safe State)로 천이시키기 위한 고도화된 **방어 운전 로직(Defensive Driving Logic)**의 산물입니다. 엔지니어는 이 코드들의 인과관계를 이해함으로써, 단순한 리셋 조치를 넘어 근본적인 원인(Root Cause)을 분석하고 공정 효율을 최적화할 수 있습니다.
# 2026-01-05 15:30:18.330 | INFO     | __main__:<module>:18 - 12 텍스트북 생성 완료
# 2026-01-05 15:30:18.332 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# BMA 공정 AMR의 주행 중 비상 정지(Emergency) 스위치 또는 범퍼 센서가 물리적 접촉을 감지하면 20006 경고가 발생한다. **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 기구적 간섭 요인을 제거한 후 제어반의 복귀 스위치를 조작해야 한다.
#
# BMA 공정 AMR이 주행 경로상의 장애물이나 복잡한 지형으로 인해 경로 계산(Cost handling) 처리를 지연할 경우 20007 경고가 발생한다.
#
# BMA 공정 AMR의 주행 중 상단 턴테이블의 정렬 상태가 허용 범위를 벗어나 틀어지면 20008 경고가 발생한다.
#
# BMA 공정 AMR의 턴테이블 정렬 상태를 복구하기 위한 자동 보정 시퀀스가 정상적으로 완료되지 않으면 20009 경고가 발생한다. **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 HMI의 수동 조작 모드에서 턴테이블을 원점으로 복귀시켜야 한다.
#
# BMA 공정 AMR의 주행 중 장애물 감지를 담당하는 3D 카메라와의 통신 연결이 끊기거나 활성화에 실패하면 20010 경고가 발생한다.
# 2026-01-05 15:30:53.766 | INFO     | __main__:<module>:10 - # BMA 공정 자율주행 로봇(AMR)의 주행 안전성 및 제어 정밀도 확보 메커니즘
#
# ## 1. 서론: BMA 공정 내 AMR 시스템의 설계 철학
# 현대자동차그룹의 배터리 모듈 어셈블리(BMA, Battery Module Assembly) 공정은 고중량의 배터리 모듈을 다루는 환경 특성상, **물리적 안전(Physical Safety)**과 **제어 정밀성(Control Precision)**이 최우선 설계 요소로 고려된다. 본 백서는 BMA 공정 내 AMR(Autonomous Mobile Robot)이 주행 및 작업 수행 중 직면할 수 있는 예외 상황(Exception)을 시스템 아키텍처 관점에서 분석한다. 특히, 물리적 충돌 감지, 경로 계획 알고리즘의 부하, 기구학적 정렬 오차, 그리고 센서 네트워크의 무결성 확보 과정에서 발생하는 경고 코드(20006~20010)의 기술적 인과관계와 시스템의 대응 로직을 심층적으로 기술한다.
#
# ---
#
# ## 2. 물리적 안전 인터록(Safety Interlock) 및 하드웨어 제어 루프
# ### 2.1. 접촉 감지 및 비상 정지 메커니즘 (Code 20006)
# AMR의 주행 안전 시스템은 소프트웨어 레벨의 장애물 회피 알고리즘이 실패할 경우를 대비하여, 하드웨어 레벨의 **이중화된 안전 루프(Redundant Safety Loop)**를 갖추고 있다.
#
# *   **트리거 메커니즘 (Trigger Mechanism):**
#     AMR이 주행 중 예상치 못한 물체와 물리적으로 접촉하거나, 작업자의 판단에 의해 비상 정지(E-Stop) 스위치가 눌러질 경우, 시스템은 즉시 **20006 경고**를 발생시킨다. 이는 단순한 소프트웨어 정지 명령이 아니다. 범퍼 센서(Bumper Sensor) 내부의 압력 감지 스위치나 E-Stop 버튼의 접점이 개방(Open)되는 순간, 모터 드라이버로 공급되는 주 전력을 물리적으로 차단하는 **STO(Safe Torque Off)** 기능이 활성화된다. 이 과정은 PLC(Programmable Logic Controller)의 연산 주기보다 빠른 전기적 신호 차단으로 이루어지며, 관성에 의한 제동 거리를 최소화한다.
#
# *   **복구 로직 및 운영 프로토콜:**
#     20006 경고는 물리적 충돌 가능성을 내포하므로, 시스템은 **자동 복구(Auto-Reset)를 원천적으로 차단**하도록 설계되었다. 이는 "충돌 원인이 해소되지 않은 상태에서의 재기동"을 방지하기 위함이다.
#     1.  **물리적 간섭 제거:** 운영자는 반드시 현장을 육안으로 확인하고, 범퍼 센서를 압박하거나 주행을 방해하는 기구적 요소를 제거해야 한다.
#     2.  **하드웨어 리셋:** 제어반의 복귀 스위치 조작은 안전 릴레이(Safety Relay)의 래치(Latch) 상태를 해제하는 전기적 신호 인가 과정이다. 이 절차가 완료되어야만 모터 드라이버의 서보 온(Servo On) 준비 상태가 복원된다.
#
# ---
#
# ## 3. 자율 주행 알고리즘과 연산 부하 관리
# ### 3.1. 동적 경로 계획 및 비용 처리 지연 (Code 20007)
# AMR은 라이다(LiDAR)와 SLAM(Simultaneous Localization and Mapping) 기술을 기반으로 실시간 경로를 생성한다. 이때 주행 가능 영역과 장애물 영역은 그리드 맵(Grid Map) 상의 **비용(Cost)**으로 수치화된다.
#
# *   **알고리즘적 병목 현상 (Algorithmic Bottleneck):**
#     공정 내 물류 흐름이 복잡해지거나 비정형 장애물이 다수 출현할 경우, AMR의 **로컬 경로 계획기(Local Path Planner)**는 최적 경로를 찾기 위해 기하급수적인 연산을 수행하게 된다. 장애물 회피를 위한 후보 경로들의 비용 함수(Cost Function) 계산량이 CPU의 처리 한계(Time Budget)를 초과하여 실시간성을 보장할 수 없게 될 때, 시스템은 주행 안전을 위해 **20007 경고**를 발생시키고 제어를 중단한다.
#
# *   **시스템 보호 논리:**
#     이는 "잘못된 경로로 주행하는 것"보다 "멈추는 것"이 안전하다는 **Fail-Safe** 설계 원칙에 따른다. 즉, 20007 코드는 경로 계산 알고리즘이 수렴하지 못하고 발산하거나, 타임아웃(Timeout)이 발생했음을 알리는 시스템의 자기 방어 기제이다.
#
# ---
#
# ## 4. 기구학적 정밀도 및 서보 제어 시스템
# ### 4.1. 턴테이블 정렬 오차 및 피드백 제어 (Code 20008)
# BMA 공정의 AMR 상단에는 배터리 모듈의 적재 방향을 제어하는 턴테이블이 장착되어 있다. 이 턴테이블은 고정밀 엔코더(Encoder)를 통해 실시간 회전각을 피드백 받는다.
#
# *   **오차 발생 원인 (Physics of Deviation):**
#     주행 중 노면의 요철에 의한 진동이나 급가감속 시 발생하는 관성 모멘트(Moment of Inertia)가 턴테이블의 홀딩 토크(Holding Torque)를 초과할 경우, 기구적인 미세 슬립(Slip)이 발생할 수 있다. 시스템이 설정한 허용 공차(Tolerance) 범위를 벗어난 각도 틀어짐이 엔코더를 통해 감지되면, 상위 제어기는 이를 **20008 경고**로 분류한다. 이는 후속 공정인 로봇 암(Robot Arm)의 픽앤플레이스(Pick & Place) 작업 시 좌표 불일치로 인한 사고를 예방하기 위한 사전 차단 조치이다.
#
# ### 4.2. 자동 보정 시퀀스 실패 및 원점 복귀 (Code 20009)
# 20008 경고 발생 후, 또는 주기적인 유지보수 과정에서 시스템은 턴테이블의 정렬을 바로잡기 위한 **자동 보정 시퀀스(Auto-Calibration Sequence)**를 수행한다.
#
# *   **제어 루프 실패 분석:**
#     만약 턴테이블 구동 모터가 목표 위치(Target Position)로 이동하라는 지령을 받았음에도 불구하고, 기구적 끼임(Jamming)이나 센서 노이즈 등으로 인해 정해진 시간 내에 목표값에 도달하지 못하면(Settling Time 초과), 시스템은 **20009 경고**를 출력한다.
#
# *   **수동 복구 절차의 공학적 의미:**
#     자동 보정 실패는 폐루프 제어(Closed-loop Control)가 불가능한 상태를 의미하므로, 운영자의 개입이 필수적이다. HMI(Human-Machine Interface)를 통한 **수동 원점 복귀(Homing)** 명령은 엔코더의 카운터 값을 초기화하고, 기구적 원점 센서(Z-phase or Limit Switch)를 다시 탐색하게 하여 절대 좌표계를 재설정하는 과정이다.
#
# ---
#
# ## 5. 센서 네트워크 무결성 및 데이터 스트림 관리
# ### 5.1. 3D 비전 센서 통신 장애 (Code 20010)
# AMR의 전방 감시 및 장애물 심도(Depth) 인식을 담당하는 3D 카메라는 대용량의 포인트 클라우드(Point Cloud) 데이터를 실시간으로 전송해야 한다.
#
# *   **데이터 흐름 및 장애 감지 (Data Flow & Watchdog):**
#     메인 컨트롤러와 3D 카메라 간의 통신(주로 USB 3.0 또는 GigE 인터페이스 사용)은 엄격한 **하트비트(Heartbeat)** 신호로 모니터링된다. 케이블의 단선, 커넥터의 접촉 불량, 또는 카메라 내부 펌웨어의 프리징(Freezing)으로 인해 데이터 스트림이 끊기거나 초기화(Activation)에 실패할 경우, 시스템은 즉시 **20010 경고**를 발생시킨다.
#
# *   **안전 로직:**
#     3D 카메라의 기능 상실은 로봇의 '시각(Vision)' 일부가 소실된 상태, 즉 **블라인드 스팟(Blind Spot)**의 확장을 의미한다. 따라서 시스템은 이를 단순 통신 에러가 아닌 치명적인 안전 위협으로 간주하여, 로봇의 주행을 즉각 차단하고 센서 재연결을 요구하게 된다.
# 2026-01-05 15:30:53.768 | INFO     | __main__:<module>:18 - 13 텍스트북 생성 완료
# 2026-01-05 15:30:53.769 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# BMA 공정 AMR의 주행 중 후쿠요(Hokuyo) 장애물 감지 센서가 물체를 감지하면 시스템은 안전을 위해 주행 속도를 즉시 감속한다.
#
# BMA 공정 AMR이 주행하는 경로 상에 장애물이 후쿠요(Hokuyo) 센서의 정지 영역 내에서 감지될 경우, AMR은 즉각적으로 주행을 중단하고 정지 상태를 유지한다.
#
# BMA 공정 AMR이 특정 구간 진입을 위한 사전 통행 허가(Pass Approval)를 획득하지 못한 상태에서 주행을 시도할 경우, 관제 시스템과의 충돌 방지를 위해 일시 정지 상태로 전환된다.
#
# BMA 공정 AMR에 장착된 후쿠요(Hokuyo) 센서로부터 규격 외의 정의되지 않은 데이터 값이 수신될 경우, 주행 안전성을 확보하기 위해 시스템은 기동을 일시 정지한다.
#
# BMA 공정 AMR 내부의 메인 제어부와 Unicon 통신 보드 간의 데이터 연결이 단절되면 하드웨어 통신 오류가 발생하며 모든 구동이 제한된다.
# 2026-01-05 15:31:30.270 | INFO     | __main__:<module>:10 - # BMA 자동화 물류 시스템의 다층적 안전 제어 및 통신 아키텍처 분석
# **Analysis of Multi-Layered Safety Control and Communication Architecture in BMA Automated Logistics**
#
# ## 1. 서론: 결정론적 안전 설계의 필요성
# 현대자동차그룹의 BMA(Battery Module Assembly) 공정은 고중량의 배터리 모듈을 다루는 환경 특성상, 자동화 시스템의 신뢰성이 공정 효율뿐만 아니라 작업자의 안전과 직결되는 핵심 요소이다. 특히 공정 내 물류를 담당하는 AMR(Autonomous Mobile Robot)은 예측 불가능한 동적 환경에서 작동하므로, 단순한 조건반사적 제어를 넘어선 **결정론적(Deterministic) 안전 설계**가 요구된다. 본 백서는 BMA 공정 AMR의 환경 인지, 트래픽 제어, 그리고 내부 통신 무결성 확보를 위한 기술적 메커니즘과 그 논리적 인과관계를 심층적으로 분석한다.
#
# ---
#
# ## 2. LiDAR 기반의 환경 인지 및 동적 제동 메커니즘 (Environmental Perception & Dynamic Braking)
#
# ### 2.1. 광학적 스캐닝과 영역 분할(Zone Segmentation) 원리
# BMA 공정 AMR의 주행 안전성을 담보하는 핵심 센서는 **후쿠요(Hokuyo) 장애물 감지 센서**이다. 이 센서는 2D LiDAR(Light Detection and Ranging) 기술을 기반으로 하며, 레이저 펄스를 방출하고 물체에 반사되어 돌아오는 시간(Time-of-Flight)을 측정하여 주변 환경을 점군(Point Cloud) 데이터로 실시간 매핑한다.
#
# 시스템 아키텍처 관점에서 이 센서의 데이터 처리는 단순한 '감지'를 넘어, AMR의 운동학적(Kinematics) 상태에 따라 가변적인 **안전 영역(Safety Field)**을 형성하는 것으로 시작된다. 시스템은 감지된 거리에 따라 영역을 크게 두 가지로 분할하여 처리한다:
# 1.  **감속 영역 (Warning Zone):** 충돌 위험이 잠재된 원거리 구간.
# 2.  **정지 영역 (Protective/Stop Zone):** 물리적 충돌이 임박한 근거리 구간.
#
# ### 2.2. 단계별 제동 시퀀스와 관성 제어
# 입력된 사실에 따르면, AMR은 물체 감지 시 즉시 감속하거나 정지한다. 이 과정은 다음과 같은 물리적/논리적 사슬을 따른다.
#
# 1.  **감속 트리거 (Deceleration Trigger):** 후쿠요 센서가 '감속 영역' 내의 장애물을 감지하면, 상위 제어기(Main Controller)는 모터 드라이버에 인가되는 PWM(Pulse Width Modulation) 듀티비를 조정하여 구동 토크를 낮춘다.
#     *   **Why?** 고중량의 배터리 모듈을 적재한 AMR은 높은 관성 모멘트(Moment of Inertia)를 가진다. 급격한 제동은 적재물의 이탈이나 슬립(Slip)을 유발할 수 있으므로, 운동 에너지($E_k = \frac{1}{2}mv^2$)를 점진적으로 소산시키기 위해 1차 감속이 필수적이다.
# 2.  **비상 정지 로직 (Emergency Stop Logic):** 장애물이 '정지 영역' 내로 진입할 경우, 시스템은 즉각적으로 **STO(Safe Torque Off)** 기능을 활성화하거나 기계적 브레이크를 체결하여 AMR을 완전 정지 상태(Zero Velocity)로 전환한다. 이는 소프트웨어적 연산을 거치지 않는 하드웨어 인터락(Interlock) 수준에서 처리되어, 연산 지연(Latency) 없는 즉각적인 반응을 보장한다.
#
# ---
#
# ## 3. 센서 데이터 무결성 검증과 Fail-Safe 설계 (Sensor Data Integrity)
#
# ### 3.1. 비정형 데이터 수신 시의 예외 처리
# 후쿠요 센서로부터 **규격 외의 정의되지 않은 데이터 값(Undefined Data)**이 수신되는 현상은 센서 내부의 광학적 노이즈, 통신 케이블의 전자기적 간섭(EMI), 혹은 센서 펌웨어의 오동작에서 기인할 수 있다.
#
# ### 3.2. 시스템의 방어적 기동 원리
# BMA 시스템 아키텍처는 이러한 비정상 데이터를 단순한 '노이즈'로 무시하지 않고, **'가장 위험한 상태(Most Critical State)'**로 간주하여 처리한다.
# *   **논리적 흐름:** [데이터 파싱 실패] → [신뢰성(Confidence Level) 하락] → [주행 불가 판정] → [기동 일시 정지]
# *   **작동 원리:** 제어 시스템은 센서 데이터가 사전에 정의된 프로토콜(Header, Data Length, Checksum 등)과 일치하지 않을 경우, 현재의 환경을 '인지 불가능(Blind)' 상태로 정의한다. 인지되지 않은 상태에서의 주행은 확률적으로 충돌 사고로 이어질 수밖에 없으므로, 시스템은 **Fail-Safe(고장 시 안전 측 동작)** 원칙에 따라 즉시 기동을 멈추고 에러 플래그를 생성한다. 이는 시스템이 불확실성을 허용하지 않음을 의미한다.
#
# ---
#
# ## 4. 관제 시스템과의 트래픽 동기화 및 교착 상태 방지 (Traffic Synchronization)
#
# ### 4.1. 사전 통행 허가(Pass Approval) 프로토콜
# 다수의 AMR이 유기적으로 움직이는 BMA 공정에서, 개별 로봇은 독립적인 판단만으로 주행하지 않는다. AMR은 특정 노드(Node)나 구간(Segment)에 진입하기 전, 상위 관제 시스템(ACS/MCS)에 **통행 허가(Pass Approval)**를 요청하는 핸드쉐이킹(Handshaking) 과정을 거친다.
#
# ### 4.2. 허가 실패 시의 대기 로직과 충돌 회피
# AMR이 Pass Approval을 획득하지 못한 상태에서 주행을 시도하려는 경우, 시스템은 이를 **논리적 충돌(Logical Collision)** 위험으로 간주한다.
# *   **Why?** 해당 구간에 이미 다른 AMR이 점유(Occupancy) 중이거나, 교차로에서의 우선순위 경합이 발생했을 가능성이 높기 때문이다.
# *   **How it works:** AMR의 네비게이션 알고리즘은 경로가 생성되어 있더라도, '허가 비트(Permission Bit)'가 활성화되지 않으면 모터 구동 명령을 차단(Block)한다. 이에 따라 AMR은 물리적 장애물이 없더라도 **일시 정지(Pause)** 상태로 전환되며, 관제 시스템으로부터 승인 신호(Ack)가 수신될 때까지 대기 모드를 유지한다. 이는 물리적 충돌을 예방할 뿐만 아니라, 시스템 전체의 교착 상태(Deadlock)를 방지하는 트래픽 제어 레이어의 핵심 로직이다.
#
# ---
#
# ## 5. 내부 임베디드 통신 아키텍처와 하드웨어 인터락 (Internal Communication Architecture)
#
# ### 5.1. 메인 제어부와 Unicon 보드 간의 종속성
# AMR 내부 아키텍처에서 **메인 제어부(Main Controller)**가 고수준의 연산(경로 계획, 위치 추정)을 담당하는 '두뇌'라면, **Unicon 통신 보드**는 모터, 센서, 액추에이터 등 하위 하드웨어를 직접 제어하는 '척수' 역할을 수행한다. 이 두 유닛 간의 데이터 연결은 시스템의 생명선과 같다.
#
# ### 5.2. 통신 단절(Disconnection) 시의 구동 제한 메커니즘
# 메인 제어부와 Unicon 보드 간의 연결이 단절되는 상황은 케이블 단선, 커넥터 접촉 불량, 혹은 통신 버스(CAN, RS-485 등)의 오류로 인해 발생한다.
# *   **Watchdog Timer의 동작:** 시스템은 주기적으로 'Heartbeat' 신호를 주고받으며 연결 상태를 확인한다. 만약 일정 시간(Timeout) 동안 응답이 없으면 통신 오류(Communication Fault)로 판정한다.
# *   **구동 제한의 인과관계:** 하위 제어기인 Unicon 보드가 상위 제어부의 명령을 수신할 수 없게 되면, AMR은 제어 불능(Runaway) 상태에 빠질 위험이 있다. 따라서 통신 단절이 감지되는 즉시, Unicon 보드는 자체적인 펌웨어 로직에 의해 **모든 구동 전원을 차단(Power Cut-off)**하거나 비상 브레이크를 작동시킨다. 이는 소프트웨어의 개입 없이 하드웨어 레벨에서 수행되는 최후의 안전장치이다.
# 2026-01-05 15:31:30.271 | INFO     | __main__:<module>:18 - 14 텍스트북 생성 완료
# 2026-01-05 15:31:30.272 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# BMA 공정 AMR의 배터리 잔량이 20% 이하로 저하될 경우 30001(Battery Low) 알람이 발생한다.
#
# BMA 공정 AMR의 비상 정지(EMG) 버튼이 물리적으로 눌린 상태에서는 30002(EMG Button pressed) 알람이 활성화된다.
#
# BMA 공정 AMR의 제어 시스템이 BMS(Battery Management System)로부터 배터리 상태 데이터를 수신하지 못할 경우 30003(Battery status not received from BMS) 경고가 발생한다.
#
# BMA 공정 AMR 구동 모터의 회전 방향이 설정된 명령과 일치하지 않는 역방향으로 구동될 경우 30004(Wrong motor direction) 경고가 발생한다.
#
# BMA 공정 AMR의 Unicon 통신 과정에서 CRC(Cyclic Redundancy Check) 오류가 검출되면 30005(Unicon crc WARN) 경고가 발생한다.
# 2026-01-05 15:32:11.606 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: AMR 결함 허용 아키텍처 및 예외 처리 메커니즘
# **(Technical Whitepaper: Fault Tolerance Architecture & Exception Handling Mechanisms in BMA AMR)**
#
# ## 1. 개요 (Overview)
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 효율성과 안전성은 자율주행 로봇(AMR)의 신뢰성에 전적으로 의존합니다. 본 챕터에서는 AMR 시스템 운용 중 발생할 수 있는 전력, 안전, 통신, 구동 계통의 이상 징후를 시스템이 어떻게 감지하고, 어떤 논리적 인과관계(Logical Causality)를 통해 방어 기제(Defense Mechanism)를 작동시키는지 기술합니다. 단순한 에러 코드의 나열이 아닌, 하드웨어(Physical Layer)와 소프트웨어(Application Layer) 간의 상호작용 및 데이터 흐름을 중심으로 분석합니다.
#
# ---
#
# ## 2. 전력 관리 시스템 및 BMS 인터페이스 (Power Management & BMS Interface)
#
# AMR의 동력원인 리튬이온 배터리 팩은 단순한 에너지 저장소를 넘어, 시스템의 가동 가능 여부를 결정하는 핵심 지표입니다. 제어 시스템은 BMS(Battery Management System)와의 실시간 통신을 통해 에너지 상태를 모니터링하며, 임계값 도달 시 즉각적인 보호 로직을 수행합니다.
#
# ### 2.1. 저전압 임계값 제어 및 SoC 관리 (Code: 30001)
# **[현상]** 배터리 잔량(SoC, State of Charge)이 20% 이하로 떨어질 경우, 시스템은 **30001(Battery Low)** 알람을 발생시킵니다.
#
# **[작동 원리 및 공학적 배경]**
# 리튬이온 배터리는 방전 심도(DoD)가 깊어질수록 전압 강하(Voltage Sag) 현상이 급격해지며, 이는 구동 모터의 토크 부족이나 제어기(Controller)의 브라운아웃(Brown-out)을 유발할 수 있습니다.
# *   **임계값 설정의 근거:** 20%라는 수치는 단순한 경고가 아닙니다. 이는 AMR이 현재 위치에서 충전 스테이션까지 복귀하기 위해 필요한 최소한의 에너지 마진(Energy Margin)과, 배터리 셀의 화학적 손상(Deep Discharge Damage)을 방지하기 위한 안전 계수가 포함된 값입니다.
# *   **시스템 로직:** 메인 컨트롤러는 BMS로부터 수신된 전압 및 전류 데이터를 적분하여 SoC를 실시간으로 계산합니다. SoC $\le$ 20% 조건이 `True`가 되는 순간, 시스템은 작업 할당(Task Assignment) 요청을 차단하고, 현재 수행 중인 미션의 우선순위를 '작업'에서 '충전 복귀'로 강제 전환하거나 운영자에게 즉각적인 개입을 요청하는 트리거를 발동합니다.
#
# ### 2.2. BMS 통신 무결성 상실 (Code: 30003)
# **[현상]** 제어 시스템이 BMS로부터 배터리 상태 데이터를 수신하지 못할 경우 **30003(Battery status not received from BMS)** 경고가 발생합니다.
#
# **[작동 원리 및 공학적 배경]**
# AMR의 메인 제어 유닛(MCU)과 BMS는 일반적으로 CAN(Controller Area Network) 통신을 통해 주기적인 상태 메시지(Heartbeat Signal)를 주고받습니다.
# *   **데이터 흐름의 단절:** 이 경고는 물리적 배선 단선, 커넥터 접촉 불량, 또는 BMS 내부 프로세서의 셧다운으로 인해 발생합니다.
# *   **위험성 및 안전 로직:** BMS 데이터 부재는 시스템이 배터리의 전압, 온도, 셀 밸런싱 상태를 전혀 알 수 없는 '블라인드(Blind)' 상태임을 의미합니다. 이는 과열(Thermal Runaway)이나 과방전과 같은 치명적인 하드웨어 손상 위험을 내포하므로, 시스템은 이를 단순 통신 오류가 아닌 '주행 불가 상태'로 간주합니다. 따라서 해당 경고 발생 시 AMR은 즉시 구동을 멈추고(Fail-Safe Stop), 전력 계통에 대한 진단을 요구하게 됩니다.
#
# ---
#
# ## 3. 하드웨어 기반 안전 인터록 (Hard-Wired Safety Interlock)
#
# 소프트웨어의 연산 오류나 지연(Latency)과 무관하게, 물리적인 안전을 보장하기 위해 하드웨어 레벨에서 직접 구동을 차단하는 메커니즘입니다.
#
# ### 3.1. 비상 정지 회로의 물리적 차단 (Code: 30002)
# **[현상]** AMR의 비상 정지(EMG) 버튼이 물리적으로 눌린 상태에서 **30002(EMG Button pressed)** 알람이 활성화됩니다.
#
# **[작동 원리 및 공학적 배경]**
# 이 알람은 소프트웨어 로직에 의해 발생하는 것이 아니라, 물리적인 회로의 개방(Open Circuit)을 감지하여 발생합니다.
# *   **NC(Normally Closed) 메커니즘:** 산업 안전 표준(ISO 13850)에 따라 EMG 버튼은 평상시 회로가 연결된 NC 접점을 사용합니다. 버튼을 누르면 회로가 물리적으로 끊어지며, 이 신호는 PLC나 모터 드라이버의 STO(Safe Torque Off) 단자로 직결됩니다.
# *   **논리적 인과관계:**
#     1.  운영자가 EMG 버튼 타격 (Action)
#     2.  안전 회로 전원 차단 (Physical Layer)
#     3.  모터 드라이버로 공급되는 전력 즉시 차단 및 브레이크 체결 (Hardware Response)
#     4.  제어기는 해당 핀(Pin)의 전압 레벨 변화(High $\to$ Low)를 감지하여 30002 알람 송출 (Software Notification)
# *   **시스템 복구:** 이 상태는 소프트웨어 리셋만으로는 해제되지 않으며, 반드시 물리적인 버튼의 릴리즈(Twist-to-release)가 선행되어야 시스템이 재기동 준비 상태(Ready)로 전환됩니다.
#
# ---
#
# ## 4. 모션 제어 피드백 루프 (Motion Control Feedback Loop)
#
# AMR의 정밀 주행은 명령(Command)과 실제 반응(Response) 간의 오차를 지속적으로 보정하는 폐루프 제어(Closed-loop Control)에 기반합니다.
#
# ### 4.1. 구동 방향 불일치 및 제어 상실 감지 (Code: 30004)
# **[현상]** 구동 모터가 설정된 명령과 반대 방향으로 회전할 경우 **30004(Wrong motor direction)** 경고가 발생합니다.
#
# **[작동 원리 및 공학적 배경]**
# 이는 모션 제어기의 PID 제어 루프 내에서 심각한 편차(Deviation)가 발생했음을 의미합니다.
# *   **엔코더 피드백(Encoder Feedback):** 제어기는 모터에 정방향(+) 전압(또는 PWM 신호)을 인가했으나, 모터 축에 장착된 엔코더(Encoder)로부터 역방향(-) 펄스가 카운팅되는 상황입니다.
# *   **발생 원인 분석:**
#     1.  **배선 오류:** 모터의 상(Phase, U/V/W) 배선이 바뀌었거나 엔코더 배선이 반대로 결선된 경우.
#     2.  **외력에 의한 밀림:** 경사로에서 중력에 의해 뒤로 밀리거나, 외부 충돌로 인해 강제로 역주행하는 경우.
# *   **방어 로직:** 제어기는 명령값(Target)과 피드백값(Actual)의 부호(Sign)가 다르고, 그 지속 시간이 설정된 허용 오차 시간(Tolerance Time)을 초과하면 즉시 모터 전원을 차단합니다. 이는 제어 불능 상태에서 AMR이 급발진하거나 예상치 못한 경로로 이탈하는 것을 방지하기 위한 필수적인 안전장치입니다.
#
# ---
#
# ## 5. 통신 데이터 무결성 검증 (Data Integrity Verification)
#
# BMA 공정 내부는 수많은 용접기, 인버터, 모터가 작동하여 전자기적 노이즈(EMI)가 매우 심한 환경입니다. 이러한 환경에서 데이터의 신뢰성을 확보하기 위한 기술입니다.
#
# ### 5.1. Unicon 통신 CRC 오류 (Code: 30005)
# **[현상]** AMR 내부 제어기와 하위 구동 유닛(Unicon) 간 통신 중 **30005(Unicon crc WARN)** 경고가 발생합니다.
#
# **[작동 원리 및 공학적 배경]**
# CRC(Cyclic Redundancy Check)는 데이터 전송 과정에서 노이즈로 인해 비트(Bit)가 반전되거나 손상되었는지를 수학적으로 검증하는 기술입니다.
# *   **검증 메커니즘:**
#     1.  **송신 측:** 보낼 데이터 패킷을 특정 다항식으로 나누어 나머지 값(Checksum)을 계산하고, 이를 패킷 끝에 붙여 전송합니다.
#     2.  **수신 측:** 받은 패킷을 동일한 다항식으로 나누어 봅니다. 이때 나머지가 0이 아니면 전송 중 데이터가 변조된 것으로 판단합니다.
# *   **시스템 대응:** 30005 경고는 "방금 수신한 데이터 패킷은 신뢰할 수 없으므로 폐기(Discard)한다"는 의미입니다.
#     *   일시적인 노이즈에 의한 단발성 경고라면 시스템은 재전송 요청(Retry)을 통해 복구합니다.
#     *   하지만 이 경고가 연속적으로 발생한다면, 통신 케이블의 쉴딩(Shielding) 손상이나 접지(Grounding) 불량에 의한 영구적 통신 장애를 시사하므로 유지보수가 필요합니다.
# 2026-01-05 15:32:11.608 | INFO     | __main__:<module>:18 - 15 텍스트북 생성 완료
# 2026-01-05 15:32:11.609 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# BMA 공정 AMR의 [30006] 알람은 모터 드라이브의 리셋 조치가 완료되었음을 의미한다.
#
# BMA 공정 AMR의 [30007] 알람은 시스템이 배터리 관리 시스템(BMS)과 통신 연결을 수행 중인 상태임을 나타낸다.
#
# BMA 공정 AMR의 [30008] 알람은 통합 제어기인 Unicon과의 통신 연결을 시도 중인 상태를 의미한다.
#
# BMA 공정 AMR의 [30009] 알람은 장비 전방에 위치한 1번 라이다(LiDAR) 센서가 시스템과 연결되지 않은 상태임을 나타낸다.
#
# BMA 공정 AMR의 [30010] 알람은 장비 후방에 위치한 2번 라이다(LiDAR) 센서가 시스템과 연결되지 않은 상태임을 나타낸다.
# 2026-01-05 15:32:51.178 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: AMR 초기화 시퀀스 및 센서 인터페이스 아키텍처
# **Technical Whitepaper: AMR Initialization Sequence & Sensor Interface Architecture in BMA Process**
#
# ---
#
# ## 1. 서론 (Introduction)
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 효율성은 자율주행 로봇(AMR)의 가동률(Availability)과 직결됩니다. AMR이 물리적 작업을 수행하기 위해서는 전원 인가 후 구동계, 에너지 관리 시스템, 상위 제어기, 그리고 인지 센서 간의 유기적인 통신 확립이 선행되어야 합니다.
#
# 본 챕터에서는 AMR 시스템의 부팅 및 초기화 단계에서 발생하는 상태 코드(30006~30010)를 통해, 시스템 내부의 **데이터 흐름(Data Flow)**과 **제어 위계(Control Hierarchy)**, 그리고 **하드웨어 추상화 계층(HAL)**에서의 상호작용 메커니즘을 심층적으로 분석합니다.
#
# ---
#
# ## 2. 구동 제어 시스템의 상태 천이 (Motion Control State Transition)
#
# ### 2.1 모터 드라이브 리셋 및 초기화 [Code: 30006]
#
# **[30006] 알람**은 단순한 상태 표시를 넘어, AMR의 구동계(Powertrain)가 **'Fault State(오류 상태)'**에서 **'Ready State(대기 상태)'**로 성공적으로 천이했음을 알리는 결정적인 신호입니다.
#
# *   **작동 원리 (Mechanism):**
#     AMR의 구동을 담당하는 서보 드라이브(Servo Drive)나 인버터는 과전류, 과부하, 위치 오차 등의 이유로 내부 보호 로직이 작동하면 'Trip' 상태가 되어 출력을 차단합니다. [30006] 코드는 상위 제어기(Main Controller)가 드라이브에 리셋(Reset) 시그널을 인가하고, 드라이브 내부의 MCU가 에러 레지스터(Error Register)를 소거(Clear)한 후, DC 링크 전압이 정상 범위에 도달했음을 확인하여 **"구동 준비 완료(Servo Ready)"** 플래그를 반환했을 때 발생합니다.
# *   **논리적 인과관계 (Logical Causality):**
#     이 신호가 확인되지 않으면, 시스템은 안전을 위해 모터에 PWM(Pulse Width Modulation) 신호를 인가하지 않습니다. 즉, [30006]은 물리적 이동(Kinematic Motion)을 허용하기 위한 **최소 필요조건(Prerequisite)**이며, 이 단계가 완료되어야만 비로소 주행 알고리즘이 모터의 토크 제어를 시작할 수 있습니다.
#
# ---
#
# ## 3. 에너지 관리 및 상위 제어 통신 (Energy Management & High-Level Control)
#
# ### 3.1 BMS 통신 핸드쉐이킹 프로토콜 [Code: 30007]
#
# **[30007] 알람**은 AMR의 메인 컨트롤러와 리튬이온 배터리 팩 내부의 **BMS(Battery Management System)** 간에 통신 세션이 수립되고 있는 과도기적 상태(Transient State)를 나타냅니다.
#
# *   **공학적 배경 (Engineering Context):**
#     BMA 공정의 AMR은 고전압 배터리를 사용하므로, 셀 밸런싱(Cell Balancing), SoC(State of Charge), SoH(State of Health), 그리고 온도 감시가 필수적입니다. 이 데이터는 주로 CAN(Controller Area Network) 버스를 통해 전송됩니다.
# *   **데이터 흐름 및 안전 로직:**
#     시스템이 부팅되면 메인 컨트롤러는 BMS에 'Wake-up' 신호를 보내고 데이터 패킷을 요청합니다. [30007] 상태는 물리적 연결은 되어 있으나, 아직 유효한 데이터 프레임(Data Frame)을 수신하지 못했거나 프로토콜의 **핸드쉐이킹(Handshaking)**이 진행 중임을 의미합니다.
#     이 단계에서 통신이 확립되지 않으면, 시스템은 배터리의 과방전이나 열폭주(Thermal Runaway) 징후를 감지할 수 없다고 판단하여, 메인 컨택터(Main Contactor)를 닫지 않고 전원 공급을 차단하는 **Fail-Safe** 모드로 진입합니다.
#
# ### 3.2 통합 제어기(Unicon)와의 링크 수립 [Code: 30008]
#
# **[30008] 알람**은 AMR 내부의 로컬 제어기가 시스템의 두뇌 역할을 하는 통합 제어기 **'Unicon'**과의 통신 연결을 시도하는 단계입니다.
#
# *   **시스템 아키텍처 (System Architecture):**
#     Unicon은 AMR 내의 하위 모듈(모터, 센서, I/O, BMS)을 통합 관리하고, 외부 관제 시스템(ACS)의 명령을 해석하여 하달하는 **오케스트레이터(Orchestrator)** 역할을 수행합니다.
# *   **작동 메커니즘:**
#     이 코드는 TCP/IP 또는 산업용 필드버스(EtherCAT/Profinet 등)를 통해 Unicon과 하위 노드 간의 소켓 연결(Socket Connection)이 시도되고 있음을 나타냅니다. 이 과정에서 **Heartbeat** 신호 교환을 통해 네트워크 지연(Latency)과 패킷 손실률을 점검합니다.
# *   **중요성:**
#     [30008] 상태가 지속된다는 것은 AMR이 '뇌'와 연결되지 않은 '식물 상태'임을 의미합니다. Unicon과의 연결이 완료되어야만 AMR은 자신의 위치 좌표를 계산하고, 작업 시나리오를 로딩할 수 있습니다.
#
# ---
#
# ## 4. 환경 인지 센서 네트워크 (Environmental Perception Sensor Network)
#
# AMR의 자율 주행(Navigation)과 안전(Safety)은 주변 환경을 정밀하게 스캔하는 **라이다(LiDAR)** 센서에 전적으로 의존합니다. [30009]와 [30010] 코드는 이 센서 데이터 스트림의 무결성(Integrity)과 관련된 물리적 연결 상태를 나타냅니다.
#
# ### 4.1 전방 라이다(LiDAR #1) 연결 무결성 [Code: 30009]
#
# **[30009] 알람**은 AMR의 진행 방향(Forward)을 감지하는 **1번 라이다 센서**의 데이터 링크가 단절되었음을 의미합니다.
#
# *   **센서 작동 원리 (Physics of LiDAR):**
#     라이다는 레이저 펄스를 발사하고 반사되어 돌아오는 시간(ToF: Time of Flight)을 측정하여 거리를 계산합니다. 이 데이터는 초당 수만 개의 포인트 클라우드(Point Cloud) 형태로 메인 프로세서에 전송됩니다.
# ...
# 2026-01-05 15:43:10.502 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# BMA 공정 AMR(나비프라 주행 시스템)에서 발생하는 80028 에러는 모터 드라이버의 응답 시간 초과(MOTOR_DRIVER_RESPONSE_TIMEOUT)를 의미한다.
#
# BMA 공정 AMR(나비프라 주행 시스템)의 80029 에러는 도킹 해제(Dock-out) 중 T-Zone 내 장애물이 감지되어 주행이 일시 정지된 상태(PAUSED_BY_DOCK_OUT_T_ZONE_OBSTACLE)를 나타낸다.
#
# BMA 공정 AMR의 ACS(Autonomous Control System) 감지 코드 3번은 로봇의 전원이 차단된 상태(POWER_OFF)를 의미한다.
#
# BMA 공정 AMR의 ACS 감지 코드 6번은 로봇이 자동 주행 모드가 아닌 수동 조작 상태(ROBOT_MANUAL_OPERATION_STATUS)임을 나타낸다.
#
# BMA 공정 AMR의 ACS 감지 코드 11번은 로봇이 설정된 경로를 주행하는 과정에서 ACS 제어 오류(ACS_ERROR_WHILE_NAVIGATING_THE_ROUTE)가 발생했음을 의미한다.
# 2026-01-05 15:43:56.870 | INFO     | __main__:<module>:10 - # BMA 공정 자율주행 물류 시스템: 제어 아키텍처와 예외 처리 메커니즘에 관한 심층 분석
#
# **작성자:** 수석 아키텍트 (Chief Architect)
# **대상:** 시스템 엔지니어링 및 유지보수 부서
# **주제:** AMR 구동 제어, 도킹 안전 로직, 그리고 ACS 관제 상태 동기화의 기술적 원리
#
# ---
#
# ## 1. 서론: 결정론적 제어와 확률론적 환경의 통합
#
# 현대자동차그룹 BMA(Battery Module Assembly) 공정 내 도입된 나비프라(Navifra) 기반의 AMR 시스템은 단순한 자재 이송 장치가 아닌, 실시간 데이터 스트림을 처리하는 엣지 컴퓨팅 노드(Edge Computing Node)로 기능합니다. 본 기술 백서는 현장에서 발생하는 주요 에러 코드와 상태 코드(Status Code)를 단순한 '고장 신호'가 아닌, **시스템 아키텍처 내의 데이터 흐름(Data Flow)과 논리적 인과관계(Logical Causality)** 관점에서 재해석합니다. 특히 하드웨어 제어 계층(Physical Layer)과 상위 관제 계층(Application Layer) 간의 상호작용을 중심으로, 시스템이 비정상 상황을 어떻게 감지하고 안전을 확보하는지 기술합니다.
#
# ---
#
# ## 2. 하드웨어 추상화 계층(HAL)과 실시간 제어 무결성
#
# AMR의 주행 성능은 상위 알고리즘의 판단을 물리적 움직임으로 변환하는 액추에이터(Actuator)의 정밀도와 응답성에 의존합니다. 이 과정에서 제어기와 구동기 간의 통신 안정성은 시스템의 핵심 요소입니다.
#
# ### 2.1 모터 드라이버 응답 시간 초과 (80028 에러)의 공학적 해석
#
# **에러 코드 80028 (MOTOR_DRIVER_RESPONSE_TIMEOUT)**은 AMR의 메인 컨트롤러(IPC 또는 PLC)와 모터 드라이버(Motor Driver) 간의 통신 링크에서 발생하는 치명적인 동기화 실패를 의미합니다.
#
# *   **작동 원리 (Mechanism):**
#     일반적으로 AMR은 CAN(Controller Area Network) 또는 EtherCAT과 같은 산업용 필드버스(Fieldbus)를 통해 모터 드라이버에 토크(Torque)나 속도(Velocity) 명령을 주기적으로 전송합니다. 이때 메인 컨트롤러는 명령을 보낸 후, 드라이버로부터 현재 모터의 상태(엔코더 값, 전류량 등)를 담은 응답 패킷(Response Packet)을 정해진 시간(Time Window, 예: 10ms~50ms) 내에 수신해야 합니다. 이를 **'핸드쉐이킹(Handshaking)'** 또는 **'하트비트(Heartbeat) 모니터링'**이라 합니다.
#
# *   **발생 원인 및 논리적 인과 (Logical Causality):**
#     이 에러는 단순히 모터가 멈춘 것이 아니라, **제어 루프(Control Loop)의 개방(Open)**을 의미합니다.
#     1.  **전자기적 간섭(EMI):** BMA 공정 내 고전압 배터리 모듈이나 용접 장비 등에서 발생하는 노이즈가 통신 케이블에 유입되어 패킷 손실(Packet Loss)을 유발할 수 있습니다.
#     2.  **CPU 과부하:** 메인 컨트롤러가 SLAM(Simultaneous Localization and Mapping) 연산이나 경로 계획(Path Planning)에 과도한 리소스를 사용하여, 드라이버 통신 스레드의 우선순위가 밀릴 경우 발생합니다.
#     3.  **하드웨어 래치(Latch):** 모터 드라이버 내부의 과전류 보호 회로가 작동하여 MCU가 일시적으로 응답 불능 상태(Hang-up)에 빠진 경우입니다.
#
# *   **시스템 안전 거동 (Fail-Safe):**
#     80028 에러가 트리거되면, 시스템은 즉시 **STO(Safe Torque Off)** 기능을 활성화합니다. 이는 소프트웨어적인 정지가 아니라, 모터로 공급되는 전력을 하드웨어적으로 차단하여 관성에 의한 주행을 최소화하고 로봇을 급정거시키는 최후의 안전장치입니다.
#
# ---
#
# ## 3. 공간 인지 및 동적 장애물 회피 로직
#
# AMR은 라이다(LiDAR)와 비전 센서를 통해 주변 환경을 확률적으로 인지합니다. 특히 도킹(Docking)과 같은 정밀 작업 구간에서는 일반 주행보다 훨씬 엄격한 안전 로직이 적용됩니다.
#
# ### 3.1 도킹 해제 시 T-Zone 장애물 감지 (80029 에러)의 심층 분석
#
# **에러 코드 80029 (PAUSED_BY_DOCK_OUT_T_ZONE_OBSTACLE)**는 AMR이 설비와 도킹을 해제하고 빠져나오는(Dock-out) 과정에서, 특정 보안 구역인 'T-Zone' 내에 장애물이 감지되어 주행 로직이 **일시 정지(Suspend)**된 상태를 나타냅니다.
#
# *   **T-Zone의 기하학적 정의:**
#     T-Zone은 도킹 스테이션 바로 앞, 로봇이 회전하거나 경로를 변경하기 위해 필요한 최소한의 물리적 공간을 가상의 펜스(Virtual Geofence)로 설정한 구역입니다. 이 구역은 로봇의 키네마틱스(Kinematics, 운동학) 모델에 따라 계산된 회전 반경을 포함합니다.
#
# *   **감지 및 처리 알고리즘 (Detection Logic):**
#     1.  **상태 전이:** 로봇이 Dock-out 명령을 받으면, 센서 민감도를 '주행 모드'에서 '정밀 안전 모드'로 전환합니다.
#     2.  **센서 퓨전:** 2D LiDAR 센서는 T-Zone 영역 내의 점군(Point Cloud) 데이터를 실시간으로 스캔합니다.
#     3.  **판단:** 사전에 매핑된 정적 환경(벽, 설비 기둥) 이외의 동적 객체(작업자의 발, 적재된 자재 등)가 T-Zone 내 좌표에서 검출되면, 충돌 확률이 100%에 가깝다고 판단합니다.
#     4.  **결과:** 시스템은 80029 코드를 발생시키며 모션 프로파일 생성을 중단합니다. 이는 '에러'라기보다는 **'능동적 대기(Active Waiting)'** 상태에 가깝습니다. 장애물이 제거되면 별도의 리셋 없이 주행을 재개할 수 있도록 설계된 경우가 많습니다. 이는 공정 효율성을 저해하지 않으면서 안전을 확보하는 타협점입니다.
#
# ---
#
# ## 4. ACS(Autonomous Control System) 관제와 상태 동기화
#
# 개별 로봇(AMR)과 중앙 관제 시스템(ACS) 간의 데이터 일관성은 전체 물류 흐름의 효율성을 결정합니다. ACS 감지 코드는 로봇의 내부 상태를 서버가 어떻게 해석하고 있는지를 보여주는 지표입니다.
#
# ### 4.1 전원 차단 및 통신 두절 (ACS 코드 3)
#
# **ACS 감지 코드 3 (POWER_OFF)**은 서버 입장에서 로봇과의 연결이 완전히 끊긴 상태를 의미합니다.
#
# *   **데이터 흐름 (Data Flow):**
#     정상적인 상태에서 AMR은 ACS 서버로 주기적인 상태 패킷(Keep-alive signal)을 전송합니다. 코드 3은 이 신호가 임계 시간(Timeout Threshold) 이상 수신되지 않을 때 서버가 생성하는 상태 값입니다.
# *   **물리적 배경:**
#     이는 배터리 방전(BMS Cut-off), 비상 정지 버튼(E-Stop)에 의한 메인 전원 차단, 또는 Wi-Fi 음영 구역 진입으로 인한 네트워크 단절을 포함합니다. 시스템은 해당 로봇을 '가용 불가(Unavailable)' 자원으로 분류하고, 할당된 작업을 다른 로봇에게 재할당(Re-dispatching)하는 로직을 수행하게 됩니다.
#
# ### 4.2 제어 권한의 이양: 수동 조작 모드 (ACS 코드 6)
#
# **ACS 감지 코드 6 (ROBOT_MANUAL_OPERATION_STATUS)**은 로봇의 제어 권한(Control Authority)이 알고리즘에서 인간 운영자로 넘어갔음을 나타냅니다.
#
# *   **작동 메커니즘:**
#     운영자가 로봇의 조이스틱을 조작하거나 티칭 펜던트(Teaching Pendant)를 활성화하면, 로봇의 내부 PLC는 'Manual Mode' 플래그를 True로 설정합니다. 이 정보는 즉시 ACS로 전송됩니다.
# *   **시스템적 함의:**
#     이 상태에서 ACS는 해당 로봇에게 경로 명령이나 작업 지시를 내리는 것을 중단합니다(Command Blocking). 이는 자동 관제 명령과 작업자의 수동 조작이 충돌하여 발생할 수 있는 급발진이나 오작동을 방지하기 위한 **상호 배제(Mutual Exclusion)** 논리가 적용된 결과입니다.
#
# ### 4.3 경로 주행 중 ACS 제어 오류 (ACS 코드 11)
#
# **ACS 감지 코드 11 (ACS_ERROR_WHILE_NAVIGATING_THE_ROUTE)**은 로봇이 목적지로 이동하는 도중, ACS의 경로 계획과 로봇의 실제 주행 상태 간에 불일치가 발생했음을 의미합니다.
#
# *   **발생 원인 (Why):**
#     1.  **위치 추정 실패 (Localization Lost):** 로봇이 자신의 위치를 놓쳐(Delocalized), ACS가 지시한 경로 좌표와 로봇이 인식한 현재 좌표 간의 오차(Error Metric)가 허용 범위를 초과한 경우입니다.
#     2.  **교착 상태 (Deadlock):** 다수의 로봇이 좁은 통로에서 마주쳐, 로컬 회피 알고리즘(Local Planner)이 글로벌 경로(Global Planner)를 수행할 수 없는 상황이 지속될 때 발생합니다.
#     3.  **데이터 패킷 손실:** 주행 명령 패킷이 네트워크 지연으로 인해 순서가 뒤바뀌거나 손실되어, 로봇이 다음 거동을 결정하지 못하고 정지하는 경우입니다.
# *   **결과:**
#     이 코드는 단순한 경고를 넘어, 시스템의 개입(Operator Intervention)이나 경로 재탐색(Re-planning) 프로세스가 필요함을 알리는 중요한 트리거 신호로 작용합니다.
#
# ---
#
# ## 5. 결론
#
# BMA 공정의 AMR 시스템에서 발생하는 에러 및 감지 코드는 단순한 오작동의 기록이 아닙니다.
# *   **80028**은 하드웨어 제어의 실시간성을 보장하기 위한 **Watchdog 메커니즘**의 결과이며,
# *   **80029**는 물리적 충돌을 방지하기 위한 **공간 인지 기반의 안전 인터락(Interlock)**입니다.
# *   **ACS 코드(3, 6, 11)**는 다수의 로봇을 효율적으로 관리하기 위한 **상태 동기화 및 예외 처리 프로토콜**의 핵심입니다.
#
# 엔지니어는 이러한 코드 이면에 숨겨진 데이터 흐름과 제어 논리를 이해함으로써, 단순한 에러 소거(Reset)를 넘어 근본적인 시스템 안정성을 확보하는 유지보수 전략을 수립해야 합니다.
# 2026-01-05 15:43:56.871 | INFO     | __main__:<module>:18 - 31 텍스트북 생성 완료
# 2026-01-05 15:43:56.872 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# BMA 공정 ACS(AMR Control System)에서 발생하는 'ERROR_OCCURRED_WHILE_SENDING_JOB_COMMAND(코드 12)' 알람은 상위 시스템이 AMR로 작업 명령을 전송하는 과정에서 통신 오류나 데이터 무결성 문제로 인해 명령 전달이 실패했음을 의미한다.
#
# BMA 공정 ACS에서 발생하는 'WORK_DELAY(코드 30)' 알람은 할당된 작업의 수행 시간이 설정된 임계치를 초과하여 공정 지연이 발생하고 있는 상태를 나타낸다.
#
# BMA 공정 ACS에서 발생하는 'MAP_VERSION_IS_DIFFERENT(코드 45)' 알람은 제어 서버에 등록된 지도 데이터와 AMR 기체에 저장된 지도 데이터의 버전이 일치하지 않아 주행 안전성을 보장할 수 없는 상태를 의미한다.
#
# BMA 공정 ACS에서 발생하는 'COMMUNICATION_ERROR(코드 46)' 알람은 ACS 서버와 AMR 기체 간의 무선 네트워크 연결이 불안정하거나 끊겨 실시간 상태 모니터링 및 제어가 불가능한 상태를 나타낸다.
#
# BMA 공정 ACS에서 발생하는 'INOPERATIVE_AFTER_COMPLETION_OF_SENDING_TASK_COMMAND(코드 51)' 알람은 AMR이 작업 명령을 정상적으로 수신했음에도 불구하고, 기구적 결함이나 구동부 인터락으로 인해 실제 주행이나 동작을 시작하지 못하는 상태를 의미한다.
#
# **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 ACS 관제 화면에서 해당 AMR의 통신 상태와 맵 버전을 확인하고, 필요 시 [Reset] 버튼을 누르거나 수동 조작 모드로 전환하여 기체의 상태를 초기화해야 한다.
# 2026-01-05 15:44:41.409 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: ACS 예외 처리 및 결함 허용 아키텍처
# **(Technical Whitepaper: Exception Handling and Fault Tolerance Architecture in BMA ACS)**
#
# ---
#
# ## 1. 서론: 결정론적 제어와 불확실성의 관리
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 핵심인 AMR(Autonomous Mobile Robot) 제어 시스템(ACS)은 단순한 물류 이송을 넘어, 정밀한 시공간 동기화(Spatio-temporal Synchronization)를 요구하는 복합 시스템이다. 수백 대의 AMR이 유기적으로 움직이는 환경에서 시스템의 신뢰성은 **'정상 작동'**이 아닌, **'비정상 상황을 얼마나 논리적으로 감지하고 격리(Isolation)하는가'**에 의해 결정된다.
#
# 본 챕터에서는 ACS와 AMR 간의 상호작용 중 발생할 수 있는 통신, 데이터 무결성, 그리고 물리적 제어 단계의 예외 상황(Exception)들이 어떠한 메커니즘으로 설계되었으며, 각 알람 코드(Alarm Code)가 내포하고 있는 시스템 아키텍처의 논리적 인과관계를 심층 분석한다.
#
# ---
#
# ## 2. 명령 트랜잭션과 데이터 무결성 (Command Transaction & Data Integrity)
#
# ACS가 상위 시스템(MES/MCS)으로부터 생산 계획을 수신하여 개별 AMR에게 작업을 할당하는 과정은 데이터베이스의 트랜잭션(Transaction)과 유사한 원자성(Atomicity)을 가져야 한다. 즉, 명령은 '완벽하게 전달되거나', '아예 전달되지 않아야' 하며, 어중간한 상태는 허용되지 않는다.
#
# ### 2.1. 전송 계층의 핸드쉐이킹 실패: ERROR_OCCURRED_WHILE_SENDING_JOB_COMMAND (Code 12)
# **Code 12**는 ACS 서버가 특정 AMR에게 작업 패킷(Job Packet)을 송신했으나, 논리적 연결 수립 단계에서 실패한 경우 발생한다.
#
# *   **발생 메커니즘 (Mechanism):**
#     ACS는 TCP/IP 혹은 산업용 프로토콜을 통해 AMR에게 작업 명령(Source, Destination, Action Type 등)을 캡슐화하여 전송한다. 이때 시스템은 **3-Way Handshaking** 또는 어플리케이션 레벨의 **ACK(Acknowledge)** 신호를 대기한다. 만약 네트워크의 일시적 폭주(Congestion)나 패킷 손실로 인해 정해진 타임아웃(Timeout) 내에 ACK가 수신되지 않거나, 수신된 패킷의 **체크섬(Checksum)** 검증 결과 데이터가 손상(Corruption)된 것으로 판명되면 시스템은 즉시 Code 12를 트리거한다.
# *   **설계 의도 (Design Rationale):**
#     이 에러는 잘못된 명령이 AMR 메모리에 적재되어 예측 불가능한 동작(Zombie Process)을 유발하는 것을 원천 차단하기 위한 방어 기제다. 데이터 무결성이 보장되지 않은 명령은 실행 단계로 넘어가지 않고 즉시 폐기(Discard)된다.
#
# ### 2.2. 실행 단계의 물리적 교착: INOPERATIVE_AFTER_COMPLETION_OF_SENDING_TASK_COMMAND (Code 51)
# **Code 51**은 Code 12와 대조적으로, 통신 계층에서는 명령이 완벽하게 수신되었으나(ACK 수신 완료), AMR의 **내부 상태 머신(Internal State Machine)**이 동작 불능 상태에 빠진 경우다.
#
# *   **논리적 인과관계 (Logical Causality):**
#     AMR의 메인 컨트롤러(PLC/PC)가 작업 명령을 수신하면, 구동 모터 드라이버와 센서 시스템에 'Ready' 신호를 인가한다. 그러나 이 시점에서 다음과 같은 물리적/논리적 인터락(Interlock)이 걸려있을 수 있다.
#     1.  **하드웨어 인터락:** 비상 정지(E-Stop) 버튼이 눌려 있거나, 범퍼 센서가 눌린 상태.
#     2.  **전력 시스템 제약:** BMS(Battery Management System)가 전압 임계치 미달(Low Voltage)을 감지하여 모터 출력을 차단(Cut-off)한 경우.
#     3.  **구동부 결함:** 서보 모터 드라이버가 알람 상태이거나 브레이크가 해제되지 않는 기구적 결함.
# *   **시스템 반응:**
#     소프트웨어적으로는 '작업 수락' 상태이나 하드웨어적으로는 '구동 불가'인 불일치(Discrepancy)가 발생하므로, 시스템은 즉시 Code 51을 송출하여 운영자에게 "통신은 정상이지만 기체를 점검하라"는 명확한 가이드를 제시한다.
#
# ---
#
# ## 3. 시공간 동기화와 내비게이션 안전성 (Spatio-temporal Synchronization)
#
# 자율주행 로봇은 자신의 위치를 추정(Localization)하고 경로를 계획(Path Planning)하기 위해 정밀한 지도 데이터와 시간 관리가 필수적이다.
#
# ### 3.1. 공간 데이터의 불일치: MAP_VERSION_IS_DIFFERENT (Code 45)
# AMR은 LiDAR 센서로 수집한 포인트 클라우드(Point Cloud) 데이터를 기체 내부에 저장된 점유 격자 지도(Occupancy Grid Map)와 대조하여 자신의 위치를 파악한다(SLAM 기술). **Code 45**는 이 과정의 전제 조건인 '지도 데이터의 동일성'이 깨진 치명적인 상태다.
#
# *   **위험성 분석 (Risk Analysis):**
#     공정 레이아웃 변경으로 ACS 서버의 지도는 업데이트(V2)되었으나, 특정 AMR이 구버전 지도(V1)를 가지고 있다고 가정해보자. AMR은 V1 지도상의 '빈 공간'으로 주행하려 하지만, 실제 환경(V2)에는 새로운 설비가 설치되어 있을 수 있다. 이는 단순한 에러가 아니라 물리적 충돌 사고로 직결될 수 있다.
# *   **검증 알고리즘:**
#     ACS는 AMR 접속 시, 서버의 지도 파일과 AMR 내부 지도 파일의 **해시값(Hash Value, 예: MD5/SHA-256)**을 대조한다. 단 1비트라도 차이가 발생하면 Code 45를 발생시키고, 해당 AMR의 주행 권한(Driving Authority)을 즉시 박탈하여 안전을 확보한다.
#
# ### 3.2. 시간적 임계치 초과: WORK_DELAY (Code 30)
# BMA 공정은 정해진 택트 타임(Takt Time) 내에 배터리 모듈이 이동해야 하는 연속 공정이다. **Code 30**은 AMR의 작업 수행 시간이 공학적으로 계산된 표준 시간(Standard Time) + 허용 오차(Margin)를 초과했음을 의미한다.
#
# *   **발생 원인과 시스템 영향:**
#     이는 단순한 '느림'이 아니다.
#     1.  **경로 계획 실패:** 다수의 AMR이 교차로에 몰려 교착 상태(Deadlock)가 발생했거나, 동적 장애물 회피를 위해 비효율적인 우회 경로를 생성했을 수 있다.
#     2.  **하드웨어 노후화:** 모터 효율 저하 또는 배터리 성능 저하로 인한 속도 감소.
# *   **피드백 루프:**
#     Code 30이 발생하면 ACS는 전체 공정의 병목(Bottleneck) 현상을 방지하기 위해 후속 공정의 투입 속도를 조절하거나, 해당 AMR을 우선순위 경로로 배정하는 등의 스케줄링 재조정을 검토해야 하는 트리거가 된다.
#
# ---
#
# ## 4. 네트워크 가용성과 감시 체계 (Network Availability & Watchdog)
#
# ### 4.1. 하트비트 소실: COMMUNICATION_ERROR (Code 46)
# 공장 내부는 수많은 금속 설비와 전파 간섭(EMI)이 존재하는 가혹한 무선 통신 환경이다. **Code 46**은 ACS와 AMR 간의 연결 고리가 끊어진 상태를 정의한다.
#
# *   **감지 메커니즘 (Watchdog Timer):**
#     ACS와 AMR은 주기적으로 **'Heartbeat'** 패킷을 주고받는다. 만약 설정된 임계 시간(예: 500ms) 동안 AMR로부터 응답이 없다면, ACS 내의 **Watchdog Timer**가 만료(Expire)된다.
# *   **Fail-Safe 동작:**
#     이 알람은 단순히 "연결 끊김"을 알리는 것을 넘어, 시스템이 해당 AMR을 **'제어 불능(Uncontrollable)'** 상태로 간주하게 한다. ACS는 즉시 해당 AMR에 대한 새로운 작업 할당을 중단하고, 주변의 다른 AMR들이 해당 기체 근처로 접근하지 않도록 가상의 안전 구역(Virtual Fence)을 설정하거나 경로를 우회시키는 방어 로직을 수행한다.
#
# ---
#
# ## 5. 시스템 복구 전략 (System Recovery Strategy)
#
# 자동화 시스템에서 에러 발생은 피할 수 없는 엔트로피의 증가 과정이다. 중요한 것은 이를 어떻게 초기 상태(Initial State)로 되돌리는가이다.
#
# ### 5.1. 수동 개입과 상태 초기화 (Human-in-the-loop Recovery)
# 자동 복구 알고리즘(Auto-Retry)이 실패하여 교착 상태가 지속될 경우, 시스템은 상위 권한을 가진 운영자의 개입을 요청한다.
#
# *   **진단 및 조치 프로세스:**
#     운영자는 ACS 관제 화면(HMI)을 통해 **통신 상태(Code 46/12 관련)**와 **맵 버전 해시(Code 45 관련)**를 시각적으로 확인한다.
# *   **Reset의 공학적 의미:**
#     운영자가 [Reset] 버튼을 누르거나 수동 조작 모드로 전환하는 행위는 단순한 재부팅이 아니다. 이는 PLC 및 제어기의 **에러 레지스터(Error Register)를 소거(Clear)**하고, 소프트웨어의 상태 머신을 'Fault' 상태에서 **'Idle(대기)'** 상태로 강제 전이(State Transition)시키는 인터럽트 신호를 인가하는 과정이다. 이를 통해 시스템은 잔류하던 논리적 오류를 털어내고 다시 명령을 수신할 수 있는 깨끗한 상태(Clean State)로 복귀한다.
# 2026-01-05 15:44:41.410 | INFO     | __main__:<module>:18 - 32 텍스트북 생성 완료
# 2026-01-05 15:44:41.411 | INFO     | __main__:<module>:7 - 챕터 번호는 없어도 돼.
#
# [입력 텍스트]
# BMA 공정 ACS(Autonomous Control System)에서 감지된 100번 에러(HARD_DISK_CAPACITY_EXCEEDED)는 제어 PC의 하드디스크 저장 용량이 임계치를 초과하여 시스템 데이터 기록이 불가능한 상태를 의미한다. **시스템 자동 복구가 실패하여 수동 조작이 필요한 경우,** 운영자는 로그 파일 삭제 또는 디스크 정리 작업을 통해 저장 공간을 확보해야 한다.
#
# BMA 공정 ACS에서 감지된 700번 경고(AMR_COLLISION_RISK_WARNING)는 주행 중인 AMR의 경로상에 장애물이 감지되어 충돌 위험이 발생했음을 나타낸다.
#
# BMA 공정 ACS에서 감지된 701번 정보(WATING_FOR_MISSION_START_COLLISION_AVOIDANCE_DECTION)는 미션 시작 전 충돌 방지 센서가 물체를 감지하여 AMR이 안전 거리 확보를 위해 대기 중인 상태를 의미한다.
# 2026-01-05 15:45:19.800 | INFO     | __main__:<module>:10 - # BMA 자동화 시스템 기술 백서: ACS 리소스 관리 및 주행 안전 프로토콜 심층 분석
#
# ## 1. 서론: 데이터 무결성과 물리적 안전의 통합 아키텍처
# 현대자동차그룹 BMA(Battery Module Assembly) 공정의 핵심인 ACS(Autonomous Control System)는 단순한 물류 이송 명령을 넘어, 시스템의 **데이터 가용성(Data Availability)**과 AMR(Autonomous Mobile Robot)의 **운동학적 안전(Kinematic Safety)**을 보장하는 이중 제어 루프를 수행한다. 본 챕터에서는 제어 PC의 리소스 포화 상태(Error 100)와 주행 중/정지 시의 충돌 방지 로직(Warning 700, Info 701)이 어떠한 메커니즘으로 상호작용하며, 시스템의 안정성을 유지하는지 공학적 관점에서 기술한다.
#
# ---
#
# ## 2. 시스템 리소스 관리 및 데이터 보존 메커니즘
# ### 2.1. 스토리지 포화와 시스템 가용성 (Error 100)
#
# **100번 에러(HARD_DISK_CAPACITY_EXCEEDED)**는 ACS 제어 PC의 물리적 스토리지(HDD/SSD) 가용 공간이 시스템이 정의한 임계치(Threshold) 미만으로 떨어졌을 때 발생하는 **치명적 리소스 예외(Critical Resource Exception)**이다.
#
# #### 발생 원인 및 데이터 흐름 (Data Flow & Causality)
# BMA 공정의 ACS는 실시간으로 수백 대의 AMR 위치 정보, 배터리 모듈의 트래킹 데이터, 통신 패킷 로그를 초당 수 기가바이트(GB) 단위로 처리한다. 통상적으로 시스템은 오래된 로그를 덮어쓰는 순환 로깅(Circular Logging) 알고리즘을 통해 저장 공간을 관리한다. 그러나 다음과 같은 상황에서 이 메커니즘이 한계에 도달한다:
# 1.  **비정상적 로그 폭주:** 네트워크 불안정이나 센서 노이즈로 인해 에러 로그가 기하급수적으로 생성되어, 삭제 속도가 생성 속도를 따라가지 못하는 경우(I/O Bottleneck).
# 2.  **파일 시스템 락(File System Lock):** 특정 프로세스가 로그 파일을 점유하고 있어 삭제 프로세스(Garbage Collector)가 접근 권한을 획득하지 못하는 경우.
#
# #### 시스템 방어 기제 및 수동 복구의 필요성
# 이 에러가 트리거되면, ACS는 데이터 무결성 훼손을 방지하기 위해 **'쓰기 방지(Write Protection)'** 모드와 유사한 방어 기제를 작동시킨다. 저장 공간이 0이 될 경우 OS(운영체제) 자체가 셧다운되거나 DB가 깨지는 치명적인 손상을 입을 수 있기 때문이다.
# 따라서 **"시스템 자동 복구가 실패하여 수동 조작이 필요한 경우"**란, 소프트웨어 레벨의 자정 작용(Self-Healing)이 물리적 한계에 봉착했음을 의미한다. 이때 운영자는 엔지니어링 모드에 진입하여 불필요한 덤프(Dump) 파일이나 아카이브된 로그를 수동으로 삭제(Purge)하거나 디스크 조각 모음을 수행하여, OS가 다시 정상적인 I/O 작업을 수행할 수 있도록 물리적 주소를 확보해야 한다.
#
# ---
#
# ## 3. AMR 주행 안전 및 충돌 회피 알고리즘
# AMR의 안전 시스템은 로봇의 운동 상태(Kinematics)에 따라 **동적 감지(Dynamic Detection)**와 **정적 감지(Static Detection)**로 구분되어 작동한다. 이는 배터리 모듈이라는 고중량/고위험 화물을 다루는 BMA 공정의 특성상 필수적인 이중 안전장치이다.
#
# ### 3.1. 동적 주행 중 충돌 예측 및 회피 (Warning 700)
#
# **700번 경고(AMR_COLLISION_RISK_WARNING)**는 AMR이 주행 벡터(Velocity Vector)를 가지고 이동하는 도중, 경로 상에 장애물이 감지되었을 때 발생하는 **실시간 경로 제어 신호**이다.
#
# #### 센서 퓨전 및 판단 로직 (Sensor Fusion & Logic)
# AMR 전방에 장착된 2D/3D LiDAR 센서는 ToF(Time of Flight) 방식을 통해 주변 환경을 포인트 클라우드(Point Cloud) 형태로 스캔한다.
# 1.  **감지(Detection):** 주행 경로(Global Path) 상에 설정된 '감속 영역(Slow-down Zone)' 또는 '정지 영역(Stop Zone)' 내에 미확인 물체의 좌표가 인식된다.
# 2.  **연산(Calculation):** AMR의 현재 속도, 적재된 배터리 모듈의 질량에 따른 관성 모멘트(Moment of Inertia)를 계산하여 **제동 거리(Braking Distance)**를 산출한다.
# 3.  **트리거(Trigger):** 산출된 제동 거리가 장애물과의 거리보다 짧아질 위험이 있을 때, 시스템은 즉시 700번 경고를 송출한다.
#
# #### 시스템 반응
# 이 코드는 단순한 알람이 아니라, AMR의 모터 컨트롤러(MCU)에 개입하여 **감속(Deceleration)** 또는 **긴급 정지(E-Stop)** 시퀀스를 활성화하는 전조 신호이다. 장애물이 제거되거나 회피 경로(Local Path Planning)가 생성되면 경고는 자동으로 해제되고 주행이 재개된다.
#
# ### 3.2. 미션 시작 전 초기 안전 인터록 (Info 701)
#
# **701번 정보(WATING_FOR_MISSION_START_COLLISION_AVOIDANCE_DECTION)**는 AMR이 정지 상태에서 새로운 미션을 부여받았으나, 출발 직전 안전 센서에 장애물이 감지되어 **기동을 유보(Suspend)**하고 있는 상태이다.
#
# #### 작동 원리: 제로 속도에서의 사각지대 감시
# AMR이 정지해 있을 때는 작업자나 다른 장비가 AMR에 매우 근접해 있을 가능성이 높다. 이때 즉시 가속할 경우, LiDAR의 최소 감지 거리(Blind Spot)나 기구적 사각지대에서 사고가 발생할 수 있다.
# 1.  **미션 수신:** 상위 시스템(ACS)으로부터 이동 명령을 수신한다.
# 2.  **프리-플라이트 체크(Pre-flight Check):** 모터에 전력을 인가하기 전, 근거리 초음파 센서나 범퍼 센서 등을 통해 AMR 주변의 안전 공간(Safety Margin)을 스캔한다.
# 3.  **인터록(Interlock) 발동:** 장애물이 감지되면 701번 코드를 띄우고, 모터 브레이크를 해제하지 않는다. 이는 에러(Error)가 아닌 **대기(Waiting)** 상태로, 시스템은 장애물이 사라질 때까지 무한 루프(Polling)를 돌며 안전을 확인한다.
#
# #### 공학적 의의
# 이 기능은 **"Blind Start(맹목적 출발)"**를 방지하는 핵심 로직이다. 운영자가 별도의 조치를 취하지 않아도, 장애물(예: 지나가는 작업자)이 안전 구역을 벗어나면 센서 신호가 Low로 떨어지며 AMR은 즉시 미션을 시작한다. 즉, 701번은 시스템의 오작동이 아니라, **안전이 확보될 때까지 물리적 기동을 원천 차단하는 능동적 방어 기제**이다.
# 2026-01-05 15:45:19.801 | INFO     | __main__:<module>:18 - 33 텍스트북 생성 완료

# %%
with open("acs_alarm_textbook_merged.json", "w", encoding="utf-8") as f:
    json.dump(result2, f, ensure_ascii=False, indent=4)

# %%
hacs_results = []
for i, x in enumerate(hacs_preprocessed):
    context = x['preprocessed']
    user_prompt = f"""[입력]
{context}"""
    logger.info(user_prompt)
    response = llm_client.generate(system_prompt=SYNTHETIC_SPECIFIC_PROMPT, chat_messages=[{"role": "user", "content": user_prompt}])
    result = response.choices[0].message.content
    logger.info(result)
    json_result = {
        'id': i,
        'preprocessed_group': context,
        'textbook': result
    }
    hacs_results.append(json_result)

with open("hacs_textbook_merged2.json", "w", encoding="utf-8") as f:
    json.dump(hacs_results, f, ensure_ascii=False, indent=4)
# Out:
# 2026-01-09 16:52:51.755 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 1. User Controller. 사용자 인증 및 관리 API
# ### 1.1 사용자 등록
# - **Endpoint**: `PUT /api/user/register`
# - **설명**: 새로운 사용자 등록
# - **Request Body**:
# ```json
# {
#   "userInfo": {
#     "UserId": "string",
#     "UserName": "string",
#     "Password": "string",
#     "Email": "string"
#   }
# }
# ```
# - **Response**:
# ```json
# {
#   "Success": true/false
# }
# ```
# - **Status Code**: 200 OK, 500 Internal Server Error
#
#
# 2026-01-09 16:53:13.239 | INFO     | __main__:<module>:9 - ## [API] 사용자 등록 (User Registration)
#
# **1. 개요 (Overview)**
# `PUT /api/user/register` API는 현대 자동화 제어 시스템(HACS) WebBackend에 접근할 수 있는 신규 사용자 계정을 생성한다. 이 API는 시스템 관리자나 운영자가 BMA(Battery Manufacturing Automation) 공정 모니터링 및 제어 권한을 획득하기 위한 최초의 자격 증명(Credentials)을 등록하는 데 사용된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/user/register`
# - **Method:** `PUT`
# - **Content-Type:** `application/json`
# - **Body Parameters:**
#   요청 본문은 `userInfo` 객체 내에 사용자 상세 정보를 포함해야 한다.
#
# | Parameter | Type | Required | Description |
# | :--- | :--- | :--- | :--- |
# | **userInfo** | Object | **Yes** | 사용자 정보 컨테이너 객체 |
# | └ `UserId` | String | **Yes** | 시스템 내에서 유일한 사용자 식별 ID (예: 사번, 시스템 ID) |
# | └ `UserName` | String | **Yes** | 사용자의 실제 이름 또는 표시명 |
# | └ `Password` | String | **Yes** | 계정 접속을 위한 비밀번호 (암호화 전송 권장) |
# | └ `Email` | String | **Yes** | 사용자 연락처 및 계정 복구용 이메일 주소 |
#
# **3. 응답 명세 (Response Specification)**
# - **Status Code:** `200 OK` (성공), `500 Internal Server Error` (서버 오류)
# - **Body Structure:**
# ```json
# {
#   "Success": true  // 등록 성공 여부 (Boolean)
# }
# ```
#
# **4. 사용 사례 (Use Case)**
# 이 API는 공장 내 신규 인력이 배치되거나 관리자 권한이 필요한 엔지니어가 추가될 때 호출된다.
# - **시나리오:** 새로운 공정 관리자(Operator)가 입사하여, 관제 시스템 대시보드에 로그인하여 AMR(자율 이동 로봇)의 위치를 모니터링하고 알람을 제어해야 하는 상황. 시스템 관리자는 이 API를 통해 해당 관리자의 `UserId`와 초기 `Password`를 시스템 DB에 등록한다.
#
# **5. 요청 예시 (Request Body Example)**
# 다음은 ID가 `HACS_OP_05`인 신규 운영자를 등록하는 요청의 예시이다.
#
# ```json
# {
#   "userInfo": {
#     "UserId": "HACS_OP_05",
#     "UserName": "Hyun-Soo Kim",
#     "Password": "InitialPassword123!",
#     "Email": "hskim@hyundai-robotics.com"
#   }
# }
# ```
# 2026-01-09 16:53:13.240 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 1. User Controller. 사용자 인증 및 관리 API
# ### 1.2 로그인
# - **Endpoint**: `PUT /api/user/login`
# - **설명**: 사용자 로그인 및 JWT 토큰 발급
# - **Request Body**:
# ```json
# {
#   "userInfo": {
#     "UserId": "string",
#     "Password": "string"
#   }
# }
# ```
# - **Response**:
# ```json
# {
#   "userInfo": {
#     "UserId": "string",
#     "UserName": "string",
#     "Email": "string",
#     "TokenLifetime": 0,
#     "ClientId": "string",
#     "Roles": ["string"]
#   },
#   "loginInfo": {
#     "Success": true,
#     "LoginTime": "2024-01-01T00:00:00",
#     "AuthToken": "string"
#   }
# }
# ```
# - **Status Code**:
#   - 200 OK
#   - 401 Unauthorized (잘못된 ID/비밀번호)
#   - 403 Forbidden (비활성 사용자)
#   - 406 Not Acceptable (최대 사용자 수 초과)
#
#
# 2026-01-09 16:53:35.782 | INFO     | __main__:<module>:9 - ## [API] 사용자 로그인 (User Login)
#
# **1. 개요 (Overview)**
# `PUT /api/user/login` API는 현대 자동화 제어 시스템(HACS)에 접근하기 위한 사용자 인증 및 세션 초기화를 수행한다. 클라이언트가 유효한 자격 증명(Credential)을 제공하면, 시스템은 접근 권한(Role)이 포함된 JWT(JSON Web Token)를 발급한다. 이 토큰은 이후 수행되는 모든 제어 및 모니터링 API 호출 시 인증 헤더로 사용되어야 한다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/user/login`
# - **Method:** `PUT`
# - **Content-Type:** `application/json`
# - **Body Parameters:**
#
# | Parameter | Type | Required | Description |
# | :--- | :--- | :--- | :--- |
# | **userInfo** | Object | **Yes** | 사용자 인증 정보를 담는 래퍼(Wrapper) 객체 |
# | └ `UserId` | String | **Yes** | 사용자 고유 식별자 (ID) |
# | └ `Password` | String | **Yes** | 사용자 비밀번호 (Plain text 또는 Hash, 시스템 설정에 따름) |
#
# **3. 응답 명세 (Response Specification)**
# 응답은 사용자 상세 정보(`userInfo`)와 인증 토큰 정보(`loginInfo`)로 구성된다.
# - **Status Codes:**
#   - `200 OK`: 로그인 성공 및 토큰 발급 완료.
#   - `401 Unauthorized`: 인증 실패 (ID 또는 비밀번호 불일치).
#   - `403 Forbidden`: 계정이 비활성화되었거나 잠김 상태임.
#   - `406 Not Acceptable`: 동시 접속자 수 초과 등 시스템 정책에 의한 거부.
#
# **4. 사용 사례 (Use Case)**
# - **HMI 단말기 접속:** BMA(Battery/Body Manufacturing Automation) 공정 라인의 작업자가 HMI 패널에서 시프트를 시작하기 위해 로그인할 때 사용된다.
# - **외부 시스템 연동:** MES(생산 관리 시스템)나 AGV 관제 서버가 제어 시스템에 명령을 내리기 전, 최초 세션을 수립(Handshake)하는 단계에서 호출된다.
#
# **5. 요청 예시 (Request Body Example)**
# ```json
# {
#   "userInfo": {
#     "UserId": "operator_line_1",
#     "Password": "HacsUser2024!"
#   }
# }
# ```
#
# **6. 응답 예시 (Response Body Example)**
# ```json
# {
#   "userInfo": {
#     "UserId": "operator_line_1",
#     "UserName": "Kim Hyundai",
#     "Email": "kim.h@hyundai-robotics.com",
#     "TokenLifetime": 3600,
#     "ClientId": "HMI_Panel_05",
#     "Roles": [
#       "Operator",
#       "Viewer"
#     ]
#   },
#   "loginInfo": {
#     "Success": true,
#     "LoginTime": "2024-05-20T08:30:00",
#     "AuthToken": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIxMjM0NTY3ODkwIiwibmFtZSI6Ik..."
#   }
# }
# ```
# 2026-01-09 16:53:35.789 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 1. User Controller. 사용자 인증 및 관리 API
# ### 1.3 로그아웃
# - **Endpoint**: `PUT /api/user/logout`
# - **설명**: 사용자 로그아웃
# - **Headers**: JWT 토큰 필요
# - **Response**: 200 OK
#
# ---
#
#
# 2026-01-09 16:54:03.252 | INFO     | __main__:<module>:9 - ## [API] 사용자 로그아웃 (User Logout)
#
# **1. 개요 (Overview)**
# `PUT /api/user/logout` API는 현재 시스템에 로그인된 사용자의 세션을 안전하게 종료하고, 활성화된 인증 토큰(JWT)을 무효화(Invalidate)하는 기능을 수행한다. 이 API는 작업자 교대, 업무 종료, 또는 보안 정책에 따른 자동 세션 만료 시 시스템 접근 권한을 즉시 회수하기 위해 사용된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/user/logout`
# - **Method:** `PUT`
# - **Content-Type:** `application/json`
# - **Header:**
#   - `Authorization`: `Bearer {AccessToken}` (필수, 유효한 JWT 토큰)
# - **Body Parameters:**
#   - 본 API는 별도의 Request Body 파라미터를 요구하지 않는다. (Empty Body)
#
# **3. 사용 사례 (Use Case)**
# - **작업자 교대:** BMA 공정 라인의 HMI(Human Machine Interface) 단말기에서 오전 조 작업자가 업무를 마치고 로그아웃 버튼을 눌러 세션을 종료할 때 호출된다.
# - **보안 타임아웃:** 제어 시스템 보안 규정에 따라, 일정 시간 동안 작업자의 입력이 감지되지 않을 경우 클라이언트 애플리케이션이 자동으로 이 API를 호출하여 강제 로그아웃 처리한다.
#
# **4. 요청 예시 (Request Body Example)**
# *본 API는 Body 없이 호출하거나, 빈 JSON 객체를 전송합니다.*
#
# ```json
# {}
# ```
#
# **5. 응답 예시 (Response Example)**
# ```json
# {
#   "statusCode": 200,
#   "message": "Logout successful",
#   "timestamp": "2023-10-27T14:30:00Z"
# }
# ```
# 2026-01-09 16:54:03.255 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 2. Work Order Controller. 작업 오더 관리 API
# ### 2.1 실행중인 작업 조회
# - **Endpoint**: `GET /api/workorder/running`
# - **설명**: 현재 실행중이거나 대기중인 작업 오더 목록 조회
# - **Headers**: JWT 토큰 필요
# - **Response**:
# ```json
# [
#   {
#     "OrderNo": 0,
#     "MissionId": 0,
#     "MissionName": "string",
#     "StartNo": "string",
#     "StartNode": "string",
#     "DestNo": "string",
#     "DestNode": "string",
#     "OST": "Idle/Running",
#     "RDT": "2024-01-01T00:00:00"
#   }
# ]
# ```
# - **Status Code**: 200 OK, 401/403 (인증 실패)
#
#
# 2026-01-09 16:54:27.179 | INFO     | __main__:<module>:9 - ## [API] 실행중인 작업 조회 (Get Running Work Orders)
#
# **1. 개요 (Overview)**
# `GET /api/workorder/running` API는 현재 시스템 내에서 **실행 중(Running)**이거나 **대기 중(Idle/Waiting)**인 모든 작업 오더(Work Order)의 목록을 실시간으로 조회한다. 이 API는 관제 시스템(ACS)의 대시보드 모니터링, 물류 흐름 파악, 그리고 병목 현상 분석을 위한 기초 데이터를 제공하는 데 사용된다.
#
# **2. 기술 명세 (Technical Specification)**
# - **Endpoint:** `/api/workorder/running`
# - **Method:** `GET`
# - **Header:**
#   - `Authorization: Bearer {Token}` (JWT 인증 필수)
#   - `Content-Type: application/json`
# - **Request Body:** 없음 (None)
# - **Response Body:** 작업 오더 객체의 배열(Array) 형태
#
# **3. 응답 필드 정의 (Response Fields)**
# 응답으로 반환되는 JSON 배열 내 각 객체의 필드 정의는 다음과 같다.
#
# | 필드명 | 타입 | 설명 | 비고 |
# | :--- | :--- | :--- | :--- |
# | `OrderNo` | Integer | 작업 오더 고유 식별 번호 | Primary Key |
# | `MissionId` | Integer | 할당된 미션 ID | 미션 템플릿 식별자 |
# | `MissionName` | String | 미션의 사람이 읽을 수 있는 이름 | 예: "Tray_Transport" |
# | `StartNo` | String | 시작 위치 번호/ID | |
# | `StartNode` | String | 시작 노드 명칭 | 토폴로지 상의 노드 이름 |
# | `DestNo` | String | 목적지 위치 번호/ID | |
# | `DestNode` | String | 목적지 노드 명칭 | |
# | `OST` | String | 오더 상태 (Order Status) | `Idle`, `Running` 등 |
# | `RDT` | String | 오더 생성 일시 (Registration Date Time) | ISO 8601 형식 |
#
# **4. 사용 사례 (Use Case)**
# - **실시간 관제 모니터링:** 운영자가 현재 공장 내에서 활성화된 모든 로봇의 작업 현황을 한눈에 파악하고자 할 때 호출한다.
# - **시스템 유지보수 전 확인:** 서버 재시작이나 로봇 점검 전, 현재 진행 중인 중요 작업이 있는지 확인하여 안전하게 작업을 종료하거나 대기시키기 위해 사용한다.
# - **작업 부하 분석:** 대기 중(`Idle`)인 오더가 급증하는 경우, 특정 구역의 병목 현상을 감지하는 로직에 활용된다.
#
# **5. 응답 예시 (Response Body Example)**
# *참고: 이 API는 GET 요청이므로 Request Body가 없습니다. 아래는 성공적인 호출 시 반환되는 **Response Body**의 예시입니다.*
#
# ```json
# [
#   {
#     "OrderNo": 1024,
#     "MissionId": 501,
#     "MissionName": "Transport_Raw_Material_A",
#     "StartNo": "LOC_001",
#     "StartNode": "Warehouse_Zone_1",
#     "DestNo": "LOC_055",
#     "DestNode": "Assembly_Line_3",
#     "OST": "Running",
#     "RDT": "2024-05-21T09:30:00"
#   },
#   {
#     "OrderNo": 1025,
#     "MissionId": 502,
#     "MissionName": "Transport_Empty_Tray",
#     "StartNo": "LOC_055",
#     "StartNode": "Assembly_Line_3",
#     "DestNo": "LOC_099",
#     "DestNode": "Cleaning_Zone",
#     "OST": "Idle",
#     "RDT": "2024-05-21T09:35:15"
#   }
# ]
# ```
# 2026-01-09 16:54:27.182 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 2. Work Order Controller. 작업 오더 관리 API
# ### 2.2 작업 이력 조회
# - **Endpoint**: `GET /api/workorder/history?hours={hours}`
# - **설명**: 특정 시간(시간 단위) 동안의 작업 오더 이력 조회
# - **Headers**: JWT 토큰 필요
# - **Query Parameters**:
#   - `hours` (int): 조회할 시간 범위 (예: 24)
# - **Response**: 2.1과 동일한 형식의 배열
# - **Status Code**: 200 OK, 401/403 (인증 실패)
#
#
# 2026-01-09 16:54:51.589 | INFO     | __main__:<module>:9 - ## [API] 작업 이력 조회 (Work Order History)
#
# **1. 개요 (Overview)**
# `GET /api/workorder/history` API는 현재 시점을 기준으로 지정된 시간 범위(Hours) 내에 생성 및 처리된 모든 작업 오더(Work Order)의 이력을 조회한다. 이 API는 시스템의 가동률 분석, 일일 작업 리포트 생성, 또는 공정 문제 발생 시 과거 작업 흐름을 역추적(Traceback)하기 위한 감사(Audit) 목적으로 사용된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/workorder/history`
# - **Method:** `GET`
# - **Header:**
#   - `Authorization`: `Bearer {Token}` (JWT 인증 토큰 필수)
#   - `Content-Type`: `application/json`
# - **Query Parameters:**
#
# | Parameter | Type | Required | Description |
# | :--- | :--- | :--- | :--- |
# | `hours` | Integer | **Yes** | 조회할 시간 범위. 현재 시점으로부터 과거 N시간 동안의 데이터를 필터링한다. (예: `24` 입력 시 최근 24시간 조회) |
#
# **3. 사용 사례 (Use Case)**
# - **일일 생산 리포트 생성:** 관리자가 교대 근무(Shift) 종료 후, 지난 8시간(`hours=8`) 동안 완료된 작업의 총량과 상태를 확인하여 생산 실적을 집계할 때 사용한다.
# - **공정 병목 분석:** 특정 시간대(최근 24시간)에 작업 지연이 발생했는지 확인하기 위해 이력을 조회하고, `COMPLETED` 시간과 `CREATED` 시간의 차이를 분석할 때 호출한다.
#
# **4. 요청 예시 (Request Example)**
# *이 API는 GET 요청이므로 Request Body가 없으며, URL Query String을 통해 파라미터를 전달한다.*
#
# ```http
# GET /api/workorder/history?hours=24 HTTP/1.1
# Host: api.hacs.hyundai.com
# Authorization: Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9...
# ```
#
# **5. 응답 예시 (Response Example)**
# *응답은 작업 오더 객체의 배열(Array) 형태로 반환된다. (구조는 2.1 작업 오더 조회와 동일하다고 가정)*
#
# ```json
# [
#   {
#     "orderId": "WO-20231025-001",
#     "workType": "TRANSPORT_MATERIAL",
#     "status": "COMPLETED",
#     "assignedRobot": "AMR_H01",
#     "priority": "HIGH",
#     "location": {
#       "source": "WAREHOUSE_A",
#       "destination": "LINE_1_INPUT"
#     },
#     "timestamps": {
#       "created": "2023-10-25T08:00:00Z",
#       "started": "2023-10-25T08:05:00Z",
#       "completed": "2023-10-25T08:15:00Z"
#     }
#   },
#   {
#     "orderId": "WO-20231025-002",
#     "workType": "CHARGE_BATTERY",
#     "status": "IN_PROGRESS",
#     "assignedRobot": "AMR_H02",
#     "priority": "NORMAL",
#     "location": {
#       "source": "LINE_2_OUTPUT",
#       "destination": "CHARGING_STATION_3"
#     },
#     "timestamps": {
#       "created": "2023-10-25T09:30:00Z",
#       "started": "2023-10-25T09:35:00Z",
#       "completed": null
#     }
#   }
# ]
# ```
#
# **6. 상태 코드 (Status Codes)**
# - `200 OK`: 요청이 성공적으로 처리되어 이력 데이터가 반환됨.
# - `400 Bad Request`: `hours` 파라미터가 누락되었거나, 정수형이 아님 (예: 음수 또는 문자열).
# - `401 Unauthorized`: 유효하지 않거나 만료된 JWT 토큰.
# - `403 Forbidden`: 해당 사용자가 작업 이력을 조회할 권한이 없음.
# 2026-01-09 16:54:51.591 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 2. Work Order Controller. 작업 오더 관리 API
# ### 2.3 작업 오더 삭제
# - **Endpoint**: `DELETE /api/workorder/order?orderNo={orderNo}`
# - **설명**: 작업 오더 삭제 (미션 관리자 권한 필요)
# - **Headers**: JWT 토큰 필요
# - **Query Parameters**:
#   - `orderNo` (long): 삭제할 작업 오더 번호
# - **Response**:
# ```json
# {
#   "Success": true/false,
#   "Message": "string"
# }
# ```
# - **Status Code**: 200 OK, 403 Forbidden (권한 없음)
#
# ---
#
#
# 2026-01-09 16:55:14.889 | INFO     | __main__:<module>:9 - ## [API] 작업 오더 삭제 (Delete Work Order)
#
# **1. 개요 (Overview)**
# `DELETE /api/workorder/order` API는 시스템에 등록된 특정 작업 오더(Work Order)를 영구적으로 제거하는 기능을 수행한다. 이 작업은 생산 계획의 변경이나 오발주된 명령을 취소하기 위해 사용되며, 데이터 무결성 및 공정 안전을 위해 **미션 관리자(Mission Manager)** 권한을 가진 사용자만이 실행할 수 있다.
#
# **2. 기술 명세 (Technical Specification)**
# - **Endpoint:** `/api/workorder/order`
# - **Method:** `DELETE`
# - **Header:**
#   - `Authorization: Bearer {Token}` (JWT 인증 토큰 필수, 미션 관리자 권한 포함)
#   - `Content-Type: application/json`
# - **Query Parameters:**
#   | 파라미터명 | 타입 (Type) | 필수 여부 | 설명 |
#   | :--- | :--- | :--- | :--- |
#   | `orderNo` | Long | **Required** | 삭제 대상 작업 오더의 고유 식별 번호 (Unique ID) |
#
# **3. 사용 사례 (Use Case)**
# BMA 공정 라인에서 다음과 같은 상황 발생 시 이 API가 호출된다.
# - **시나리오:** 생산 관리자가 실수로 자재가 준비되지 않은 라인으로 AGV 운송 명령(Order No: 10502)을 생성하였다. 해당 오더가 실행될 경우 AGV가 대기 상태로 정체(Deadlock)될 위험이 있다.
# - **조치:** 관제 시스템의 미션 관리자는 해당 오더 번호(`10502`)를 파라미터로 하여 삭제 API를 호출함으로써, 대기열에서 해당 작업을 즉시 제거하고 리소스를 확보한다.
#
# **4. 요청 예시 (Request Example)**
# 이 API는 Query Parameter를 사용하므로 Request Body는 비어 있습니다.
#
# **HTTP Request:**
# ```http
# DELETE /api/workorder/order?orderNo=10502 HTTP/1.1
# Host: bma-backend.hyundai.com
# Authorization: Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9...
# ```
#
# **5. 응답 예시 (Response Example)**
#
# **성공 시 (Status: 200 OK):**
# ```json
# {
#   "Success": true,
#   "Message": "작업 오더(10502)가 성공적으로 삭제되었습니다."
# }
# ```
#
# **실패 시 - 권한 없음 (Status: 403 Forbidden):**
# ```json
# {
#   "Success": false,
#   "Message": "삭제 권한이 없습니다. 미션 관리자 권한이 필요합니다."
# }
# ```
# 2026-01-09 16:55:14.890 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 3. Object Controller. 맵 객체 및 AMR 상태 관리 API
# ### 3.1 기본 테스트 엔드포인트
# - **Endpoint**: `GET /api/object/default`
# - **설명**: API 테스트용 기본 엔드포인트
# - **Response**: "Hello, Default" (문자열)
# - **Status Code**: 200 OK
#
#
# 2026-01-09 16:55:34.731 | INFO     | __main__:<module>:9 - ## [API] 객체 제어 모듈 연결 테스트 (Object Controller Connectivity Test)
#
# **1. 개요 (Overview)**
# `GET /api/object/default` API는 **Object Controller(맵 객체 및 AMR 상태 관리 모듈)**의 서비스 가용성(Availability)을 확인하기 위한 진단용 엔드포인트이다. 클라이언트(프론트엔드 또는 타 시스템)가 해당 컨트롤러와 정상적으로 통신 가능한 상태인지 검증하는 헬스 체크(Health Check) 목적으로 사용된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/object/default`
# - **Method:** `GET`
# - **Content-Type:** `N/A` (요청 본문 없음)
# - **Header:**
#   - `Authorization: Bearer {Token}` (시스템 보안 정책에 따라 인증 토큰이 필요할 수 있음)
# - **Path/Query Parameters:** 없음
#
# **3. 사용 사례 (Use Case)**
# 이 API는 BMA 공정 시스템 내에서 다음과 같은 상황에 활용된다.
# - **시스템 초기화(Initialization):** 관제 시스템 부팅 시, Object Controller 백엔드가 정상적으로 기동되었는지 확인하는 초기 핸드셰이크(Handshake) 과정.
# - **하트비트 모니터링(Heartbeat):** 네트워크 단절이나 서비스 크래시(Crash) 여부를 감지하기 위해 주기적으로 호출하여 연결 상태를 점검.
# - **API 라우팅 디버깅:** 개발 단계에서 API 게이트웨이 또는 프록시 설정이 올바르게 Object Controller로 라우팅 되는지 검증.
#
# **4. 요청 및 응답 예시 (Request & Response Example)**
#
# **Request (cURL Example)**
# ```bash
# curl -X GET "http://{HOST}/api/object/default" \
#      -H "Authorization: Bearer {YOUR_ACCESS_TOKEN}"
# ```
#
# **Response (Success, 200 OK)**
# > 본 API는 JSON 객체가 아닌 단순 문자열(String)을 반환한다.
# ```text
# "Hello, Default"
# ```
# 2026-01-09 16:55:34.734 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 3. Object Controller. 맵 객체 및 AMR 상태 관리 API
# ### 3.2 헬로 테스트 엔드포인트
# - **Endpoint**: `GET /api/object/hello`
# - **설명**: API 테스트용 헬로 엔드포인트
# - **Response**: "Hello, World" (문자열)
# - **Status Code**: 200 OK
#
#
# 2026-01-09 16:55:54.107 | INFO     | __main__:<module>:9 - ## [API] 서비스 가용성 진단 (Service Availability Check / Hello)
#
# **1. 개요 (Overview)**
# `GET /api/object/hello` API는 Object Controller 서비스의 정상 동작 여부 및 클라이언트와의 네트워크 연결 상태를 확인하기 위한 진단(Diagnostic) 엔드포인트이다. 복잡한 제어 명령을 수행하기 전, 시스템의 응답 가능 상태(Liveness)를 검증하는 데 사용된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/object/hello`
# - **Method:** `GET`
# - **Header:**
#   - `Accept: text/plain` (또는 `application/json`)
# - **Path/Query Parameters:** 없음
# - **Body Parameters:** 없음 (No Request Body)
#
# **3. 사용 사례 (Use Case)**
# 이 API는 다음과 같은 BMA 공정 시나리오에서 활용된다.
# - **시스템 초기화 (Initialization):** ACS(Automated Control System) 클라이언트 또는 에이전트가 부팅된 직후, 백엔드 서버와 통신이 가능한지 확인하는 핸드쉐이킹(Handshaking) 단계.
# - **상태 모니터링 (Health Check):** 외부 모니터링 시스템이 주기적으로 호출하여 Object Controller 서비스의 다운타임(Downtime) 여부를 감지.
# - **네트워크 디버깅:** 맵 객체 동기화 실패 시, 네트워크 단절인지 인증 문제인지 격리하기 위한 1차 테스트.
#
# **4. 요청 및 응답 예시 (Request & Response Example)**
#
# **Request (HTTP)**
# ```http
# GET /api/object/hello HTTP/1.1
# Host: {Server_IP}: {Port}
# Accept: text/plain
# ```
#
# **Response (Success)**
# ```text
# Hello, World
# ```
# *(참고: 해당 API는 단순 문자열을 반환하며, Status Code 200 OK는 서비스가 정상임을 의미한다.)*
# 2026-01-09 16:55:54.108 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 3. Object Controller. 맵 객체 및 AMR 상태 관리 API
# ### 3.3 맵 객체 조회
# - **Endpoint**: `GET /api/object/map`
# - **설명**: 맵 상의 모든 객체 정보 조회
# - **Headers**: JWT 토큰 필요
# - **Response**:
# ```json
# [
#   {
#     "LayoutId": 0,
#     "ObjId": 0,
#     "ObjType": "string",
#     "ObjNo": 0,
#     "ObjNM": "string",
#     "SubType": 0,
#     "X": 0,
#     "Y": 0,
#     "W": 0,
#     "H": 0,
#     "R": 0.0,
#     "Angle": 0.0,
#     "Border": 0,
#     "Path": "string",
#     "Align": 0,
#     "ColorSet": 0,
#     "FontSet": 0,
#     "Properties": "string",
#     "PrcsCD": "string"
#   }
# ]
# ```
# - **Status Code**: 200 OK
#
#
# 2026-01-09 16:56:20.366 | INFO     | __main__:<module>:9 - ## [API] 맵 객체 전체 조회 (Retrieve Map Objects)
#
# **1. 개요 (Definition)**
# `GET /api/object/map` API는 공장 레이아웃을 구성하는 모든 정적/동적 객체(설비, 벽, 구역, 경로 등)의 메타데이터와 공간 좌표 정보를 조회한다. 관제 시스템(Dashboard)이 디지털 트윈(Digital Twin) 환경을 렌더링하거나, AMR이 주행 중 참조해야 할 환경 정보를 동기화하기 위해 사용된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/object/map`
# - **Method:** `GET`
# - **Header:**
#   - `Authorization: Bearer {Token}` (JWT 인증 필수)
#   - `Content-Type: application/json`
# - **Request Body:** 없음 (None)
#
# **3. 응답 데이터 구조 (Response Data Structure)**
# 응답은 객체 정보 객체들의 배열(`Array`) 형태이다.
#
# | 필드명 (Field) | 타입 (Type) | 설명 (Description) |
# | :--- | :--- | :--- |
# | `LayoutId` | Integer | 객체가 소속된 레이어 또는 맵 ID |
# | `ObjId` | Integer | 객체 고유 식별자 (Primary Key) |
# | `ObjType` | String | 객체 유형 (예: `EQUIPMENT`, `WALL`, `ZONE`) |
# | `ObjNo` | Integer | 객체 관리 번호 |
# | `ObjNM` | String | 객체 명칭 (표시용 이름) |
# | `SubType` | Integer | 객체 하위 유형 분류 코드 |
# | `X`, `Y` | Number | 맵 상의 절대 좌표 (X, Y) |
# | `W`, `H` | Number | 객체의 너비(Width) 및 높이(Height) |
# | `R`, `Angle` | Number | 회전 반경(Radius) 및 각도(Angle, 도 단위) |
# | `Border` | Integer | 테두리 스타일 코드 |
# | `Path` | String | 벡터 그래픽 경로 데이터 (SVG Path 등) |
# | `Align` | Integer | 정렬 기준 코드 |
# | `ColorSet`, `FontSet` | Integer | 시각화 렌더링을 위한 색상 및 폰트 설정 ID |
# | `Properties` | String | 객체별 추가 속성 (JSON String 형태 권장) |
# | `PrcsCD` | String | 연동된 공정 코드 (Process Code, MES 연동용) |
#
# **4. 사용 사례 (Use Case)**
# - **관제 시스템 초기화:** 웹 클라이언트가 최초 로딩될 때, 공장의 배경 맵과 설비 배치를 2D/3D로 시각화하기 위해 호출한다.
# - **좌표 매핑:** 특정 공정(`PrcsCD`)이 수행되는 설비의 물리적 위치(`X`, `Y`)를 파악하여, AMR에게 해당 설비 앞을 목적지로 설정할 때 참조 데이터로 활용한다.
#
# **5. 응답 예시 (Response Body Example)**
# ```json
# [
#   {
#     "LayoutId": 1,
#     "ObjId": 1001,
#     "ObjType": "STATION",
#     "ObjNo": 101,
#     "ObjNM": "Assembly_Station_A",
#     "SubType": 2,
#     "X": 1500.5,
#     "Y": 3200.0,
#     "W": 200,
#     "H": 150,
#     "R": 0.0,
#     "Angle": 90.0,
#     "Border": 1,
#     "Path": "M10 10 H 90 V 90 H 10 L 10 10",
#     "Align": 4,
#     "ColorSet": 5,
#     "FontSet": 1,
#     "Properties": "{\"isActive\": true, \"capacity\": 5}",
#     "PrcsCD": "PRCS_ASM_01"
#   },
#   {
#     "LayoutId": 1,
#     "ObjId": 2005,
#     "ObjType": "OBSTACLE",
#     "ObjNo": 99,
#     "ObjNM": "Safety_Pillar",
#     "SubType": 0,
#     "X": 1800.0,
#     "Y": 3200.0,
#     "W": 50,
#     "H": 50,
#     "R": 25.0,
#     "Angle": 0.0,
#     "Border": 0,
#     "Path": "",
#     "Align": 0,
#     "ColorSet": 2,
#     "FontSet": 0,
#     "Properties": "",
#     "PrcsCD": ""
#   }
# ]
# ```
# 2026-01-09 16:56:20.367 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 3. Object Controller. 맵 객체 및 AMR 상태 관리 API
# ### 3.4 맵 스타일 조회
# - **Endpoint**: `GET /api/object/mapstyle`
# - **설명**: 맵 스타일 정보 조회
# - **Headers**: JWT 토큰 필요
# - **Response**:
# ```json
# [
#   {
#     "ObjType": "AMR/Node/Rack 등",
#     "StyleType": 0,
#     "StyleId": 0,
#     "Prop": 0,
#     "Font": "Arial",
#     "FontSize": 12.0,
#     "FontStyle": 0,
#     "TextColor": 0,
#     "BackColor": 0,
#     "SelectedColor": 0,
#     "HilightColor": 0,
#     "BorderColor": 0,
#     "SelBorderColor": 0,
#     "Opt": 0,
#     "IsDefault": true
#   }
# ]
# ```
# - **Status Code**: 200 OK
#
#
# 2026-01-09 16:56:45.436 | INFO     | __main__:<module>:9 - ## [API] 맵 스타일 구성 정보 조회 (Get Map Style Configuration)
#
# **1. 개요 (Overview)**
# `GET /api/object/mapstyle` API는 관제 시스템(Web Monitoring Dashboard) 내에서 렌더링되는 다양한 객체(AMR, Node, Rack 등)의 시각적 스타일 정의를 조회한다. 클라이언트 애플리케이션은 이 정보를 바탕으로 각 객체의 폰트, 배경색, 테두리 색상, 선택 시 하이라이트 효과 등을 일관성 있게 표현한다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/object/mapstyle`
# - **Method:** `GET`
# - **Header:**
#   - `Authorization: Bearer {Token}` (유효한 JWT 인증 토큰 필수)
#   - `Content-Type: application/json`
# - **Request Body:** 없음 (None)
#
# **3. 응답 명세 (Response Specification)**
# 응답은 스타일 객체의 배열(Array) 형태로 반환된다.
#
# | 필드명 (Field) | 타입 (Type) | 설명 (Description) |
# | :--- | :--- | :--- |
# | `ObjType` | String | 스타일이 적용될 객체의 유형 (예: "AMR", "Node", "Rack") |
# | `StyleType` | Integer | 스타일의 분류 코드 |
# | `StyleId` | Integer | 고유 스타일 ID |
# | `Prop` | Integer | 객체 속성 값 (Property) |
# | `Font` | String | 폰트 패밀리 명 (예: "Arial", "Malgun Gothic") |
# | `FontSize` | Float | 폰트 크기 |
# | `FontStyle` | Integer | 폰트 스타일 플래그 (0: Regular, 1: Bold 등) |
# | `TextColor` | Integer | 텍스트 색상 코드 (ARGB Int or Hex Int) |
# | `BackColor` | Integer | 배경 색상 코드 |
# | `SelectedColor` | Integer | 객체 선택 시 표시될 색상 코드 |
# | `HilightColor` | Integer | 강조(Highlight) 상태일 때의 색상 코드 |
# | `BorderColor` | Integer | 테두리 색상 코드 |
# | `SelBorderColor`| Integer | 선택 시 테두리 색상 코드 |
# | `Opt` | Integer | 추가 렌더링 옵션 플래그 |
# | `IsDefault` | Boolean | 해당 객체 타입의 기본 스타일 여부 |
#
# **4. 사용 사례 (Use Case)**
# - **관제 대시보드 초기화:** 웹 클라이언트가 처음 로딩될 때, 맵 상에 표시될 수백 개의 노드와 로봇(AMR)을 그리기 전 이 API를 호출한다.
# - **상태별 시각화:** 예를 들어, '작업 중인 AMR'과 '에러 상태인 AMR'을 서로 다른 배경색(`BackColor`)으로 구분하여 운영자가 직관적으로 상태를 파악할 수 있도록 렌더링 규칙을 수립할 때 사용된다.
#
# **5. 응답 예시 (Response Example)**
# ```json
# [
#   {
#     "ObjType": "AMR",
#     "StyleType": 1,
#     "StyleId": 101,
#     "Prop": 0,
#     "Font": "Arial",
#     "FontSize": 12.0,
#     "FontStyle": 1,
#     "TextColor": -16777216,
#     "BackColor": -256,
#     "SelectedColor": -16711936,
#     "HilightColor": -65536,
#     "BorderColor": -16777216,
#     "SelBorderColor": -16711681,
#     "Opt": 0,
#     "IsDefault": true
#   },
#   {
#     "ObjType": "Node",
#     "StyleType": 0,
#     "StyleId": 201,
#     "Prop": 0,
#     "Font": "Malgun Gothic",
#     "FontSize": 10.0,
#     "FontStyle": 0,
#     "TextColor": -16777216,
#     "BackColor": -3355444,
#     "SelectedColor": -16711936,
#     "HilightColor": -256,
#     "BorderColor": -8355712,
#     "SelBorderColor": -16776961,
#     "Opt": 0,
#     "IsDefault": true
#   }
# ]
# ```
# 2026-01-09 16:56:45.439 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 3. Object Controller. 맵 객체 및 AMR 상태 관리 API
# ### 3.5 AMR 목록 조회
# - **Endpoint**: `GET /api/object/amr`
# - **설명**: AMR 객체 목록 조회
# - **Headers**: JWT 토큰 필요
# - **Response**:
# ```json
# [
#   {
#     "amrId": 0,
#     "TypeId": 0,
#     "NetId": "001",
#     "objNo": 0,
#     "objNM": "string",
#     "rpX": 0,
#     "rpY": 0,
#     "rpWidth": 500,
#     "rpHeight": 500,
#     "heading": 0.0,
#     "Host": "192.168.1.100",
#     "Port": 11000,
#     "RealIP": "192.168.1.100",
#     "RealPort": 11000,
#     "LiftCnt": 0,
#     "IsTrafficInclude": true,
#     "MDir": 0,
#     "Area": "string",
#     "Active": true
#   }
# ]
# ```
# - **Status Code**: 200 OK
#
#
# 2026-01-09 16:57:09.178 | INFO     | __main__:<module>:9 - ## [API] AMR 목록 및 상태 조회 (Get AMR List)
#
# **1. 개요 (Overview)**
# `GET /api/object/amr` API는 시스템에 등록된 모든 자율 주행 로봇(AMR)의 실시간 상태 및 구성 정보를 조회하는 인터페이스다. 각 로봇의 고유 식별자(NetId), 현재 물리적 좌표(X, Y), 헤딩(Heading), 네트워크 설정 및 활성화 여부(Active)를 포함한 전체 객체 목록을 반환한다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/object/amr`
# - **Method:** `GET`
# - **Header:**
#   - `Authorization: Bearer {Token}` (JWT 인증 필수)
#   - `Content-Type: application/json`
# - **Query Parameters:** 없음 (전체 목록 조회)
# - **Request Body:** 없음 (Empty)
#
# **3. 응답 명세 (Response Specification)**
# 응답은 AMR 객체들의 배열(Array) 형태로 반환된다. 주요 필드는 다음과 같다.
#
# | 필드명 | 타입 | 설명 |
# | :--- | :--- | :--- |
# | `amrId` | Integer | 시스템 내부 관리용 AMR 고유 ID |
# | `NetId` | String | 로봇의 네트워크 식별자 (예: "001") |
# | `objNM` | String | 로봇의 표시 이름 (Display Name) |
# | `rpX` / `rpY` | Number | 맵 상의 현재 X, Y 좌표 (mm 단위) |
# | `heading` | Number | 로봇의 현재 주행 방향 (각도) |
# | `Host` | String | 로봇의 제어 PC IP 주소 |
# | `Active` | Boolean | 로봇의 시스템 활성화 여부 (True: 가동 중) |
# | `IsTrafficInclude` | Boolean | 교통 관제(Traffic Control) 대상 포함 여부 |
#
# **4. 사용 사례 (Use Case)**
# - **관제 대시보드 렌더링:** 운영자가 보는 모니터링 화면(Dashboard)을 초기화하거나 갱신할 때, 공장 내 모든 로봇의 현재 위치와 상태를 시각화하기 위해 호출한다.
# - **트래픽 제어 및 경로 할당:** 상위 시스템(ACS)이 특정 로봇에게 작업을 할당하기 전, 현재 가동 중(`Active: true`)인 로봇들의 위치 분포를 파악하여 충돌 없는 경로를 계산하기 위해 사용된다.
#
# **5. 응답 예시 (Response Body Example)**
# ```json
# [
#   {
#     "amrId": 101,
#     "TypeId": 1,
#     "NetId": "AMR_001",
#     "objNo": 1,
#     "objNM": "Transporter-01",
#     "rpX": 15000,
#     "rpY": 4500,
#     "rpWidth": 800,
#     "rpHeight": 600,
#     "heading": 90.5,
#     "Host": "192.168.10.101",
#     "Port": 11000,
#     "RealIP": "192.168.10.101",
#     "RealPort": 11000,
#     "LiftCnt": 0,
#     "IsTrafficInclude": true,
#     "MDir": 1,
#     "Area": "Zone_A",
#     "Active": true
#   },
#   {
#     "amrId": 102,
#     "TypeId": 1,
#     "NetId": "AMR_002",
#     "objNo": 2,
#     "objNM": "Transporter-02",
#     "rpX": 12000,
#     "rpY": 4500,
#     "rpWidth": 800,
#     "rpHeight": 600,
#     "heading": 270.0,
#     "Host": "192.168.10.102",
#     "Port": 11000,
#     "RealIP": "192.168.10.102",
#     "RealPort": 11000,
#     "LiftCnt": 1,
#     "IsTrafficInclude": true,
#     "MDir": 0,
#     "Area": "Zone_B",
#     "Active": false
#   }
# ]
# ```
# 2026-01-09 16:57:09.181 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 3. Object Controller. 맵 객체 및 AMR 상태 관리 API
# ### 3.6 AMR 상태 조회
# - **Endpoint**: `GET /api/object/status`
# - **설명**: AMR 상태 정보 조회
# - **Headers**: JWT 토큰 필요
# - **Response**:
# ```json
# [
#   {
#     "NetId": "001",
#     "ACSMode": "Auto",
#     "AMRStatus": "Idle",
#     "Battery": 85,
#     "AMRManual": false,
#     "X": 1000,
#     "Y": 2000,
#     "H": 90.0,
#     "Connected": true,
#     "IsStandby": false,
#     "Pause": false,
#     "IsSlowDown": false,
#     "Ready": true,
#     "GICCmdId": "string",
#     "TaskId": "string",
#     "MissionId": 0,
#     "MissionType": "string",
#     "State": "string",
#     "Loaded": false,
#     "PalletType": "string",
#     "PalletWidth": 0,
#     "PalletHeight": 0,
#     "PalletLength": 0,
#     "PalletColor": 0,
#     "Speed": 0.5,
#     "Obstacle": 0,
#     "AMRLCCSOnOff": 0,
#     "AMRLCCSLevel": 0,
#     "AlarmVolumeLevel": 0,
#     "IsGetGlobalPlanner": false,
#     "IsGetLidarData": false,
#     "IsGetObstacleData": false,
#     "LidarData": [],
#     "ObstacleData": [],
#     "LidarRange": 10,
#     "CartHorCnt": 0,
#     "CartVerCnt": 0,
#     "TurnTableStatus": 0,
#     "LoadedState": 0,
#     "CurrentRackObject": "string",
#     "CurrentRackDockOutArea": "string",
#     "SupportMultiAlramVolume": false,
#     "PathList": [
#       {
#         "X": 0,
#         "Y": 0,
#         "H": 0.0,
#         "Complete": false
#       }
#     ],
#     "Errors": [
#       {
#         "Type": "string",
#         "Level": "string",
#         "Code": 0,
#         "Message": "string",
#         "Time": "2024-01-01T00:00:00"
#       }
#     ]
#   }
# ]
# ```
# - **Status Code**: 200 OK
#
#
# 2026-01-09 16:57:35.165 | INFO     | __main__:<module>:9 - ## [API] AMR 상태 조회 (AMR Status Retrieval)
#
# **1. 개요 (Overview)**
# `GET /api/object/status` API는 Object Controller에 등록된 모든 AMR(Autonomous Mobile Robot)의 실시간 상태 및 텔레메트리(Telemetry) 정보를 조회한다.
# 이 API는 관제 시스템(ACS)의 대시보드 렌더링, 로봇의 가용성 판단, 위치 추적 및 에러 모니터링을 위한 핵심 데이터를 제공하며, 주기적인 폴링(Polling) 또는 상태 갱신 시 호출된다.
#
# **2. 기술 명세 (Technical Specification)**
# - **Endpoint:** `/api/object/status`
# - **Method:** `GET`
# - **Header:** `Authorization: Bearer {Token}` (JWT 인증 필수)
# - **Request Body:** 없음 (None)
#
# **3. 응답 데이터 상세 (Response Field Details)**
# 응답은 AMR 객체들의 배열(Array)로 반환되며, 주요 필드는 다음과 같다.
#
# | 카테고리 | 필드명 | 타입 | 설명 |
# | :--- | :--- | :--- | :--- |
# | **식별** | `NetId` | String | 로봇의 네트워크 식별 ID (예: "001") |
# | **상태** | `ACSMode` | String | 제어 모드 (예: "Auto", "Manual") |
# | | `AMRStatus` | String | 현재 동작 상태 (예: "Idle", "Run", "Error") |
# | | `Connected` | Boolean | 관제 서버와의 연결 여부 |
# | | `Ready` | Boolean | 작업 수행 가능 여부 |
# | **위치/배터리** | `X`, `Y`, `H` | Number | 맵 상의 절대 좌표(mm) 및 헤딩 각도(도) |
# | | `Battery` | Number | 배터리 잔량 (%) |
# | **작업** | `TaskId`, `MissionId` | String/Int | 현재 수행 중인 작업 및 미션 ID |
# | | `Loaded` | Boolean | 자재 적재 여부 |
# | **경로** | `PathList` | Array | 현재 주행 중인 경로의 노드 리스트 |
# | **장애** | `Errors` | Array | 현재 발생한 에러 목록 (Code, Message, Level 포함) |
#
# **4. 사용 사례 (Use Case)**
# - **대시보드 모니터링:** 관제 화면(UI)에서 로봇의 실시간 위치(`X`, `Y`)를 맵에 표시하고 배터리(`Battery`) 상태를 시각화할 때 사용.
# - **작업 할당 전 가용성 체크:** 새로운 운송 명령을 내리기 전, 대상 로봇이 `Connected: true`, `AMRStatus: Idle`, `Errors: []` (Empty) 상태인지 검증하는 로직에 사용.
# - **장애 감지 및 알림:** `Errors` 배열에 데이터가 존재할 경우, 즉시 운영자에게 알람을 띄우거나 유지보수 모드로 전환하는 트리거로 활용.
#
# **5. 응답 예시 (Response Body Example)**
# ```json
# [
#   {
#     "NetId": "001",
#     "ACSMode": "Auto",
#     "AMRStatus": "Run",
#     "Battery": 85,
#     "AMRManual": false,
#     "X": 1000,
#     "Y": 2000,
#     "H": 90.0,
#     "Connected": true,
#     "IsStandby": false,
#     "Pause": false,
#     "IsSlowDown": false,
#     "Ready": true,
#     "GICCmdId": "CMD_20240520_001",
#     "TaskId": "TASK_A_01",
#     "MissionId": 102,
#     "MissionType": "Transport",
#     "State": "Moving",
#     "Loaded": true,
#     "PalletType": "Standard",
#     "PalletWidth": 1200,
#     "PalletHeight": 150,
#     "PalletLength": 1000,
#     "PalletColor": 1,
#     "Speed": 0.8,
#     "Obstacle": 0,
#     "AMRLCCSOnOff": 1,
#     "AMRLCCSLevel": 2,
#     "AlarmVolumeLevel": 5,
#     "IsGetGlobalPlanner": true,
#     "IsGetLidarData": false,
#     "IsGetObstacleData": false,
#     "LidarData": [],
#     "ObstacleData": [],
#     "LidarRange": 10,
#     "CartHorCnt": 0,
#     "CartVerCnt": 0,
#     "TurnTableStatus": 0,
#     "LoadedState": 1,
#     "CurrentRackObject": "RACK_A01",
#     "CurrentRackDockOutArea": "AREA_OUT_01",
#     "SupportMultiAlramVolume": true,
#     "PathList": [
#       {
#         "X": 1000,
#         "Y": 2500,
#         "H": 90.0,
#         "Complete": false
#       },
#       {
#         "X": 1000,
#         "Y": 3000,
#         "H": 90.0,
#         "Complete": false
#       }
#     ],
#     "Errors": []
#   }
# ]
# ```
# 2026-01-09 16:57:35.167 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 3. Object Controller. 맵 객체 및 AMR 상태 관리 API
# ### 3.7 그리드 정보 조회
# - **Endpoint**: `GET /api/object/gridinfo`
# - **설명**: 그리드 레이아웃 정보 조회
# - **Headers**: JWT 토큰 필요
# - **Response**:
# ```json
# {
#   "OffsetX": 0,
#   "OffsetY": 0,
#   "Scale": 1.0,
#   "Rotate": 0.0,
#   "Version": "1.0",
#   "OriginX": 0.0,
#   "OriginY": 0.0,
#   "Resolution": 0.05,
#   "ImageWidth": 1920,
#   "ImageHeight": 1080
# }
# ```
# - **Status Code**: 200 OK
#
#
# 2026-01-09 16:57:57.258 | INFO     | __main__:<module>:9 - ## [API] 그리드 정보 조회 (Get Grid Information)
#
# **1. 개요 (Overview)**
# `GET /api/object/gridinfo` API는 BMA(Building Management/Automation) 시스템 내에서 사용되는 공간 맵(Map)의 메타데이터와 좌표 변환 정보를 조회한다. 이 정보는 AMR(Autonomous Mobile Robot)의 위치를 시각화하거나, 물리적 좌표(World Coordinate)와 이미지 픽셀 좌표(Grid Coordinate) 간의 상호 변환을 수행하기 위한 필수 기준 데이터로 사용된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/object/gridinfo`
# - **Method:** `GET`
# - **Header:**
#   - `Authorization: Bearer {Token}` (JWT 인증 토큰 필수)
#   - `Content-Type: application/json`
# - **Request Body:** 없음 (None)
#
# **3. 응답 명세 (Response Specification)**
# 요청 성공 시(200 OK), 맵의 물리적 속성과 렌더링 정보를 포함한 JSON 객체를 반환한다.
#
# | 필드명 (Field) | 타입 (Type) | 설명 (Description) |
# | :--- | :--- | :--- |
# | `Version` | String | 맵 데이터의 버전 식별자. |
# | `Resolution` | Float | 그리드 맵의 해상도 (Meters per Pixel). 1픽셀이 실제 공간에서 차지하는 거리. |
# | `ImageWidth` | Integer | 맵 이미지의 가로 픽셀 크기. |
# | `ImageHeight` | Integer | 맵 이미지의 세로 픽셀 크기. |
# | `OriginX` | Float | 맵 원점(0,0)의 실제 물리적 X 좌표 (World Coordinate). |
# | `OriginY` | Float | 맵 원점(0,0)의 실제 물리적 Y 좌표 (World Coordinate). |
# | `OffsetX` | Integer | 렌더링 시 적용할 X축 오프셋 보정값. |
# | `OffsetY` | Integer | 렌더링 시 적용할 Y축 오프셋 보정값. |
# | `Scale` | Float | 맵 렌더링 시 적용할 확대/축소 비율. |
# | `Rotate` | Float | 맵의 회전 각도 (Degree 또는 Radian). |
#
# **4. 사용 사례 (Use Case)**
# - **관제 시스템 UI 초기화:** 웹 프론트엔드에서 관제 화면을 로드할 때, 배경이 되는 공장 레이아웃(Grid Map)을 올바른 비율과 위치에 렌더링하기 위해 호출한다.
# - **AMR 위치 동기화:** 로봇이 보고하는 물리적 좌표(x, y meters)를 화면상의 픽셀 좌표로 변환하여 실시간 위치를 표시할 때 `Resolution`과 `Origin` 값을 참조 계수로 사용한다.
# - **경로 계획 검증:** 에이전트가 생성한 이동 경로가 유효한 맵 범위(`ImageWidth`, `ImageHeight`) 내에 존재하는지 검증할 때 사용된다.
#
# **5. 응답 예시 (Response Body Example)**
# ```json
# {
#   "OffsetX": 0,
#   "OffsetY": 0,
#   "Scale": 1.0,
#   "Rotate": 0.0,
#   "Version": "1.0",
#   "OriginX": -15.5,
#   "OriginY": -10.2,
#   "Resolution": 0.05,
#   "ImageWidth": 1920,
#   "ImageHeight": 1080
# }
# ```
# 2026-01-09 16:57:57.259 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 3. Object Controller. 맵 객체 및 AMR 상태 관리 API
# ### 3.8 랙 정보 수정
# - **Endpoint**: `PUT /api/object/rack`
# - **설명**: 랙 정보 수정
# - **Headers**: JWT 토큰 필요
# - **Request Body**:
# ```json
# {
#   "ObjNo": 0,
#   "X": 0.0,
#   "Y": 0.0,
#   "Width": 0.0,
#   "Height": 0.0,
#   "AngleOffset": 0.0,
#   "CenterOffset": 0.0,
#   "DisplayName": "string",
#   "RackStatus": [
#     {
#       "PLTNo": "string",
#       "PLTType": "string",
#       "PLTStatus": "string",
#       "TransNo": "string",
#       "PartNo": "string",
#       "PartID": "string",
#       "PartLevel": 0,
#       "PartCount": 0,
#       "PartStatus": 0
#     }
#   ]
# }
# ```
# - **Response**: 200 OK
# - **Status Code**: 200 OK
#
#
# 2026-01-09 16:58:22.579 | INFO     | __main__:<module>:9 - ## [API] 랙 정보 수정 (Modify Rack Information)
#
# **1. 개요 (Definition)**
# `PUT /api/object/rack` API는 관제 시스템(ACS) 맵 상에 정의된 특정 랙(Rack) 객체의 **물리적 속성(좌표, 크기, 오프셋)** 및 **논리적 적재 상태(Pallet 및 부품 정보)**를 갱신하는 인터페이스다.
# 주로 랙의 위치가 변경되었거나, AMR/지게차에 의해 화물이 입출고되어 재고 상태가 변동되었을 때 디지털 트윈(Digital Twin) 정보를 동기화하기 위해 사용된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/object/rack`
# - **Method:** `PUT`
# - **Header:**
#   - `Content-Type`: `application/json`
#   - `Authorization`: `Bearer {Token}` (JWT 인증 필수)
# - **Body Parameters:**
#
# | Parameter | Type | Required | Description |
# | :--- | :--- | :---: | :--- |
# | **`ObjNo`** | Integer | **Yes** | 수정할 랙의 고유 식별 번호 (Object ID) |
# | `X` | Float | Yes | 맵 상의 X 좌표 (mm 단위) |
# | `Y` | Float | Yes | 맵 상의 Y 좌표 (mm 단위) |
# | `Width` | Float | Yes | 랙의 가로 폭 (mm 단위) |
# | `Height` | Float | Yes | 랙의 세로 높이 (mm 단위) |
# | `AngleOffset` | Float | No | 랙의 회전 보정값 (Degree) |
# | `CenterOffset` | Float | No | 랙 중심점 보정값 (mm) |
# | `DisplayName` | String | No | 관제 화면에 표시될 랙의 이름 (예: "R-101") |
# | **`RackStatus`** | Array | No | 랙 내부의 적재 슬롯 상태 리스트 |
# | └ `PLTNo` | String | No | 적재된 팔레트 번호 |
# | └ `PLTType` | String | No | 팔레트 유형 (예: "Wooden", "Plastic") |
# | └ `PLTStatus` | String | No | 팔레트 상태 (예: "Loaded", "Empty") |
# | └ `TransNo` | String | No | 관련 운송 지시 번호 (Transaction ID) |
# | └ `PartNo` | String | No | 부품 번호 |
# | └ `PartID` | String | No | 부품 고유 ID |
# | └ `PartLevel` | Integer | No | 적재 단수 (Layer Level) |
# | └ `PartCount` | Integer | No | 적재 수량 |
# | └ `PartStatus` | Integer | No | 부품 상태 코드 |
#
# **3. 사용 사례 (Use Case)**
# - **시나리오 1 (레이아웃 변경):** 공장 레이아웃 변경으로 인해 랙의 물리적 위치(`X`, `Y`)가 이동되었을 때 좌표 정보를 갱신.
# - **시나리오 2 (재고 동기화):** AMR이 랙에 팔레트를 적재(Loading) 완료한 후, 해당 랙에 어떤 팔레트(`PLTNo`)와 부품(`PartNo`)이 적재되었는지 시스템에 반영.
# - **시나리오 3 (미세 보정):** AMR의 도킹 정밀도를 높이기 위해 랙의 `AngleOffset` 값을 수정하여 진입 각도를 보정.
#
# **4. 요청 예시 (Request Body Example)**
# ```json
# {
#   "ObjNo": 105,
#   "X": 12500.5,
#   "Y": 4500.0,
#   "Width": 1200.0,
#   "Height": 1000.0,
#   "AngleOffset": 0.5,
#   "CenterOffset": 0.0,
#   "DisplayName": "RCK_ZN01_05",
#   "RackStatus": [
#     {
#       "PLTNo": "PLT_998877",
#       "PLTType": "Standard_1100",
#       "PLTStatus": "Loaded",
#       "TransNo": "TRX_20231025_001",
#       "PartNo": "PART_HY_55",
#       "PartID": "PID_5501",
#       "PartLevel": 1,
#       "PartCount": 50,
#       "PartStatus": 1
#     }
#   ]
# }
# ```
#
# **5. 응답 (Response)**
# - **Status Code:** `200 OK`
# - **Body:** (성공 시 별도의 Body 없이 상태 코드만 반환되거나, 갱신된 객체 정보를 반환할 수 있음. 표준 응답은 200 OK)
# 2026-01-09 16:58:22.581 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 3. Object Controller. 맵 객체 및 AMR 상태 관리 API
# ### 3.9 AMR 확장 속성 조회
# - **Endpoint**: `GET /api/object/extraproperties`
# - **설명**: AMR 확장 속성 정보 조회 (AMR별 그룹별 속성 목록)
# - **Headers**: JWT 토큰 필요
# - **Response**:
# ```json
# [
#   [
#     [
#       ["PropertyName", "PropertyValue"]
#     ]
#   ]
# ]
# ```
# - **참고**: 3차원 배열 구조 - [AMR][Group][Properties]
# - **Status Code**: 200 OK
#
#
# 2026-01-09 16:58:50.630 | INFO     | __main__:<module>:9 - ## [API] AMR 확장 속성 조회 (AMR Extended Properties Query)
#
# **1. 개요 (Overview)**
# `GET /api/object/extraproperties` API는 시스템에 등록된 모든 AMR(Autonomous Mobile Robot)의 **확장 속성(Extended Properties)** 정보를 조회한다.
# 표준 상태 정보(위치, 배터리 등) 외에, 로봇별로 상이하게 설정된 그룹별 커스텀 파라미터나 하드웨어 세부 명세를 **3차원 배열 구조**로 반환하여, 관제 시스템이 로봇의 특수 설정을 파악하고 관리할 수 있도록 지원한다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/object/extraproperties`
# - **Method:** `GET`
# - **Header:**
#   - `Authorization: Bearer {Token}` (JWT 인증 토큰 필수)
#   - `Content-Type: application/json`
# - **Query Parameters:** 없음 (전체 대상 조회)
# - **Body:** 없음
#
# **3. 응답 명세 (Response Specification)**
# 응답은 **AMR > 속성 그룹(Group) > 속성(Property) > 키-값 쌍(Key-Value Pair)**의 계층 구조를 가진 다차원 배열로 반환된다.
#
# | 레벨 (Level) | 구조 설명 | 데이터 타입 | 비고 |
# | :--- | :--- | :--- | :--- |
# | Root | `Array[]` | List | 전체 AMR 목록 |
# | Depth 1 | `Array[]` | List | 특정 AMR의 속성 그룹 목록 |
# | Depth 2 | `Array[]` | List | 특정 그룹 내의 속성 목록 |
# | Depth 3 | `Array[Key, Value]` | List<String> | 실제 속성 데이터 (0번 인덱스: 이름, 1번 인덱스: 값) |
#
# **4. 사용 사례 (Use Case)**
# 이 API는 다음과 같은 BMA(Battery Manufacturing Automation) 공정 시나리오에서 활용된다.
# - **이기종 로봇 통합 관리:** 제조사가 다른 AMR들이 혼재된 환경에서, 각 로봇 고유의 벤더(Vendor) 파라미터나 펌웨어 버전을 확인할 때 사용.
# - **작업 할당 전 제약 조건 확인:** 특정 로봇이 '고중량 운송' 그룹 속성을 가지고 있는지, 혹은 '정밀 주행' 모드 설정값이 활성화되어 있는지 사전에 검증.
# - **유지보수 및 디버깅:** 현장 엔지니어가 로봇의 내부 설정값(예: 센서 민감도, 타임아웃 임계값)을 관제 웹 콘솔에서 즉시 조회하여 문제 원인을 분석할 때 사용.
#
# **5. 요청 및 응답 예시 (Example)**
#
# **Request (HTTP)**
# ```http
# GET /api/object/extraproperties HTTP/1.1
# Host: bma-backend.hyundai-auto.com
# Authorization: Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9...
# ```
#
# **Response (JSON)**
# ```json
# [
#   // AMR #1 (예: R_101)
#   [
#     // Group #1: Hardware Info
#     [
#       ["Vendor", "Hyundai_Robotics"],
#       ["Model", "LIFT_500"],
#       ["SerialNo", "HR-2023-001"]
#     ],
#     // Group #2: Operation Settings
#     [
#       ["MaxSpeed", "1.5"],
#       ["LiftingHeight", "200"],
#       ["SafetyZone", "Wide"]
#     ]
#   ],
#   // AMR #2 (예: R_102)
#   [
#     // Group #1: Hardware Info
#     [
#       ["Vendor", "Third_Party_A"],
#       ["Model", "TUG_100"],
#       ["SerialNo", "TP-999-055"]
#     ],
#     // Group #2: Operation Settings
#     [
#       ["MaxSpeed", "1.2"],
#       ["NetworkPriority", "High"]
#     ]
#   ]
# ]
# ```
#
# **6. 상태 코드 (Status Codes)**
# - `200 OK`: 요청이 성공적으로 처리되어 속성 목록이 반환됨.
# - `401 Unauthorized`: 유효하지 않은 JWT 토큰이거나 토큰이 누락됨.
# - `500 Internal Server Error`: 서버 내부 오류로 인해 속성 정보를 불러올 수 없음.
# 2026-01-09 16:58:50.632 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 3. Object Controller. 맵 객체 및 AMR 상태 관리 API
# ### 3.10 파레트 정보 조회
# - **Endpoint**: `GET /api/object/pallet`
# - **설명**: 파레트 정보 조회
# - **Headers**: JWT 토큰 필요
# - **Response**:
# ```json
# [
#   {
#     "PrcsCD": "string",
#     "PLTType": "string",
#     "PLTNo": "string",
#     "PLTTagId": "string",
#     "ItemNo": "string",
#     "PLTInfo": "string",
#     "UYN": true
#   }
# ]
# ```
# - **Status Code**: 200 OK
#
#
# 2026-01-09 16:59:13.862 | INFO     | __main__:<module>:9 - ## [API] 파레트 정보 조회 (Retrieve Pallet Information)
#
# **1. 개요 (Overview)**
# `GET /api/object/pallet` API는 BMA(Battery Module Assembly) 시스템 내에 등록된 모든 파레트(Pallet) 객체의 상세 정보를 조회한다. 이 API는 관제 시스템이 현재 공정 내 파레트의 식별 정보(Tag ID), 적재된 품목(ItemNo), 그리고 사용 가능 여부(UYN)를 파악하여 물류 흐름을 모니터링하거나 AMR 작업 할당 전 유효성을 검증하는 데 사용된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/object/pallet`
# - **Method:** `GET`
# - **Header:**
#   - `Authorization: Bearer {Token}` (JWT 인증 토큰 필수)
#   - `Content-Type: application/json`
# - **Query Parameters:** 없음 (전체 조회)
#
# **3. 응답 명세 (Response Specification)**
# 응답은 파레트 객체들의 리스트(Array) 형태로 반환된다.
#
# | 필드명 | 데이터 타입 | 설명 | 비고 |
# |:---:|:---:|:---|:---|
# | `PrcsCD` | String | 공정 코드 (Process Code) | 해당 파레트가 위치한 공정 식별자 |
# | `PLTType` | String | 파레트 유형 (Pallet Type) | 파레트의 규격 또는 종류 |
# | `PLTNo` | String | 파레트 번호 (Pallet Number) | 시스템 내부 관리 번호 |
# | `PLTTagId` | String | 파레트 태그 ID (Tag ID) | RFID 또는 QR 코드 등 물리적 식별 ID |
# | `ItemNo` | String | 품목 번호 (Item Number) | 파레트에 적재된 제품/자재 번호 |
# | `PLTInfo` | String | 파레트 부가 정보 (Additional Info) | 파레트 관련 기타 메타데이터 |
# | `UYN` | Boolean | 사용 여부 (Use Y/N) | `true`: 사용 중/활성, `false`: 미사용/비활성 |
#
# **4. 사용 사례 (Use Case)**
# - **공정 모니터링:** 관제 화면(Dashboard)에서 현재 공정에 투입된 파레트의 목록과 적재된 자재 정보를 실시간으로 표시할 때 호출한다.
# - **AMR 작업 검증:** AMR이 특정 파레트를 리프팅(Lifting)하기 전, 비전 센서나 RFID로 인식한 태그 ID(`PLTTagId`)가 시스템상의 정보와 일치하는지, 그리고 해당 파레트가 현재 사용 가능한 상태(`UYN`)인지 교차 검증하기 위해 사용된다.
# - **재고 관리:** 특정 품목(`ItemNo`)이 적재된 파레트의 수량을 파악하거나 위치를 추적하기 위한 기초 데이터로 활용된다.
#
# **5. 응답 예시 (Response Body Example)**
# ```json
# [
#   {
#     "PrcsCD": "PRCS_ASM_01",
#     "PLTType": "TRAY_STD_V2",
#     "PLTNo": "PLT_1001",
#     "PLTTagId": "RF_TAG_5501A",
#     "ItemNo": "BAT_MOD_GEN5",
#     "PLTInfo": "Assembly Line A - Buffer",
#     "UYN": true
#   },
#   {
#     "PrcsCD": "PRCS_PKG_02",
#     "PLTType": "WOODEN_PLT",
#     "PLTNo": "PLT_2045",
#     "PLTTagId": "QR_9982X",
#     "ItemNo": "EMPTY",
#     "PLTInfo": "Waiting for return",
#     "UYN": false
#   }
# ]
# ```
# 2026-01-09 16:59:13.863 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 3. Object Controller. 맵 객체 및 AMR 상태 관리 API
# ### 3.11 파레트 타입 조회
# - **Endpoint**: `GET /api/object/plttype`
# - **설명**: 파레트 타입 정보 조회
# - **Headers**: JWT 토큰 필요
# - **Response**:
# ```json
# [
#   {
#     "PrcsCD": "string",
#     "PLTType": "string",
#     "TypeNo": 0,
#     "PLTColor": 0,
#     "PW": 1200,
#     "PL": 1000,
#     "PH": 150,
#     "POpt": 0,
#     "EmptyWeight": 50,
#     "FullWeight": 500
#   }
# ]
# ```
# - **Status Code**: 200 OK
#
#
# 2026-01-09 16:59:39.133 | INFO     | __main__:<module>:9 - ## [API] 파레트 타입 조회 (Palette Type Inquiry)
#
# **1. 개요 (Overview)**
# `GET /api/object/plttype` API는 BMA(Battery Manufacturing Automation) 시스템 내에 정의된 모든 파레트(Palette)의 물리적 규격, 중량 제한 및 시각화 속성 정보를 조회한다.
# 이 API는 관제 시스템이 맵 상에 파레트를 렌더링하거나, AMR(Autonomous Mobile Robot)이 이송 대상 파레트의 제원(크기, 무게)을 확인하여 작업 적합성을 판단하는 기초 데이터로 활용된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/object/plttype`
# - **Method:** `GET`
# - **Header:**
#   - `Authorization: Bearer {Token}` (JWT 인증 필수)
#   - `Content-Type: application/json`
# - **Query Parameters:** 없음 (전체 목록 조회)
#
# **3. 응답 명세 (Response Specification)**
# 응답은 파레트 정의 객체의 배열(Array) 형태로 반환된다.
#
# | 필드명 | 데이터 타입 | 설명 | 비고 |
# | :--- | :--- | :--- | :--- |
# | `PrcsCD` | String | 공정 코드 (Process Code) | 해당 파레트가 사용되는 공정 식별자 |
# | `PLTType` | String | 파레트 타입 명칭 | 예: "Standard_Wood", "Plastic_Blue" |
# | `TypeNo` | Integer | 파레트 타입 고유 번호 | 시스템 내부 관리용 ID |
# | `PLTColor` | Integer | 파레트 색상 코드 | UI 시각화용 (RGB 또는 Index) |
# | `PW` | Integer | 파레트 폭 (Width) | 단위: mm |
# | `PL` | Integer | 파레트 길이 (Length) | 단위: mm |
# | `PH` | Integer | 파레트 높이 (Height) | 단위: mm |
# | `POpt` | Integer | 파레트 옵션 플래그 | 특수 속성 비트마스크 (예: 회전 가능 여부 등) |
# | `EmptyWeight` | Number | 공차 중량 (Empty Weight) | 적재물이 없을 때의 무게 (kg) |
# | `FullWeight` | Number | 만재 중량 (Full Weight) | 최대 적재 허용 무게 (kg) |
#
# **4. 사용 사례 (Use Case)**
# - **관제 시스템 초기화:** 웹 프론트엔드 로딩 시, 공장 내 존재하는 모든 파레트의 규격 정보를 미리 로드하여 3D/2D 맵 뷰어에서 정확한 크기와 색상으로 파레트를 렌더링하기 위해 호출한다.
# - **이송 안전성 검증:** 상위 시스템(ACS)이 AMR에게 작업을 할당하기 전, 대상 파레트의 `FullWeight`와 `PW/PL` 정보를 조회하여 해당 AMR 기종이 이송 가능한 스펙인지 검증하는 로직에 사용된다.
#
# **5. 요청 및 응답 예시 (Example)**
#
# **Request (HTTP)**
# ```http
# GET /api/object/plttype HTTP/1.1
# Host: bma-backend.hyundai-acs.com
# Authorization: Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9...
# ```
#
# **Response (JSON)**
# ```json
# [
#   {
#     "PrcsCD": "PRCS_ASSEMBLY_01",
#     "PLTType": "STD_WOOD_1210",
#     "TypeNo": 101,
#     "PLTColor": 16711680,
#     "PW": 1200,
#     "PL": 1000,
#     "PH": 150,
#     "POpt": 0,
#     "EmptyWeight": 25.5,
#     "FullWeight": 1000.0
#   },
#   {
#     "PrcsCD": "PRCS_PACKAGING_02",
#     "PLTType": "PLASTIC_BLUE_1111",
#     "TypeNo": 102,
#     "PLTColor": 255,
#     "PW": 1100,
#     "PL": 1100,
#     "PH": 140,
#     "POpt": 1,
#     "EmptyWeight": 15.0,
#     "FullWeight": 800.0
#   }
# ]
# ```
# 2026-01-09 16:59:39.135 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 3. Object Controller. 맵 객체 및 AMR 상태 관리 API
# ### 3.12 랙 상태 조회
# - **Endpoint**: `GET /api/object/rackstate`
# - **설명**: 랙 상태 정보 조회 (DB)
# - **Headers**: JWT 토큰 필요
# - **Response**:
# ```json
# [
#   {
#     "PrcsCD": "string",
#     "RackNo": 0,
#     "RackNM": "string",
#     "RackIndex": 0,
#     "PLTNo": "string",
#     "PLTType": "string",
#     "PLTTypeNo": 0,
#     "PLTStatus": 0,
#     "TransNo": "string",
#     "PartNo": "string",
#     "PartID": "string",
#     "PartType": 0,
#     "PartLevel": 0,
#     "PartCount": 0,
#     "PartStatus": 0,
#     "PartInfoValue": "string",
#     "UpTM": "2024-01-01T00:00:00"
#   }
# ]
# ```
# - **Status Code**: 200 OK
#
#
# 2026-01-09 17:00:05.718 | INFO     | __main__:<module>:9 - ## [API] 랙 상태 정보 조회 (Rack Status Query)
#
# **1. 개요 (Overview)**
# `GET /api/object/rackstate` API는 공장 내 배치된 랙(Rack)의 현재 적재 상태와 재고 정보를 데이터베이스(DB)로부터 조회하는 인터페이스다. 특정 랙의 위치(Index)에 어떤 팔레트(Pallet)와 자재(Part)가 적재되어 있는지, 혹은 비어 있는지(Empty)를 파악하여 물류 흐름을 제어하거나 재고 현황을 모니터링하는 데 사용된다.
#
# **2. 기술 명세 (Technical Specification)**
# - **Endpoint:** `/api/object/rackstate`
# - **Method:** `GET`
# - **Header:**
#   - `Authorization: Bearer {Token}` (JWT 인증 토큰 필수)
#   - `Content-Type: application/json`
# - **Request Parameters:** 없음 (전체 조회)
# - **Response Body Fields:**
#
# | 필드명 | 타입 | 설명 |
# | :--- | :--- | :--- |
# | `PrcsCD` | String | 공정 코드 (Process Code) |
# | `RackNo` | Integer | 랙 고유 번호 |
# | `RackNM` | String | 랙 명칭 (예: "Rack-A-01") |
# | `RackIndex` | Integer | 랙 내 세부 위치 인덱스 (Slot/Cell 번호) |
# | `PLTNo` | String | 적재된 팔레트 번호 (비어있을 경우 null 또는 빈 값) |
# | `PLTType` | String | 팔레트 유형 |
# | `PLTTypeNo` | Integer | 팔레트 유형 식별 번호 |
# | `PLTStatus` | Integer | 팔레트 상태 코드 (예: 0=Empty, 1=Loaded) |
# | `TransNo` | String | 이송 번호 (Transaction ID) |
# | `PartNo` | String | 자재/부품 번호 |
# | `PartID` | String | 자재 고유 ID |
# | `PartType` | Integer | 자재 유형 코드 |
# | `PartLevel` | Integer | 자재 등급 또는 적재 높이 레벨 |
# | `PartCount` | Integer | 적재된 자재 수량 |
# | `PartStatus` | Integer | 자재 상태 코드 (예: 0=Normal, 1=Defect) |
# | `PartInfoValue` | String | 기타 자재 부가 정보 |
# | `UpTM` | String | 데이터 최종 갱신 시간 (ISO 8601 형식) |
#
# **3. 사용 사례 (Use Case)**
# - **재고 현황 모니터링:** 관제 시스템(WCS/ACS) 대시보드에서 현재 공장 내 모든 랙의 점유율과 자재 위치를 시각화할 때 호출한다.
# - **AMR 작업 할당 전 검증:** AMR이 팔레트를 랙에 적재(Unloading)하기 전, 해당 `RackIndex`가 실제로 비어 있는지, 혹은 이미 다른 자재가 있는지 DB 상의 상태를 교차 검증(Double Check)하기 위해 사용된다.
# - **자재 추적 (Traceability):** 특정 `PartNo`가 현재 어느 랙의 몇 번째 칸(`RackIndex`)에 보관되어 있는지 위치를 추적할 때 사용된다.
#
# **4. 요청 및 응답 예시 (Request & Response Example)**
#
# **Request (cURL)**
# ```bash
# curl -X GET "https://{HOST}/api/object/rackstate" \
#      -H "Authorization: Bearer eyJhbGciOiJIUzI1NiIsIn..." \
#      -H "Content-Type: application/json"
# ```
#
# **Response (JSON)**
# ```json
# [
#   {
#     "PrcsCD": "PRCS_BODY_01",
#     "RackNo": 101,
#     "RackNM": "Rack-A-Zone-1",
#     "RackIndex": 1,
#     "PLTNo": "PLT_99821",
#     "PLTType": "Steel_Type_A",
#     "PLTTypeNo": 10,
#     "PLTStatus": 1,
#     "TransNo": "TRX_20240101_005",
#     "PartNo": "PN_5502-A",
#     "PartID": "PID_UUID_V4",
#     "PartType": 2,
#     "PartLevel": 1,
#     "PartCount": 50,
#     "PartStatus": 0,
#     "PartInfoValue": "Batch_005",
#     "UpTM": "2024-05-20T14:30:00"
#   },
#   {
#     "PrcsCD": "PRCS_BODY_01",
#     "RackNo": 101,
#     "RackNM": "Rack-A-Zone-1",
#     "RackIndex": 2,
#     "PLTNo": "",
#     "PLTType": "",
#     "PLTTypeNo": 0,
#     "PLTStatus": 0,
#     "TransNo": "",
#     "PartNo": "",
#     "PartID": "",
#     "PartType": 0,
#     "PartLevel": 0,
#     "PartCount": 0,
#     "PartStatus": 0,
#     "PartInfoValue": "",
#     "UpTM": "2024-05-20T10:00:00"
#   }
# ]
# ```
# 2026-01-09 17:00:05.719 | INFO     | __main__:<module>:6 - [입력]
# ...
#
# ## 4. 요청 예시 (Request Examples)
#
# ### 4.1 토큰 발급 요청 (Login Request Body)
# ```json
# {
#   "username": "sys_admin_01",
#   "password": "secure_password_123!"
# }
# ```
#
# ### 4.2 인증 헤더가 포함된 API 호출 예시 (Authenticated Request)
# 실제 비즈니스 로직 API(예: 로봇 상태 조회)를 호출할 때의 HTTP 요청 구조이다.
#
# ```http
# GET /api/robot/status/R_101 HTTP/1.1
# Host: api.hyundai-acs.com
# Authorization: Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIxMjM0NTY3ODkwIiwibmFtZSI...
# Content-Type: application/json
# ```
#
# ### 4.3 인증 실패 응답 (Error Response)
# 유효하지 않거나 만료된 토큰 사용 시 반환되는 응답이다.
#
# ```json
# {
#   "code": 401,
#   "message": "Unauthorized: Token has expired or is invalid.",
#   "timestamp": "2023-10-27T10:00:00Z"
# }
# ```
# 2026-01-09 17:23:43.529 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 인증 (Authentication)
# ### 토큰 사용 방법
# 1. `/api/user/login` 엔드포인트를 통해 로그인
# 2. 응답에서 받은 `AuthToken`을 요청 헤더에 포함
# 3. 헤더 형식: `Authorization: Bearer {AuthToken}`
#
#
# 2026-01-09 17:24:07.002 | INFO     | __main__:<module>:9 - ## [API] 사용자 로그인 및 인증 (User Login & Authentication)
#
# **1. 개요 (Overview)**
# `/api/user/login` API는 현대 자동화 제어 시스템(Hyundai Automated Control System)에 접근하기 위한 최초 진입점이다. 사용자의 자격 증명(Credentials)을 검증하고, 이후 모든 보안 API 호출에 필수적인 `AuthToken`을 발급하기 위해 사용된다. 이 과정을 거치지 않은 요청은 시스템에서 거부(401 Unauthorized)된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/user/login`
# - **Method:** `POST`
# - **Content-Type:** `application/json`
# - **Body Parameters:**
#   | Parameter | Type | Required | Description |
#   | :--- | :--- | :--- | :--- |
#   | `userId` | String | Yes | 사용자 또는 시스템 계정 ID |
#   | `password` | String | Yes | 계정 비밀번호 |
#
# **3. 응답 명세 (Response Specification)**
# 성공적인 인증 시, 시스템은 후속 요청에 사용할 수 있는 인증 토큰을 반환한다.
# - **Response Body Parameters:**
#   | Parameter | Type | Description |
#   | :--- | :--- | :--- |
#   | `AuthToken` | String | JWT(JSON Web Token) 형식의 암호화된 액세스 토큰 |
#   | `expiresIn` | Integer | (Optional) 토큰 만료 시간 (초 단위) |
#
# **4. 사용 사례 (Use Case)**
# - **작업자 로그인:** 현장 오퍼레이터가 HMI 또는 웹 콘솔에 접속하여 제어 권한을 획득할 때 사용된다.
# - **시스템 연동:** 상위 시스템(MES/ERP)이나 외부 에이전트가 BMA 시스템에 작업 지시를 내리기 전, 세션을 초기화하기 위해 호출한다.
#
# **5. 인증 토큰 사용 가이드 (Token Usage Guide)**
# 로그인 API를 통해 발급받은 `AuthToken`은 이후 호출되는 모든 API의 HTTP Header에 반드시 포함되어야 한다.
# - **Header Key:** `Authorization`
# - **Header Value Format:** `Bearer {AuthToken}`
#   - *주의: `Bearer`와 토큰 문자열 사이에 공백(Space)이 하나 있어야 한다.*
#
# **6. 요청 및 응답 예시 (Examples)**
#
# **Request Body Example**
# ```json
# {
#   "userId": "sys_admin_01",
#   "password": "securePassword123!"
# }
# ```
#
# **Response Body Example**
# ```json
# {
#   "AuthToken": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIxMjM0NTY3ODkwIiwibmFtZSI...",
#   "expiresIn": 3600
# }
# ```
#
# **Subsequent Request Header Example (후속 요청 헤더 적용 예시)**
# ```http
# POST /api/command/move HTTP/1.1
# Host: api.hyundai-acs.com
# Authorization: Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIxMjM0NTY3ODkwIiwibmFtZSI...
# Content-Type: application/json
# ```
# 2026-01-09 17:24:07.004 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 인증 (Authentication)
# ### 권한 레벨
# - **일반 사용자**: 기본 조회 권한
# - **미션 관리자** (ROLE_MISSION_MANAGER): 미션 및 작업 오더 관리 권한
# - **관리자** (ROLE_ADMIN): 시스템 관리 권한
#
#
# 2026-01-09 17:24:36.896 | INFO     | __main__:<module>:9 - 제공된 입력 데이터는 구체적인 API Endpoint가 아닌, 시스템 전반의 **인증(Authentication) 및 권한(Authorization) 정책**에 대한 정의입니다. 따라서 본 문서는 개별 API 호출 명세서가 아닌, **시스템 보안 및 권한 제어 표준 명세서(Security & Access Control Specification)** 형식으로 작성되었습니다.
#
# 이를 통해 개발자는 각 API 구현 시 어떤 권한 레벨을 적용해야 하는지, 클라이언트는 어떻게 인증 정보를 전달해야 하는지 파악할 수 있습니다.
#
# ---
#
# # [System Spec] 인증 및 권한 제어 (Authentication & RBAC)
#
# ## 1. 개요 (Overview)
# Hyundai Automated Control System WebBackend는 **JWT (JSON Web Token)** 기반의 인증 방식을 채택하며, 사용자 역할(Role)에 따른 **RBAC (Role-Based Access Control)** 모델을 통해 API 접근 권한을 제어한다. 모든 클라이언트는 API 호출 시 적절한 인증 토큰을 헤더에 포함해야 하며, 서버는 해당 토큰 내의 `roles` 클레임을 검증하여 리소스 접근을 허용하거나 거부한다.
#
# ## 2. 권한 레벨 명세 (Permission Levels)
# 시스템 내 정의된 권한 레벨과 각 역할별 접근 범위는 다음과 같다.
#
# | 역할 명 (Role Name) | 시스템 코드 (System Code) | 접근 권한 및 설명 |
# | :--- | :--- | :--- |
# | **일반 사용자** | `ROLE_USER` (Default) | **[Read-Only]** 대시보드 모니터링, 로봇 상태 조회, 로그 열람 등 시스템 상태 변경을 유발하지 않는 단순 조회 기능만 허용된다. |
# | **미션 관리자** | `ROLE_MISSION_MANAGER` | **[Operation]** 작업 오더(Order) 생성/수정/삭제, 미션 할당, 로봇 제어(일시정지/재개) 등 공정 운영에 필요한 핵심 기능을 수행한다. |
# | **관리자** | `ROLE_ADMIN` | **[System Config]** 사용자 계정 관리, 시스템 설정 변경, 맵(Map) 데이터 수정 등 시스템 전반에 대한 모든 제어 권한을 가진다. |
#
# ## 3. 기술적 상세 (Technical Details)
#
# ### 3.1 인증 헤더 (Request Header)
# 보호된 리소스(Protected Resource)에 접근하는 모든 API 요청은 아래의 HTTP Header를 반드시 포함해야 한다.
# - **Header Key:** `Authorization`
# - **Value Format:** `Bearer {Access_Token}`
#
# ### 3.2 인증 프로세스 예시 (Login API)
# *참고: 입력 데이터에 구체적인 로그인 Endpoint가 명시되지 않았으나, 표준적인 JWT 발급 절차를 기반으로 작성됨.*
#
# - **Endpoint:** `/api/auth/login`
# - **Method:** `POST`
# - **Content-Type:** `application/json`
#
# ### 3.3 응답 상태 코드 (Status Codes)
# - `200 OK`: 인증 성공 및 요청 처리 완료.
# - `401 Unauthorized`: 유효하지 않은 토큰, 만료된 토큰, 또는 토큰 누락.
# - `403 Forbidden`: 인증은 되었으나, 해당 리소스에 접근할 권한(Role)이 부족함.
#
# ## 4. 사용 사례 (Use Cases)
#
# 1.  **일반 사용자 (General User):**
#     *   현장 작업자가 태블릿을 통해 현재 AGV/AMR의 위치를 실시간으로 모니터링하는 경우.
#     *   `GET /api/robots/status` 호출 시 `ROLE_USER` 권한으로 접근 가능.
#
# 2.  **미션 관리자 (Mission Manager):**
#     *   공정 제어 담당자가 특정 로봇에게 자재 운반 명령을 내리거나, 긴급 정지된 로봇의 에러를 리셋하는 경우.
#     *   `POST /api/missions` 또는 `PUT /api/robots/{id}/reset` 호출 시 `ROLE_MISSION_MANAGER` 권한 필수.
#
# 3.  **관리자 (Admin):**
#     *   새로운 미션 관리자를 시스템에 등록하거나, 공장 레이아웃 변경에 따른 맵 데이터를 업데이트하는 경우.
#     *   `POST /api/users` 또는 `PUT /api/system/config` 호출 시 `ROLE_ADMIN` 권한 필수.
#
# ## 5. JSON 예시 (JSON Examples)
#
# ### 5.1 로그인 요청 (Request Body)
# 사용자가 시스템에 접근하기 위해 자격 증명을 전송하는 예시입니다.
# ```json
# {
#   "username": "hmg_operator_01",
#   "password": "secure_password_123!"
# }
# ```
#
# ### 5.2 인증 성공 응답 (Response Body)
# 서버가 유효한 JWT와 해당 사용자의 권한(`roles`)을 반환하는 예시입니다. 클라이언트는 이 `accessToken`을 저장하여 후속 요청에 사용해야 합니다.
#
# ```json
# {
#   "accessToken": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJobWdfb3BlcmF0b3JfMDEiLCJyb2xlcyI6WyJST0xFX01JU1NJT05fTUFOQUdFUiJdLCJpYXQiOjE2MTYyMzkwMjJ9.SflKxwRJSMeKKF2QT4fwpMeJf36POk6yJV_adQssw5c",
#   "tokenType": "Bearer",
#   "expiresIn": 3600,
#   "userInfo": {
#     "id": "user_5521",
#     "username": "hmg_operator_01",
#     "roles": [
#       "ROLE_MISSION_MANAGER"
#     ],
#     "department": "Logistics Control Team"
#   }
# }
# ```
#
# ### 5.3 권한이 적용된 API 호출 헤더 예시
# 미션 관리자가 작업을 생성할 때 전송하는 실제 HTTP 요청 헤더입니다.
# ```http
# POST /api/missions HTTP/1.1
# Host: api.hyundai-acs.com
# Authorization: Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9... (Token)
# Content-Type: application/json
#
# {
#   "missionId": "MS_20231025_001",
#   "targetRobot": "AMR_05",
#   "action": "TRANSPORT_PALLET"
# }
# ```
# 2026-01-09 17:24:36.898 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 인증 (Authentication)
# ### 에러 코드
# - **401 Unauthorized**: 인증 실패 (토큰 없음 또는 유효하지 않음)
# - **403 Forbidden**: 권한 부족
# - **406 Not Acceptable**: 동시 접속자 수 초과
#
# ---
#
#
# 2026-01-09 17:25:03.128 | INFO     | __main__:<module>:9 - ## [System] 인증 정책 및 공통 에러 명세 (Authentication & Common Error Specification)
#
# **1. 개요 (Definition)**
# 본 명세는 **Hyundai Automated Control System WebBackend**의 모든 API 엔드포인트 접근 시 적용되는 공통 인증 정책과, 인증 실패 및 시스템 제한 상황에서 반환되는 표준 에러 코드를 정의한다. 클라이언트(HMI, 에이전트 등)는 API 호출 시 유효한 인증 자격을 제시해야 하며, 시스템은 아래 명세에 따라 접근 허용 여부를 결정한다.
#
# **2. 기술 상세 (Technical Details)**
# 모든 보안 API 요청은 적절한 인증 헤더를 포함해야 하며, 위반 시 다음과 같은 HTTP 상태 코드를 반환한다.
#
# - **적용 범위:** 인증이 요구되는 모든 API Endpoints
# - **주요 에러 코드 명세:**
#     | HTTP Code | Status | 설명 (Description) | 발생 원인 |
#     | :--- | :--- | :--- | :--- |
#     | **401** | `Unauthorized` | 인증 실패 | 요청 헤더에 토큰이 없거나, 만료되었거나, 위조된 경우 발생한다. |
#     | **403** | `Forbidden` | 권한 부족 | 인증은 되었으나, 해당 계정이 요청한 리소스(예: 관리자 전용 설정)에 접근할 권한(Role)이 없는 경우 발생한다. |
#     | **406** | `Not Acceptable` | 동시 접속 초과 | 시스템 안정성을 위해 설정된 최대 동시 접속자 수(Session Limit)를 초과하여 신규 연결이 거부된 경우 발생한다. |
#
# **3. 사용 사례 (Use Case)**
# 실제 BMA 공정 운영 중 발생할 수 있는 시나리오는 다음과 같다.
#
# 1.  **세션 만료 (401):** 현장 작업자가 태블릿 HMI를 켜둔 채 장시간 자리를 비운 후, 다시 `GET /api/status`를 호출했을 때 토큰 만료로 인해 로그아웃 처리된다.
# 2.  **권한 제어 (403):** 일반 오퍼레이터(Operator) 계정으로 시스템의 전역 파라미터 설정(`PUT /api/config/global`)을 변경하려 할 때, 보안 정책에 의해 요청이 거부된다.
# 3.  **트래픽 제어 (406):** 교대 근무 시간(Shift Change)에 수백 명의 작업자가 동시에 시스템 로그인을 시도하여, 백엔드 부하 방지를 위해 설정된 임계치를 초과했을 때 연결이 차단된다.
#
# **4. 응답 예시 (Response Body Example)**
# 에러 발생 시 시스템은 HTTP Status Code와 함께 아래와 같은 표준 JSON 포맷을 반환한다.
#
# **Case 1: 401 Unauthorized (인증 토큰 만료)**
# ```json
# {
#   "timestamp": "2023-10-27T14:30:00Z",
#   "status": 401,
#   "error": "Unauthorized",
#   "message": "Access token has expired or is invalid.",
#   "path": "/api/robot/control"
# }
# ```
#
# **Case 2: 406 Not Acceptable (동시 접속자 수 초과)**
# ```json
# {
#   "timestamp": "2023-10-27T09:00:05Z",
#   "status": 406,
#   "error": "Not Acceptable",
#   "message": "Maximum number of concurrent users exceeded. Please try again later.",
#   "details": {
#     "current_sessions": 500,
#     "max_allowed": 500
#   }
# }
# ```
# 2026-01-09 17:25:03.131 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 공통 Response 형식
# ### 성공 응답
# ```json
# {
#   "Success": true,
#   "Message": "작업이 성공적으로 완료되었습니다",
#   "Data": { /* 데이터 객체 */ }
# }
# ```
#
#
# 2026-01-09 17:25:28.897 | INFO     | __main__:<module>:9 - 제공해주신 입력 데이터는 **[공통 응답 형식]**에 대한 정의입니다. 이는 개별 API 엔드포인트가 아닌, 시스템 전체에 적용되는 **아키텍처 표준(Architectural Standard)**입니다.
#
# 이에 따라, 개발자와 에이전트가 응답을 파싱(Parsing)할 때 반드시 준수해야 할 **공통 응답 프로토콜 명세서**를 작성하였습니다.
#
# ---
#
# # BMA System API Technical Specification
#
# ## [System Architecture] 공통 응답 프로토콜 (Common Response Protocol)
#
# **1. 개요 (Overview)**
# Hyundai Automated Control System WebBackend의 모든 API 엔드포인트는 클라이언트(Frontend, Agent, 3rd Party System)와의 일관된 통신을 보장하기 위해 표준화된 JSON 래퍼(Wrapper) 구조를 반환한다. 클라이언트는 HTTP Status Code와 무관하게, 본 응답 본문(Body)의 `Success` 필드를 통해 비즈니스 로직의 성공 여부를 1차적으로 판단해야 한다.
#
# **2. 응답 명세 (Response Specification)**
# 모든 API 응답은 아래의 3가지 핵심 필드로 구성된다.
#
# - **Format:** JSON
# - **Content-Type:** `application/json`
# - **Structure Fields:**
#
# | 필드명 (Field) | 타입 (Type) | 필수 (Required) | 설명 (Description) |
# | :--- | :--- | :--- | :--- |
# | **`Success`** | Boolean | **Yes** | 요청 처리 성공 여부.<br>• `true`: 로직 정상 수행 완료<br>• `false`: 로직 수행 중 오류 발생 (Validation, Server Error 등) |
# | **`Message`** | String | **Yes** | 처리 결과에 대한 사람이 읽을 수 있는 메시지.<br>• 성공 시: "작업이 성공적으로 완료되었습니다" 등의 확인 메시지<br>• 실패 시: 구체적인 에러 원인 또는 디버깅 가이드 |
# | **`Data`** | Object / Array / Null | **Yes** | 실제 요청한 비즈니스 데이터 페이로드.<br>• 데이터가 없는 경우 `null` 또는 빈 객체 `{}` 반환 가능<br>• 에러 발생 시 일반적으로 `null` 반환 |
#
# **3. 처리 로직 및 사용 사례 (Processing Logic & Use Case)**
# 클라이언트 애플리케이션은 API 호출 후 다음과 같은 순서로 응답을 처리해야 한다.
#
# 1.  **HTTP Status 확인:** 200 OK 계열인지 확인한다.
# 2.  **Success 필드 검증:** JSON Body의 `Success` 값이 `true`인지 확인한다.
# 3.  **데이터 추출:** `Success`가 `true`일 경우 `Data` 객체 내부의 정보를 UI에 바인딩하거나 로직에 사용한다.
# 4.  **에러 핸들링:** `Success`가 `false`일 경우 `Message` 필드의 내용을 사용자에게 알림(Toast/Alert)으로 표시하거나 로그에 기록한다.
#
# **4. 응답 예시 (Response Body Examples)**
#
# **Case A: 데이터 조회 성공 (Success with Data)**
# *특정 로봇(AMR)의 상태 정보를 조회했을 때의 응답 예시*
# ```json
# {
#   "Success": true,
#   "Message": "작업이 성공적으로 완료되었습니다",
#   "Data": {
#     "RobotId": "AMR_001",
#     "Status": "Running",
#     "BatteryLevel": 85,
#     "CurrentLocation": {
#       "X": 120.5,
#       "Y": 45.2
#     }
#   }
# }
# ```
#
# **Case B: 단순 명령 성공 (Success without Data)**
# *로봇 리셋 명령 등 별도의 반환 데이터가 필요 없는 경우의 예시*
# ```json
# {
#   "Success": true,
#   "Message": "작업이 성공적으로 완료되었습니다",
#   "Data": {}
# }
# ```
#
# **Case C: 비즈니스 로직 실패 (Failure)**
# *유효하지 않은 ID로 요청했을 때의 응답 예시*
# ```json
# {
#   "Success": false,
#   "Message": "존재하지 않는 로봇 ID입니다. 입력 값을 확인해주세요.",
#   "Data": null
# }
# ```
# 2026-01-09 17:25:28.899 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 공통 Response 형식
# ### 에러 응답
# ```json
# {
#   "Success": false,
#   "Message": "에러 메시지",
#   "ErrorCode": "ERROR_CODE"
# }
# ```
#
#
#
# 2026-01-09 17:25:50.312 | INFO     | __main__:<module>:9 - 제공해주신 입력 데이터를 바탕으로 **Hyundai Automated Control System WebBackend**의 **공통 에러 응답 규격**에 대한 기술 명세서를 작성합니다.
#
# ---
#
# ## [API] 공통 에러 응답 규격 (Common Error Response Specification)
#
# **1. 개요 (Overview)**
# 본 명세는 Hyundai Automated Control System WebBackend의 모든 API Endpoint에서 요청 처리에 실패했을 때 반환되는 **표준 JSON 응답 구조**를 정의한다. 클라이언트(Frontend, Agent, 3rd Party System)는 HTTP Status Code와 관계없이 본 응답 본문(Body)을 파싱하여 에러의 구체적인 원인을 식별하고, `ErrorCode`에 따른 적절한 예외 처리 로직을 수행해야 한다.
#
# **2. 응답 명세 (Response Specification)**
# - **Applicability:** 시스템 내 모든 API Endpoint
# - **Condition:** 비즈니스 로직 실패, 유효성 검증 실패, 서버 내부 오류 발생 시
# - **Response Body Fields:**
#
# | 필드명 (Field) | 타입 (Type) | 설명 (Description) |
# | :--- | :--- | :--- |
# | `Success` | Boolean | 요청 처리 성공 여부. 에러 응답 시 항상 `false`로 고정된다. |
# | `Message` | String | 에러에 대한 상세 설명(Human-readable). 디버깅 용도 또는 사용자 UI 알림 메시지로 활용된다. |
# | `ErrorCode` | String | 에러 유형을 식별하는 고유 코드(Machine-readable). 클라이언트가 에러별 분기 처리를 수행하는 기준이 된다. |
#
# **3. 사용 사례 (Use Case)**
# 이 응답 규격은 다음과 같은 상황에서 시스템의 일관성을 유지하기 위해 사용된다.
# - **유효성 검증 실패:** 클라이언트가 필수 파라미터를 누락하거나 잘못된 형식의 데이터를 전송했을 때.
# - **리소스 상태 충돌:** 제어하려는 AMR(로봇)이 이미 다른 작업을 수행 중이거나 오프라인 상태일 때.
# - **인증/권한 오류:** API 토큰이 만료되었거나 해당 명령을 수행할 권한이 없을 때.
#
# **4. 응답 예시 (Response Body Example)**
#
# 다음은 특정 로봇(`AMR_101`)에게 작업을 할당하려 했으나, 해당 로봇이 이미 작업 중이어서 요청이 거부된 경우의 응답 예시이다.
#
# ```json
# {
#   "Success": false,
#   "Message": "Target robot 'AMR_101' is currently executing another task and cannot accept new commands.",
#   "ErrorCode": "ROBOT_BUSY_STATE"
# }
# ```
# 2026-01-09 17:25:50.314 | INFO     | __main__:<module>:6 - [입력]
# # Hyundai Automated Control System WebBackend API 문서
# ## 공통 Response 형식
# ### 참고사항
# - **API 버전**: 1.0
# - **프레임워크**: ASP.NET Web API
# - **인증**: JWT (JSON Web Token)
# - **데이터 형식**: JSON
# - **문자 인코딩**: UTF-8
#
# 1. 모든 날짜/시간은 ISO 8601 형식을 사용합니다
# 2. 녹화 ID는 "YYYYMMDDHHMMSS" 형식의 14자리 문자열 또는 "current"를 사용합니다
# 3. 센서 값 조회는 1초 캐싱이 적용되어 있습니다
# 4. 바이너리 데이터는 Base64 인코딩되어 전송됩니다
# 5. 동시 접속 사용자 수에 제한이 있을 수 있습니다
#
# 2026-01-09 17:26:13.155 | INFO     | __main__:<module>:9 - # Hyundai Automated Control System - API 공통 프로토콜 명세서 (Common Protocol Specification)
#
# **1. 개요 (Overview)**
# 본 문서는 **Hyundai Automated Control System WebBackend API (v1.0)** 와의 통신을 위한 기본 아키텍처 표준 및 데이터 규약을 정의한다. 모든 클라이언트(HMI, 에이전트, 타사 시스템)는 개별 Endpoint를 호출하기 전, 본 문서에 명시된 인증 방식, 데이터 포맷, 캐싱 정책을 준수해야 한다.
#
# **2. 기술적 상세 (Technical Details)**
#
# *   **기반 프레임워크:** ASP.NET Web API
# *   **통신 프로토콜:** HTTP/1.1 over TLS
# *   **인증 (Authentication):**
#     *   모든 요청은 **JWT (JSON Web Token)** 기반의 인증을 수행해야 한다.
#     *   **Header:** `Authorization: Bearer {Access_Token}`
# *   **데이터 형식 (Data Format):**
#     *   **Content-Type:** `application/json`
#     *   **Encoding:** `UTF-8`
# *   **데이터 포맷팅 규칙 (Formatting Rules):**
#     *   **날짜/시간 (Date/Time):** ISO 8601 표준 (`YYYY-MM-DDTHH:mm:ss.sssZ`)을 엄격히 준수한다.
#     *   **바이너리 데이터 (Binary):** 이미지, 로그 파일 등 바이너리 데이터는 반드시 **Base64 String**으로 인코딩하여 전송한다.
#     *   **녹화 ID (Record ID):** `YYYYMMDDHHMMSS` (14자리 문자열) 또는 실시간 조회를 위한 `current` 리터럴을 사용한다.
# *   **성능 및 제약 사항 (Constraints):**
#     *   **센서 데이터 캐싱:** 시스템 부하 방지를 위해 센서 값 조회 시 **1초(1000ms)의 서버 측 캐싱**이 적용된다. 1초 이내의 중복 호출은 동일한 값을 반환할 수 있다.
#     *   **동시성:** 동시 접속 사용자 수에 따른 Rate Limiting이 발생할 수 있다.
#
# **3. 사용 사례 (Use Case)**
#
# *   **데이터 폴링 (Polling):** 클라이언트가 로봇의 센서 데이터를 주기적으로 조회할 때, 1초 미만의 간격으로 호출하는 것은 무의미하며(캐싱 정책), 네트워크 대역폭 낭비를 초래하므로 1초 이상의 간격을 권장한다.
# *   **이력 조회 (History Retrieval):** 특정 시점의 사고 기록이나 작업 로그를 조회할 때, `RecordID` 필드에 `20231025143000`과 같은 포맷을 사용하여 정확한 시점을 지정한다.
# *   **이미지 전송:** 로봇의 카메라 캡처 데이터를 전송받을 때, JSON 응답 내 `ImagePayload` 필드의 Base64 문자열을 디코딩하여 렌더링한다.
#
# **4. 공통 응답 예시 (Common Response Example)**
#
# 아래는 위 규칙들이 적용된 가상의 센서 데이터 조회 응답 예시이다. 날짜 형식, 바이너리 인코딩, ID 형식을 참고하시오.
#
# ```json
# {
#   "meta": {
#     "apiVersion": "1.0",
#     "timestamp": "2023-10-27T14:30:05.123Z",  // ISO 8601 형식 준수
#     "status": "success",
#     "requestId": "req_a1b2c3d4"
#   },
#   "data": {
#     "recordId": "current",                     // 실시간 데이터 조회 시 'current' 사용
#     "sensorValues": {
#       "temperature": 45.2,
#       "vibration": 0.05,
#       "lastUpdated": "2023-10-27T14:30:04.000Z" // 1초 캐싱 정책에 의해 요청 시간과 차이 발생 가능
#     },
#     "snapshot": {
#       "format": "png",
#       "encoding": "base64",
#       "payload": "iVBORw0KGgoAAAANSUhEUgAAAAEAAAABCAQAAAC1HAwCAAAAC0lEQVR42mNk+A8AAQUBAScY42YAAAAASUVORK5CYII=" // Base64 인코딩된 바이너리
#     }
#   }
# }
# ```

# %%
mcs_results = []
for i, x in enumerate(mcs_preprocessed):
    context = x['preprocessed']
    user_prompt = f"""[입력]
{context}"""
    logger.info(user_prompt)
    response = llm_client.generate(system_prompt=SYNTHETIC_SPECIFIC_PROMPT, chat_messages=[{"role": "user", "content": user_prompt}])
    result = response.choices[0].message.content
    logger.info(result)
    json_result = {
        'id': i,
        'preprocessed_group': context,
        'textbook': result
    }
    mcs_results.append(json_result)

with open("mcs_textbook_merged2.json", "w", encoding="utf-8") as f:
    json.dump(mcs_results, f, ensure_ascii=False, indent=4)
# Out:
# 2026-01-09 17:26:13.188 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## PLCController. PLC(Programmable Logic Controller) 센서 값을 관리하는 API입니다.
# ### 1. PUT /api/PLC/sensorvalue
#
# 센서 값을 업데이트합니다.
#
# **Endpoint:** `PUT /api/PLC/sensorvalue`
#
# **Request Body:**
# ```json
# {
#   "SensorId": 1001,
#   "Current": "25.5"
# }
# ```
#
# **Response:**
# ```json
# {
#   "Success": true,
#   "Error": null
# }
# ```
#
# **인증:** JWT Token 필요
#
# **설명:**
# - 사용자 정보는 JWT Token에서 추출됩니다.
# - 센서 값을 PLC에 기록하고 결과를 반환합니다.
#
# ---
#
#
# 2026-01-09 17:26:33.689 | INFO     | __main__:<module>:9 - ## [API] PLC 센서 값 갱신 (Update PLC Sensor Value)
#
# **1. 개요 (Overview)**
# `PUT /api/PLC/sensorvalue` API는 MCS(Material Control System)가 관리하는 특정 PLC(Programmable Logic Controller) 센서의 현재 상태 값을 강제로 갱신하거나 보정하는 기능을 수행한다. 이 API는 물리적 센서 데이터의 소프트웨어적 오버라이드(Override) 또는 시뮬레이션 환경에서의 가상 데이터 주입을 위해 사용된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/PLC/sensorvalue`
# - **Method:** `PUT`
# - **Header:**
#   - `Content-Type`: `application/json`
#   - `Authorization`: `Bearer {JWT_Token}` (필수: 유효한 사용자 인증 토큰)
# - **Body Parameters:**
#
# | Parameter | Type | Required | Description |
# | :--- | :--- | :--- | :--- |
# | `SensorId` | Integer | **Yes** | 값을 갱신할 대상 센서의 고유 식별자 (PLC 레지스터 매핑 ID) |
# | `Current` | String | **Yes** | 갱신할 센서의 측정값 (실수형 데이터도 문자열 형태로 전송) |
#
# **3. 사용 사례 (Use Case)**
# 이 API는 BMA 공정 중 다음과 같은 상황에서 주로 호출된다:
# - **센서 보정 (Calibration):** 물리적 센서의 노후화나 오차로 인해, 시스템 상에서 인식해야 하는 기준값으로 강제 보정이 필요한 경우.
# - **수동 오버라이드 (Manual Override):** 센서 고장으로 인해 공정이 중단되었을 때, 운영자가 수동으로 '정상' 또는 특정 수치를 입력하여 공정 로직(Interlock)을 우회하고 AMR을 이동시켜야 하는 경우.
# - **시뮬레이션 (Simulation):** 실제 하드웨어 연결 없이 MCS 로직을 테스트하기 위해 가상의 온도, 압력, 위치 값을 PLC 메모리에 주입하는 경우.
#
# **4. 요청 예시 (Request Body Example)**
# 다음은 ID가 `1001`인 온도 센서의 값을 `25.5`도로 갱신하는 요청 예시이다.
#
# ```json
# {
#   "SensorId": 1001,
#   "Current": "25.5"
# }
# ```
#
# **5. 응답 예시 (Response Example)**
# 요청이 성공적으로 PLC에 반영되었을 경우의 응답이다.
#
# ```json
# {
#   "Success": true,
#   "Error": null
# }
# ```
# 2026-01-09 17:26:33.692 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## ObjectController. 시스템 객체(장소, 호출, 미션 등)를 관리하는 API입니다.
# ### 1. GET /api/Object/Hello
#
# 서버 연결 테스트용 헬로우 API입니다.
#
# **Endpoint:** `GET /api/Object/Hello`
#
# **Response:**
# ```json
# "Hello, World"
# ```
#
# **인증:** 불필요
#
# ---
#
#
# 2026-01-09 17:26:51.109 | INFO     | __main__:<module>:9 - ## [API] 서버 연결 상태 확인 (Server Connectivity Check)
#
# **1. 개요 (Overview)**
# `GET /api/Object/Hello` API는 MCS(Material Control System) 백엔드 서버의 가용성(Availability)을 확인하고, 클라이언트(AMR, 관제 PC 등)와 서버 간의 네트워크 연결 상태를 점검하기 위한 진단용 인터페이스(Health Check)이다. 별도의 인증 절차 없이 호출 가능하므로 시스템 초기화 단계나 네트워크 트러블슈팅 시 가장 먼저 수행된다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/Object/Hello`
# - **Method:** `GET`
# - **Header:**
#   - `Content-Type`: `application/json` (권장)
#   - **Authorization:** 불필요 (Anonymous Access Allowed)
# - **Query Parameters:** 없음
# - **Body Parameters:** 없음 (Empty Body)
#
# **3. 사용 사례 (Use Case)**
# - **시스템 초기화 (System Initialization):** 에이전트나 관제 클라이언트가 부팅된 직후, 주요 로직을 수행하기 전에 서버가 정상적으로 응답하는지 확인하기 위해 호출한다.
# - **네트워크 진단 (Network Diagnostics):** 로봇 제어 명령이 실패하거나 타임아웃이 발생할 때, 문제의 원인이 서버 다운인지 단순 명령 오류인지 판별하기 위한 'Ping' 용도로 사용한다.
# - **하트비트 모니터링 (Heartbeat Monitoring):** 외부 모니터링 시스템이 주기적으로 이 API를 호출하여 MCS 서버의 생존 여부를 기록한다.
#
# **4. 요청 및 응답 예시 (Request & Response Example)**
#
# **Request (HTTP)**
# ```http
# GET /api/Object/Hello HTTP/1.1
# Host: {MCS_Server_IP}
# Accept: application/json
# ```
#
# **Response (JSON)**
# > 서버가 정상 작동 중일 경우, 아래와 같은 문자열을 반환한다.
# ```json
# "Hello, World"
# ```
# 2026-01-09 17:26:51.111 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## ObjectController. 시스템 객체(장소, 호출, 미션 등)를 관리하는 API입니다.
# ### 2. GET /api/Object/places
#
# 모든 장소(Place) 정보를 조회합니다.
#
# **Endpoint:** `GET /api/Object/places`
#
# **Response:**
# ```json
# [
#   {
#     "Code": "P001",
#     "AlarmState": "Normal",
#     "ModeState": "Auto",
#     "PlaceRunState": "Run",
#     "LogisticsState": "Available"
#   },
#   {
#     "Code": "P002",
#     "AlarmState": "Warning",
#     "ModeState": "Manual",
#     "PlaceRunState": "Stop",
#     "LogisticsState": "Unavailable"
#   }
# ]
# ```
#
# **인증:** 불필요
#
# **설명:**
# - 시스템에 등록된 모든 장소 정보를 반환합니다.
# - 비동기로 처리됩니다.
#
# ---
#
#
# 2026-01-09 17:27:13.525 | INFO     | __main__:<module>:9 - ## [API] 전체 장소 상태 조회 (Get All Places)
#
# **1. 개요 (Definition)**
# `GET /api/Object/places` API는 MCS(Material Control System)에 등록된 모든 물리적, 논리적 장소(Place)의 현재 상태 정보를 조회하는 인터페이스이다. 각 장소(Port, Station, Waypoint 등)의 알람 유무, 운영 모드, 실행 상태 및 물류 작업 가능 여부를 파악하여 시스템 전반의 가시성을 확보하는 데 사용된다.
#
# **2. 기술 명세 (Technical Specification)**
# - **Endpoint:** `/api/Object/places`
# - **Method:** `GET`
# - **Header:**
#   - `Content-Type`: `application/json`
#   - **Authentication:** 불필요 (Anonymous Access Allowed)
# - **Request Parameters:** 없음 (전체 조회)
#
# **3. 응답 데이터 명세 (Response Data Specification)**
# 응답은 JSON Array 형태로 반환되며, 각 객체는 다음 필드를 포함한다.
#
# | 필드명 (Field) | 타입 (Type) | 설명 (Description) |
# | :--- | :--- | :--- |
# | `Code` | String | 장소의 고유 식별자 (예: P001, ST_CHG_01) |
# | `AlarmState` | String | 장소의 알람 상태 (예: `Normal`, `Warning`, `Error`) |
# | `ModeState` | String | 장소의 제어 모드 (예: `Auto`, `Manual`) |
# | `PlaceRunState` | String | 장소의 가동 상태 (예: `Run`, `Stop`) |
# | `LogisticsState` | String | 물류 작업 가능 여부 (예: `Available`, `Unavailable`) |
#
# **4. 사용 사례 (Use Case)**
# 이 API는 다음과 같은 BMA 공정 시나리오에서 활용된다.
# - **관제 대시보드 갱신:** 공장 전체 맵(Map) 상에 각 설비(Port)나 대기 장소의 상태(고장, 수동 모드 등)를 실시간으로 시각화할 때 주기적으로 호출한다.
# - **미션 할당 전 유효성 검사:** 상위 시스템(WMS/MES)이 특정 장소로 AMR을 이동시키기 전, 해당 목적지가 현재 `LogisticsState: Available` 상태인지, `AlarmState: Normal`인지 사전에 검증하여 불필요한 미션 실패를 방지한다.
#
# **5. 응답 예시 (Response Body Example)**
# ```json
# [
#   {
#     "Code": "P001",
#     "AlarmState": "Normal",
#     "ModeState": "Auto",
#     "PlaceRunState": "Run",
#     "LogisticsState": "Available"
#   },
#   {
#     "Code": "P002",
#     "AlarmState": "Warning",
#     "ModeState": "Manual",
#     "PlaceRunState": "Stop",
#     "LogisticsState": "Unavailable"
#   },
#   {
#     "Code": "ST_CHG_01",
#     "AlarmState": "Normal",
#     "ModeState": "Auto",
#     "PlaceRunState": "Run",
#     "LogisticsState": "Available"
#   }
# ]
# ```
# 2026-01-09 17:27:13.527 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## ObjectController. 시스템 객체(장소, 호출, 미션 등)를 관리하는 API입니다.
# ### 3. PUT /api/Object/place
#
# 장소 정보를 업데이트합니다.
#
# **Endpoint:** `PUT /api/Object/place`
#
# **Request Body:**
# ```json
# {
#   "Code": "P001",
#   "AlarmState": "Normal",
#   "ModeState": "Auto",
#   "PlaceRunState": "Run",
#   "LogisticsState": "Available"
# }
# ```
#
# **Response:**
# ```json
# {
#   "Result": true,
#   "Message": "Place updated successfully"
# }
# ```
#
# **인증:** JWT Token 필요
#
# **설명:**
# - 특정 장소의 정보를 업데이트합니다.
# - 사용자 정보는 JWT Token에서 추출됩니다.
#
# ---
#
#
# 2026-01-09 17:27:35.271 | INFO     | __main__:<module>:9 - ## [API] 장소 상태 정보 갱신 (Update Place Status)
#
# **1. 개요 (Overview)**
# `PUT /api/Object/place` API는 MCS(Material Control System) 상에 등록된 특정 장소(Place)의 운영 상태 및 물류 속성을 갱신하는 인터페이스이다. 설비의 고장, 유지보수 모드 전환, 또는 자재 유무 변경 시 이 API를 호출하여 AMR(Autonomous Mobile Robot)이 해당 장소로 진입 가능한지 여부를 시스템에 동기화한다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/Object/place`
# - **Method:** `PUT`
# - **Header:**
#   - `Content-Type`: `application/json`
#   - `Authorization`: `Bearer {Access_Token}` (유효한 JWT 토큰 필수)
# - **Body Parameters:**
#
# | 파라미터명 | 타입 (Type) | 필수 여부 | 설명 |
# | :--- | :--- | :--- | :--- |
# | **`Code`** | String | **Required** | 상태를 변경할 장소의 고유 식별 코드 (예: Station ID, Port ID) |
# | **`AlarmState`** | String | Optional | 장소의 알람 상태 (예: `Normal`, `Error`, `Warning`) |
# | **`ModeState`** | String | Optional | 장소의 운영 모드 (예: `Auto`, `Manual`) |
# | **`PlaceRunState`** | String | Optional | 장소의 가동 상태 (예: `Run`, `Stop`, `Pause`) |
# | **`LogisticsState`** | String | Optional | 물류 가용 상태 (예: `Available`, `Full`, `Empty`, `Reserved`) |
#
# **3. 사용 사례 (Use Case)**
# - **설비 유지보수 전환:** 특정 포트(`P001`)에서 설비 점검이 시작되어, AMR의 접근을 막기 위해 `ModeState`를 `Manual`로, `PlaceRunState`를 `Stop`으로 변경해야 할 때 사용한다.
# - **에러 복구:** 설비 알람이 해제된 후, 시스템 상의 상태를 정상화하기 위해 `AlarmState`를 `Normal`로 리셋할 때 사용한다.
# - **자재 상태 동기화:** 센서에 의해 자재가 감지되었을 때, `LogisticsState`를 업데이트하여 후속 공정(AMR 픽업 등)을 트리거하기 위해 사용한다.
#
# **4. 요청 예시 (Request Body Example)**
# 다음은 장소 코드 `P001`을 정상 가동(Auto/Run) 상태로 설정하고, 물류 작업을 수행할 수 있음(Available)으로 갱신하는 예시이다.
#
# ```json
# {
#   "Code": "P001",
#   "AlarmState": "Normal",
#   "ModeState": "Auto",
#   "PlaceRunState": "Run",
#   "LogisticsState": "Available"
# }
# ```
#
# **5. 응답 예시 (Response Example)**
# 요청이 성공적으로 처리되었을 경우의 응답이다.
#
# ```json
# {
#   "Result": true,
#   "Message": "Place updated successfully"
# }
# ```
# 2026-01-09 17:27:35.273 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## ObjectController. 시스템 객체(장소, 호출, 미션 등)를 관리하는 API입니다.
# ### 4. GET /api/Object/Call
#
# 모든 호출(Call) 정보를 조회합니다.
#
# **Endpoint:** `GET /api/Object/Call`
#
# **Response:**
# ```json
# [
#   {
#     "CODE": "AA001_20250319_P001",
#     "CALL_DT": "20250319",
#     "CALL_ID": "AA001",
#     "CALL_TYPE": "1",
#     "CALLER": "PLC_01",
#     "CALL_PLACE": "P001",
#     "PARAM": "0",
#     "CALL_QUANTITY": 1,
#     "CALL_PRIORITY": 5,
#     "REPEAT_COUNT": 0,
#     "REPEAT_DELAY": 0,
#     "USE_YN": "Y",
#     "STS": "A",
#     "REG_ID": "SYSTEM",
#     "REG_DT": "2025-03-19T10:30:00",
#     "MOD_ID": "SYSTEM",
#     "MOD_DT": "2025-03-19T10:30:00",
#     "MISSION": "M001",
#     "SUBMISSION": "SUB001",
#     "STATE": "ASSIGNED",
#     "UPDATE_DT": "2025-03-19T10:30:15",
#     "GROUP": "GROUP_A"
#   }
# ]
# ```
#
# **인증:** 불필요
#
# **설명:**
# - 시스템의 모든 호출 정보를 반환합니다.
# - 비동기로 처리됩니다.
# - 500ms 캐싱이 적용됩니다.
#
# ---
#
#
# 2026-01-09 17:27:58.965 | INFO     | __main__:<module>:9 - ## [API] 전체 호출 정보 조회 (Retrieve All Calls)
#
# **1. 개요 (Definition)**
# `GET /api/Object/Call` API는 MCS(Material Control System)에 등록된 모든 자재 운송 요청(Call) 객체의 상세 정보와 현재 상태를 조회하는 인터페이스이다. 특정 시점의 전체 작업 대기열(Queue)을 확인하거나, 외부 시스템(PLC, MES)에서 요청한 작업이 정상적으로 등록 및 할당되었는지 모니터링하는 데 사용된다.
#
# **2. 기술 명세 (Technical Specification)**
# - **Endpoint:** `/api/Object/Call`
# - **Method:** `GET`
# - **Authentication:** 불필요 (Anonymous Access Allowed)
# - **Performance & Caching:**
#   - **비동기 처리(Async):** 요청은 비동기적으로 처리되어 시스템 부하를 최소화한다.
#   - **캐싱(Caching):** 데이터는 **500ms** 동안 캐싱된다. 따라서 호출 시점에 따라 최대 0.5초 전의 데이터가 반환될 수 있음을 고려해야 한다.
#
# **3. 응답 데이터 구조 (Response Data Structure)**
# 응답은 JSON Array 형태이며, 각 객체는 다음과 같은 필드를 포함한다.
#
# | 필드명 | 타입 | 설명 |
# | :--- | :--- | :--- |
# | `CODE` | String | 호출 고유 식별 키 (Primary Key, 예: `AA001_20250319_P001`) |
# | `CALL_ID` | String | 호출 논리 ID (예: `AA001`) |
# | `CALL_TYPE` | String | 호출 유형 코드 (예: `1`=일반 운송, `2`=긴급 등) |
# | `CALLER` | String | 호출을 생성한 주체 (예: `PLC_01`, `MES`) |
# | `CALL_PLACE` | String | 작업 대상 위치 노드 ID (예: `P001`) |
# | `CALL_PRIORITY` | Integer | 작업 우선순위 (높을수록 우선 할당) |
# | `STS` | String | 레코드 상태 (예: `A`=Active) |
# | `STATE` | String | 작업 진행 상태 (예: `ASSIGNED`, `WAITING`, `COMPLETED`) |
# | `MISSION` | String | 해당 호출에 할당된 상위 미션 ID |
# | `GROUP` | String | 로봇 또는 작업 그룹 ID |
#
# **4. 사용 사례 (Use Case)**
# - **통합 관제 대시보드 구성:** 현재 시스템 내 대기 중이거나 진행 중인 모든 운송 요청 목록을 시각화할 때 사용한다.
# - **작업 누락 디버깅:** PLC가 작업을 요청했으나 로봇이 할당되지 않는 경우, 이 API를 호출하여 `STATE`가 `WAITING`인지, 혹은 `CALL_PRIORITY`가 낮게 설정되었는지 확인한다.
# - **교착 상태 분석:** 다수의 호출이 `ASSIGNED` 상태이나 진행되지 않는 경우, 전체 목록을 조회하여 병목 지점을 파악한다.
#
# **5. 응답 예시 (Response Body Example)**
# ```json
# [
#   {
#     "CODE": "AA001_20250319_P001",
#     "CALL_DT": "20250319",
#     "CALL_ID": "AA001",
#     "CALL_TYPE": "1",
#     "CALLER": "PLC_01",
#     "CALL_PLACE": "P001",
#     "PARAM": "0",
#     "CALL_QUANTITY": 1,
#     "CALL_PRIORITY": 5,
#     "REPEAT_COUNT": 0,
#     "REPEAT_DELAY": 0,
#     "USE_YN": "Y",
#     "STS": "A",
#     "REG_ID": "SYSTEM",
#     "REG_DT": "2025-03-19T10:30:00",
#     "MOD_ID": "SYSTEM",
#     "MOD_DT": "2025-03-19T10:30:00",
#     "MISSION": "M001",
#     "SUBMISSION": "SUB001",
#     "STATE": "ASSIGNED",
#     "UPDATE_DT": "2025-03-19T10:30:15",
#     "GROUP": "GROUP_A"
#   }
# ]
# ```
# 2026-01-09 17:27:58.967 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## ObjectController. 시스템 객체(장소, 호출, 미션 등)를 관리하는 API입니다.
# ### 5. GET /api/Object/Mission
#
# 모든 미션(Mission) 정보를 조회합니다.
#
# **Endpoint:** `GET /api/Object/Mission`
#
# **Response:**
# ```json
# [
#   {
#     "CODE": "CMD_20250319_001",
#     "CONTROLLER": "RCS_01",
#     "SUBJECT": "MOVE",
#     "CONTENT": "{\"from\":\"P001\",\"to\":\"P002\"}",
#     "PARAM1": "P001",
#     "PARAM2": "P002",
#     "NEED_ACK_YN": "Y",
#     "USE_YN": "Y",
#     "STS": "A",
#     "REG_ID": "SYSTEM",
#     "REG_DT": "2025-03-19T10:30:00",
#     "MOD_ID": "SYSTEM",
#     "MOD_DT": "2025-03-19T10:30:00",
#     "RUN_STATE": "RUNNING",
#     "RETRY_COUNT": 0,
#     "ASSIGNED_WORKER": "AMR_001",
#     "RESPONSE_CONTROLLER": "RCS_01",
#     "RESPONSE_SUBJECT": "MOVE_ACK",
#     "RESPONSE_MESSAGE": "Command received",
#     "START_DT": "2025-03-19T10:30:05",
#     "END_DT": "0001-01-01T00:00:00",
#     "DATA_1": "MOVING",
#     "DATA_2": null,
#     "UPDATE_DT": "2025-03-19T10:30:15"
#   }
# ]
# ```
#
# **인증:** 불필요
#
# **설명:**
# - 시스템의 모든 미션(명령) 정보를 반환합니다.
# - 비동기로 처리됩니다.
# - 500ms 캐싱이 적용됩니다.
#
# ---
#
#
# 2026-01-09 17:28:26.030 | INFO     | __main__:<module>:9 - ## [API] 전체 미션 목록 조회 (Retrieve All Missions)
#
# **1. 개요 (Overview)**
# `GET /api/Object/Mission` API는 MCS(Material Control System)에 등록된 모든 미션(Mission) 객체의 상세 정보를 조회하는 인터페이스이다. 시스템 내에서 생성된 명령(Command)의 생명주기, 할당된 작업자(AMR), 실행 상태(`RUN_STATE`), 그리고 타임스탬프 정보를 반환하여 전체 공정의 흐름을 모니터링하는 데 사용된다.
#
# **2. 기술 명세 (Technical Specification)**
# - **Endpoint:** `/api/Object/Mission`
# - **Method:** `GET`
# - **Authentication:** 불필요 (Internal Network Trust)
# - **Performance:**
#   - **Caching:** 500ms (서버 부하 방지를 위해 0.5초 간격의 데이터 스냅샷 제공)
#   - **Processing:** 비동기(Asynchronous) 데이터 조회
# - **Request Parameters:** 없음 (Query String 또는 Body 불필요)
#
# **3. 응답 데이터 명세 (Response Data Structure)**
# 응답은 JSON Array 형태이며, 주요 필드는 다음과 같다.
#
# | 필드명 | 타입 | 설명 |
# | :--- | :--- | :--- |
# | `CODE` | String | 미션 고유 식별자 (예: `CMD_20250319_001`) |
# | `CONTROLLER` | String | 명령을 관장하는 제어기 ID (예: `RCS_01`) |
# | `SUBJECT` | String | 명령의 주제/유형 (예: `MOVE`, `LIFT`) |
# | `CONTENT` | JSON String | 명령의 세부 파라미터 (출발지, 목적지 등) |
# | `RUN_STATE` | String | 현재 미션의 실행 상태 (예: `RUNNING`, `COMPLETED`, `ERROR`) |
# | `ASSIGNED_WORKER` | String | 미션을 수행 중인 AMR ID |
# | `STS` | String | 레코드 상태 코드 (예: `A` = Active) |
# | `REG_DT` / `UPDATE_DT` | DateTime | 미션 생성 및 최종 수정 일시 |
#
# **4. 사용 사례 (Use Case)**
# - **실시간 관제 대시보드(Dashboard):** VMS(Vehicle Management System) 화면에서 현재 공장 내 모든 로봇의 작업 할당 현황과 진행률을 시각화하기 위해 주기적으로 폴링(Polling)한다.
# - **교착 상태(Deadlock) 분석:** 특정 로봇이 장시간 대기 중일 때, 해당 로봇(`ASSIGNED_WORKER`)에 할당된 미션의 `RUN_STATE`와 `RESPONSE_MESSAGE`를 확인하여 시스템 오류인지 물리적 장애인지 판단한다.
# - **작업 이력 감사(Audit):** 완료된 미션의 `START_DT`와 `END_DT`를 수집하여 로봇의 가동률(OEE) 및 작업 효율성을 분석한다.
#
# **5. 응답 예시 (Response Example)**
# ```json
# [
#   {
#     "CODE": "CMD_20250319_001",
#     "CONTROLLER": "RCS_01",
#     "SUBJECT": "MOVE",
#     "CONTENT": "{\"from\":\"P001\",\"to\":\"P002\"}",
#     "PARAM1": "P001",
#     "PARAM2": "P002",
#     "NEED_ACK_YN": "Y",
#     "USE_YN": "Y",
#     "STS": "A",
#     "REG_ID": "SYSTEM",
#     "REG_DT": "2025-03-19T10:30:00",
#     "MOD_ID": "SYSTEM",
#     "MOD_DT": "2025-03-19T10:30:00",
#     "RUN_STATE": "RUNNING",
#     "RETRY_COUNT": 0,
#     "ASSIGNED_WORKER": "AMR_001",
#     "RESPONSE_CONTROLLER": "RCS_01",
#     "RESPONSE_SUBJECT": "MOVE_ACK",
#     "RESPONSE_MESSAGE": "Command received",
#     "START_DT": "2025-03-19T10:30:05",
#     "END_DT": "0001-01-01T00:00:00",
#     "DATA_1": "MOVING",
#     "DATA_2": null,
#     "UPDATE_DT": "2025-03-19T10:30:15"
#   }
# ]
# ```
# 2026-01-09 17:28:26.033 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## ObjectController. 시스템 객체(장소, 호출, 미션 등)를 관리하는 API입니다.
# ### 6. GET /api/Object/callplaces
#
# 호출 장소의 상태 정보를 조회합니다.
#
# **Endpoint:** `GET /api/Object/callplaces`
#
# **Response:**
# ```json
# [
#   {
#     "Place": "P001",
#     "MachineRequest": 1,
#     "AMRResponse": 2,
#     "PLCMode": 1,
#     "DockRequest": 0
#   },
#   {
#     "Place": "P002",
#     "MachineRequest": 258,
#     "AMRResponse": 1,
#     "PLCMode": 2,
#     "DockRequest": 1
#   }
# ]
# ```
#
# **인증:** 불필요
#
# **설명:**
# - 각 장소의 PLC 태그 정보를 조회합니다.
# - 캐싱 기능이 적용되어 있습니다 (1.5초 간격).
# - MachineRequest는 여러 태그의 값을 합산합니다 (MachineRequest01, MachineRequest02, MachineRequest03).
# - DockRequest는 Docking Out 상태 표시를 위해 추가되었습니다.
#
# **PLC 태그 매핑:**
# - `{Place}.MachineRequest01`: 기계 요청 값 (하위 바이트)
# - `{Place}.MachineRequest02`: 기계 요청 값 (중위 바이트) × 256
# - `{Place}.MachineRequest03`: 기계 요청 값 (상위 바이트) × 256²
# - `{Place}.AMRResponse` 또는 `{Place}.AMRResponse01`: AMR 응답 값
# - `{Place}.DockStatus`: PLC 모드
# - `{Place}.DockRequest`: 도킹 요청 값
#
# ---
#
#
# 2026-01-09 17:28:47.556 | INFO     | __main__:<module>:9 - ## [API] 호출 장소 상태 조회 (Get Call Places Status)
#
# **1. 개요 (Definition)**
# `GET /api/Object/callplaces` API는 MCS(Material Control System)에 등록된 모든 호출 장소(Call Places)의 실시간 PLC 신호 및 상태 정보를 일괄 조회하는 인터페이스이다. 설비(Machine)와 AMR 간의 핸드쉐이크(Handshake) 상태, 도킹 요청 여부, 그리고 PLC 모드 정보를 모니터링하여 시스템의 현재 운영 상황을 파악하는 데 사용된다.
#
# **2. 기술 명세 (Technical Specifications)**
# - **Endpoint:** `/api/Object/callplaces`
# - **Method:** `GET`
# - **Authentication:** 불필요 (Anonymous Access)
# - **Caching:** 서버 측에서 **1.5초** 간격으로 캐싱(Caching)된 데이터를 반환하므로, 최대 1.5초의 데이터 지연(Latency)이 발생할 수 있음.
# - **Request Parameters:** 없음 (No Query or Path parameters required)
#
# **3. 응답 데이터 명세 (Response Data Specification)**
# 응답은 JSON Array 형태이며, 각 객체는 개별 장소의 상태를 나타낸다.
#
# | 필드명 (Field) | 타입 (Type) | 설명 (Description) |
# | :--- | :--- | :--- |
# | `Place` | String | 장소 식별자 (Location ID). |
# | `MachineRequest` | Integer | 설비(Machine)가 요청한 작업 값의 총합. <br>*(계산식: Request01 + (Request02 × 256) + (Request03 × 65536))* |
# | `AMRResponse` | Integer | 해당 장소에 대한 AMR의 응답 신호 값. |
# | `PLCMode` | Integer | PLC의 현재 모드 상태 (PLC Tag: `DockStatus` 매핑). |
# | `DockRequest` | Integer | 도킹(Docking Out) 요청 상태 값. |
#
# **4. 사용 사례 (Use Cases)**
# - **통합 관제 모니터링:** 대시보드에서 전체 공정의 설비 요청 상태와 AMR 응답 상태를 시각화할 때 주기적으로 호출.
# - **신호 디버깅:** 설비가 작업을 요청했으나 AMR이 배차되지 않는 경우, `MachineRequest` 값이 정상적으로 수신되고 있는지(비트 연산 오류 확인 등) 검증.
# - **도킹 프로세스 확인:** `DockRequest` 값을 통해 특정 장소에서 도킹 해제(Docking Out) 프로세스가 진행 중인지 확인.
#
# **5. 응답 예시 (Response Body Example)**
# ```json
# [
#   {
#     "Place": "P001",
#     "MachineRequest": 1,
#     "AMRResponse": 2,
#     "PLCMode": 1,
#     "DockRequest": 0
#   },
#   {
#     "Place": "P002",
#     "MachineRequest": 258,
#     "AMRResponse": 1,
#     "PLCMode": 2,
#     "DockRequest": 1
#   }
# ]
# ```
#
# **6. 구현 참고 사항 (Implementation Notes)**
# - **MachineRequest 연산 로직:**
#   이 필드는 단일 PLC 태그가 아니라, 하위/중위/상위 바이트 태그의 조합으로 구성된다.
#   - `MachineRequest` = `MachineRequest01` (Low) + `MachineRequest02` (Mid) × $2^8$ + `MachineRequest03` (High) × $2^{16}$
# - **PLC 태그 매핑 정보:**
#   백엔드는 아래의 PLC 태그를 읽어 응답을 구성한다.
#   - `{Place}.MachineRequest01` ~ `03`: 기계 요청 값 구성 요소
#   - `{Place}.AMRResponse` (또는 `01`): AMR 응답
#   - `{Place}.DockStatus`: `PLCMode` 필드에 매핑
#   - `{Place}.DockRequest`: `DockRequest` 필드에 매핑
# 2026-01-09 17:28:47.559 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## ObjectController. 시스템 객체(장소, 호출, 미션 등)를 관리하는 API입니다.
# ### 7. GET /api/Object/mcsalarms
#
# MCS 알람 정보를 조회합니다.
#
# **Endpoint:** `GET /api/Object/mcsalarms`
#
# **Response:**
# ```json
# [
#   {
#     "Id": "ALM_20250319_001",
#     "AlarmCode": "1001",
#     "Publisher": "MCS_SYSTEM",
#     "AlarmSource": "P001",
#     "AlarmData": "Communication timeout with PLC",
#     "AlarmRunState": 1,
#     "AlarmDt": "2025-03-19T10:25:30",
#     "ReleaseDt": null,
#     "Releaser": null
#   },
#   {
#     "Id": "ALM_20250319_002",
#     "AlarmCode": "2001",
#     "Publisher": "AMR_001",
#     "AlarmSource": "AMR_001",
#     "AlarmData": "Low battery warning",
#     "AlarmRunState": 1,
#     "AlarmDt": "2025-03-19T10:30:00",
#     "ReleaseDt": null,
#     "Releaser": null
#   }
# ]
# ```
#
# **인증:** 불필요
#
# **설명:**
# - MCS 시스템의 알람 정보를 반환합니다.
# - 비동기로 처리됩니다.
#
# ---
#
#
# 2026-01-09 17:29:10.288 | INFO     | __main__:<module>:9 - ## [API] MCS 알람 정보 조회 (Retrieve MCS Alarms)
#
# **1. 개요 (Definition)**
# `GET /api/Object/mcsalarms` API는 MCS(Material Control System) 내에서 발생한 모든 시스템 및 장비(AMR)의 알람 이력을 조회하는 모니터링 인터페이스다. 시스템의 건전성(Health Check)을 확인하거나, 공정 중단 원인을 파악하기 위한 로그 데이터를 비동기적으로 반환한다.
#
# **2. 기술 명세 (Technical Specification)**
# - **Endpoint:** `/api/Object/mcsalarms`
# - **Method:** `GET`
# - **Authentication:** 불필요 (Anonymous Access Allowed)
# - **Request Parameters:** 없음 (None)
# - **Response Structure (JSON Array):**
#   응답은 알람 객체의 배열로 반환되며, 각 객체는 다음 필드를 포함한다.
#
# | 필드명 (Field) | 타입 (Type) | 설명 (Description) |
# | :--- | :--- | :--- |
# | `Id` | String | 알람 고유 식별자 (예: ALM_YYYYMMDD_SEQ) |
# | `AlarmCode` | String | 알람 유형을 구분하는 표준 코드 |
# | `Publisher` | String | 알람을 발행한 주체 (예: MCS_SYSTEM, AMR_ID) |
# | `AlarmSource` | String | 알람이 발생한 물리적/논리적 위치 또는 장비명 |
# | `AlarmData` | String | 알람 상세 메시지 또는 에러 로그 |
# | `AlarmRunState` | Integer | 알람 활성화 상태 (1: 발생 중/Active, 0: 해제됨/Cleared) |
# | `AlarmDt` | DateTime | 알람 발생 시각 (ISO 8601 형식) |
# | `ReleaseDt` | DateTime | 알람 해제 시각 (Null일 경우 현재 활성 상태) |
# | `Releaser` | String | 알람을 해제한 주체 (사용자 ID 또는 시스템) |
#
# **3. 사용 사례 (Use Case)**
# - **실시간 관제 대시보드:** 운영자가 현재 공장 내에서 발생 중인 에러(예: PLC 통신 두절, 배터리 부족 등)를 실시간으로 시각화하여 모니터링할 때 사용한다.
# - **장애 원인 분석 (Root Cause Analysis):** 특정 AMR이 작업을 멈추거나 지연되었을 때, 해당 시점(`AlarmDt`)에 발생한 경고 메시지(`AlarmData`)를 조회하여 하드웨어 고장인지 통신 문제인지 진단한다.
# - **유지보수 이력 관리:** 주기적으로 알람 로그를 수집하여 장비별 고장 빈도를 분석하고 예방 정비 계획을 수립한다.
#
# **4. 응답 예시 (Response Body Example)**
# 요청 성공 시, 시스템에 기록된 알람 리스트를 반환한다.
#
# ```json
# [
#   {
#     "Id": "ALM_20250319_001",
#     "AlarmCode": "1001",
#     "Publisher": "MCS_SYSTEM",
#     "AlarmSource": "P001",
#     "AlarmData": "Communication timeout with PLC",
#     "AlarmRunState": 1,
#     "AlarmDt": "2025-03-19T10:25:30",
#     "ReleaseDt": null,
#     "Releaser": null
#   },
#   {
#     "Id": "ALM_20250319_002",
#     "AlarmCode": "2001",
#     "Publisher": "AMR_001",
#     "AlarmSource": "AMR_001",
#     "AlarmData": "Low battery warning",
#     "AlarmRunState": 1,
#     "AlarmDt": "2025-03-19T10:30:00",
#     "ReleaseDt": null,
#     "Releaser": null
#   }
# ]
# ```
# 2026-01-09 17:29:10.290 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## CommandController. AMR 명령 및 시스템 제어 명령을 처리하는 API입니다.
# ### 1. PUT /api/Command/Move
#
# AMR 이동 명령을 전송합니다.
#
# **Endpoint:** `PUT /api/Command/Move`
#
# **Request Body:**
# ```json
# {
#   "Target": "AMR_001",
#   "Command": "move",
#   "Node": {
#     "ObjNo": 1001,
#     "X": 1500,
#     "Y": 2000
#   }
# }
# ```
#
# **Response:**
# ```json
# {
#   "Success": true,
#   "Error": null
# }
# ```
#
# **인증:** JWT Token 필요
#
# **설명:**
# - AMR에게 이동 명령을 전송합니다.
# - 사용자 정보는 JWT Token에서 추출됩니다.
#
# ---
#
#
# 2026-01-09 17:29:33.043 | INFO     | __main__:<module>:9 - ## [API] AMR 이동 명령 (Move Command)
#
# **1. 개요 (Overview)**
# `PUT /api/Command/Move` API는 MCS(Material Control System)가 특정 AMR(Autonomous Mobile Robot)에게 물리적 이동을 지시하는 제어 인터페이스다. 지정된 로봇(`Target`)을 목표 노드(`Node`) 및 좌표(`X, Y`)로 주행하도록 명령하며, 자재 운송 프로세스의 시작점 또는 대기 위치 복귀 시 호출된다.
#
# **2. 요청 명세 (Request Specification)**
#
# *   **Endpoint:** `/api/Command/Move`
# *   **Method:** `PUT`
# *   **Content-Type:** `application/json`
# *   **Header:**
#     *   `Authorization`: `Bearer {JWT_Token}` (필수, 유효한 사용자 또는 시스템 토큰)
#
# *   **Body Parameters:**
#
# | Parameter | Type | Required | Description |
# | :--- | :--- | :---: | :--- |
# | **Target** | `String` | **Yes** | 제어 대상 AMR의 고유 식별자 (예: "AMR_001") |
# | **Command** | `String` | **Yes** | 수행할 명령의 종류. 이동 명령 시 `"move"` 고정 값 사용 |
# | **Node** | `Object` | **Yes** | 목표 위치 정보를 담은 객체 |
# | └ `ObjNo` | `Integer` | **Yes** | 맵 상의 노드(Node) 번호 또는 설비 포트 ID |
# | └ `X` | `Number` | **Yes** | 목표 지점의 X 좌표 (Global Map 기준) |
# | └ `Y` | `Number` | **Yes** | 목표 지점의 Y 좌표 (Global Map 기준) |
#
# **3. 사용 사례 (Use Case)**
#
# 이 API는 BMA(Battery Manufacturing/Assembly) 공정 내 물류 흐름에서 다음과 같은 상황에 필수적으로 사용된다.
#
# 1.  **자재 픽업 이동:** 창고 관리 시스템(WMS)으로부터 출고 요청이 발생했을 때, 대기 중인 AMR을 자재 적재 위치(Source Port)로 이동시키는 경우.
# 2.  **공정 간 이송:** 전공정(예: 코팅)에서 후공정(예: 프레스)으로 롤(Roll)이나 매거진을 이송하기 위해, 적재된 AMR을 목적지 설비 앞으로 주행시키는 경우.
# 3.  **대기 및 충전 복귀:** 작업이 없는 유휴 시간(Idle Time)에 트래픽 혼잡을 방지하기 위해 AMR을 지정된 대기 구역(Standby Node)으로 이동시키거나, 배터리 부족 시 충전 스테이션으로 이동시킬 때.
#
# **4. 요청 예시 (Request Body Example)**
#
# 다음은 `AMR_001` 로봇을 노드 번호 `1001`번(좌표 1500, 2000)으로 이동시키는 실제 요청 JSON이다.
#
# ```json
# {
#   "Target": "AMR_001",
#   "Command": "move",
#   "Node": {
#     "ObjNo": 1001,
#     "X": 1500,
#     "Y": 2000
#   }
# }
# ```
#
# **5. 응답 예시 (Response Example)**
#
# 명령이 시스템에 의해 성공적으로 수신되고 큐(Queue)에 등록되었을 때의 응답이다.
#
# ```json
# {
#   "Success": true,
#   "Error": null
# }
# ```
# 2026-01-09 17:29:33.044 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## CommandController. AMR 명령 및 시스템 제어 명령을 처리하는 API입니다.
# ### 2. PUT /api/Command/CallState
#
# 호출 상태를 변경합니다.
#
# **Endpoint:** `PUT /api/Command/CallState`
#
# **Request Body:**
# ```json
# {
#   "id": "REQ_001",
#   "call": "AA001_20250319_P001",
#   "state": "CANCELLED"
# }
# ```
#
# **Response:**
# ```json
# {
#   "Result": true,
#   "Message": "Call state changed successfully"
# }
# ```
#
# **인증:** JWT Token 필요
#
# **설명:**
# - 호출의 상태를 변경합니다.
# - 사용자 정보는 JWT Token에서 추출됩니다.
# - state 값: WAITING, ASSIGNED, COMPLETED, CANCELLED 등
#
# ---
#
#
# 2026-01-09 17:29:54.026 | INFO     | __main__:<module>:9 - ## [API] 호출 상태 변경 (Change Call State)
#
# **1. 개요 (Overview)**
# `PUT /api/Command/CallState` API는 MCS(Material Control System) 내에서 생성된 특정 자재 운송 요청(Call)의 생명주기 상태를 갱신하는 인터페이스다. 운영자가 수동으로 작업을 취소하거나, 시스템 로직에 의해 작업 상태를 강제로 동기화해야 할 때 사용된다.
#
# **2. 기술 명세 (Technical Specification)**
# - **Endpoint:** `/api/Command/CallState`
# - **Method:** `PUT`
# - **Content-Type:** `application/json`
# - **Header:** `Authorization: Bearer {Token}` (유효한 JWT 토큰 필수)
# - **Body Parameters:**
#
# | 파라미터 명 | 타입 (Type) | 필수 여부 | 설명 (Description) |
# | :--- | :--- | :--- | :--- |
# | `id` | String | **Required** | 해당 상태 변경 요청을 추적하기 위한 트랜잭션 ID (예: `REQ_001`) |
# | `call` | String | **Required** | 상태를 변경하고자 하는 대상 운송 요청(Call)의 고유 식별자 |
# | `state` | String | **Required** | 변경할 목표 상태 값 (Enum) <br> - `WAITING`: 대기 중 <br> - `ASSIGNED`: 할당됨 <br> - `COMPLETED`: 완료됨 <br> - `CANCELLED`: 취소됨 |
#
# **3. 사용 사례 (Use Case)**
# 이 API는 다음과 같은 BMA 공정 시나리오에서 활용된다:
# 1.  **작업 취소 (Cancellation):** 생산 계획 변경으로 인해 이미 생성된 자재 이송 요청(`WAITING` 상태)이 더 이상 필요 없을 때, 운영자가 해당 Call을 `CANCELLED`로 변경하여 AMR 할당을 방지한다.
# 2.  **상태 강제 동기화 (Force Sync):** AMR이 네트워크 음영 지역에서 작업을 완료했으나 서버로 완료 신호를 보내지 못한 경우, 관리자가 육안 확인 후 해당 Call의 상태를 `COMPLETED`로 강제 업데이트하여 다음 공정을 진행시킨다.
# 3.  **교착 상태 해결:** 특정 Call이 비정상적인 상태로 락(Lock)이 걸려있을 때, 이를 초기화하거나 종료 처리하기 위해 사용된다.
#
# **4. 요청 예시 (Request Body Example)**
# 다음은 ID가 `AA001_20250319_P001`인 운송 요청을 '취소(CANCELLED)' 상태로 변경하는 JSON 요청 예시이다.
#
# ```json
# {
#   "id": "TRX_20250319_9981",
#   "call": "AA001_20250319_P001",
#   "state": "CANCELLED"
# }
# ```
#
# **5. 응답 예시 (Response Example)**
# 요청이 성공적으로 처리되었을 경우의 응답이다.
#
# ```json
# {
#   "Result": true,
#   "Message": "Call state changed successfully"
# }
# ```
# 2026-01-09 17:29:54.028 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## CommandController. AMR 명령 및 시스템 제어 명령을 처리하는 API입니다.
# ### 3. PUT /api/Command/CommandState
#
# 명령 상태를 변경합니다.
#
# **Endpoint:** `PUT /api/Command/CommandState`
#
# **Request Body:**
# ```json
# {
#   "id": "REQ_002",
#   "mission": "CMD_20250319_001",
#   "state": "PAUSED"
# }
# ```
#
# **Response:**
# ```json
# {
#   "Result": true,
#   "Message": "Command state changed successfully"
# }
# ```
#
# **인증:** JWT Token 필요
#
# **설명:**
# - 명령의 상태를 변경합니다.
# - 사용자 정보는 JWT Token에서 추출됩니다.
# - state 값: READY, RUNNING, PAUSED, COMPLETED, FAILED 등
#
# ---
#
#
# 2026-01-09 17:30:13.787 | INFO     | __main__:<module>:9 - ## [API] 명령 상태 변경 (Change Command State)
#
# **1. 개요 (Overview)**
# `PUT /api/Command/CommandState` API는 MCS(Material Control System) 내에서 관리되는 특정 미션(Mission)의 실행 라이프사이클 상태를 강제로 변경하는 제어 인터페이스이다. 관리자 또는 상위 시스템이 AMR의 작업을 일시 정지(PAUSE), 재개(RUNNING), 또는 강제 종료(FAILED/COMPLETED) 처리해야 할 때 사용된다.
#
# **2. 요청 명세 (Request Specification)**
#
# *   **Endpoint:** `/api/Command/CommandState`
# *   **Method:** `PUT`
# *   **Content-Type:** `application/json`
# *   **Header:**
#     *   `Authorization: Bearer {Token}` (유효한 JWT Access Token 필수)
# *   **Body Parameters:**
#
# | 파라미터 명 | 타입 (Type) | 필수 여부 | 설명 (Description) |
# | :--- | :--- | :---: | :--- |
# | `id` | String | **Required** | 요청 추적을 위한 고유 트랜잭션 ID (예: REQ_002) |
# | `mission` | String | **Required** | 상태를 변경할 대상 미션(Command)의 고유 ID |
# | `state` | String | **Required** | 변경하고자 하는 목표 상태 값<br/>**(허용 값: `READY`, `RUNNING`, `PAUSED`, `COMPLETED`, `FAILED`)** |
#
# **3. 사용 사례 (Use Case)**
#
# 이 API는 BMA 공정 내에서 다음과 같은 예외 상황 처리 및 흐름 제어 시나리오에 필수적으로 사용된다.
#
# *   **긴급 일시 정지 (Pause):** AMR 이동 경로상에 예상치 못한 장애물이 감지되거나, 작업자가 유지보수를 위해 라인에 진입할 때 해당 로봇의 미션 상태를 `PAUSED`로 변경하여 대기시킨다.
# *   **작업 재개 (Resume):** 장애 요인이 제거된 후, `PAUSED` 상태인 미션을 다시 `RUNNING`으로 변경하여 공정을 계속 진행한다.
# *   **오류 처리 및 리소스 해제 (Force Fail):** 하드웨어 고장 등으로 미션 수행이 불가능한 경우, 상태를 `FAILED`로 강제 변경하여 시스템이 해당 로봇에 할당된 리소스를 해제하고 다음 작업을 스케줄링할 수 있도록 한다.
#
# **4. 요청 예시 (Request Body Example)**
#
# 다음은 특정 미션(`CMD_20250319_001`)을 일시 정지(`PAUSED`) 상태로 변경하는 요청의 예시이다.
#
# ```json
# {
#   "id": "REQ_TRACE_8821",
#   "mission": "CMD_20250319_001",
#   "state": "PAUSED"
# }
# ```
#
# **5. 응답 예시 (Response Example)**
#
# 요청이 성공적으로 처리되었을 경우의 응답이다.
#
# ```json
# {
#   "Result": true,
#   "Message": "Command state changed successfully"
# }
# ```
# 2026-01-09 17:30:13.789 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## CommandController. AMR 명령 및 시스템 제어 명령을 처리하는 API입니다.
# ### 4. PUT /api/Command/manualcall
#
# 수동 호출을 생성합니다.
#
# **Endpoint:** `PUT /api/Command/manualcall`
#
# **Request Body:**
# ```json
# {
#   "id": "MANUAL_REQ_001",
#   "code": "MC001",
#   "place": "P001",
#   "payloadType": "PALLET",
#   "quantity": "2",
#   "param": "0",
#   "repeatCount": 1,
#   "repeatDelay": 0
# }
# ```
#
# **Response:**
# ```json
# {
#   "Result": true,
#   "Message": "Manual call created successfully"
# }
# ```
#
# **인증:** JWT Token 필요
#
# **설명:**
# - 수동으로 호출을 생성합니다.
# - 사용자 정보는 JWT Token에서 추출됩니다.
# - repeatCount: 반복 횟수, repeatDelay: 반복 간 지연시간(초)
#
# ---
#
#
# 2026-01-09 17:30:35.806 | INFO     | __main__:<module>:9 - ## [API] 수동 호출 생성 (Create Manual Call)
#
# **1. 개요 (Overview)**
# `PUT /api/Command/manualcall` API는 MCS(Material Control System)의 자동 스케줄링 로직을 우회하여, 운영자나 관리자가 직접 특정 작업(이송, 이동 등)에 대한 AMR 호출 명령을 생성하는 인터페이스이다. 요청자의 신원은 헤더의 JWT Token을 통해 식별되며, 단일 수행뿐만 아니라 반복 수행(Loop Test) 설정도 지원한다.
#
# **2. 기술 명세 (Technical Specification)**
#
# *   **Endpoint:** `/api/Command/manualcall`
# *   **Method:** `PUT`
# *   **Content-Type:** `application/json`
# *   **Header:**
#     *   `Authorization`: `Bearer {Access_Token}` (필수, 유효한 JWT 토큰)
#
# *   **Body Parameters:**
#
# | 파라미터 명 | 데이터 타입 | 필수 여부 | 설명 |
# | :--- | :--- | :--- | :--- |
# | `id` | String | **Required** | 요청을 식별하는 고유 ID (예: `MANUAL_REQ_{Timestamp}`) |
# | `code` | String | **Required** | 수행할 명령 코드 (예: 작업 유형 식별자) |
# | `place` | String | **Required** | 작업이 수행될 목표 위치(Node ID 또는 Station ID) |
# | `payloadType` | String | **Required** | 이송 대상 자재의 유형 (예: `PALLET`, `FOUP`, `TRAY`) |
# | `quantity` | String | Optional | 자재의 수량 (문자열 형식의 숫자) |
# | `param` | String | Optional | 명령 수행에 필요한 추가 파라미터 (기본값: `"0"`) |
# | `repeatCount` | Integer | Optional | 명령 반복 횟수 (기본값: `1`) |
# | `repeatDelay` | Integer | Optional | 반복 수행 시 명령 간 대기 시간 (단위: 초, 기본값: `0`) |
#
# **3. 사용 사례 (Use Case)**
# 이 API는 다음과 같은 BMA 공정 시나리오에서 주로 사용된다:
# *   **긴급 자재 이송:** 상위 시스템(MES/WMS)의 자동 지시 없이, 현장 작업자가 HMI를 통해 긴급하게 자재를 특정 설비로 투입해야 하는 경우.
# *   **설비 시운전 및 테스트:** 특정 Station으로의 AMR 진입/진출 정밀도를 테스트하기 위해, 동일한 이동 명령을 `repeatCount`를 설정하여 10회 이상 연속 반복 수행시키는 경우.
# *   **예외 상황 처리:** 공정 에러로 인해 자동 배차가 실패했을 때, 관제실에서 수동으로 로봇을 호출하여 자재를 회수하거나 재배치하는 경우.
#
# **4. 요청 예시 (Request Body Example)**
# 다음은 `STATION_P001` 위치로 `PALLET` 유형의 자재 이송을 1회 요청하는 JSON 예시이다.
#
# ```json
# {
#   "id": "MANUAL_REQ_20231027_05",
#   "code": "CMD_MOVE_LOAD",
#   "place": "STATION_P001",
#   "payloadType": "PALLET",
#   "quantity": "1",
#   "param": "0",
#   "repeatCount": 1,
#   "repeatDelay": 0
# }
# ```
#
# **5. 응답 예시 (Response Example)**
# 요청이 성공적으로 MCS 큐(Queue)에 등록되었을 때의 응답이다.
#
# ```json
# {
#   "Result": true,
#   "Message": "Manual call created successfully"
# }
# ```
# 2026-01-09 17:30:35.806 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## CommandController. AMR 명령 및 시스템 제어 명령을 처리하는 API입니다.
# ### 5. PUT /api/Command/manualcommand
#
# 수동 명령을 생성합니다.
#
# **Endpoint:** `PUT /api/Command/manualcommand`
#
# **Request Body:**
# ```json
# {
#   "id": "MANUAL_CMD_001",
#   "subject": "MOVE",
#   "start": "P001",
#   "dest": "P002",
#   "robot": "AMR_001",
#   "code": "MANUAL_MOVE_001"
# }
# ```
#
# **Response:**
# ```json
# {
#   "Result": true,
#   "Message": "Manual command created successfully"
# }
# ```
#
# **인증:** JWT Token 필요
#
# **설명:**
# - 수동으로 명령을 생성합니다.
# - 사용자 정보는 JWT Token에서 추출됩니다.
# - subject: 명령 종류 (MOVE, CHARGE, DOCK 등)
#
# ---
#
#
# 2026-01-09 17:30:58.318 | INFO     | __main__:<module>:9 - ## [API] 수동 명령 생성 (Create Manual Command)
#
# **1. 개요 (Overview)**
# `PUT /api/Command/manualcommand` API는 MCS(Material Control System)의 자동 스케줄링 로직을 우회하여, 운영자가 특정 AMR(Autonomous Mobile Robot)에게 직접적인 작업을 지시할 때 사용된다. 이 API는 로봇의 이동(MOVE), 충전(CHARGE), 도킹(DOCK) 등의 단일 작업을 즉시 할당하며, 생성된 명령의 추적을 위해 고유 ID와 작업 코드를 포함한다.
#
# **2. 기술 명세 (Technical Specification)**
#
# *   **Endpoint:** `/api/Command/manualcommand`
# *   **Method:** `PUT`
# *   **Content-Type:** `application/json`
# *   **Authentication:**
#     *   **Header:** `Authorization: Bearer {Access_Token}`
#     *   *Note:* 명령을 생성한 사용자(Operator)의 신원은 JWT Token에서 자동으로 추출되어 로깅된다.
#
# *   **Body Parameters:**
#
# | Parameter | Type | Required | Description |
# | :--- | :--- | :--- | :--- |
# | `id` | String | **Yes** | 명령을 식별하기 위한 고유 ID (예: UUID 또는 시스템 생성 시퀀스) |
# | `subject` | String | **Yes** | 명령의 유형 (Enum: `MOVE`, `CHARGE`, `DOCK`, `LIFT_UP`, `LIFT_DOWN` 등) |
# | `start` | String | **Yes** | 작업 시작 노드 또는 현재 위치 ID |
# | `dest` | String | **Yes** | 작업의 목적지 노드 ID |
# | `robot` | String | **Yes** | 명령을 수행할 대상 AMR의 하드웨어 ID |
# | `code` | String | **Yes** | 작업 관리 코드 또는 시나리오 코드 (예: 수동 작업 분류용 코드) |
#
# **3. 사용 사례 (Use Cases)**
#
# *   **시나리오 1: 설비 유지보수를 위한 강제 이동**
#     *   특정 AMR(`AMR_005`)에 하드웨어 점검이 필요하여, 자동 운송 작업을 중단시키고 정비 구역(`MAINTENANCE_ZONE_01`)으로 즉시 이동시켜야 하는 경우.
# *   **시나리오 2: 배터리 부족 긴급 대응**
#     *   시스템 자동 충전 임계값에 도달하지 않았으나, 장시간 대기가 예상되어 운영자가 수동으로 충전 스테이션(`CHG_STATION_02`)으로 이동(`CHARGE`) 명령을 내리는 경우.
# *   **시나리오 3: 교착 상태(Deadlock) 해소**
#     *   좁은 통로에서 다수의 로봇이 대치 중일 때, 특정 로봇을 임의의 대피 노드(`WAIT_NODE_10`)로 이동시켜 경로를 확보하는 경우.
#
# **4. 요청 예시 (Request Body Example)**
#
# 다음은 `AMR_001` 로봇에게 `P001`에서 `P002`로 이동하라는 수동 명령을 내리는 JSON 예시이다.
#
# ```json
# {
#   "id": "MANUAL_CMD_20231027_001",
#   "subject": "MOVE",
#   "start": "P001",
#   "dest": "P002",
#   "robot": "AMR_001",
#   "code": "MANUAL_OP_URGENT"
# }
# ```
#
# **5. 응답 예시 (Response Example)**
#
# 요청이 성공적으로 MCS 큐에 등록되었을 때의 응답이다.
#
# ```json
# {
#   "Result": true,
#   "Message": "Manual command created successfully"
# }
# ```
# 2026-01-09 17:30:58.319 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## CommandController. AMR 명령 및 시스템 제어 명령을 처리하는 API입니다.
# ### 6. PUT /api/Command/retrycommand
#
# 명령을 재시도합니다.
#
# **Endpoint:** `PUT /api/Command/retrycommand`
#
# **Request Body:**
# ```json
# {
#   "id": "RETRY_REQ_001",
#   "mission": "CMD_20250319_001",
#   "robot": "AMR_002"
# }
# ```
#
# **Response:**
# ```json
# {
#   "Result": true,
#   "Message": "Command retry initiated successfully"
# }
# ```
#
# **인증:** JWT Token 필요
#
# **설명:**
# - 실패한 명령을 재시도합니다.
# - 사용자 정보는 JWT Token에서 추출됩니다.
# - robot 파라미터로 다른 로봇에 재할당 가능
#
# ---
#
#
# 2026-01-09 17:31:20.176 | INFO     | __main__:<module>:9 - ## [API] 명령 재시도 (Retry Command)
#
# **1. 개요 (Overview)**
# `PUT /api/Command/retrycommand` API는 MCS(Material Control System) 내에서 실패했거나 중단된 AMR 제어 명령(Mission)을 다시 실행하기 위한 인터페이스이다. 단순한 재실행뿐만 아니라, **대상 로봇을 변경하여 작업을 재할당(Reassignment)** 할 수 있는 기능을 포함하고 있어, 특정 로봇의 하드웨어 고장 시 대체 로봇을 투입하는 공정 복구(Recovery) 시나리오의 핵심 API로 정의된다.
#
# **2. 요청 명세 (Request Specification)**
#
# *   **Endpoint:** `/api/Command/retrycommand`
# *   **Method:** `PUT`
# *   **Content-Type:** `application/json`
# *   **Header:**
#     *   `Authorization`: `Bearer {JWT_TOKEN}` (필수, 유효한 사용자/시스템 토큰)
#
# *   **Body Parameters:**
#
# | 파라미터 명 | 타입 (Type) | 필수 여부 | 설명 (Description) |
# | :--- | :--- | :--- | :--- |
# | `id` | String | **Required** | 요청 추적을 위한 고유 트랜잭션 ID (Request ID). |
# | `mission` | String | **Required** | 재시도할 대상이 되는 원본 명령(Mission)의 고유 ID. |
# | `robot` | String | **Required** | 명령을 수행할 대상 로봇(AMR)의 ID. <br>*(참고: 원본 명령을 수행하던 로봇과 다른 ID를 입력할 경우, 해당 로봇으로 작업이 이관됨)* |
#
# **3. 사용 사례 (Use Case)**
#
# 이 API는 BMA 공정 중 다음과 같은 예외 상황 처리에 주로 사용된다.
#
# *   **시나리오 1: 하드웨어 고장 시 대체 로봇 투입 (Failover)**
#     *   상황: `AMR_001`이 자재 운송 중 리프트 고장으로 에러 상태가 됨.
#     *   조치: 관제 시스템이 이를 감지하고, 대기 중인 `AMR_002`를 지정하여 `mission`을 재할당. 이를 통해 전체 공정 라인의 정지(Downtime)를 방지함.
# *   **시나리오 2: 일시적 통신 오류 복구**
#     *   상황: 특정 구역(음영 지역)에서 명령 수신 타임아웃이 발생하여 작업이 실패 처리됨.
#     *   조치: 동일한 `robot` ID로 재시도 명령을 전송하여 작업을 재개시킴.
#
# **4. 요청 예시 (Request Body Example)**
#
# 다음은 `CMD_20250319_001` 미션을 `AMR_002` 로봇에게 재할당하여 실행하는 JSON 요청 예시이다.
#
# ```json
# {
#   "id": "RETRY_REQ_20250319_05",
#   "mission": "CMD_20250319_001",
#   "robot": "AMR_002"
# }
# ```
#
# **5. 응답 예시 (Response Example)**
#
# 요청이 성공적으로 MCS 큐에 등록되었을 때의 응답이다.
#
# ```json
# {
#   "Result": true,
#   "Message": "Command retry initiated successfully"
# }
# ```
# 2026-01-09 17:31:20.179 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## 공통 정보
# ### 인증
# - JWT(JSON Web Token) 기반 인증을 사용합니다.
# - 인증이 필요한 API는 요청 헤더에 JWT Token을 포함해야 합니다.
# - Token에서 사용자 정보(UserId)를 추출하여 사용합니다.
#
#
# 2026-01-09 17:31:43.067 | INFO     | __main__:<module>:9 - 제공해주신 입력 데이터는 **MCS.Backend API의 공통 아키텍처 및 인증(Authentication)**에 관한 내용입니다. 이에 따라 시스템 전반에 적용되는 **공통 기술 명세서(General Technical Specification)**를 작성하였습니다.
#
# 이 문서는 이후 정의될 모든 개별 API Endpoint가 준수해야 할 기본 프로토콜을 정의합니다.
#
# ---
#
# # MCS.Backend API 기술 명세서: 공통 아키텍처 및 인증
#
# ## [System] MCS Backend API 개요 및 인증 표준
#
# **1. 개요 (Overview)**
# MCS(Material Control System) Backend API는 공장 내 자재 흐름을 관리하고 **AMR(Autonomous Mobile Robot)** 시스템을 실시간으로 제어 및 모니터링하기 위한 RESTful 인터페이스 집합이다. 본 시스템은 무상태(Stateless) 아키텍처를 지향하며, 모든 트랜잭션은 **JWT(JSON Web Token)** 기반의 보안 프로토콜을 통해 인가된 사용자(또는 시스템 에이전트)에 의해서만 수행된다.
#
# **2. 기술 상세 (Technical Details)**
# 모든 API 요청은 아래의 공통 규격을 준수해야 한다.
#
# *   **Protocol:** HTTP/1.1 (RESTful)
# *   **Data Format:** JSON (application/json)
# *   **Authentication Mechanism:**
#     *   **Type:** JWT (JSON Web Token)
#     *   **Header Key:** `Authorization`
#     *   **Header Value Format:** `Bearer {Access_Token}`
#     *   **Identity Extraction:** 서버는 수신된 Token의 Payload를 디코딩하여 `UserId`를 추출하고, 이를 통해 요청 주체의 권한을 검증한다.
#
# **3. 사용 사례 (Use Case)**
# 이 인증 표준은 로그인(Token 발급)을 제외한 **모든 보호된 리소스(Protected Resources) 접근 시** 필수적으로 적용된다.
# *   **시나리오 예시:**
#     1.  **작업자 개입:** 운영자가 HMI를 통해 특정 AMR의 에러를 리셋하려 할 때, 프론트엔드 클라이언트는 로그인 시 발급받은 JWT를 헤더에 실어 요청을 보낸다.
#     2.  **시스템 연동:** 상위 시스템(MES/WMS)이 자재 운송 명령을 내릴 때, 사전에 발급된 시스템 계정용 토큰을 사용하여 API를 호출한다.
#
# **4. 요청 예시 (Standard Request Format)**
# 모든 API 호출 시 아래와 같이 HTTP Header에 인증 정보를 포함해야 한다.
#
# ```http
# POST /api/{endpoint} HTTP/1.1
# Host: mcs-backend.local
# Content-Type: application/json
# Authorization: Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJBRE1JTl8wMSIsImV4cCI6MTcxNDQ...
# ```
#
# **5. 클라이언트 구현 가이드 (Client Implementation Guide)**
# 클라이언트(Web, Mobile, Agent)는 API 호출 시 다음의 JSON 구조를 참조하여 헤더를 구성해야 한다. (Body는 개별 API 명세에 따름)
#
# ```json
# // Axios 또는 Fetch API 사용 시 Header 설정 예시
# {
#   "headers": {
#     "Authorization": "Bearer <YOUR_JWT_TOKEN>",
#     "Content-Type": "application/json"
#   },
#   "method": "POST", // or GET, PUT, DELETE
#   "body": {
#     // 개별 API별 Payload가 이곳에 위치함
#   }
# }
# ```
#
# ---
#
# **[요청]**
# 현재 제공해주신 정보는 **공통 헤더 및 인증 정보**입니다.
# 상세한 API 명세서 작성을 위해, **개별 API Endpoint 정보(예: 작업 생성, 로봇 상태 조회, 이동 명령 등)**를 입력해주시면 위 양식에 맞춰 상세 문서를 작성해 드리겠습니다.
# 2026-01-09 17:31:43.069 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## 공통 정보
# ### 응답 형식
# - 모든 응답은 JSON 형식입니다.
# - Content-Type: `application/json`
# - Encoding: `UTF-8`
# - Formatting: `Indented` (가독성을 위한 들여쓰기)
#
#
# 2026-01-09 17:32:06.526 | INFO     | __main__:<module>:9 - 제공해주신 [입력] 데이터는 MCS(Material Control System)의 **공통 설정 및 아키텍처 원칙**에 해당합니다. 이에 따라 시스템 전반에 적용되는 **API 공통 기술 명세서(General API Conventions)**를 작성하였습니다.
#
# ---
#
# # MCS.Backend API 기술 명세서 (Technical Specification)
#
# ## [Section 0] 공통 아키텍처 및 데이터 규약 (General Conventions)
#
# **1. 개요 (Overview)**
# MCS.Backend API는 공장 내 물류 제어 시스템(MCS)과 자율 주행 로봇(AMR) 간의 통신을 중개하는 RESTful 인터페이스이다. 본 문서는 시스템 내 모든 Endpoint가 준수해야 할 데이터 교환 형식, 인코딩 표준 및 응답 구조에 대한 공통 규약을 정의한다.
#
# **2. 기술 상세 (Technical Details)**
# 모든 API 요청 및 응답은 아래의 기술 표준을 엄격히 준수해야 한다.
#
# - **Architecture Style:** RESTful API
# - **Communication Protocol:** HTTP/1.1 or HTTP/2
# - **Data Serialization:** JSON (JavaScript Object Notation)
# - **Header Configuration:**
#   - `Content-Type`: `application/json` (필수)
#   - `Accept`: `application/json` (권장)
# - **Character Encoding:** `UTF-8`
#   - 다국어 처리 및 특수 문자(좌표계 기호 등)의 깨짐 방지를 위해 UTF-8 인코딩을 강제한다.
# - **Formatting:** `Indented` (Pretty-print)
#   - 디버깅 및 로그 가독성을 위해 응답 본문(Body)은 들여쓰기(Indentation)가 적용된 형태로 반환된다.
#
# **3. 사용 사례 (Use Case)**
# 이 공통 규약은 다음과 같은 모든 BMA 공정 시나리오에 적용된다.
# - **AMR 제어:** 로봇 이동, 정지, 리셋 명령 시 Payload 전송.
# - **모니터링:** 실시간 로봇 위치, 배터리 상태, 에러 로그 조회.
# - **시스템 통합:** 상위 시스템(MES/WMS)과의 데이터 동기화.
#
# 개발자 및 클라이언트 에이전트는 모든 HTTP 요청 시 `Content-Type: application/json` 헤더를 포함해야 하며, 응답 파싱 시 JSON 포맷을 기대해야 한다.
#
# **4. 공통 응답 예시 (Generic Response Example)**
# 모든 API 응답은 아래와 같이 `UTF-8`로 인코딩되고 `Indented` 된 JSON 형식을 따른다. (아래는 표준적인 성공 응답의 구조 예시이다.)
#
# ```json
# {
#   "meta": {
#     "code": 200,
#     "message": "OK",
#     "timestamp": "2023-10-27T10:00:00Z"
#   },
#   "data": {
#     "systemStatus": "Running",
#     "activeRobots": 5,
#     "description": "모든 응답은 이와 같이 들여쓰기(Indentation)가 적용되어 반환됩니다."
#   }
# }
# ```
#
# ---
# **[참고]** 현재 입력된 데이터는 **공통 정보**뿐입니다. 특정 기능(예: 로봇 이동, 상태 조회 등)에 대한 API 명세가 필요하다면, 해당 Endpoint 정보를 추가로 입력해 주십시오.
# 2026-01-09 17:32:06.528 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## 공통 정보
# ### HTTP 상태 코드
# - `200 OK`: 요청이 성공적으로 처리됨
# - 기타 상태 코드는 인증 실패 등의 경우 반환될 수 있음
#
#
# 2026-01-09 17:32:35.698 | INFO     | __main__:<module>:9 - 제공해주신 입력 데이터는 **MCS Backend API의 개요 및 공통 정보**에 해당합니다. 현재 구체적인 API Endpoint(예: 작업 지시, 상태 조회 등)에 대한 정보는 포함되어 있지 않으므로, **[공통 기술 명세서]**를 우선 작성해 드립니다.
#
# 추후 구체적인 API 정보(URI, Method, Parameter)를 입력해 주시면, 각 API별 상세 명세를 작성할 수 있습니다.
#
# ---
#
# # MCS (Material Control System) Backend API 기술 명세서
#
# ## 1. 시스템 개요 (System Overview)
# **MCS Backend API**는 물류 제어 시스템(MCS)의 핵심 인터페이스로, 현장에 배치된 **AMR(Autonomous Mobile Robot)** 군집을 중앙에서 제어하고 실시간으로 모니터링하기 위해 설계되었다. 본 API는 **RESTful 아키텍처**를 기반으로 하며, 상위 시스템(WMS/MES) 또는 운영 클라이언트가 로봇에게 작업을 할당하거나 상태를 추적하는 표준 통신 채널을 제공한다.
#
# ## 2. 인터페이스 공통 규약 (Common Interface Standards)
#
# ### 2.1 아키텍처 스타일 (Architecture Style)
# - **Protocol:** HTTP/1.1 over TCP/IP
# - **Architecture:** RESTful API
# - **Data Format:** JSON (JavaScript Object Notation) - 요청 및 응답 본문
#
# ### 2.2 HTTP 상태 코드 (HTTP Status Codes)
# 본 시스템은 표준 HTTP 상태 코드를 사용하여 요청의 처리 결과를 반환한다. 클라이언트는 응답의 `Status Code`를 통해 성공 여부를 1차적으로 판단해야 한다.
#
# | Status Code | Description | 의미 및 처리 가이드 |
# |:---:|:---:|:---|
# | **200** | **OK** | **요청 성공.** 서버가 요청을 정상적으로 수신하고 처리를 완료했음을 의미한다. (GET, PUT, POST 등) |
# | **401** | **Unauthorized** | **인증 실패.** 유효하지 않은 토큰이거나 인증 헤더가 누락됨. 재로그인 또는 토큰 갱신 필요. |
# | **403** | **Forbidden** | **권한 없음.** 인증은 되었으나 해당 리소스에 접근할 권한이 없음. |
# | **400** | **Bad Request** | **잘못된 요청.** 필수 파라미터 누락 또는 데이터 형식 오류. |
# | **500** | **Internal Server Error** | **서버 내부 오류.** 서버 측 로직 에러 발생. 관리자 문의 필요. |
#
# ---
#
# ## [요청] 추가 데이터 필요
# **수석 소프트웨어 아키텍트의 제언:**
# 현재 제공된 데이터는 API의 '서문'에 해당합니다. 개발자와 에이전트가 실제로 사용할 수 있는 문서를 완성하기 위해, 아래와 같은 **구체적인 API Endpoint 정보**를 추가로 입력해 주십시오.
#
# **추가 입력이 필요한 정보 예시:**
# - `POST /api/mission/assign` (작업 할당)
# - `GET /api/robot/status` (로봇 상태 조회)
# - `PUT /api/control/pause` (일시 정지)
#
# **데이터를 추가로 제공해 주시면, 즉시 상세 명세서(Endpoint, Body Syntax, JSON Example 포함)를 작성해 드리겠습니다.**
# 2026-01-09 17:32:35.698 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## 공통 정보
# ### 비동기 처리
# - `ObjectController`의 대부분의 GET 메서드는 비동기(`async/await`)로 처리됩니다.
# - 대용량 데이터 조회 시에도 서버 성능에 영향을 최소화합니다.
#
#
# 2026-01-09 17:33:07.481 | INFO     | __main__:<module>:9 - 제공해주신 [입력] 데이터는 MCS Backend의 **공통 아키텍처 원칙**과 **ObjectController의 동작 방식**에 대한 기술적 요약입니다. 이를 바탕으로 개발자가 준수해야 할 **공통 기술 명세서(Common Technical Specification)**와 해당 원칙이 적용된 **대표 API 명세**를 작성하였습니다.
#
# ---
#
# # [System] MCS Backend 공통 기술 명세서
#
# ## 1. 시스템 개요 (System Overview)
# MCS(Material Control System) Backend는 공장 내 자재 흐름을 제어하고 AMR(Autonomous Mobile Robot) 시스템을 통합 관리하기 위한 RESTful API 서버이다. 본 문서는 `ObjectController`를 포함한 주요 모듈의 비동기 처리 표준과 데이터 조회 원칙을 정의한다.
#
# ## 2. 아키텍처 표준: 비동기 데이터 처리 (Async Data Processing)
#
# **2.1. 정의 (Definition)**
# `ObjectController` 및 데이터 조회와 관련된 모든 GET 메서드는 **비동기(Asynchronous, `async/await`)** 패턴을 기반으로 구현된다. 이는 I/O 바운드 작업 시 스레드 차단을 방지하고 서버의 처리량(Throughput)을 극대화하기 위함이다.
#
# **2.2. 기술적 상세 (Technical Details)**
# - **적용 범위:** `ObjectController` 내의 모든 조회용 Endpoint (List, Detail, Status Check 등).
# - **구현 원칙:**
#   - 데이터베이스 쿼리 및 외부 시스템 통신 시 반드시 `await` 키워드를 사용하여 비동기 호출한다.
#   - 대용량 데이터(Bulk Data) 조회 시 페이징(Paging) 또는 스트리밍 처리를 권장하나, 기본적으로 비동기 처리를 통해 응답 지연(Latency)이 전체 시스템의 병목이 되지 않도록 설계한다.
# - **HTTP Status Code:**
#   - `200 OK`: 요청 성공 및 데이터 반환.
#   - `202 Accepted`: (배치 작업 등) 요청은 접수되었으나 처리가 완료되지 않음 (필요 시).
#
# **2.3. 사용 사례 (Use Case)**
# - **대규모 AMR 모니터링:** 수백 대 이상의 AMR 로봇 상태(배터리, 위치, 에러 코드)를 관제 시스템(Dashboard)에서 1초 단위로 폴링(Polling)할 때, 서버 스레드 고갈(Thread Starvation) 없이 안정적인 응답을 제공한다.
# - **히스토리 분석:** 과거 1개월 치의 주행 로그나 에러 이력을 조회할 때, 다른 실시간 제어 명령(Command) 처리에 영향을 주지 않고 데이터를 반환한다.
#
# ---
#
# ## 3. [API] 객체 목록 비동기 조회 (Get Objects Async)
#
# *주: 입력된 공통 정보를 바탕으로 `ObjectController`의 표준 조회 API를 구체화한 명세입니다.*
#
# **1. 개요**
# `GET /api/objects` API는 시스템에 등록된 모든 관리 객체(AMR, Port, Charger 등)의 최신 상태 정보를 비동기적으로 조회한다. 대용량 데이터 처리에 최적화되어 있다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/objects`
# - **Method:** `GET`
# - **Header:**
#   - `Content-Type: application/json`
#   - `Authorization: Bearer {Token}`
# - **Query Parameters (Optional):**
#   - `type` (String): 객체 유형 필터 (예: `AMR`, `CHARGER`).
#   - `status` (String): 상태 필터 (예: `IDLE`, `BUSY`, `ERROR`).
# - **Body:** None (GET 요청은 Body를 포함하지 않음)
#
# **3. 응답 예시 (Response Example)**
# *비동기 처리를 통해 반환되는 표준 JSON 응답 구조이다.*
#
# ```json
# {
#   "meta": {
#     "timestamp": "2023-10-27T10:00:00Z",
#     "totalCount": 2,
#     "processingType": "Async"
#   },
#   "data": [
#     {
#       "id": "AMR_001",
#       "type": "AMR",
#       "status": "RUNNING",
#       "position": {
#         "x": 150.5,
#         "y": 200.0,
#         "theta": 90.0
#       },
#       "batteryLevel": 85,
#       "currentTask": "TASK_1023"
#     },
#     {
#       "id": "AMR_002",
#       "type": "AMR",
#       "status": "IDLE",
#       "position": {
#         "x": 10.0,
#         "y": 50.0,
#         "theta": 0.0
#       },
#       "batteryLevel": 40,
#       "currentTask": null
#     }
#   ]
# }
# ```
# 2026-01-09 17:33:07.483 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## 공통 정보
# ### 캐싱
# - `callplaces` API는 1.5초 캐싱을 적용하여 PLC 조회 부하를 줄입니다.
#
#
#
# 2026-01-09 17:33:39.786 | INFO     | __main__:<module>:9 - 제공해주신 [API Raw Data]는 MCS Backend API의 **공통 정책(General Policy)** 및 **특정 엔드포인트(`callplaces`)의 성능 제약 사항**을 담고 있습니다. 이를 바탕으로 시스템 아키텍처 관점의 기술 명세서를 작성합니다.
#
# ---
#
# # MCS (Material Control System) Backend API 기술 명세서
#
# ## 1. 시스템 개요 (System Overview)
# MCS Backend API는 **AMR(Autonomous Mobile Robot)** 시스템의 통합 제어 및 실시간 모니터링을 수행하기 위한 RESTful 인터페이스 집합이다. 본 시스템은 상위 시스템(MES/WMS)과 하위 제어 설비(PLC) 간의 미들웨어 역할을 수행하며, 자재 흐름(Material Flow)을 최적화하는 것을 목적으로 한다.
#
# ## 2. 아키텍처 정책: 데이터 캐싱 (Architecture Policy: Caching)
#
# **1. 정의 (Definition)**
# PLC(Programmable Logic Controller)와 같은 하위 하드웨어 제어기와의 통신 부하를 최소화하기 위해, 빈번한 조회가 발생하는 특정 API에 대해 **서버 측 캐싱(Server-side Caching)** 전략을 적용한다.
#
# **2. 기술적 상세 (Technical Details)**
# - **적용 대상:** `callplaces` (호출 위치 조회) API 및 고빈도 조회 엔드포인트.
# - **캐시 수명(TTL):** **1.5초 (1500ms)**
# - **동작 원리:**
#   1. 클라이언트가 API를 호출하면 서버는 메모리 캐시를 확인한다.
#   2. 마지막 PLC 조회 시점으로부터 1.5초가 경과하지 않았다면, PLC를 다시 조회하지 않고 **캐시된 이전 데이터**를 즉시 반환한다.
#   3. 1.5초가 경과했다면, PLC로부터 최신 데이터를 조회(Read)하여 캐시를 갱신한 후 반환한다.
#
# **3. 사용 사례 (Use Case)**
# - **시나리오:** 다수의 AMR 에이전트나 모니터링 대시보드가 `callplaces` API를 0.5초 단위로 폴링(Polling)하는 상황.
# - **효과:** 실제 PLC에 가해지는 조회 요청 횟수를 제한하여, 하드웨어 통신 과부하로 인한 타임아웃이나 제어 지연(Latency)을 방지한다.
#
# ---
#
# ## [API] 호출 위치 조회 (Get Call Places)
#
# **1. 개요**
# `GET /api/callplaces` API는 현재 자재 운송 요청(Call)이 발생한 위치(Place)들의 목록과 상태 정보를 조회한다. 이 API는 상기 기술된 **1.5초 캐싱 정책**이 적용되어 있어, 연속 호출 시 데이터 갱신에 미세한 지연이 있을 수 있음을 고려해야 한다.
#
# **2. 요청 명세 (Request Specification)**
# - **Endpoint:** `/api/callplaces`
# - **Method:** `GET`
# - **Header:**
#   - `Content-Type`: `application/json`
#   - `Authorization`: `Bearer {Token}` (권장)
# - **Query Parameters (Optional):**
#   - `zone_id` (String): 특정 구역(Zone) 내의 호출 위치만 필터링할 경우 사용.
#
# **3. 응답 명세 (Response Specification)**
# 응답은 호출 위치 객체의 배열을 반환하며, 각 객체는 PLC로부터 수집된 최신(또는 캐시된) 상태 값을 포함한다.
#
# **4. 요청 및 응답 예시 (Example)**
#
# **Request (GET)**
# ```http
# GET /api/callplaces?zone_id=Z_A01 HTTP/1.1
# Host: mcs-backend.local
# Authorization: Bearer eyJhbGciOiJIUzI1Ni...
# ```
#
# **Response (JSON)**
# ```json
# {
#   "meta": {
#     "timestamp": "2023-10-27T14:30:01.500Z",
#     "cached": true,
#     "cache_age_ms": 450
#   },
#   "data": [
#     {
#       "place_id": "LOC_101",
#       "status": "ACTIVE",
#       "request_type": "PICKUP",
#       "priority": 1,
#       "plc_signal_address": "D1000"
#     },
#     {
#       "place_id": "LOC_105",
#       "status": "IDLE",
#       "request_type": "NONE",
#       "priority": 0,
#       "plc_signal_address": "D1005"
#     }
#   ]
# }
# ```
# *(주: `meta.cached` 필드를 통해 현재 응답이 캐시된 데이터인지 여부를 확인할 수 있도록 구현하는 것을 권장함)*
# 2026-01-09 17:33:39.787 | INFO     | __main__:<module>:6 - [입력]
# # MCS.Backend API 문서. MCS(Material Control System) Backend API 문서입니다. 이 API는 AMR(Autonomous Mobile Robot) 시스템을 제어하고 모니터링하기 위한 RESTful API를 제공합니다.
# ## 참고사항
# - 일부 조회 API(places, Call, Mission)는 인증 로직이 구현되어 있지 않아 인증 없이 접근 가능합니다.
# - 마지막 업데이트: 2025-03-19
# - DockRequest 필드 추가 (Docking Out 상태 표시용)
#
# 2026-01-09 17:34:15.265 | INFO     | __main__:<module>:9 - 제공된 입력 데이터는 **MCS.Backend API 문서의 개요(Header) 및 변경 이력**에 해당합니다.
# 따라서 아래 문서는 입력된 개요 정보를 바탕으로 작성된 **시스템 명세서 서문(Introduction)**과, 언급된 주요 키워드(`places`, `Call`, `Mission`, `DockRequest`)를 기반으로 재구성한 **상세 명세(Detailed Specification)**입니다.
#
# ---
#
# # MCS.Backend API 기술 명세서 (Technical Specification)
#
# **문서 버전:** 2025-03-19 Update
# **대상 시스템:** MCS (Material Control System) Backend
# **담당자:** 수석 소프트웨어 아키텍트
#
# ---
#
# ## 1. 시스템 개요 (System Overview)
# 본 API는 BMA(Battery Manufacturing Automation) 공정 내 **AMR(Autonomous Mobile Robot)** 시스템을 제어하고 모니터링하기 위한 RESTful 인터페이스를 제공한다. 외부 시스템(MES, WMS) 및 운영 클라이언트는 이 API를 통해 로봇의 위치 파악, 작업 할당(Mission), 호출(Call) 등의 명령을 수행한다.
#
# ### 1.1 보안 및 인증 정책 (Security & Authentication)
# - **기본 정책:** 대부분의 제어 명령 API는 보안 토큰(Bearer Token) 기반의 인증을 요구한다.
# - **예외 정책 (주의):** 시스템 모니터링 및 긴급 호출의 편의성을 위해 아래 조회/요청 API는 **인증 없이(Anonymous)** 접근 가능하다.
#   - `places` (위치 정보 조회)
#   - `Call` (로봇 호출)
#   - `Mission` (작업 할당 및 조회)
# - **권고 사항:** 상기 예외 API는 사내 폐쇄망(Intranet) 내에서만 호출되도록 네트워크 레벨의 방화벽 정책 수립을 권장한다.
#
# ---
#
# ## 2. API 상세 명세 (API Detailed Specifications)
#
# ### [API] 위치 정보 조회 (Get Places)
#
# **1. 정의 (Definition)**
# `GET /api/places` API는 공장 내 정의된 모든 노드(Node), 스테이션(Station), 충전소 등의 위치 정보를 반환한다. 인증 없이 접근 가능하며, 주로 관제 시스템의 맵(Map) 시각화나 경로 계획(Path Planning) 기초 데이터로 사용된다.
#
# **2. 기술적 상세 (Technical Details)**
# - **Endpoint:** `/api/places`
# - **Method:** `GET`
# - **Header:** `Content-Type: application/json` (인증 불필요)
# - **Query Parameters:**
#   - `floor` (String, Optional): 특정 층(Floor)의 데이터만 필터링할 경우 사용.
#
# **3. 사용 사례 (Use Case)**
# - **시각화:** 대시보드 UI에서 로봇이 이동 가능한 경로와 목적지(Station)를 렌더링할 때 호출.
# - **유효성 검증:** 작업 지시 전, 목적지 ID가 유효한지 검증하기 위해 마스터 데이터를 동기화할 때 사용.
#
# **4. 응답 예시 (Response Body Example)**
# ```json
# {
#   "timestamp": "2025-03-19T14:00:00Z",
#   "places": [
#     {
#       "id": "ST_101",
#       "type": "Station",
#       "name": "Assembly_Input_A",
#       "coordinates": { "x": 12.5, "y": 45.2, "theta": 90.0 },
#       "properties": { "isActive": true }
#     },
#     {
#       "id": "CHG_01",
#       "type": "Charger",
#       "name": "Fast_Charger_1",
#       "coordinates": { "x": 0.0, "y": 0.0, "theta": 0.0 }
#     }
#   ]
# }
# ```
#
# ---
#
# ### [API] 로봇 호출 (Call Robot)
#
# **1. 정의 (Definition)**
# `POST /api/call` API는 특정 위치(Station)로 가용 가능한 AMR을 즉시 호출한다. 인증 로직이 제외되어 있어 물리 버튼(IoT Dash Button)이나 키오스크 등 경량 클라이언트에서 빠르게 통합 가능하다.
#
# **2. 기술적 상세 (Technical Details)**
# - **Endpoint:** `/api/call`
# - **Method:** `POST`
# - **Header:** `Content-Type: application/json` (인증 불필요)
# - **Body Parameters:**
#   - `locationId` (String, Required): 로봇이 도착해야 할 목적지 ID.
#   - `priority` (Integer, Optional): 호출 우선순위 (기본값: 1, 높을수록 긴급).
#
# **3. 사용 사례 (Use Case)**
# - **자재 수거 요청:** 작업자가 공정 라인 끝에서 완제품 적재가 완료되었음을 알리고, 이를 이송할 로봇을 부를 때 사용.
#
# **4. 요청 예시 (Request Body Example)**
# ```json
# {
#   "locationId": "ST_PACKING_04",
#   "priority": 5,
#   "requester": "Operator_Kiosk_02"
# }
# ```
#
# ---
#
# ### [API] 미션 생성 및 제어 (Create Mission)
#
# **1. 정의 (Definition)**
# `POST /api/mission` API는 AMR에게 복합적인 작업(이동, 리프트 동작, 도킹 등)을 지시한다. **2025-03-19 업데이트**를 통해 `DockRequest` 필드가 추가되어, 도킹 해제(Docking Out) 상태를 명시적으로 제어할 수 있게 되었다.
#
# **2. 기술적 상세 (Technical Details)**
# - **Endpoint:** `/api/mission`
# - **Method:** `POST`
# - **Header:** `Content-Type: application/json` (인증 불필요)
# - **Body Parameters:**
#   - `robotId` (String, Optional): 특정 로봇 지정 시 사용 (미지정 시 시스템이 자동 할당).
#   - `tasks` (Array, Required): 수행할 작업 목록.
#   - `DockRequest` (Object, Optional): **[New]** 도킹 관련 세부 제어 파라미터.
#     - `action` (String): `DOCK_IN` 또는 `DOCK_OUT`.
#     - `targetCharger` (String): 대상 충전소 ID.
#
# **3. 사용 사례 (Use Case)**
# - **충전 복귀 및 이탈:** 배터리가 부족한 로봇을 충전소로 보내거나(`DOCK_IN`), 충전이 완료된 로봇을 작업 대기 장소로 출차(`DOCK_OUT`)시킬 때 사용.
# - **자재 이송:** A지점에서 자재를 들어(Lift Up) B지점으로 이동 후 내리는(Lift Down) 일련의 시퀀스 작업.
#
# **4. 요청 예시 (Request Body Example)**
# ```json
# {
#   "missionId": "MS_20250319_001",
#   "robotId": "AMR_05",
#   "priority": 10,
#   "DockRequest": {
#     "action": "DOCK_OUT",
#     "targetCharger": "CHG_01",
#     "forceUndock": true
#   },
#   "tasks": [
#     {
#       "sequence": 1,
#       "type": "MOVE",
#       "destination": "ST_BUFFER_ZONE"
#     }
#   ]
# }
# ```

# %% [markdown]
# ### 에러 시나리오는 바로 conversation 포맷으로 변경

# %%
model = "google/gemini-3-pro-preview"
provider = "openrouter"
api_key = config["openrouter"]["api_key"]
params = {
    "max_tokens": 32768,
    "temperature": 0.7
}
llm_client = OpenAILLMClient(model=model, provider=provider, api_key=api_key, params=params)
# Out:
# 2026-01-12 11:13:31.627 | INFO     | app.common.llm_clients.openai_client:_create_clients:57 - Creating OpenRouter client.

# %%
# ==========================================
# [Track 3] 행동 & 절차 데이터 증강용 입력 데이터
# ==========================================

# 1. 공통 로직 (Base Logic) - Scenario 1
base_logics = {
    "Scenario_1": """
    1. 상태 확인: GET /api/object/status (에러 및 미션 확인)
    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)
    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)
    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand
    5. 모드 복구: PUT /api/command/mode (Auto)
    """
}

# 2. 갈아 끼울 부품 (Cases) - Scenario 1 그룹
cases = [
    # Case 1: 도킹 마커 미인식
    {
        "code": "80018",
        "name": "Dock Not Find",
        "desc": "로봇이 도킹 스테이션 앞에서 마커를 인식하지 못해 진입 직전 멈춰 서 있는 상태.",
        "reasoning": "현재 위치에서는 센서가 마커를 놓쳤기 때문에 제자리 재시도는 무의미함. 반드시 Undock을 통해 로봇을 뒤로 물려 시야(FOV)를 확보하고 마커를 다시 스캔해야 함.",
        "group": "Scenario_1"
    },

    # Case 2: 진입 각도 초과
    {
        "code": "80015",
        "name": "Heading Exceeded",
        "desc": "도킹 시도 중 AMR의 진입 각도(Heading)가 허용 오차 범위를 초과하여 진입이 차단된 상태.",
        "reasoning": "이미 진입 각도가 틀어진 상태(Skew)이므로 단순 재시도는 실패함. Undock으로 도킹 구역을 완전히 빠져나와 차체 정렬을 초기화한 후 똑바로 재진입해야 함.",
        "group": "Scenario_1"
    },

    # Case 3: IR 센서 감지 실패
    {
        "code": "10015",
        "name": "IR Detection Fail",
        "desc": "AMR 하부의 IR 센서가 설비 스토퍼(Dog Plate)를 감지하지 못해 도킹 위치를 확정하지 못한 상태.",
        "reasoning": "설비 도그플레이트 파손이나 위치 틀어짐이 원인일 수 있음. Undock으로 빠져나와 센서 감지 범위를 리셋하고, 재진입 시 IR 센서가 정상적으로 신호를 잡는지 다시 확인해야 함.",
        "group": "Scenario_1"
    }
]

# ==========================================
# [Scenario 2] 도킹/주행 중 멈춤 (User 개입 필수)
# ==========================================

# 1. 공통 로직 (Base Logic) - Scenario 2
# 특징: 중간에 API 호출이 아닌 '작업자의 물리적 조치'가 반드시 포함됨
base_logics["Scenario_2"] = """
    1. 상태 확인: GET /api/object/status (에러 코드 및 상세 원인 파악)
    2. 작업 취소: PUT /api/command/cancel (ACS Job 강제 종료)
    3. [현장 조치]: 에러 유형에 따라 '수동 이동(Jog)', '장애물 제거', '물리적 리셋', '위치 초기화(Init)' 등 특정 조치 수행 (작업자 개입 필수)
    4. 미션 재할당: GET /api/Object/Mission (기존 미션 조회) -> PUT /api/Command/retrycommand
    5. 모드 복구: PUT /api/command/mode (Auto)
"""

# 2. 갈아 끼울 부품 (Cases) - Scenario 2 그룹
cases_scenario_2 = [
    # Group A: 위치 및 경로 이탈 (수동 이동/보정 필요)
    {
        "code": "80023",
        "name": "Pos Exceed",
        "desc": "도킹 프로세스 중 로봇의 위치가 허용 범위를 벗어나거나 하드웨어 이슈로 멈춘 상태.",
        "reasoning": "로봇이 스스로 경로에 복귀할 수 없음. 작업 취소(Cancel) 후, 충돌 여부를 확인하고 수동 조작(Jog)으로 안전한 위치까지 이동시킨 뒤 재시도해야 함.",
        "group": "Scenario_2"
    },
    {
        "code": "80024",
        "name": "Timeout",
        "desc": "도킹 또는 주행 중 정해진 시간 내에 목표에 도달하지 못해 타임아웃이 발생함.",
        "reasoning": "물리적인 간섭이나 경로상 문제일 가능성이 높음. Cancel 후 수동으로 로봇을 안전 구역으로 빼내고 재시도 명령을 내려야 함.",
        "group": "Scenario_2"
    },
    {
        "code": "11",
        "name": "ACS_ERROR_WHILE_NAVIGATING",
        "desc": "AMR이 지정된 경로(Path)를 벗어나 '주행 불가 영역(흰색 배경)'에 위치함.",
        "reasoning": "ACS 상에서 로봇이 길을 잃은 상태. JOG 모드를 활성화하여 작업자가 직접 로봇을 정상 경로(색상이 있는 라인) 위로 끌어다 놓아야만 다시 명령을 수행할 수 있음.",
        "group": "Scenario_2"
    },
    {
        "code": "80003",
        "name": "ERROR_CONFIDENCE_LOW",
        "desc": "AMR이 현재 자신의 위치를 잃어버림(Delocalization). 맵과 매칭되는 지형지물을 찾지 못함.",
        "reasoning": "단순 이동으로는 해결되지 않음. 주변 장애물을 치워 시야를 확보하거나, ACS 상에서 'Init Position' 기능을 사용해 수동으로 로봇의 현재 좌표와 헤딩을 지정해줘야 함.",
        "group": "Scenario_2"
    },

    # Group B: 하드웨어 센서 및 장애물 이슈 (제거/리셋 필요)
    {
        "code": "80014",
        "name": "Encoder Error",
        "desc": "주행 중 모터 회전수를 감지하는 엔코더 데이터가 업데이트되지 않음.",
        "reasoning": "일시적인 통신 오류일 수 있으나 하드웨어 행(Hang) 상태일 가능성이 큼. Job Cancel 후 기체 측면의 물리적 'RESET 버튼'을 눌러 하드웨어를 재부팅해야 함.",
        "group": "Scenario_2"
    },
    {
        "code": "20014",
        "name": "HOKUYO Lidar Obstacle",
        "desc": "라이다 센서가 반사판(작업조끼, 안전콘 등)을 장애물로 오인하여 정지함.",
        "reasoning": "소프트웨어적인 해제가 불가능함. 반사체를 2m 이상 이격시키고, 렌즈를 닦은 후 물리적 'RESET 버튼'을 눌러 OSSD 락을 풀어야 함.",
        "group": "Scenario_2"
    },
    {
        "code": "30020",
        "name": "OSSD LIDAR ERROR",
        "desc": "안전 비상 정지(OSSD) 신호가 발생하여 이동이 차단됨. 주로 센서 오염이나 근접 장애물 때문임.",
        "reasoning": "센서 표면의 이물질을 제거하거나 장애물을 치워야 함. 물리적 원인이 제거되지 않으면 시스템 리셋을 해도 다시 에러가 발생함.",
        "group": "Scenario_2"
    },
    {
        "code": "80025",
        "name": "PAUSED_BY_LIDAR_OBSTACLE",
        "desc": "라이다가 로봇의 '충돌 감지 영역(Safety Zone)' 내에서 장애물을 감지함.",
        "reasoning": "도킹 구역 내 이물질(실, 조각)이나 빛 반사가 원인임. 로봇을 Undock 하거나 장애물을 물리적으로 제거한 후 재시도(CallRetry) 해야 함.",
        "group": "Scenario_2"
    },
    {
        "code": "80026",
        "name": "PAUSE_BY_CAMERA_OBSTACLE",
        "desc": "3D 카메라가 상단부나 바닥의 장애물(케이블, 튀어나온 패널)을 감지함.",
        "reasoning": "라이다로는 안 보이는 높이의 장애물일 수 있음. 해당 장애물을 제거하거나 설비 위치를 조정해야 하며, 해결 전까지는 로봇이 움직이지 못함.",
        "group": "Scenario_2"
    }
]

# 기존 cases 리스트에 병합
cases.extend(cases_scenario_2)

# ==========================================
# [Scenario 3] 신호 인터페이스 에러 (PLC Reset 필수)
# ==========================================

# 1. 공통 로직 (Base Logic) - Scenario 3
# 특징: 물리적 이동(Undock)이 없고, 대신 'PLC 제어 명령(dock_reset -> dock_ok)'이 포함됨
base_logics["Scenario_3"] = """
    1. 상태 확인: GET /api/object/status (에러 코드 및 CurrentRackObject/DockOutArea 확인)
    2. 작업 취소: PUT /api/command/cancel (ACS Job 중단)
    3. PLC 리셋: PUT /api/plc/placecommand (Command: "dock_reset") -> 설비 신호 초기화
    4. 핸드쉐이크 재개: PUT /api/plc/placecommand (Command: "dock_ok") -> 작업 가능 상태 알림
    5. 미션 재할당: GET /api/Object/Mission (기존 미션 조회) -> PUT /api/Command/retrycommand
    6. 모드 복구: PUT /api/command/mode (Auto)
"""

# 2. 갈아 끼울 부품 (Cases) - Scenario 3 그룹
cases_scenario_3 = [
    # Case 1: 작업 요청 신호 꺼짐 (U/L_REQ OFF)
    {
        "code": "70008",
        "name": "U_REQ/L_REQ OFF ALARM",
        "desc": "로봇이 도착했는데 설비(PLC)가 작업을 요청하는 신호(REQ)를 갑자기 꺼버린 상태.",
        "reasoning": "설비 측의 일시적인 신호 끊김이거나 센서 오인식임. PLC의 상태를 'dock_reset'으로 초기화한 뒤, 다시 'dock_ok'를 보내 로봇이 준비되었음을 강제로 알려줘야 함.",
        "group": "Scenario_3"
    },

    # Case 2: 준비 완료 신호 꺼짐 (READY OFF)
    {
        "code": "70009",
        "name": "READY OFF ALARM",
        "desc": "작업 도중 설비의 준비(READY) 신호가 꺼져서 인터페이스가 중단됨.",
        "reasoning": "설비가 준비 태세를 풀었으므로 로봇도 대기하게 됨. 'dock_reset'으로 설비의 에러를 클리어하고, 'dock_ok' 신호로 재작업 의사를 전달하여 핸드쉐이킹을 복구해야 함.",
        "group": "Scenario_3"
    },

    # Case 3: 작업 시작 지연 (WORK START TIME OVER)
    {
        "code": "70010",
        "name": "WORK START TIME OVER",
        "desc": "도킹 완료 후 일정 시간 내에 실제 작업(이송/적재)이 시작되지 않음.",
        "reasoning": "서로 '네가 먼저 시작해'라며 눈치만 보는 교착 상태(Deadlock). PLC 로직을 'dock_reset'으로 리셋하여 타이머를 초기화하고 프로세스를 처음부터 다시 트리거해야 함.",
        "group": "Scenario_3"
    },

    # Case 4: T2 타임아웃 (내부 동작 불가)
    {
        "code": "70011",
        "name": "T2 TIME OVER",
        "desc": "물건을 받기 전(Loading 전) 설비 내부의 선행 동작이 시간 내에 완료되지 않음.",
        "reasoning": "설비 내부 실린더나 센서가 늦게 반응한 경우임. 'dock_reset'을 통해 설비에게 '다시 준비하라'는 명령을 내리고, 'dock_ok'로 로봇은 대기 상태임을 재확인시켜야 함.",
        "group": "Scenario_3"
    }
]

# 기존 cases 리스트에 병합
cases.extend(cases_scenario_3)

# ==========================================
# [Scenario 4] 적재/이재 작업 중단 (Payload & Data Sync)
# ==========================================

# 1. 공통 로직 (Base Logic) - Scenario 4
# 특징: '적재 상태(LoadedState)' 확인과 '데이터 수정(Payload Update)'이 핵심
base_logics["Scenario_4"] = """
    1. 상태 확인: GET /api/object/status (LoadedState: 0=Empty, 3=Full 확인)
    2. 작업 취소: PUT /api/command/cancel (ACS Job 중단)
    3. 적재물 확인: 실제 로봇 상단에 화물(SKID/Box)이 있는지 육안 확인 (필수)
    4. 설비 리셋: PUT /api/plc/placecommand (Command: "dock_reset" -> "dock_ok")
    5. 데이터 동기화: PUT /api/command/payload (실제 화물 상태에 맞춰 시스템 값 덮어쓰기)
    6. 작업 완료/재개: 상황에 따라 PUT /api/command/jobcomplete (강제 완료) 또는 Auto Mode 복귀
"""

# 2. 갈아 끼울 부품 (Cases) - Scenario 4 그룹
cases_scenario_4 = [
    # Case 1: T4 타임아웃 (이재 중 멈춤)
    {
        "code": "70012",
        "name": "T4 TIME OVER",
        "desc": "물건을 주고받는(이재) 도중 센서 중복 감지나 끼임으로 인해 시간 초과 발생.",
        "reasoning": "물리적 이재는 완료되었으나 신호가 꼬인 경우가 많음. 실제 적재가 완료되었다면 'Payload Save'로 정보를 갱신하고, 설비 신호를 리셋한 뒤 작업을 마쳐야 함.",
        "group": "Scenario_4"
    },

    # Case 2: 단순 끼임 (Resume 가능)
    {
        "code": "Simple Jam",
        "name": "Conveyor Jam / Delay",
        "desc": "컨베이어 이송 중 박스가 살짝 걸리거나 일시적 지연으로 알람 발생.",
        "reasoning": "심각한 데이터 불일치가 아님. 0.3T AMR HMI에서 'RESUME' 버튼을 눌러 작업을 재개(Retry)하는 것만으로 해결 가능함.",
        "group": "Scenario_4"
    },

    # Case 3: Port Full (공급 불가)
    {
        "code": "Port Full",
        "name": "Supply Port Full",
        "desc": "물건을 주러 갔는데(Supply), 설비 포트에 이미 다른 물건이 차 있어서 작업을 못 함.",
        "reasoning": "물리적으로 불가능한 작업임. Payload를 'Full(적재 상태)'로 유지한 채 'Job Complete'로 강제 완료 처리하고, 로봇을 창고로 회차시켜야 함.",
        "group": "Scenario_4"
    },

    # Case 4: 1단만 공급 (부분 완료)
    {
        "code": "Partial Supply",
        "name": "Supply Incomplete (1/2)",
        "desc": "2단 공급 미션이었으나 1단만 주고 멈춤. 남은 1개는 로봇 위에 있음.",
        "reasoning": "잔여 화물 정보를 업데이트해야 함. Payload를 '1EA-Full, 1EA-None'으로 수정하고 'Job Complete' 처리하여 재고 정보를 맞춰야 함.",
        "group": "Scenario_4"
    },

    # Case 5: 빈 박스 없음 (회수 불가)
    {
        "code": "No Empty Box",
        "name": "Return Port Empty",
        "desc": "빈 박스를 가지러 갔는데(Return), 설비 포트가 비어있음.",
        "reasoning": "가져올 물건이 없음. Payload를 'Clear(없음)'로 설정하고 'Job Complete' 처리하여 빈차로 복귀시켜야 함.",
        "group": "Scenario_4"
    },

    # Case 6: Work 없음 (작업물 미준비)
    {
        "code": "No Work",
        "name": "Work Not Ready / Start Delay",
        "desc": "도킹했으나 설비가 물건을 내어주지 않음 (지게차 간섭 등으로 실제 물건 부재).",
        "reasoning": "기다려도 소용없음. 설비 측 'Work Reset' 후 로봇 상태를 'After Docking'으로 변경하여 미션을 취소하거나 재시도 대기 상태로 만들어야 함.",
        "group": "Scenario_4"
    },

    # Case 7: 센서 미감지/잔류 (Phantom Sensor)
    {
        "code": "Sensor Error",
        "name": "On-board Sensor Fail",
        "desc": "물건이 있는데 센서가 안 켜지거나(미감지), 물건이 없는데 센서가 켜짐(잔류).",
        "reasoning": "하드웨어 점검 필요. 'Payload Clear' 후 로봇을 점검 구역으로 빼내야 하며, 절대 그대로 자동 운행을 시키면 안 됨 (유령 재고 발생 위험).",
        "group": "Scenario_4"
    }
]

# 기존 cases 리스트에 병합
cases.extend(cases_scenario_4)

# %%
user_question_templates = {
    # Type A: 표준 절차서 (Standard SOP) -> "문서 줘", "절차 알려줘"
    "STANDARD_SOP": [
        "BMA 공정에서 발생하는 [{code}] {name} 에러의 표준 처리 절차(SOP)를 서술하시오.", # 정석
        "[{code}] 에러 발생 시 준수해야 할 공식 복구 매뉴얼을 작성해 주세요.", # 정중
        "[{code}] {name} 에러에 대한 표준 운영 절차서는 무엇입니까?", # 의문형
    ],

    # Type B: 현장 매뉴얼 (Field Manual) -> "급해", "어떻게 해?", "도와줘"
    "FIELD_MANUAL": [
        "지금 현장에 [{code}] 알람이 떴습니다. 즉시 조치할 수 있는 가이드를 주세요.", # 다급함
        "[{code}] {name} 에러 발생. 현장 대응 방법 요약 좀.", # 보고체/구어체
        "[{code}] 트러블슈팅 가이드." # 초단답형 (검색 키워드 식)
    ],

    # Type C: 사고 리포트 (Incident Report) -> "사례 알려줘", "리포트 써줘"
    "INCIDENT_REPORT": [
        "[{code}] 에러와 관련된 과거 해결 사례를 리포트 형식으로 작성하시오.", # 정석
        "[{code}] {name} 발생 시 올바른 조치 과정을 담은 사고 분석 보고서를 써주세요.", # 요청
        "[{code}] 에러 대응 이력 리포트 생성." # 단답형
    ]
}

# SOP 데이터 증강을 위한 Think Template (스타일별 맞춤)
sop_think_templates = {
    # Type A: 표준 절차서 (Standard SOP)
    "STANDARD_SOP": """<think>
사용자가 '{code} {name}' 에러 상황에 대한 공식적인 표준 복구 절차(SOP)를 요청했다.
이 에러는 '{reasoning}'이(가) 주 원인이므로, 단순 재시도가 아닌 '{base_logic_summary}' 로직을 적용해야 한다.
이에 따라 BMA 공정의 안전 규정과 표준 프로토콜을 준수하는 기술 문서를 작성하여 제시한다.
</think>""",

    # Type B: 현장 매뉴얼 (Field Manual)
    "FIELD_MANUAL": """<think>
사용자가 '{code}' 에러 발생 직후의 현장 대응 가이드를 긴급히 요청했다.
현재 상황은 '{desc}' 상태이므로, 신속한 복구를 위해 작업자가 즉시 수행해야 할 행동 지침(Action Item) 위주로 답변을 구성해야 한다.
특히 '{reasoning}' 이슈를 해결하기 위한 구체적인 조작법과 주의사항을 강조하여 설명한다.
</think>""",

    # Type C: 사고 리포트 (Incident Report)
    "INCIDENT_REPORT": """<think>
사용자가 '{code}' 에러의 해결 사례에 대한 분석 리포트를 요청했다.
과거 사례를 재구성하여, 문제 발생 원인('{desc}')과 당시 적용된 해결 로직('{base_logic_summary}')의 인과관계를 명확히 서술해야 한다.
이를 통해 해당 절차를 준수해야 하는 공학적/경험적 근거를 제시한다.
</think>""",

    # Type D: 기술 Q&A (Tech Q&A)
    "TECH_QNA": """<think>
사용자가 '{code}' 에러 처리 과정의 기술적 원리와 당위성에 대해 질문했다.
사용자는 특정 단계(예: Undock, Payload Update 등)가 왜 필요한지 궁금해하고 있다.
따라서 '{reasoning}'이라는 시스템적 배경을 근거로 들어, 해당 로직이 필수적인 이유를 논리적으로 설명한다.
</think>"""
}

# %%
from ml.data_processing.prompt import SOP_AUGMENTATION_PROMPTS
from ml.utils.util import parse_json

# %%
generated_dataset = []
for case in cases:
    group_name = case['group']
    base_logic_text = base_logics[group_name]
    formatted_input_info = f"""
    [Target Situation]
    - Error Code: {case['code']}
    - Name: {case['name']}
    - Symptom: {case['desc']}
    - Context/Reasoning: {case['reasoning']}

    [Recovery Logic]{base_logic_text}"""

    for style_name, prompt_template in SOP_AUGMENTATION_PROMPTS.items():
        if style_name != "TECH_QNA":
            user_questions = user_question_templates[style_name]
            for selected_template in user_questions:
                # (C) 데이터 파싱 및 조립
                final_user_content = ""
                final_assistant_content = ""

                response = llm_client.generate(system_prompt=prompt_template, chat_messages=[{"role": "user", "content": formatted_input_info}])
                raw_content = response.choices[0].message.content
                final_user_content = selected_template.format(
                    code=case['code'],
                    name=case['name']
                )

                # Think Block + 생성된 본문
                think_block = sop_think_templates[style_name].format(
                    code=case['code'],
                    name=case['name'],
                    desc=case['desc'],
                    reasoning=case['reasoning'],
                    base_logic_summary=base_logic_text.strip()
                )
                final_assistant_content = think_block + "\n\n" + raw_content

                # (D) 최종 저장 (동일)
                data_entry = {
                    "conversation": [
                        { "role": "system", "content": "당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다." },
                        { "role": "user", "content": final_user_content },
                        { "role": "assistant", "content": final_assistant_content }
                    ]
                }
                logger.info(data_entry)
                generated_dataset.append(data_entry)

        else:
            for _ in range(3):
                response = llm_client.generate(system_prompt=prompt_template, chat_messages=[{"role": "user", "content": formatted_input_info}])
                raw_content = response.choices[0].message.content
                qa_data = parse_json(raw_content)
                final_user_content = qa_data["question"]
                think_block = sop_think_templates[style_name].format(
                    code=case['code'],
                    name=case['name'],
                    desc=case['desc'],
                    reasoning=case['reasoning'],
                    base_logic_summary=base_logic_text.strip()
                )
                final_assistant_content = think_block + "\n\n" + qa_data["answer"]
                data_entry = {
                    "conversation": [
                        { "role": "system", "content": "당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다." },
                        { "role": "user", "content": final_user_content },
                        { "role": "assistant", "content": final_assistant_content }
                    ]
                }
                logger.info(data_entry)
                generated_dataset.append(data_entry)
# Out:
# 2026-01-12 11:44:13.368 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': 'BMA 공정에서 발생하는 [80018] Dock Not Find 에러의 표준 처리 절차(SOP)를 서술하시오.'}, {'role': 'assistant', 'content': "<think>\n사용자가 '80018 Dock Not Find' 에러 상황에 대한 공식적인 표준 복구 절차(SOP)를 요청했다.\n이 에러는 '현재 위치에서는 센서가 마커를 놓쳤기 때문에 제자리 재시도는 무의미함. 반드시 Undock을 통해 로봇을 뒤로 물려 시야(FOV)를 확보하고 마커를 다시 스캔해야 함.'이(가) 주 원인이므로, 단순 재시도가 아닌 '1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)' 로직을 적용해야 한다.\n이에 따라 BMA 공정의 안전 규정과 표준 프로토콜을 준수하는 기술 문서를 작성하여 제시한다.\n</think>\n\n# 표준 절차: [80018] Dock Not Find 복구\n\n## 1. 개요\n본 문서는 BMA 공정 내 로봇이 도킹 스테이션 진입 시도 중 마커를 인식하지 못하여 발생하는 **[80018] Dock Not Find** 에러에 대한 표준 복구 절차를 기술한다.\n\n## 2. 현상 및 원인 분석\n*   **현상:** 로봇이 도킹 스테이션 진입 직전 멈춰 서 있으며, 시스템상 80018 에러가 발생함.\n*   **원인:** 진입 각도 또는 조도 등의 영향으로 센서가 도킹 마커를 놓친 상태임.\n*   **조치 방향:** 현재 위치에서는 마커 재인식이 불가능하므로(제자리 재시도 무의미), 로봇을 강제로 후진(Undock)시켜 센서의 시야(FOV)를 확보한 뒤 작업을 재개해야 함.\n\n---\n\n## 3. 표준 복구 절차 (Recovery Procedure)\n\n**단계 1: 상태 및 미션 정보 확인**\n*   현재 로봇의 정확한 에러 코드와 중단된 미션 ID를 파악하기 위해 `GET /api/object/status`를 호출함.\n*   반환된 데이터에서 Error Code 80018 여부를 확인함.\n\n**단계 2: 기존 작업 중단 (Job Cancel)**\n*   실패한 도킹 시퀀스를 초기화하고 로봇 제어권을 확보하기 위해 `PUT /api/command/cancel`을 수행함.\n*   이전의 실패한 명령이 잔존할 경우 후속 이동 명령이 거부될 수 있으므로 반드시 선행되어야 함.\n\n**단계 3: 물리적 후진 및 시야 확보 (Undock Move)**\n*   **[핵심 절차]** 현재 위치에서는 센서가 마커를 감지할 수 없으므로, 로봇을 도킹 스테이션으로부터 이격시켜야 함.\n*   `PUT /api/command/move` (Target: Undock_Point)를 전송하여 로봇을 후진시킴.\n*   본 과정을 통해 로봇 센서의 시야(FOV) 내에 도킹 마커가 다시 들어오도록 유도함.\n\n**단계 4: 미션 재할당 (Retry)**\n*   시야가 확보된 위치에서 중단되었던 작업을 재개함.\n*   `GET /api/Object/Mission`을 통해 수행해야 할 미션 정보를 재확인한 뒤, `PUT /api/Command/retrycommand`를 전송하여 도킹을 재시도함.\n\n**단계 5: 운영 모드 정상화**\n*   예외 처리 종료 후 로봇이 공정 스케줄에 따라 자동으로 동작할 수 있도록 `PUT /api/command/mode` (Parameter: Auto)를 수행하여 Auto 모드로 복귀시킴."}]}
# 2026-01-12 11:44:30.454 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80018] 에러 발생 시 준수해야 할 공식 복구 매뉴얼을 작성해 주세요.'}, {'role': 'assistant', 'content': "<think>\n사용자가 '80018 Dock Not Find' 에러 상황에 대한 공식적인 표준 복구 절차(SOP)를 요청했다.\n이 에러는 '현재 위치에서는 센서가 마커를 놓쳤기 때문에 제자리 재시도는 무의미함. 반드시 Undock을 통해 로봇을 뒤로 물려 시야(FOV)를 확보하고 마커를 다시 스캔해야 함.'이(가) 주 원인이므로, 단순 재시도가 아닌 '1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)' 로직을 적용해야 한다.\n이에 따라 BMA 공정의 안전 규정과 표준 프로토콜을 준수하는 기술 문서를 작성하여 제시한다.\n</think>\n\n# 표준 절차: [80018] Dock Not Find 복구\n\n## 1. 개요\n본 절차서는 BMA 공정 중 로봇이 도킹 스테이션 진입 직전 마커를 인식하지 못하여 정지한 상황(Error Code: 80018)에 대한 표준 복구 방법을 기술한다. \n\n해당 에러 발생 시, 현재 위치에서는 센서가 마커를 소실한 상태이므로 제자리 재시도는 무의미하다. 따라서 로봇을 강제로 후진(Undock)시켜 센서 시야(FOV)를 다시 확보하는 과정이 필수적이다.\n\n---\n\n## 2. 복구 절차\n\n**1단계: 로봇 상태 및 에러 확인**\n- 현장 엔지니어는 관제 시스템을 통해 로봇의 현재 상태를 진단한다.\n- `GET /api/object/status`를 호출하여 80018 에러 발생 여부 및 중단된 미션 정보를 확인함.\n\n**2단계: 기존 작업 중단**\n- 마커 미인식 상태에서 무리한 진입 시도를 방지하기 위해 현재 진행 중인 명령을 취소한다.\n- `PUT /api/command/cancel`을 전송하여 로봇의 기존 작업을 즉시 중단함.\n\n**3단계: 시야 확보를 위한 후진(Undock)**\n- **(중요)** 현재 위치는 마커 인식이 불가능한 사각지대이므로, 마커를 재스캔할 수 있는 거리까지 로봇을 이동시켜야 한다.\n- `PUT /api/command/move` (Target: Undock_Point)를 수행하여 로봇을 도킹 스테이션 반대 방향으로 후진시킴으로써 센서의 시야(FOV)를 확보함.\n\n**4단계: 미션 정보 확인 및 재할당**\n- 로봇이 마커 인식이 가능한 위치로 이동 완료했음을 확인한다.\n- `GET /api/Object/Mission`으로 중단되었던 작업 내용을 로드한 뒤, `PUT /api/Command/retrycommand`를 전송하여 도킹 미션을 재시도함.\n\n**5단계: 운전 모드 복구**\n- 로봇이 정상적으로 도킹 프로세스를 재개하는지 모니터링한다.\n- `PUT /api/command/mode` (Auto)를 전송하여 로봇을 시스템 제어 하의 자동 운전 상태로 전환하고 복구 절차를 종료함."}]}
# 2026-01-12 11:44:49.231 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80018] Dock Not Find 에러에 대한 표준 운영 절차서는 무엇입니까?'}, {'role': 'assistant', 'content': "<think>\n사용자가 '80018 Dock Not Find' 에러 상황에 대한 공식적인 표준 복구 절차(SOP)를 요청했다.\n이 에러는 '현재 위치에서는 센서가 마커를 놓쳤기 때문에 제자리 재시도는 무의미함. 반드시 Undock을 통해 로봇을 뒤로 물려 시야(FOV)를 확보하고 마커를 다시 스캔해야 함.'이(가) 주 원인이므로, 단순 재시도가 아닌 '1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)' 로직을 적용해야 한다.\n이에 따라 BMA 공정의 안전 규정과 표준 프로토콜을 준수하는 기술 문서를 작성하여 제시한다.\n</think>\n\n# 표준 절차: [80018] Dock Not Find 복구\n\n**문서 번호:** SOP-80018-REC-01\n**적용 대상:** BMA 공정 현장 운영 엔지니어\n**대상 에러:** Error Code 80018 (Dock Not Find)\n\n---\n\n### 1. 개요 및 현상 분석\n본 절차서는 로봇이 도킹 스테이션 진입 직전, 마커를 인식하지 못하여 정지한 상황(Dock Not Find)에 대한 복구 방법을 기술한다. 현재 로봇의 위치는 센서 인식 범위를 벗어나 있거나 사각지대에 위치한 상태이므로, 제자리에서의 단순 재시도는 무의미하다. 따라서 로봇을 강제로 후진(Undock)시켜 마커 스캔이 가능한 시야(FOV)를 확보한 후 미션을 재개해야 한다.\n\n### 2. 표준 복구 절차 (Recovery Procedure)\n\n**Step 1: 로봇 상태 및 미션 확인**\n*   현재 발생한 에러 코드(80018)와 중단된 미션의 세부 정보를 파악하기 위해 상태 조회 명령을 수행함.\n*   **Command:** `GET /api/object/status`\n\n**Step 2: 기존 작업 취소**\n*   마커 미인식으로 인해 교착 상태에 빠진 현재 작업을 중단하고 초기화하기 위해 취소 명령을 수행함.\n*   **Command:** `PUT /api/command/cancel`\n\n**Step 3: 시야 확보를 위한 물리적 후진 (Undock)**\n*   현재 위치에서는 센서가 마커를 놓친 상태이므로, 마커를 다시 스캔할 수 있는 거리와 각도를 확보하기 위해 로봇을 물리적으로 후진시킴.\n*   **Command:** `PUT /api/command/move` (Parameter: `Target: Undock_Point`)\n\n**Step 4: 미션 정보 갱신 및 재할당**\n*   후진 동작이 완료되어 마커 인식 범위 내로 진입했음을 확인한 후, 미션 정보를 다시 불러오고 도킹 명령을 재시도함.\n*   **Command:** `GET /api/Object/Mission` 확인 후 `PUT /api/Command/retrycommand`\n\n**Step 5: 운용 모드 정상화**\n*   복구 조치 완료 후, 공정의 연속성을 보장하기 위해 로봇의 제어 모드를 자동으로 전환함.\n*   **Command:** `PUT /api/command/mode` (Parameter: `Auto`)\n\n---\n**작성자:** BMA 공정 SOP 관리자\n**최종 수정일:** 202X.XX.XX"}]}
# 2026-01-12 11:45:09.919 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '지금 현장에 [80018] 알람이 떴습니다. 즉시 조치할 수 있는 가이드를 주세요.'}, {'role': 'assistant', 'content': '<think>\n사용자가 \'80018\' 에러 발생 직후의 현장 대응 가이드를 긴급히 요청했다.\n현재 상황은 \'로봇이 도킹 스테이션 앞에서 마커를 인식하지 못해 진입 직전 멈춰 서 있는 상태.\' 상태이므로, 신속한 복구를 위해 작업자가 즉시 수행해야 할 행동 지침(Action Item) 위주로 답변을 구성해야 한다.\n특히 \'현재 위치에서는 센서가 마커를 놓쳤기 때문에 제자리 재시도는 무의미함. 반드시 Undock을 통해 로봇을 뒤로 물려 시야(FOV)를 확보하고 마커를 다시 스캔해야 함.\' 이슈를 해결하기 위한 구체적인 조작법과 주의사항을 강조하여 설명한다.\n</think>\n\n## [현장 가이드] 에러코드 80018: Dock Not Find 조치 매뉴얼\n\n어이 신입, 당황하지 말고 화면 보세요.\n지금 HMI 화면에 **[Error Code: 80018]**이 떴습니까? 그리고 로봇이 **도킹 스테이션 바로 코앞에서 마커를 못 찾고 멍하니 멈춰 서 있는 상태**인가요?\n\n이건 로봇이 너무 가까이 붙어서 센서가 도킹 마커를 놓친 겁니다. 등잔 밑이 어둡다는 말 알죠? 딱 그 상황입니다. 침착하게 아래 순서대로 조치하세요.\n\n---\n\n### 1. 작업 취소 (Cancel Command)\n가장 먼저 제어 화면에서 **[작업 취소(Cancel)]** 버튼을 누르세요.\n*   **이유:** 지금 상태에서 제자리 재시도(Retry)를 눌러봤자 로봇은 마커를 볼 수 없습니다. 의미 없는 시도를 끊어줘야 합니다.\n\n### 2. 로봇 뒤로 물리기 (Undock)\n수동 제어 메뉴나 명령창에서 **[Undock]** 명령을 실행하여 로봇을 뒤로 물리세요.\n*   **이유:** 로봇이 도킹 스테이션에서 일정 거리 이상 멀어져야 센서의 시야각(FOV) 안에 마커가 다시 들어옵니다. **반드시 물리적으로 거리를 벌려줘야** 센서가 "아, 저기 도킹 스테이션이 있구나" 하고 인식할 수 있습니다.\n\n### 3. 미션 재할당 (Retry Command)\n로봇이 충분히 뒤로 물러나서 대기 상태가 되면, 다시 **[미션 재시도(Retry Command)]**를 입력하세요.\n*   **이유:** 이제 시야가 확보되었으니, 로봇이 정상적으로 마커를 스캔하고 도킹 궤적을 다시 계산해서 진입할 수 있습니다.\n\n### 4. 모드 확인 (Auto Mode Check)\n로봇이 다시 움직이기 시작하면, 시스템 모드가 **[Auto]**로 되어 있는지 확인하세요.\n*   **이유:** 트러블슈팅 과정에서 매뉴얼 모드로 바뀌었을 수 있습니다. 공정 흐름이 끊기지 않도록 자동 모드 복귀를 잊지 마세요.\n\n---\n\n### ※ 선임의 주의사항 (Safety & Tips)\n*   **절대 밀지 마세요:** 로봇이 멈췄다고 손으로 밀어서 도킹 스테이션에 억지로 끼워 넣지 마십시오. 위치 값이 틀어져서 더 큰 에러가 납니다.\n*   **주변 확인:** Undock으로 로봇이 후진할 때, 로봇 뒤쪽에 자재나 사람이 없는지 **반드시 육안으로 확인**하고 명령을 내리세요.'}]}
# 2026-01-12 11:45:30.049 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80018] Dock Not Find 에러 발생. 현장 대응 방법 요약 좀.'}, {'role': 'assistant', 'content': '<think>\n사용자가 \'80018\' 에러 발생 직후의 현장 대응 가이드를 긴급히 요청했다.\n현재 상황은 \'로봇이 도킹 스테이션 앞에서 마커를 인식하지 못해 진입 직전 멈춰 서 있는 상태.\' 상태이므로, 신속한 복구를 위해 작업자가 즉시 수행해야 할 행동 지침(Action Item) 위주로 답변을 구성해야 한다.\n특히 \'현재 위치에서는 센서가 마커를 놓쳤기 때문에 제자리 재시도는 무의미함. 반드시 Undock을 통해 로봇을 뒤로 물려 시야(FOV)를 확보하고 마커를 다시 스캔해야 함.\' 이슈를 해결하기 위한 구체적인 조작법과 주의사항을 강조하여 설명한다.\n</think>\n\n## 👷 현장 트러블슈팅 가이드: Dock Not Find\n\n**작성자:** 현장 기술 선임 (Senior Technician)\n**대상:** 신입 사원\n**상황:** 도킹 마커 인식 실패 (Error 80018)\n\n---\n\n### 1. 상황 인식 (Situation Awareness)\n"자, 지금 HMI 화면에 **[Error Code: 80018]**이 떴나요?\n로봇이 도킹 스테이션 코앞까지 갔는데, 더 이상 진입하지 못하고 **[멈춰 서 있는]** 상태입니까?"\n\n### 2. 조치 순서 (Action Steps)\n\n**Step 1. 즉시 작업 취소 (Cancel Command)**\n*   관리자 콘솔에서 **[작업 취소 (Cancel)]** 버튼을 누르거나 `/api/command/cancel` 명령을 보내세요.\n*   **이유:** 로봇이 이미 마커를 놓친 상태입니다. 이 상태에서 가만히 놔두거나 단순히 \'재시도(Retry)\'만 누르면, 로봇은 마커를 찾으려고 제자리에서 헤매기만 할 뿐 해결되지 않습니다. 일단 꼬인 작업을 끊어줘야 합니다.\n\n**Step 2. 로봇 후진 및 시야 확보 (Undock Move)**\n*   로봇에게 **[Undock]** 명령을 내리거나, `/api/command/move` (Target: Undock_Point)를 전송하여 로봇을 뒤로 물리세요.\n*   **이유:** 지금 로봇이 도킹 스테이션에 너무 가까이 붙어 있어서 센서의 시야각(FOV) 밖으로 마커가 벗어난 겁니다. 사람으로 치면 코앞에 물건이 있어 초점이 안 맞는 상황이니, 뒤로 물러나서 다시 스캔할 거리를 만들어줘야 합니다.\n\n**Step 3. 미션 재할당 (Retry Mission)**\n*   로봇이 Undock 위치로 완전히 빠져나온 것을 확인한 후, **[미션 재시도 (Retry Command)]**를 실행하세요.\n*   **이유:** 이제 센서가 마커를 정면에서 볼 수 있는 위치가 되었습니다. 지금 다시 진입 명령을 내려야 로봇이 정상적으로 도킹 경로를 계산합니다.\n\n**Step 4. 자동 모드 복구 (Mode Recovery)**\n*   로봇이 정상적으로 도킹에 성공하면 시스템이 **[Auto Mode]**로 복귀되었는지 확인하세요.\n*   **이유:** 수동 조작이나 에러 처리가 끝나면 로봇이 Manual 모드에 머물러 있을 수 있습니다. 다음 공정을 위해 반드시 Auto 상태로 돌려놔야 합니다.\n\n---\n\n### ⚠️ 현장 안전 주의사항 (Safety Check)\n*   **후방 충돌 주의:** **Undock 명령을 내리기 전에 로봇 바로 뒤에 사람이나 적재물이 없는지 반드시 눈으로 확인하세요.** 로봇이 예고 없이 후진할 때가 현장에서 가장 사고가 많이 나는 순간입니다.\n*   **센서 오염 확인:** 만약 위 조치 후에도 동일한 80018 에러가 반복된다면, 로봇 하단의 **LiDAR 센서나 카메라 렌즈에 먼지가 묻었는지** 확인하고 닦아내야 합니다.'}]}
# 2026-01-12 11:45:49.324 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80018] 트러블슈팅 가이드.'}, {'role': 'assistant', 'content': '<think>\n사용자가 \'80018\' 에러 발생 직후의 현장 대응 가이드를 긴급히 요청했다.\n현재 상황은 \'로봇이 도킹 스테이션 앞에서 마커를 인식하지 못해 진입 직전 멈춰 서 있는 상태.\' 상태이므로, 신속한 복구를 위해 작업자가 즉시 수행해야 할 행동 지침(Action Item) 위주로 답변을 구성해야 한다.\n특히 \'현재 위치에서는 센서가 마커를 놓쳤기 때문에 제자리 재시도는 무의미함. 반드시 Undock을 통해 로봇을 뒤로 물려 시야(FOV)를 확보하고 마커를 다시 스캔해야 함.\' 이슈를 해결하기 위한 구체적인 조작법과 주의사항을 강조하여 설명한다.\n</think>\n\n# [현장 트러블슈팅 가이드] Error 80018: Dock Not Find\n\n어이 신입, 당황하지 말고 화면부터 보세요.\n지금 HMI 화면에 **[Error Code: 80018]**가 떴나요? 로봇이 도킹 스테이션 코앞까지 가서 **[마커를 못 찾고 멍하니 멈춰 있는]** 상태입니까?\n\n이건 로봇이 너무 가까이 붙어서 센서 시야각(FOV)에서 마커를 놓친 겁니다. 사람이 코앞에 있는 글씨 못 읽는 거랑 똑같아요. 이 상태에서는 제자리 재시도 백날 눌러봐야 소용없습니다. 아래 순서대로 조치하세요.\n\n---\n\n### 1. 작업 중단 (Cancel)\n먼저 꼬여버린 현재 미션부터 끊어내세요.\n*   **조치:** 제어 화면에서 **[Cancel]** 버튼을 누르세요. (API: `PUT /api/command/cancel`)\n*   **이유:** 로봇이 엉뚱한 곳을 찾으려 애쓰고 있는 상태를 확실히 초기화해야 다음 명령이 먹힙니다.\n\n### 2. 시야 확보를 위한 후진 (Undock)\n여기가 제일 중요합니다. 로봇을 뒤로 물려서 마커를 다시 보게 만들어야 합니다.\n*   **조치:** 로봇 이동 명령 메뉴에서 **[Undock]** 기능을 실행하세요. (API: `PUT /api/command/move` -> Target: Undock_Point)\n*   **이유:** 로봇이 물리적으로 뒤로 빠져줘야 센서가 도킹 마커 전체를 다시 스캔할 수 있습니다. **절대로 손으로 밀거나 강제로 옮기지 마세요.** 좌표 틀어집니다.\n\n### 3. 미션 재할당 (Retry)\n로봇이 뒤로 물러나서 자리를 잡았나요? 그럼 다시 일을 시킵시다.\n*   **조치:** 미션 관리 화면에서 **[Retry Command]**를 입력하세요.\n*   **이유:** 시야가 확보된 상태에서 다시 진입 명령을 받으면, 이번에는 센서가 마커를 제대로 인식하고 도킹에 성공할 겁니다.\n\n### 4. 자동 모드 복구 (Auto Mode Check)\n*   **조치:** 마지막으로 로봇 상태가 **[Auto]** 모드로 정상 복귀했는지 확인하세요.\n\n---\n\n### ⚠️ [주의사항: 안전 제일]\n**Undock(후진) 명령 내리기 전에 반드시 로봇 뒤쪽을 확인하세요!**\n로봇이 예고 없이 뒤로 빠지기 때문에, 뒤에 사람이나 지게차가 있으면 충돌 사고 납니다. "로봇 후진합니다!"라고 복창하고 버튼 누르세요. 알겠습니까?'}]}
# 2026-01-12 11:46:12.033 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80018] 에러와 관련된 과거 해결 사례를 리포트 형식으로 작성하시오.'}, {'role': 'assistant', 'content': "<think>\n사용자가 '80018' 에러의 해결 사례에 대한 분석 리포트를 요청했다.\n과거 사례를 재구성하여, 문제 발생 원인('로봇이 도킹 스테이션 앞에서 마커를 인식하지 못해 진입 직전 멈춰 서 있는 상태.')과 당시 적용된 해결 로직('1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)')의 인과관계를 명확히 서술해야 한다.\n이를 통해 해당 절차를 준수해야 하는 공학적/경험적 근거를 제시한다.\n</think>\n\n# [QA Report] 에러 대응 성공 사례 분석: Dock Not Find (80018)\n\n**작성자:** 설비 보전팀 QA 분석가\n**작성일:** 2023년 10월 25일\n**문서 번호:** QA-REC-231025-04\n\n---\n\n### 1. 개요 (Incident Overview)\n*   **발생 일시:** 2023년 10월 24일 14:30\n*   **대상 설비:** 물류 이송 로봇 AMR-04호기\n*   **발생 에러:** Error Code 80018 (Dock Not Find)\n*   **증상 (Symptom):**\n    로봇이 충전 스테이션(Dock) 진입을 시도하던 중, 도킹 스테이션 바로 앞에서 정지함. 육안상으로는 진입 경로에 문제가 없어 보였으나, 로봇은 마커를 인식하지 못한 채 제자리에서 대기 상태로 전환됨.\n\n### 2. 해결 과정 (Resolution Process)\n\n당시 현장 오퍼레이터는 관제 모니터링 중 AMR-04호기가 충전 구역 앞에서 장시간 정지해 있는 것을 발견했습니다. 즉시 **`GET /api/object/status`**를 호출하여 로봇의 상태를 점검한 결과, **Error 80018 (Dock Not Find)** 코드가 반환됨을 확인했습니다.\n\n일반적인 에러라면 제자리에서 'Resume(재개)' 명령을 내렸겠지만, 오퍼레이터는 해당 에러의 특성(Context)을 정확히 파악하고 있었습니다. 로봇이 도킹 스테이션에 너무 근접하여 멈춘 경우, **센서의 시야각(FOV) 내에서 마커가 벗어났거나 초점이 맞지 않아 제자리 재시도는 무의미하다는 점**을 인지한 것입니다.\n\n이에 따라 오퍼레이터는 당황하지 않고 다음의 표준 복구 절차를 수행했습니다.\n\n1.  우선 엉켜버린 현재 작업을 초기화하기 위해 **`PUT /api/command/cancel`**을 전송하여 기존 진입 명령을 중단시켰습니다.\n2.  가장 핵심적인 조치로, 로봇이 마커를 다시 스캔할 수 있는 거리를 확보하기 위해 물리적인 후진(Undock)을 결정했습니다. **`PUT /api/command/move`** API를 사용하여 로봇을 사전에 정의된 **'Undock_Point'**로 이동시켰습니다.\n3.  로봇이 뒤로 물러나 충분한 시야를 확보한 것을 확인한 후, **`GET /api/Object/Mission`**으로 기존 미션 정보를 불러와 **`PUT /api/Command/retrycommand`**를 통해 재진입 명령을 하달했습니다.\n4.  마지막으로 로봇이 정상적으로 도킹을 시작하는 것을 확인한 뒤, **`PUT /api/command/mode`**를 통해 시스템을 Auto 모드로 복구시켰습니다.\n\n결과적으로 로봇은 적절한 거리에서 마커를 재인식하고 부드럽게 도킹에 성공했습니다.\n\n### 3. 결론 (Conclusion)\n\n이번 사례는 작업자가 에러 코드의 원인을 정확히 이해하고 메뉴얼대로 조치하여 불필요한 가동 중단을 막은 모범 사례입니다.\n\n이 사례에서 보듯, **[Error Code: 80018] 발생 시에는 제자리 재시도를 지양하고, 반드시 [물리적 후진(Undock)을 통한 시야 확보] 단계를 선행해야 함**을 다시 한번 강조합니다."}]}
# 2026-01-12 11:46:34.309 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80018] Dock Not Find 발생 시 올바른 조치 과정을 담은 사고 분석 보고서를 써주세요.'}, {'role': 'assistant', 'content': '<think>\n사용자가 \'80018\' 에러의 해결 사례에 대한 분석 리포트를 요청했다.\n과거 사례를 재구성하여, 문제 발생 원인(\'로봇이 도킹 스테이션 앞에서 마커를 인식하지 못해 진입 직전 멈춰 서 있는 상태.\')과 당시 적용된 해결 로직(\'1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)\')의 인과관계를 명확히 서술해야 한다.\n이를 통해 해당 절차를 준수해야 하는 공학적/경험적 근거를 제시한다.\n</think>\n\n**[QA Report] 표준 대응 프로세스 준수를 통한 Dock Not Find 에러 해결 우수 사례**\n\n**작성자:** 설비 보전팀 QA 분석가\n**작성일:** 202X년 X월 X일\n\n---\n\n### 1. 개요 (Incident Overview)\n\n*   **발생 일시:** 202X년 10월 24일 14:30\n*   **대상 설비:** 물류 이송 로봇 AMR-L04호기\n*   **발생 에러:** Error Code 80018 (Dock Not Find)\n*   **증상 (Symptom):**\n    로봇이 충전 스테이션(Dock) 진입을 시도하던 중, 스테이션 바로 앞에서 정지함. 육안 확인 결과, 로봇이 도킹 스테이션과 매우 근접해 있었으나 최종 진입 동작을 수행하지 못하고 대기 상태에 머물러 있었음.\n\n---\n\n### 2. 해결 과정 (Resolution Narrative)\n\n당시 현장 오퍼레이터는 관제 모니터링 중 AMR-L04호기의 이상 정지를 감지했습니다. 오퍼레이터는 당황하지 않고 표준 대응 매뉴얼(SOP)에 따라 다음과 같이 침착하게 트러블슈팅을 진행했습니다.\n\n**① 정확한 상태 진단**\n가장 먼저 `GET /api/object/status`를 호출하여 로봇의 상태를 조회했습니다. 리턴된 값에서 **Error Code: 80018 (Dock Not Find)**를 확인한 오퍼레이터는, 단순히 로봇이 멈춘 것이 아니라 \'마커를 인식하지 못한 상태\'임을 파악했습니다.\n\n**② 상황 판단 및 원인 분석 (Reasoning)**\n오퍼레이터는 현장 카메라를 통해 로봇이 도킹 스테이션 코앞까지 진입해 있는 것을 확인했습니다. 그는 **"현재 로봇이 너무 가까이 붙어 있어 센서의 시야각(FOV) 내에 마커가 들어오지 않는 상황"**이라고 판단했습니다. 이 상태에서는 제자리에서 재시도(Retry) 명령을 내려봤자 센서가 여전히 마커를 볼 수 없으므로 무의미하다는 것을 인지하고 있었습니다. 따라서 **물리적으로 로봇을 뒤로 물려 시야를 확보하는 것이 우선**이라는 결론을 내렸습니다.\n\n**③ 작업 취소 및 물리적 후진 (Action)**\n오퍼레이터는 꼬여있는 현재 작업을 초기화하기 위해 `PUT /api/command/cancel`을 전송하여 기존 미션을 중단시켰습니다. 그 후, 즉시 `PUT /api/command/move` 명령을 사용하여 로봇을 사전 정의된 **\'Undock_Point\'**(후방 약 1.5m 지점)로 이동시켰습니다. 로봇이 뒤로 물러나면서 도킹 스테이션의 마커가 다시 센서의 유효 인식 범위 내로 들어오는 것이 확인되었습니다.\n\n**④ 미션 재할당 및 복구**\n시야가 확보되자 오퍼레이터는 `GET /api/Object/Mission`으로 중단되었던 미션 데이터를 확인한 뒤, `PUT /api/Command/retrycommand`를 전송하여 도킹 미션을 재할당했습니다. 마지막으로 `PUT /api/command/mode`를 호출하여 로봇을 Auto 모드로 전환함으로써, 로봇은 정상적으로 마커를 스캔하고 도킹에 성공했습니다.\n\n---\n\n### 3. 결론 (Conclusion)\n\n본 사례는 작업자가 에러 코드의 의미를 정확히 이해하고 논리적으로 대응하여 다운타임을 최소화한 모범 사례입니다.\n\n이 사례에서 보듯, **[Error Code: 80018] 발생 시에는 제자리 재시도가 아닌, 반드시 [Undock을 통한 시야(FOV) 확보] 단계를 선행해야 함**을 명심해야 합니다.'}]}
# 2026-01-12 11:46:56.430 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80018] 에러 대응 이력 리포트 생성.'}, {'role': 'assistant', 'content': "<think>\n사용자가 '80018' 에러의 해결 사례에 대한 분석 리포트를 요청했다.\n과거 사례를 재구성하여, 문제 발생 원인('로봇이 도킹 스테이션 앞에서 마커를 인식하지 못해 진입 직전 멈춰 서 있는 상태.')과 당시 적용된 해결 로직('1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)')의 인과관계를 명확히 서술해야 한다.\n이를 통해 해당 절차를 준수해야 하는 공학적/경험적 근거를 제시한다.\n</think>\n\n# QA 분석 리포트: 도킹 에러(80018) 표준 조치 성공 사례\n\n**작성자:** 설비 보전팀 QA 분석가\n**문서 번호:** QA-2023-REC-80018\n**작성 일자:** 2023년 10월 27일\n\n---\n\n### 1. 개요 (Incident Overview)\n\n*   **발생 일시:** 2023년 10월 24일 14:30\n*   **대상 설비:** 물류 이송 로봇 4호기 (AMB-04)\n*   **발생 에러:** **[Error Code: 80018] Dock Not Find**\n*   **현장 증상:** 로봇이 충전 스테이션 진입을 시도하던 중, 도킹 스테이션 바로 앞에서 멈춰 선 채 더 이상 진입하지 못하고 대기 상태에 빠짐.\n\n### 2. 해결 과정 (Resolution Process)\n\n당시 현장 오퍼레이터는 관제 모니터링 중 AMB-04호기가 충전 구역 앞에서 정지해 있는 것을 발견했습니다. 오퍼레이터는 당황하지 않고 표준 매뉴얼의 **[Recovery Logic]**에 따라 다음과 같이 순차적인 조치를 수행했습니다.\n\n1.  **상태 진단 및 원인 파악**\n    가장 먼저 `GET /api/object/status`를 호출하여 로봇의 상태를 확인했습니다. 리턴된 값에서 **Error Code 80018**을 확인한 오퍼레이터는, 이것이 단순한 통신 오류가 아니라 **'센서 시야각(FOV) 문제'**임을 즉시 인지했습니다. 로봇이 도킹 스테이션에 너무 근접하여 각도가 어긋난 상태였으므로, **제자리에서 재시도(Retry)를 해봤자 센서가 마커를 인식할 수 없어 무의미하다는 점**을 정확히 판단했습니다.\n\n2.  **작업 초기화**\n    오퍼레이터는 꼬인 프로세스를 풀기 위해 우선 `PUT /api/command/cancel`을 전송하여 현재 진행 중이던 도킹 미션을 안전하게 중단시켰습니다.\n\n3.  **물리적 시야 확보 (핵심 조치)**\n    이 단계에서 오퍼레이터는 **반드시 로봇을 뒤로 물려야 한다**는 판단 하에 `PUT /api/command/move` (Target: Undock_Point) 명령을 실행했습니다. 로봇은 충전기 앞에서 약 1.5m가량 후진(Undock)하여 정지했습니다. 이 물리적 후진을 통해 로봇의 센서는 도킹 마커를 다시금 명확한 시야(FOV) 내에 확보할 수 있었습니다.\n\n4.  **미션 재개 및 완료**\n    시야가 확보된 것을 확인한 후, `GET /api/Object/Mission`으로 이전 미션 정보를 불러왔고, `PUT /api/Command/retrycommand`를 통해 도킹 명령을 재전송했습니다. 로봇은 정상적으로 마커를 인식하고 매끄럽게 도킹에 성공했습니다.\n\n5.  **정상화**\n    마지막으로 `PUT /api/command/mode`를 호출하여 로봇을 Auto 모드로 복귀시킴으로써 모든 조치를 완료했습니다.\n\n### 3. 결론 (Conclusion)\n\n이번 사례는 작업자가 에러 코드의 본질적인 원인(마커 인식 실패)을 정확히 이해하고 대처한 모범 사례입니다.\n\n이 사례에서 보듯, **[Error Code: 80018] 발생 시에는 제자리 재시도를 지양하고, 반드시 [물리적 후진(Undock)] 단계를 수행하여 센서 시야를 확보한 뒤 재진입**해야 문제를 원활하게 해결할 수 있습니다."}]}
# 2026-01-12 11:47:09.245 | INFO     | __main__:<module>:71 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': "80018(Dock Not Find) 에러 발생 시, 로봇이 이미 도킹 스테이션 바로 앞에 위치해 있는데 왜 제자리에서 즉시 재시도하지 않고 굳이 'Undock(후진)' 동작을 선행해야 합니까?"}, {'role': 'assistant', 'content': "<think>\n사용자가 '80018' 에러 처리 과정의 기술적 원리와 당위성에 대해 질문했다.\n사용자는 특정 단계(예: Undock, Payload Update 등)가 왜 필요한지 궁금해하고 있다.\n따라서 '현재 위치에서는 센서가 마커를 놓쳤기 때문에 제자리 재시도는 무의미함. 반드시 Undock을 통해 로봇을 뒤로 물려 시야(FOV)를 확보하고 마커를 다시 스캔해야 함.'이라는 시스템적 배경을 근거로 들어, 해당 로직이 필수적인 이유를 논리적으로 설명한다.\n</think>\n\n80018 에러는 로봇이 도킹 진입 직전 마커 인식을 실패하고 멈춘 상태입니다. 이 위치는 로봇이 도크에 지나치게 근접하여 센서의 최소 초점 거리나 시야각(FOV)을 벗어났을 확률이 매우 높습니다. 따라서 제자리 재시도는 물리적으로 성공할 수 없으며, 반드시 로봇을 뒤로 물려(Undock) 마커를 다시 스캔할 수 있는 시야를 확보해야 합니다. 전체 복구 절차는 [상태 확인 및 작업 취소] -> [Undock을 통한 물리적 거리 확보] -> [미션 재할당 및 재시도] -> [Auto 모드 복구] 순으로 진행되어야 합니다."}]}
# 2026-01-12 11:47:23.779 | INFO     | __main__:<module>:71 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': "Error Code 80018(Dock Not Find) 발생 시, 로봇은 이미 도킹 스테이션 진입 직전에 위치해 있습니다. 이 상황에서 즉시 재진입을 시도하지 않고, 굳이 'Undock(물리적 후진)' 단계를 수행해야 하는 기술적 이유는 무엇입니까?"}, {'role': 'assistant', 'content': "<think>\n사용자가 '80018' 에러 처리 과정의 기술적 원리와 당위성에 대해 질문했다.\n사용자는 특정 단계(예: Undock, Payload Update 등)가 왜 필요한지 궁금해하고 있다.\n따라서 '현재 위치에서는 센서가 마커를 놓쳤기 때문에 제자리 재시도는 무의미함. 반드시 Undock을 통해 로봇을 뒤로 물려 시야(FOV)를 확보하고 마커를 다시 스캔해야 함.'이라는 시스템적 배경을 근거로 들어, 해당 로직이 필수적인 이유를 논리적으로 설명한다.\n</think>\n\n80018 에러는 로봇이 도킹 진입 최종 단계에서 마커 인식에 실패하여 멈춘 상태입니다. 이때 로봇은 도킹 스테이션과 너무 근접해 있어 센서의 최소 초점 거리나 시야각(FOV)을 벗어난 '인식 사각지대'에 위치할 가능성이 매우 높습니다. 따라서 제자리 재시도는 실패할 확률이 크며, 반드시 로봇을 뒤로 물려(Undock) 센서가 마커를 다시 스캔할 수 있는 적정 거리와 시야를 확보해야 합니다. 전체 복구 절차는 [상태 확인 및 작업 취소] -> [Undock을 통한 물리적 후진 및 시야 확보] -> [미션 재할당(Retry)] -> [Auto 모드 복귀] 순으로 진행되어야 안전한 재도킹이 보장됩니다."}]}
# 2026-01-12 11:47:39.769 | INFO     | __main__:<module>:71 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': 'Error Code 80018(Dock Not Find) 발생 시, 로봇이 이미 도킹 스테이션 바로 앞에 위치해 있습니다. 굳이 뒤로 물러나는 Undock 과정을 거치지 않고 제자리에서 즉시 도킹을 재시도하면 안 되는 기술적 이유가 무엇입니까?'}, {'role': 'assistant', 'content': "<think>\n사용자가 '80018' 에러 처리 과정의 기술적 원리와 당위성에 대해 질문했다.\n사용자는 특정 단계(예: Undock, Payload Update 등)가 왜 필요한지 궁금해하고 있다.\n따라서 '현재 위치에서는 센서가 마커를 놓쳤기 때문에 제자리 재시도는 무의미함. 반드시 Undock을 통해 로봇을 뒤로 물려 시야(FOV)를 확보하고 마커를 다시 스캔해야 함.'이라는 시스템적 배경을 근거로 들어, 해당 로직이 필수적인 이유를 논리적으로 설명한다.\n</think>\n\n80018 에러는 로봇이 도킹 진입 직전 위치에서 마커 인식에 실패했음을 의미합니다. 이는 현재 로봇의 좌표나 각도가 센서의 유효 시야각(FOV)을 벗어났거나, 너무 근접하여 사각지대에 들어갔기 때문입니다. 센서가 마커를 놓친 현 위치(Dead Zone)에서 단순 재시도를 수행하는 것은 동일한 실패를 반복할 확률이 매우 높습니다.\n\n따라서 물리적으로 로봇을 후진시키는 **Undock** 동작이 필수적입니다. 이를 통해 센서와 마커 사이의 적정 초점 거리를 다시 확보하고, 마커를 유효 범위 내에서 재스캔할 수 있는 환경을 만들어야 합니다.\n\n권장되는 복구 로직은 **[상태 확인 및 기존 작업 취소] -> [Undock을 통한 물리적 거리 및 시야 확보] -> [미션 재할당] -> [Auto 모드 복구]** 순으로 진행하여 안전한 재진입을 유도해야 합니다."}]}
# 2026-01-12 11:47:58.665 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': 'BMA 공정에서 발생하는 [80015] Heading Exceeded 에러의 표준 처리 절차(SOP)를 서술하시오.'}, {'role': 'assistant', 'content': "<think>\n사용자가 '80015 Heading Exceeded' 에러 상황에 대한 공식적인 표준 복구 절차(SOP)를 요청했다.\n이 에러는 '이미 진입 각도가 틀어진 상태(Skew)이므로 단순 재시도는 실패함. Undock으로 도킹 구역을 완전히 빠져나와 차체 정렬을 초기화한 후 똑바로 재진입해야 함.'이(가) 주 원인이므로, 단순 재시도가 아닌 '1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)' 로직을 적용해야 한다.\n이에 따라 BMA 공정의 안전 규정과 표준 프로토콜을 준수하는 기술 문서를 작성하여 제시한다.\n</think>\n\n# 표준 절차: [80015] Heading Exceeded 복구\n\n**문서 번호:** SOP-80015-REC\n**적용 대상:** 현장 운용 엔지니어 및 관제 시스템 담당자\n**개요:** 본 문서는 도킹 시도 중 AMR의 진입 각도(Heading)가 허용 오차 범위를 초과하여 진입이 차단된 경우의 표준 복구 절차를 기술한다.\n\n---\n\n### 1. 상태 확인 (Status Check)\n*   **절차:** `GET /api/object/status` 호출\n*   **상세:** 현재 로봇의 에러 코드(80015) 점유 여부 및 진행 중이던 미션 상태를 확인함. 이는 후속 조치의 대상이 되는 로봇을 식별하고 에러 상황을 확정하기 위함임.\n\n### 2. 작업 취소 (Cancel Job)\n*   **절차:** `PUT /api/command/cancel` 수행\n*   **상세:** 현재 AMR의 진입 각도가 이미 틀어진(Skew) 상태이므로, 기존 궤적을 유지한 채 진행하는 것은 불가능함. 따라서 기존 작업을 즉시 중단하여 충돌 및 추가 이탈을 방지함.\n\n### 3. 물리적 후진 및 정렬 초기화 (Undock & Re-alignment)\n*   **절차:** `PUT /api/command/move` (Target: Undock_Point) 수행\n*   **상세:** 단순 재시도는 각도 오차로 인해 반복 실패할 가능성이 높음. 차체 정렬을 초기화하고 올바른 진입 각도를 확보하기 위해, Undock 지점까지 로봇을 완전히 후진시켜 도킹 구역을 이탈함.\n\n### 4. 미션 재할당 (Mission Retry)\n*   **절차:** `GET /api/Object/Mission` 확인 후 `PUT /api/Command/retrycommand` 수행\n*   **상세:** 로봇이 도킹 구역 밖에서 정렬을 마친 상태이므로, 보류되었던 미션 정보를 확인하고 재시도 명령을 전송하여 정상적인 각도로 도킹을 재수행함.\n\n### 5. 모드 복구 (Restore Auto Mode)\n*   **절차:** `PUT /api/command/mode` (Parameter: Auto) 수행\n*   **상세:** 복구 기동이 완료된 후, 시스템이 연속적인 작업을 수행할 수 있도록 제어 권한을 Auto 모드로 변경하여 절차를 종료함."}]}
# 2026-01-12 11:48:18.109 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80015] 에러 발생 시 준수해야 할 공식 복구 매뉴얼을 작성해 주세요.'}, {'role': 'assistant', 'content': "<think>\n사용자가 '80015 Heading Exceeded' 에러 상황에 대한 공식적인 표준 복구 절차(SOP)를 요청했다.\n이 에러는 '이미 진입 각도가 틀어진 상태(Skew)이므로 단순 재시도는 실패함. Undock으로 도킹 구역을 완전히 빠져나와 차체 정렬을 초기화한 후 똑바로 재진입해야 함.'이(가) 주 원인이므로, 단순 재시도가 아닌 '1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)' 로직을 적용해야 한다.\n이에 따라 BMA 공정의 안전 규정과 표준 프로토콜을 준수하는 기술 문서를 작성하여 제시한다.\n</think>\n\n# 표준 절차: [80015] Heading Exceeded 복구\n\n**문서 번호:** SOP-BMA-80015\n**작성자:** BMA 공정 SOP 관리자\n**적용 대상:** 현장 운용 엔지니어 및 관제 시스템 관리자\n\n---\n\n## 1. 개요 및 증상\n본 절차서는 AMR이 도킹 스테이션 진입 시도시 허용된 진입 각도(Heading) 범위를 초과하여 진입이 차단된 경우의 표준 복구 방법을 기술한다.\n\n*   **Error Code:** 80015\n*   **Error Name:** Heading Exceeded\n*   **증상:** 도킹 마커 인식 또는 경로 진입 과정에서 로봇의 헤딩(Heading) 각도가 오차 범위를 벗어나 정지함.\n*   **원인 분석:** 현재 차체가 틀어진 상태(Skew)로 도킹 구역에 위치해 있어, 제자리에서의 단순 재시도로는 각도 보정이 불가능함. 따라서 도킹 구역을 완전히 벗어나 정렬을 초기화하는 과정이 필수적임.\n\n---\n\n## 2. 표준 복구 절차 (Standard Recovery Procedure)\n\n현장 엔지니어는 아래 순서에 따라 복구 작업을 수행한다.\n\n**1단계: 상태 및 에러 확인**\n*   로봇의 현재 상태와 에러 발생 여부를 명확히 파악하기 위해 `GET /api/object/status`를 호출함.\n*   반환된 데이터에서 Error Code 80015 및 중단된 미션 정보를 확인함.\n\n**2단계: 기존 작업 중단**\n*   이미 진입 각도가 틀어진 상태에서의 도킹 진행은 물리적으로 불가능하므로, `PUT /api/command/cancel`을 전송하여 현재 수행 중인 도킹 작업을 취소함.\n\n**3단계: 도킹 구역 이탈 및 정렬 초기화 (Undock)**\n*   단순 제자리 회전으로는 Heading 오차 수정이 어려우므로, `PUT /api/command/move` (Target: Undock_Point)를 수행함.\n*   로봇을 도킹 구역 밖으로 완전히 후진(Undock)시켜 차체 정렬을 초기화하고, 재진입을 위한 직선 경로를 확보함.\n\n**4단계: 미션 재할당 및 재시도**\n*   차체 정렬이 완료된 위치에서 `GET /api/Object/Mission`을 호출하여 보류된 미션 정보를 확인함.\n*   확인된 미션을 바탕으로 `PUT /api/Command/retrycommand`를 전송하여, 올바른 진입 각도로 도킹을 처음부터 다시 수행하도록 지시함.\n\n**5단계: 자동 운전 모드 복구**\n*   재시도 명령이 정상적으로 접수되었음을 확인한 후, `PUT /api/command/mode` (Auto)를 전송하여 로봇을 자동 운전 모드(Auto Mode)로 전환 및 공정 사이클에 복귀시킴."}]}
# 2026-01-12 11:48:34.051 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80015] Heading Exceeded 에러에 대한 표준 운영 절차서는 무엇입니까?'}, {'role': 'assistant', 'content': "<think>\n사용자가 '80015 Heading Exceeded' 에러 상황에 대한 공식적인 표준 복구 절차(SOP)를 요청했다.\n이 에러는 '이미 진입 각도가 틀어진 상태(Skew)이므로 단순 재시도는 실패함. Undock으로 도킹 구역을 완전히 빠져나와 차체 정렬을 초기화한 후 똑바로 재진입해야 함.'이(가) 주 원인이므로, 단순 재시도가 아닌 '1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)' 로직을 적용해야 한다.\n이에 따라 BMA 공정의 안전 규정과 표준 프로토콜을 준수하는 기술 문서를 작성하여 제시한다.\n</think>\n\n# 표준 절차: [80015] Heading Exceeded 복구\n\n## 1. 개요\n본 문서는 AMR 도킹 시도 중 진입 각도(Heading)가 허용 오차 범위를 초과하여 발생한 **[80015] Heading Exceeded** 에러의 표준 복구 절차를 기술한다. 해당 상황은 차체가 이미 틀어진 상태(Skew)이므로 단순 제자리 재시도로는 해결이 불가능하며, 물리적인 위치 재정렬이 필수적이다.\n\n## 2. 복구 절차\n\n### 1단계: 상태 및 미션 확인\n*   **Action:** `GET /api/object/status` 호출\n*   **Description:** 현재 AMR의 에러 코드(80015) 점유 상태 및 중단된 미션 ID를 확인하여 복구 대상임을 식별함.\n\n### 2단계: 기존 작업 취소\n*   **Action:** `PUT /api/command/cancel` 수행\n*   **Description:** 현재 진입 각도로는 도킹 성공이 불가능하므로, 잘못된 경로로 진행 중인 선행 작업을 즉시 중단시킴.\n\n### 3단계: 물리적 후진 및 정렬 초기화 (Undock)\n*   **Action:** `PUT /api/command/move` (Target: Undock_Point) 수행\n*   **Description:** 이미 진입 각도가 틀어진 상태에서의 단순 재시도는 실패를 유발함. 따라서 **도킹 구역을 완전히 빠져나와 차체 정렬을 초기화**하고 올바른 진입 각도를 재확보하기 위해, 지정된 Undock 지점으로 로봇을 이동시킴.\n\n### 4단계: 미션 재할당\n*   **Action:** `GET /api/Object/Mission` 조회 후 `PUT /api/Command/retrycommand` 수행\n*   **Description:** 차체가 정렬된 상태(Undock 완료)에서, 조회된 미션 정보를 기반으로 도킹 명령을 재할당하여 정상 진입을 시도함.\n\n### 5단계: 자동 운용 모드 복구\n*   **Action:** `PUT /api/command/mode` (Parameter: Auto) 수행\n*   **Description:** 미션 재개 후 시스템이 연속적인 작업을 수행할 수 있도록 제어 모드를 Auto 상태로 전환하여 복구를 완료함."}]}
# 2026-01-12 11:48:57.565 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '지금 현장에 [80015] 알람이 떴습니다. 즉시 조치할 수 있는 가이드를 주세요.'}, {'role': 'assistant', 'content': "<think>\n사용자가 '80015' 에러 발생 직후의 현장 대응 가이드를 긴급히 요청했다.\n현재 상황은 '도킹 시도 중 AMR의 진입 각도(Heading)가 허용 오차 범위를 초과하여 진입이 차단된 상태.' 상태이므로, 신속한 복구를 위해 작업자가 즉시 수행해야 할 행동 지침(Action Item) 위주로 답변을 구성해야 한다.\n특히 '이미 진입 각도가 틀어진 상태(Skew)이므로 단순 재시도는 실패함. Undock으로 도킹 구역을 완전히 빠져나와 차체 정렬을 초기화한 후 똑바로 재진입해야 함.' 이슈를 해결하기 위한 구체적인 조작법과 주의사항을 강조하여 설명한다.\n</think>\n\n## [현장 트러블슈팅 가이드: Error 80015]\n\n어이 신입, 당황하지 말고 화면 잘 보세요.\n지금 HMI 화면에 **[Error Code: 80015]**가 떴나요? 로봇이 충전기나 설비 앞에서 **비스듬하게 틀어진 채로 멈춰 있는(Symptom)** 상태입니까?\n\n이건 **'Heading Exceeded'** 오류입니다. 쉽게 말해 로봇이 들어갈 각도가 안 나오는데 억지로 들어가려다 걸린 겁니다.\n\n지금 상태에서 무조건 '재시작(Retry)' 버튼만 누른다고 해결되지 않습니다. 이미 각도(Skew)가 틀어져 있어서, 제자리에서 다시 시도해봤자 또 에러만 뜹니다.\n\n아래 순서대로 조치해서 로봇을 **'빼냈다가 다시'** 집어넣으세요.\n\n---\n\n### 🛠️ 조치 순서 (Recovery Steps)\n\n**1. 현재 작업 명령부터 취소하세요.**\n*   **Action:** 제어 화면에서 **[Cancel Command]**를 실행하세요. (`PUT /api/command/cancel`)\n*   **Reason:** 진입에 실패한 죽은 명령을 계속 잡고 있으면 다음 동작이 안 됩니다. 일단 꼬인 명령부터 끊어줘야 합니다.\n\n**2. 로봇을 도킹 구역 밖으로 빼내세요 (Undock).**\n*   **Action:** 수동 조작이나 명령을 통해 **[Undock_Point]**로 로봇을 후진 이동시키세요. (`PUT /api/command/move`)\n*   **Reason:** 이게 핵심입니다. 로봇이 차체를 다시 똑바로 정렬하려면 **공간**이 필요합니다. 좁은 곳에 끼인 상태로는 각도를 못 맞추니, 넓은 곳으로 완전히 빼내야 합니다.\n\n**3. 미션을 다시 내려서 '똑바로' 진입시키세요.**\n*   **Action:** 로봇이 밖으로 나왔으면 **[Retry Command]**를 전송하세요. (`PUT /api/Command/retrycommand`)\n*   **Reason:** 이제 정렬할 거리가 확보되었습니다. 로봇이 멀리서부터 라인을 타고 정확한 각도로 다시 진입할 겁니다.\n\n**4. 자동 운전 모드로 복귀시키세요.**\n*   **Action:** 로봇 상태가 **[Auto]**인지 최종 확인하세요. (`PUT /api/command/mode`)\n*   **Reason:** 조치 다 해놓고 수동(Manual)에 놔두면 로봇이 일을 안 하겠죠?\n\n---\n\n### ⚠️ 현장 안전 주의사항 (Safety First)\n\n*   **후방 사각지대 주의:** 2번 단계에서 **로봇을 후진(Undock)시킬 때가 가장 위험**합니다. 로봇 뒤쪽에 자재 박스나 다른 작업자가 없는지 **반드시 눈으로 직접 확인**하고 이동 버튼을 누르세요. 센서만 믿다가 뒤에 있는 물건 박살 냅니다.\n*   **무리한 진입 금지:** 만약 Undock 후 재진입했는데도 똑같은 80015 에러가 뜬다면, 바닥에 이물질이 있거나 유도 라인(마그네틱/QR 등)이 손상된 것일 수 있습니다. 그때는 억지로 넣지 말고 나를 부르세요."}]}
# 2026-01-12 11:49:18.375 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80015] Heading Exceeded 에러 발생. 현장 대응 방법 요약 좀.'}, {'role': 'assistant', 'content': '<think>\n사용자가 \'80015\' 에러 발생 직후의 현장 대응 가이드를 긴급히 요청했다.\n현재 상황은 \'도킹 시도 중 AMR의 진입 각도(Heading)가 허용 오차 범위를 초과하여 진입이 차단된 상태.\' 상태이므로, 신속한 복구를 위해 작업자가 즉시 수행해야 할 행동 지침(Action Item) 위주로 답변을 구성해야 한다.\n특히 \'이미 진입 각도가 틀어진 상태(Skew)이므로 단순 재시도는 실패함. Undock으로 도킹 구역을 완전히 빠져나와 차체 정렬을 초기화한 후 똑바로 재진입해야 함.\' 이슈를 해결하기 위한 구체적인 조작법과 주의사항을 강조하여 설명한다.\n</think>\n\n## 🔧 현장 트러블슈팅 가이드: 도킹 진입 각도 초과 (Error 80015)\n\n**수신:** 신입 사원 (현장 오퍼레이터)\n**발신:** 기술 선임 (Senior Technician)\n\n---\n\n### 1. 상황 인식 (Situation Awareness)\n"어이 김신입, 지금 HMI 화면에 **[Error Code: 80015]**가 떴나요?\n로봇이 충전기나 설비 앞에서 **진입하지 못하고 멈춰 있는(Symptom)** 상태인가요?"\n\n그렇다면 이건 **\'Heading Exceeded\'** 오류입니다. 쉽게 말해 로봇이 도킹 구역으로 들어가려는데, **진입 각도가 너무 삐딱해서(Skew)** 시스템이 안전을 위해 진입을 막은 겁니다.\n\n### 2. 조치 방법 (Action Steps)\n당황하지 말고 아래 순서대로 딱딱 진행하세요. 이 상황에선 그냥 재시도(Retry)만 누르면 100% 또 에러 납니다.\n\n**Step 1. 기존 작업 취소하기**\n*   가장 먼저 HMI에서 **[작업 취소(Cancel)]** 버튼을 누르세요.\n*   **이유:** 이미 각도가 틀어진 상태에서 억지로 진행하려는 현재의 미션을 끊어줘야 합니다.\n\n**Step 2. 로봇 뒤로 빼기 (Undock)**\n*   수동 조작 메뉴나 명령창에서 **[Undock]** 기능을 실행하세요. (또는 지정된 \'Undock_Point\'로 이동 명령)\n*   **이유:** 로봇이 도킹 구역을 **완전히 빠져나와야** 차체 정렬을 초기화할 수 있습니다. 좁은 곳에서 제자리 회전하려고 하면 더 꼬입니다.\n\n**Step 3. 미션 재할당 및 재진입**\n*   로봇이 밖으로 완전히 나왔다면, 다시 **[미션 재시도(Retry Command)]**를 누르세요.\n*   **이유:** 이제 로봇이 넓은 공간에서 정면을 바라보고 \'똑바로\' 다시 진입을 시도할 겁니다.\n\n**Step 4. 모드 확인**\n*   마지막으로 상단 상태바에 **[Auto Mode]**가 정상적으로 켜졌는지 확인하세요.\n\n### 3. 현장 주의사항 (Safety Check)\n> **⚠️ 잠깐! 버튼 누르기 전에 뒤를 보세요!**\n>\n> **Step 2(Undock)**를 실행할 때 로봇이 **후진**으로 빠져나옵니다.\n> 로봇 뒤쪽 사각지대에 **적재물이나 사람이 없는지 반드시 눈으로 확인**한 후 명령을 내리세요. 각도가 틀어진 상태라 예상보다 넓게 회전하며 후진할 수 있습니다. 충돌 주의하세요'}]}
# 2026-01-12 11:49:37.581 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80015] 트러블슈팅 가이드.'}, {'role': 'assistant', 'content': '<think>\n사용자가 \'80015\' 에러 발생 직후의 현장 대응 가이드를 긴급히 요청했다.\n현재 상황은 \'도킹 시도 중 AMR의 진입 각도(Heading)가 허용 오차 범위를 초과하여 진입이 차단된 상태.\' 상태이므로, 신속한 복구를 위해 작업자가 즉시 수행해야 할 행동 지침(Action Item) 위주로 답변을 구성해야 한다.\n특히 \'이미 진입 각도가 틀어진 상태(Skew)이므로 단순 재시도는 실패함. Undock으로 도킹 구역을 완전히 빠져나와 차체 정렬을 초기화한 후 똑바로 재진입해야 함.\' 이슈를 해결하기 위한 구체적인 조작법과 주의사항을 강조하여 설명한다.\n</think>\n\n# 🔧 현장 트러블슈팅 가이드: AMR 도킹 진입 각도 오류 (Error 80015)\n\n어이 신입, 당황하지 말고 화면부터 보세요.\n지금 HMI 화면에 **[Error Code: 80015 (Heading Exceeded)]**가 떴나요?\n로봇이 충전기나 설비에 도킹하려다가 **[비스듬하게 진입해서 멈춰버린]** 상태입니까?\n\n이건 로봇이 "너무 삐딱해서 더 이상 못 들어가겠다"고 손을 든 겁니다. 이 상태에서 그냥 \'재시도\'만 누르면 로봇은 틀어진 각도 그대로 다시 들이받으려고 할 겁니다.\n\n자, 아래 순서대로 조치해서 로봇을 **\'똑바로\'** 만들어줍시다.\n\n---\n\n### 1단계: 상황 파악 및 작업 중단\n가장 먼저 **[작업 취소(Cancel)]** 버튼을 누르세요.\n*   **이유:** 이미 진입 각도가 허용 범위를 넘었습니다(Skew). 현재 물려있는 미션을 취소해서 로봇이 억지로 진입하려는 시도를 멈춰야 합니다.\n    *   *(API: GET /api/object/status 확인 후 PUT /api/command/cancel)*\n\n### 2단계: 위치 초기화 (Undock)\n수동 조작 메뉴에서 **[Undock_Point로 이동]** 명령을 내리세요.\n*   **이유:** 차체 정렬을 다시 하려면 공간이 필요합니다. 도킹 구역을 완전히 빠져나와야 로봇이 다시 라인을 잡고 똑바로 진입할 수 있습니다. 어설프게 제자리 회전시키지 말고 확실하게 뒤로 빼세요.\n    *   *(API: PUT /api/command/move, Target: Undock_Point)*\n\n### 3단계: 미션 재할당 (Retry)\n로봇이 도킹 구역 밖으로 완전히 나왔다면, **[미션 재시도(Retry Command)]**를 입력하세요.\n*   **이유:** 이제 로봇이 정면을 바라볼 공간이 확보되었습니다. 다시 명령을 주면 이번에는 올바른 각도로 진입할 겁니다.\n    *   *(API: GET /api/Object/Mission 확인 후 PUT /api/Command/retrycommand)*\n\n### 4단계: 정상 가동 확인\n마지막으로 로봇 상태가 **[Auto 모드]**로 변경되었는지 확인하세요.\n*   **이유:** 트러블슈팅 과정에서 Manual로 바뀌었을 수 있습니다. Auto로 돌려놔야 작업을 계속 수행합니다.\n    *   *(API: PUT /api/command/mode -> Auto)*\n\n---\n\n### ⚠️ [주의사항: 안전 제일]\n**Undock(후진) 명령을 내리기 전에 로봇 뒤쪽을 반드시 육안으로 확인하세요!**\n로봇이 빠져나오면서 뒤에 있는 자재나 사람을 칠 수 있습니다. 센서가 있다고 방심하지 말고, 신입이 직접 **후방 안전 확보** 후 버튼을 누르십시오. 알겠습니까?'}]}
# 2026-01-12 11:50:01.992 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80015] 에러와 관련된 과거 해결 사례를 리포트 형식으로 작성하시오.'}, {'role': 'assistant', 'content': '<think>\n사용자가 \'80015\' 에러의 해결 사례에 대한 분석 리포트를 요청했다.\n과거 사례를 재구성하여, 문제 발생 원인(\'도킹 시도 중 AMR의 진입 각도(Heading)가 허용 오차 범위를 초과하여 진입이 차단된 상태.\')과 당시 적용된 해결 로직(\'1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)\')의 인과관계를 명확히 서술해야 한다.\n이를 통해 해당 절차를 준수해야 하는 공학적/경험적 근거를 제시한다.\n</think>\n\n# [QA 분석 리포트] 도킹 진입 각도 오차(Heading Exceeded) 해결 우수 사례\n\n**작성자:** 설비 보전팀 QA 분석가\n**작성일:** 2023년 10월 24일\n\n---\n\n### 1. 개요 (Incident Overview)\n*   **발생 일시:** 2023년 10월 24일 14:30\n*   **대상 설비:** AMR-L2-04 (물류 2라인 4호기)\n*   **발생 에러:** `Error Code: 80015` (Heading Exceeded)\n*   **증상 (Symptom):** 충전 스테이션 도킹 시도 중, AMR의 진입 각도(Heading)가 허용 오차 범위를 초과하여 진입이 시스템적으로 차단됨. 로봇이 스테이션 앞에서 정지한 상태로 알람 발생.\n\n### 2. 해결 과정 (Resolution Process)\n\n현장 작업자는 알람 발생 즉시 관제 시스템에 접속하여 상황 파악 및 복구 절차를 시작했습니다. 당시 작업자는 해당 에러가 단순 통신 오류가 아닌, **물리적인 진입 각도 틀어짐(Skew)**에 기인한 것임을 정확히 인지하고 다음과 같이 조치했습니다.\n\n1.  **상태 및 원인 파악 (Status Check):**\n    작업자는 먼저 `GET /api/object/status`를 호출하여 현재 로봇의 상태를 조회했습니다. 리턴된 에러 코드가 **80015(Heading Exceeded)**임을 확인한 작업자는, 현재 로봇이 비스듬하게 진입하려다 멈춘 상태이므로 **"제자리에서 단순 재시도(Retry)를 할 경우, 틀어진 각도가 수정되지 않아 또다시 실패할 것"**이라고 정확히 판단했습니다.\n\n2.  **기존 작업 중단 (Cancel Job):**\n    잘못된 각도로 진입하려는 현재의 미션을 강제로 종료하기 위해 `PUT /api/command/cancel`을 실행했습니다. 이를 통해 로봇을 대기(Idle) 상태로 전환하여 새로운 명령을 받을 준비를 마쳤습니다.\n\n3.  **물리적 후진 및 정렬 초기화 (Undock - Key Step):**\n    이 단계가 가장 핵심적인 조치였습니다. 작업자는 로봇의 차체를 정렬하기 위해 `PUT /api/command/move` 명령을 사용하여 타겟을 **\'Undock_Point(도킹 구역 밖의 지정된 대기 지점)\'**로 설정했습니다. 로봇이 도킹 구역을 완전히 빠져나오게 함으로써, 틀어졌던 진입 각도를 물리적으로 초기화하고 직선 진입로를 다시 확보했습니다.\n\n4.  **미션 재할당 (Retry Command):**\n    로봇이 Undock 지점에 정렬된 것을 확인한 후, 작업자는 `GET /api/Object/Mission`으로 수행 중이던 미션 데이터를 불러왔습니다. 이후 `PUT /api/Command/retrycommand`를 전송하여 로봇이 올바른 각도로 다시 도킹을 시도하도록 지시했습니다.\n\n5.  **모드 복구 (Restore Mode):**\n    마지막으로 `PUT /api/command/mode`를 호출하여 로봇을 \'Auto\' 모드로 전환, 정상적인 물류 흐름에 복귀시켰습니다. 로봇은 정렬된 각도로 재진입하여 단 한 번의 시도 만에 도킹에 성공했습니다.\n\n### 3. 결론 (Conclusion)\n\n이 사례에서 보듯, **[Error Code: 80015] 발생 시에는 반드시 [Undock(물리적 후진을 통한 정렬 초기화)] 단계를 수행해야 합니다.**\n\n단순 에러 리셋만으로는 틀어진 진입 각도가 수정되지 않아 에러가 반복되므로, 작업자는 반드시 로봇을 도킹 구역 밖으로 이동시켜 진입 경로를 재설정하는 과정을 준수해야 합니다.'}]}
# 2026-01-12 11:50:24.472 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80015] Heading Exceeded 발생 시 올바른 조치 과정을 담은 사고 분석 보고서를 써주세요.'}, {'role': 'assistant', 'content': '<think>\n사용자가 \'80015\' 에러의 해결 사례에 대한 분석 리포트를 요청했다.\n과거 사례를 재구성하여, 문제 발생 원인(\'도킹 시도 중 AMR의 진입 각도(Heading)가 허용 오차 범위를 초과하여 진입이 차단된 상태.\')과 당시 적용된 해결 로직(\'1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)\')의 인과관계를 명확히 서술해야 한다.\n이를 통해 해당 절차를 준수해야 하는 공학적/경험적 근거를 제시한다.\n</think>\n\n# [QA Report] 표준 복구 로직 준수를 통한 도킹 에러(80015) 해결 우수 사례\n\n**작성자:** 설비 보전팀 QA 분석가\n**작성일:** 2023년 10월 27일\n**문서 번호:** QA-REC-231027-04\n\n---\n\n### 1. 개요 (Incident Overview)\n*   **발생 일시:** 2023년 10월 24일 14:35\n*   **대상 설비:** AMR-L2-04 (물류 이송 로봇 4호기)\n*   **발생 에러:** **[Error Code: 80015] Heading Exceeded**\n*   **증상 (Symptom):**\n    충전 스테이션 도킹을 시도하던 AMR이 진입 지점에서 멈춰 선 상태로 알람을 발생시켰습니다. 육안 확인 결과, 로봇의 전면부가 도킹 가이드라인 대비 약 15도 이상 틀어져 있어(Skew), 진입 허용 오차 범위를 초과하여 안전 시스템에 의해 진입이 차단된 상태였습니다.\n\n---\n\n### 2. 해결 과정 (Resolution Process)\n\n당시 현장 오퍼레이터는 에러 발생 직후 당황하지 않고 표준 운영 절차(SOP)에 따라 침착하게 대응하였습니다. 특히, 단순 에러 리셋이 아닌 **\'진입 각도 재정렬(Realignment)\'의 필요성**을 정확히 인지하고 다음과 같이 조치하였습니다.\n\n**Step 1: 상태 진단 및 원인 파악**\n오퍼레이터는 먼저 콘솔을 통해 `GET /api/object/status`를 호출하여 현재 로봇의 상태를 조회했습니다. 반환된 상태 값에서 **Error Code 80015 (Heading Exceeded)**를 확인한 작업자는, 이것이 단순 센서 오류가 아니라 로봇의 진입 각도가 물리적으로 틀어진 상황임을 파악했습니다.\n\n**Step 2: 기존 작업 중단**\n이미 각도가 틀어진 상태에서의 무리한 진입 시도는 하드웨어 충돌로 이어질 수 있음을 인지한 작업자는, 즉시 `PUT /api/command/cancel`을 전송하여 로봇이 수행 중이던 잘못된 도킹 프로세스를 완전히 중단시켰습니다.\n\n**Step 3: 물리적 후진 및 정렬 초기화 (핵심 조치)**\n작업자는 **"이미 각도가 틀어진(Skew) 상태이므로 제자리 재시도는 무의미하다"**는 점을 정확히 판단했습니다. 이에 따라 로봇을 도킹 구역 밖으로 완전히 빼내어 차체를 정렬하기 위해 `PUT /api/command/move` 명령을 전송, 타겟을 **\'Undock_Point\'**로 설정하여 로봇을 물리적으로 후진시켰습니다. 이 과정을 통해 로봇은 틀어진 각도를 바로잡고 진입을 위한 직선 경로를 확보할 수 있었습니다.\n\n**Step 4: 미션 재할당 및 재진입**\n로봇이 Undock 위치에서 정렬을 마친 것을 확인한 후, 작업자는 `GET /api/Object/Mission`으로 기존 수행 미션 정보를 불러왔습니다. 이후 `PUT /api/Command/retrycommand`를 전송하여 로봇이 올바른 각도로 다시 도킹을 시도하도록 유도했습니다.\n\n**Step 5: 자동 운전 모드 복구**\n재진입 시도가 정상적으로 이루어지고 도킹이 완료되자, 작업자는 마지막으로 `PUT /api/command/mode` (Payload: Auto)를 전송하여 로봇을 시스템 관제 하의 자동 운전 모드로 복귀시키며 상황을 종료했습니다.\n\n---\n\n### 3. 결론 (Conclusion)\n\n본 사례는 작업자가 에러 코드의 의미를 정확히 이해하고 상황에 맞는 물리적 조치를 수행하여 설비 가동 중단을 최소화한 모범 사례입니다.\n\n이 사례에서 보듯, **[Error Code: 80015] 발생 시에는 단순 재시도가 아닌, 반드시 [Undock을 통한 물리적 후진 및 정렬 초기화] 단계를 선행해야 함**을 다시 한번 강조합니다. 이는 충돌 사고를 예방하고 복구 시간을 단축하는 핵심 절차입니다.'}]}
# 2026-01-12 11:50:46.146 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[80015] 에러 대응 이력 리포트 생성.'}, {'role': 'assistant', 'content': '<think>\n사용자가 \'80015\' 에러의 해결 사례에 대한 분석 리포트를 요청했다.\n과거 사례를 재구성하여, 문제 발생 원인(\'도킹 시도 중 AMR의 진입 각도(Heading)가 허용 오차 범위를 초과하여 진입이 차단된 상태.\')과 당시 적용된 해결 로직(\'1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)\')의 인과관계를 명확히 서술해야 한다.\n이를 통해 해당 절차를 준수해야 하는 공학적/경험적 근거를 제시한다.\n</think>\n\n# 설비 보전팀 QA 분석 리포트: 에러 대응 성공 사례\n\n**작성자:** QA 분석가 (Quality Assurance Analyst)\n**주제:** Error 80015 (Heading Exceeded) 발생 시 표준 복구 절차 준수 사례\n\n---\n\n### 1. 개요 (Overview)\n\n*   **발생 일시:** 2023년 10월 24일, 14:15\n*   **대상 설비:** AMR-L2-04 (Line 2 Logistics Unit)\n*   **발생 에러:** `Error Code: 80015` (Name: Heading Exceeded)\n*   **증상 (Symptom):** 충전 스테이션 도킹 시도 중, AMR의 진입 각도(Heading)가 허용 오차 범위를 벗어나 안전 인터락에 의해 진입이 차단되고 정지됨.\n\n---\n\n### 2. 해결 과정 (Recovery Process Analysis)\n\n오후 2시 15분경, AMR-L2-04 호기가 도킹 스테이션 앞에서 비정상적으로 정지해 있다는 알람이 관제실에 접수되었습니다. 담당 오퍼레이터는 즉시 매뉴얼에 명시된 **[Recovery Logic]**에 따라 침착하게 대응을 시작했습니다.\n\n가장 먼저 오퍼레이터는 **`GET /api/object/status`**를 호출하여 설비의 정확한 상태를 진단했습니다. 리턴된 값에서 **Error Code 80015 (Heading Exceeded)**를 확인한 작업자는, 이 상황이 단순한 통신 오류나 일시적 장애가 아님을 직감했습니다.\n\n작업자는 **"진입 각도가 이미 틀어진 상태(Skew)에서는 제자리에서 재시도(Retry)를 해도 물리적으로 진입이 불가능하다"**는 80015 에러의 핵심 원인을 정확히 파악하고 있었습니다. 따라서 무의미한 재시도 대신, 선행 작업을 초기화하기 위해 **`PUT /api/command/cancel`**을 전송하여 꼬여버린 기존 작업을 우선 중단시켰습니다.\n\n이후 가장 중요한 단계인 \'차체 정렬 초기화\'를 수행했습니다. 작업자는 로봇이 도킹 구역을 완전히 빠져나와 자세를 바로잡을 수 있도록 **`PUT /api/command/move`** 명령어를 사용하여 타겟을 **\'Undock_Point\'**로 설정했습니다. 로봇은 후진하여 넓은 공간으로 이동했고, 이를 통해 틀어졌던 진입 각도를 물리적으로 초기화했습니다.\n\nAMR이 정렬된 위치(Undock Point)에 도착한 것을 확인한 작업자는 **`GET /api/Object/Mission`**으로 보류되었던 미션 정보를 확인한 뒤, **`PUT /api/Command/retrycommand`**를 전송하여 도킹을 처음부터 다시 시도하도록 지시했습니다. 직선주로에서 올바른 각도로 재진입한 AMR은 성공적으로 도킹에 성공하였으며, 마지막으로 **`PUT /api/command/mode (Auto)`**를 입력하여 설비를 자동 운전 모드로 복귀시켰습니다.\n\n---\n\n### 3. 결론 (Conclusion)\n\n본 사례는 작업자가 에러 코드의 의미를 정확히 이해하고, 물리적인 위치 보정 없이는 해결될 수 없음을 인지하여 신속하게 대처한 모범 사례입니다.\n\n이 사례에서 보듯, **[Error Code: 80015] 발생 시에는 단순 재시도가 아닌, 반드시 [Undock을 통한 차체 정렬 초기화] 단계를 수행해야 함**을 다시 한번 강조합니다.'}]}
# 2026-01-12 11:51:02.659 | INFO     | __main__:<module>:71 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': 'Error 80015(Heading Exceeded) 발생 시, 제자리에서 각도만 보정하여 즉시 재시도하지 않고 반드시 Undock(물리적 후진) 절차를 선행해야 하는 기술적 이유는 무엇입니까?'}, {'role': 'assistant', 'content': "<think>\n사용자가 '80015' 에러 처리 과정의 기술적 원리와 당위성에 대해 질문했다.\n사용자는 특정 단계(예: Undock, Payload Update 등)가 왜 필요한지 궁금해하고 있다.\n따라서 '이미 진입 각도가 틀어진 상태(Skew)이므로 단순 재시도는 실패함. Undock으로 도킹 구역을 완전히 빠져나와 차체 정렬을 초기화한 후 똑바로 재진입해야 함.'이라는 시스템적 배경을 근거로 들어, 해당 로직이 필수적인 이유를 논리적으로 설명한다.\n</think>\n\n80015 에러는 AMR이 도킹 스테이션 진입 허용 각도를 이미 벗어난 상태(Skew)임을 의미합니다. 이 위치에서 무리하게 제자리 회전을 시도할 경우, 도킹 구조물과의 물리적 충돌 위험이 있으며 센서가 정렬 마커를 정확히 인식하기 어렵습니다. 따라서 차체 정렬(Alignment)을 초기화하고 올바른 진입 벡터를 다시 확보하기 위해 도킹 구역을 완전히 벗어나는 Undock 과정이 필수적입니다.\n\n전체 복구 로직은 [상태 확인(GET) -> 작업 취소(Cancel) -> Undock(물리적 후진 및 정렬 초기화) -> 미션 재할당(Retry) -> 모드 복구(Auto)] 순으로 진행되어 안전한 재진입을 보장합니다."}]}
# 2026-01-12 11:51:17.279 | INFO     | __main__:<module>:71 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '80015 (Heading Exceeded) 에러 발생 시, 현재 위치에서 즉시 재시도(Retry)하지 않고 반드시 Undock(물리적 후진) 절차를 선행해야 하는 기술적 이유는 무엇입니까?'}, {'role': 'assistant', 'content': "<think>\n사용자가 '80015' 에러 처리 과정의 기술적 원리와 당위성에 대해 질문했다.\n사용자는 특정 단계(예: Undock, Payload Update 등)가 왜 필요한지 궁금해하고 있다.\n따라서 '이미 진입 각도가 틀어진 상태(Skew)이므로 단순 재시도는 실패함. Undock으로 도킹 구역을 완전히 빠져나와 차체 정렬을 초기화한 후 똑바로 재진입해야 함.'이라는 시스템적 배경을 근거로 들어, 해당 로직이 필수적인 이유를 논리적으로 설명한다.\n</think>\n\n80015 에러는 AMR의 도킹 진입 각도(Heading)가 이미 허용 오차 범위를 벗어나 물리적으로 비스듬한(Skew) 상태임을 의미합니다. 이 위치에서 단순 재시도를 수행할 경우, 소프트웨어 보정 한계를 초과한 상태이므로 진입 실패가 반복되거나 설비와 충돌할 위험이 있습니다. 따라서 'Undock'을 통해 도킹 구역을 완전히 빠져나와 차체 정렬을 초기화한 후, 정면에서 다시 진입하는 것이 필수적입니다. 전체 복구 로직은 [상태 확인 및 작업 취소 -> Undock(정렬 초기화) -> 미션 재할당 -> 모드 복구]의 흐름으로 구성됩니다."}]}
# 2026-01-12 11:51:32.548 | INFO     | __main__:<module>:71 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': "80015(Heading Exceeded) 에러 발생 시, 현재 위치에서 즉시 재시도하지 않고 반드시 'Undock' 단계를 거쳐 후진해야 하는 기술적 이유는 무엇입니까?"}, {'role': 'assistant', 'content': "<think>\n사용자가 '80015' 에러 처리 과정의 기술적 원리와 당위성에 대해 질문했다.\n사용자는 특정 단계(예: Undock, Payload Update 등)가 왜 필요한지 궁금해하고 있다.\n따라서 '이미 진입 각도가 틀어진 상태(Skew)이므로 단순 재시도는 실패함. Undock으로 도킹 구역을 완전히 빠져나와 차체 정렬을 초기화한 후 똑바로 재진입해야 함.'이라는 시스템적 배경을 근거로 들어, 해당 로직이 필수적인 이유를 논리적으로 설명한다.\n</think>\n\n80015 에러는 AMR의 진입 각도가 허용 오차를 벗어나 비스듬하게(Skewed) 진입했음을 의미합니다. 이 상태에서는 도킹 가이드와의 물리적 간섭이나 센서 사각지대 문제로 인해 제자리 회전만으로는 정렬 보정이 불가능합니다. 따라서 **Undock**을 통해 도킹 구역을 완전히 벗어나, 로봇이 직선 진입 벡터를 다시 계산할 수 있는 공간을 확보하는 것이 필수적입니다. 전체 복구 절차는 **[상태 확인 → 작업 취소 → Undock(정렬 초기화) → 미션 재할당 → Auto 모드 복구]** 순으로 진행되어야 안전한 재진입을 보장할 수 있습니다."}]}
# 2026-01-12 11:51:49.896 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': 'BMA 공정에서 발생하는 [10015] IR Detection Fail 에러의 표준 처리 절차(SOP)를 서술하시오.'}, {'role': 'assistant', 'content': "<think>\n사용자가 '10015 IR Detection Fail' 에러 상황에 대한 공식적인 표준 복구 절차(SOP)를 요청했다.\n이 에러는 '설비 도그플레이트 파손이나 위치 틀어짐이 원인일 수 있음. Undock으로 빠져나와 센서 감지 범위를 리셋하고, 재진입 시 IR 센서가 정상적으로 신호를 잡는지 다시 확인해야 함.'이(가) 주 원인이므로, 단순 재시도가 아닌 '1. 상태 확인: GET /api/object/status (에러 및 미션 확인)\n    2. 작업 취소: PUT /api/command/cancel (기존 작업 중단)\n    3. 물리적 후진(Undock): PUT /api/command/move (Target: Undock_Point)\n    4. 미션 재할당: GET /api/Object/Mission -> PUT /api/Command/retrycommand\n    5. 모드 복구: PUT /api/command/mode (Auto)' 로직을 적용해야 한다.\n이에 따라 BMA 공정의 안전 규정과 표준 프로토콜을 준수하는 기술 문서를 작성하여 제시한다.\n</think>\n\n# 표준 절차: [10015] IR Detection Fail 복구\n\n**개요:**\n본 문서는 AMR 하부 IR 센서가 설비 스토퍼(Dog Plate)를 감지하지 못하여 도킹 위치를 확정할 수 없는 상황(Error Code: 10015)에 대한 표준 복구 절차를 기술한다. 설비 도그플레이트의 물리적 상태(파손, 위치 틀어짐) 확인 및 센서 재인식을 위한 재진입 과정을 포함한다.\n\n---\n\n### 1. 상태 및 에러 확인\n*   **목적:** 현재 발생한 에러 코드(10015)와 중단된 미션의 상세 정보를 파악한다.\n*   **수행:** `GET /api/object/status`를 호출하여 시스템 상태 및 에러 로그를 확인함.\n\n### 2. 기존 작업 중단\n*   **목적:** IR 센서 미감지로 인해 현재의 도킹 시도가 유효하지 않으므로 작업을 중지한다.\n*   **수행:** `PUT /api/command/cancel`을 실행하여 진행 중인 모든 명령을 취소함.\n\n### 3. 물리적 후진 (Undock)\n*   **목적:** 센서 감지 범위를 리셋하고, 재진입을 통해 IR 센서가 정상적으로 신호를 잡는지 확인하기 위한 시야와 거리를 확보한다.\n*   **수행:** `PUT /api/command/move` (Target: Undock_Point)를 호출하여 AMR을 설비로부터 안전하게 후진시킴.\n\n### 4. 미션 재할당 및 재진입 시도\n*   **목적:** 초기화된 위치에서 다시 진입하여 설비 도그플레이트 감지 및 도킹 위치 확정을 재시도한다.\n*   **수행:** `GET /api/Object/Mission`으로 기존 미션 정보를 로드한 뒤, `PUT /api/Command/retrycommand`를 실행하여 미션을 재시작함.\n\n### 5. 자동 운전 모드 복구\n*   **목적:** 복구 절차 완료 후 시스템을 정상 운영 상태로 전환한다.\n*   **수행:** `PUT /api/command/mode` (Auto)를 호출하여 AMR을 자동 모드로 복귀시킴."}]}
# ...
# 2026-01-12 13:15:39.191 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[Sensor Error] 트러블슈팅 가이드.'}, {'role': 'assistant', 'content': "<think>\n사용자가 'Sensor Error' 에러 발생 직후의 현장 대응 가이드를 긴급히 요청했다.\n현재 상황은 '물건이 있는데 센서가 안 켜지거나(미감지), 물건이 없는데 센서가 켜짐(잔류).' 상태이므로, 신속한 복구를 위해 작업자가 즉시 수행해야 할 행동 지침(Action Item) 위주로 답변을 구성해야 한다.\n특히 '하드웨어 점검 필요. 'Payload Clear' 후 로봇을 점검 구역으로 빼내야 하며, 절대 그대로 자동 운행을 시키면 안 됨 (유령 재고 발생 위험).' 이슈를 해결하기 위한 구체적인 조작법과 주의사항을 강조하여 설명한다.\n</think>\n\n# [현장 가이드] On-board Sensor Fail 조치 매뉴얼\n\n자, 김 사원. 당황하지 말고 화면부터 봅시다.\n지금 HMI 화면에 **[Sensor Error: On-board Sensor Fail]** 알람이 떴나요?\n로봇 위에 **물건이 있는데 센서 감지가 안 되거나, 반대로 빈 로봇인데 센서가 켜져 있는(잔류)** 상태입니까?\n\n이건 로봇의 '눈'인 센서 하드웨어에 문제가 생긴 겁니다. 기계가 거짓말을 하고 있는 상황이니 시스템을 믿지 말고 다음 순서대로 조치하세요.\n\n---\n\n### 1. 작업 중단 및 육안 확인\n가장 먼저 **[작업 취소(Cancel)]** 버튼을 눌러 로봇을 멈추세요.\n*   **이유:** 센서 정보가 틀렸기 때문에 로봇이 엉뚱한 행동을 할 수 있습니다.\n\n그다음, **로봇 상단을 직접 눈으로 확인하세요.**\n*   실제로 박스(SKID)가 있습니까, 없습니까? 이 '실제 상태'가 기준이 됩니다.\n\n### 2. 설비 리셋 (Signal Reset)\nHMI 메뉴에서 **[Dock Reset]**을 누르고, 상태가 **[Dock OK]**로 바뀌는지 확인하세요.\n*   **이유:** 센서 오류로 인해 꼬여있는 PLC 상위 제어 신호를 초기화해줘야 다음 명령이 먹힙니다.\n\n### 3. 데이터 동기화 (Payload Update) - **[중요]**\n방금 눈으로 확인한 실제 화물 상태에 맞춰 시스템 값을 수동으로 고쳐야 합니다.\n*   **실제 화물이 있는 경우:** 시스템 상의 상태를 **[Full / Loaded]**로 변경하세요.\n*   **실제 화물이 없는 경우:** 시스템 상의 상태를 **[Empty]**로 변경하세요.\n*   **이유:** 이걸 안 맞추면 전산상에만 물건이 존재하는 **'유령 재고'**가 발생하거나, 물건이 있는데 또 적재하려는 충돌 사고가 납니다.\n\n### 4. 작업 강제 완료 및 점검 구역 이동\n데이터를 맞췄으면 **[강제 완료(Job Complete)]**를 눌러 현재 잡혀있는 작업을 전산상으로 끝내버리세요.\n그 후, 로봇을 수동 조작하여 **점검 구역(Maintenance Zone)으로 빼내세요.**\n\n---\n\n### ⚠️ 선임의 당부 (주의사항)\n**절대 이 상태에서 '자동 운전(Auto Resume)'을 바로 걸지 마세요!**\n이 에러는 센서 하드웨어(배선, 단선, 센서 파손 등)를 수리하기 전까지는 계속 재발합니다. Payload 정보만 맞추고 바로 투입하면 또 에러가 뜨거나 재고가 꼬이게 됩니다. 반드시 하드웨어 교체나 수리가 끝난 뒤에 라인에 복귀시키세요. 알겠죠?"}]}
# 2026-01-12 13:16:05.750 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[Sensor Error] 에러와 관련된 과거 해결 사례를 리포트 형식으로 작성하시오.'}, {'role': 'assistant', 'content': '<think>\n사용자가 \'Sensor Error\' 에러의 해결 사례에 대한 분석 리포트를 요청했다.\n과거 사례를 재구성하여, 문제 발생 원인(\'물건이 있는데 센서가 안 켜지거나(미감지), 물건이 없는데 센서가 켜짐(잔류).\')과 당시 적용된 해결 로직(\'1. 상태 확인: GET /api/object/status (LoadedState: 0=Empty, 3=Full 확인)\n    2. 작업 취소: PUT /api/command/cancel (ACS Job 중단)\n    3. 적재물 확인: 실제 로봇 상단에 화물(SKID/Box)이 있는지 육안 확인 (필수)\n    4. 설비 리셋: PUT /api/plc/placecommand (Command: "dock_reset" -> "dock_ok")\n    5. 데이터 동기화: PUT /api/command/payload (실제 화물 상태에 맞춰 시스템 값 덮어쓰기)\n    6. 작업 완료/재개: 상황에 따라 PUT /api/command/jobcomplete (강제 완료) 또는 Auto Mode 복귀\')의 인과관계를 명확히 서술해야 한다.\n이를 통해 해당 절차를 준수해야 하는 공학적/경험적 근거를 제시한다.\n</think>\n\n**[QA 성공 사례 리포트: On-board Sensor Fail 대응 및 유령 재고 방지]**\n\n**작성자:** 설비 보전팀 QA 분석가\n**작성일:** 202X년 X월 X일\n\n---\n\n### 1. 개요 (Incident Overview)\n\n*   **발생 일시:** 2024년 05월 20일 14:15\n*   **대상 설비:** AGV-R05 (자율주행 운송 로봇 5호기)\n*   **Error Code:** Sensor Error\n*   **Error Name:** On-board Sensor Fail\n*   **Symptom (증상):** 로봇 상단에 적재물이 없는 공차(Empty) 상태임에도 불구하고, 화물 감지 센서가 지속적으로 `ON` 상태를 유지하여 다음 작업 할당이 불가능한 상태(잔류 오인식).\n\n---\n\n### 2. 해결 과정 (Resolution Process)\n\n당시 현장 오퍼레이터는 AGV-R05가 작업을 마친 후 대기 장소로 이동하지 못하고 정지해 있는 것을 발견했습니다. 오퍼레이터는 당황하지 않고 **[Recovery Logic]**에 의거하여 다음과 같이 단계별 조치를 수행했습니다.\n\n1.  **상태 데이터 확인 (Logic 1):**\n    가장 먼저 관제 시스템을 통해 `GET /api/object/status`를 조회했습니다. 시스템상 로봇의 `LoadedState`는 `0`(Empty)이었으나, 센서 신호가 불안정함을 확인했습니다.\n\n2.  **작업 중단 및 안전 확보 (Logic 2):**\n    센서 오작동으로 인한 오주행을 방지하기 위해 즉시 `PUT /api/command/cancel`을 전송하여 현재 수행 중이던 ACS Job을 안전하게 중단시켰습니다.\n\n3.  **육안 확인 및 원인 파악 (Logic 3 & Reasoning):**\n    **이 단계가 가장 중요했습니다.** 오퍼레이터는 로봇으로 직접 이동하여 상단에 실제 화물이 있는지 육안으로 확인했습니다. 확인 결과 화물은 없었으나(Empty), 센서 표면에 먼지가 두껍게 쌓여 있어 센서가 물체를 감지한 것으로 오인하고 있음을 파악했습니다. 이는 **하드웨어 점검이 필요한 상황**임을 의미했습니다.\n\n4.  **설비 리셋 (Logic 4):**\n    센서 오류로 락(Lock)이 걸린 상태를 해제하기 위해 `PUT /api/plc/placecommand`를 호출했습니다. 먼저 `dock_reset` 커맨드로 에러를 클리어하고, 이어 `dock_ok`를 전송하여 통신 상태를 정상화했습니다.\n\n5.  **데이터 동기화 (Logic 5):**\n    센서가 여전히 오작동 중이었으므로 시스템이 혼란을 겪을 수 있었습니다. 오퍼레이터는 육안 확인 결과(공차)를 신뢰하여 `PUT /api/command/payload`를 실행, 강제로 시스템상의 적재 상태를 \'Empty\'로 덮어씌워 **데이터 정합성**을 맞췄습니다.\n\n6.  **하드웨어 조치 및 완료 (Logic 6 & Reasoning):**\n    오퍼레이터는 **"하드웨어 점검 필요 시 절대 그대로 자동 운행을 시키면 안 된다"**는 핵심 수칙을 기억했습니다. 즉시 자동 운행을 재개할 경우 \'유령 재고(Ghost Inventory)\'가 발생하거나, 이동 중 센서 오류로 급정거할 위험이 있었기 때문입니다.\n    따라서 `PUT /api/command/jobcomplete`로 시스템상 작업만 완료 처리를 한 뒤, 로봇을 **수동 모드**로 전환하여 점검 구역(Maintenance Zone)으로 이동시켰습니다. 이후 센서 클리닝을 마치고 나서야 정상 라인에 복귀시켰습니다.\n\n---\n\n### 3. 결론 (Conclusion)\n\n이 사례에서 보듯, **[Sensor Error]** 발생 시에는 시스템 값만 믿지 말고 **반드시 [실제 화물 육안 확인 및 Payload Data 동기화]를 수행해야 합니다.**\n\n특히 이번 사례는 센서 오작동 상황에서 무리하게 자동 운행을 재개하지 않고, **데이터 동기화(\'Payload Clear\') 후 점검 구역으로 이동**시켜 잠재적인 유령 재고 발생 및 2차 사고를 완벽히 예방한 모범적인 대응이었습니다.'}]}
# 2026-01-12 13:16:35.252 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[Sensor Error] On-board Sensor Fail 발생 시 올바른 조치 과정을 담은 사고 분석 보고서를 써주세요.'}, {'role': 'assistant', 'content': '<think>\n사용자가 \'Sensor Error\' 에러의 해결 사례에 대한 분석 리포트를 요청했다.\n과거 사례를 재구성하여, 문제 발생 원인(\'물건이 있는데 센서가 안 켜지거나(미감지), 물건이 없는데 센서가 켜짐(잔류).\')과 당시 적용된 해결 로직(\'1. 상태 확인: GET /api/object/status (LoadedState: 0=Empty, 3=Full 확인)\n    2. 작업 취소: PUT /api/command/cancel (ACS Job 중단)\n    3. 적재물 확인: 실제 로봇 상단에 화물(SKID/Box)이 있는지 육안 확인 (필수)\n    4. 설비 리셋: PUT /api/plc/placecommand (Command: "dock_reset" -> "dock_ok")\n    5. 데이터 동기화: PUT /api/command/payload (실제 화물 상태에 맞춰 시스템 값 덮어쓰기)\n    6. 작업 완료/재개: 상황에 따라 PUT /api/command/jobcomplete (강제 완료) 또는 Auto Mode 복귀\')의 인과관계를 명확히 서술해야 한다.\n이를 통해 해당 절차를 준수해야 하는 공학적/경험적 근거를 제시한다.\n</think>\n\n## [QA Report] On-board Sensor Fail 대응 성공 사례 분석\n\n**작성자:** 설비 보전팀 QA 분석가\n**작성일:** 2024년 05월 20일\n\n---\n\n### 1. 개요 (Incident Overview)\n\n*   **발생 일시:** 2024년 05월 14일 10:45 AM\n*   **대상 설비:** AMR-Unit-104 (물류 이송 로봇)\n*   **발생 에러 (Error Code):** Sensor Error\n*   **에러 명 (Name):** On-board Sensor Fail\n*   **증상 (Symptom):** 로봇 상단에 SKID(화물)가 적재되어 있음에도 불구하고, 센서가 이를 감지하지 못하여 시스템상 `LoadedState: 0 (Empty)`으로 표시되는 \'미감지(False Negative)\' 현상 발생.\n\n### 2. 해결 과정 (Resolution Process)\n\n당시 현장 오퍼레이터는 알람 발생 직후 당황하지 않고 표준 Recovery Logic을 준수하여, 자칫 발생할 수 있었던 \'유령 재고(Ghost Inventory)\' 문제와 설비 충돌 사고를 미연에 방지했습니다. 구체적인 조치 과정은 다음과 같습니다.\n\n1.  **상태 데이터 확인 (Status Check)**\n    오퍼레이터는 먼저 `GET /api/object/status`를 호출하여 로봇의 현재 상태 값을 조회했습니다. 그 결과, 로봇은 작업을 수행 중이었으나 센서 데이터인 `LoadedState`가 `0`(Empty)으로 출력되는 모순을 확인했습니다.\n\n2.  **작업 즉시 중단 (Job Cancel)**\n    센서 값의 신뢰성이 깨진 상태에서 로봇이 계속 움직일 경우, 다음 적재 장소에서 이중 적재로 인한 충돌이 발생할 수 있음을 인지했습니다. 이에 즉시 `PUT /api/command/cancel`을 전송하여 ACS Job을 강제 중단시켰습니다.\n\n3.  **육안 점검 및 원인 파악 (Visual Inspection & Reasoning)**\n    **[핵심 단계]** 오퍼레이터는 모니터링 화면만 믿지 않고 로봇 위치로 이동하여 **육안 확인**을 실시했습니다. 확인 결과, 로봇 상단에는 실제 화물이 존재했습니다.\n    작업자는 이것이 단순한 통신 딜레이가 아닌 **\'하드웨어 센서 고장\'**임을 직감했습니다. 이 상황에서 시스템 값만 강제로 수정하여 자동 운행을 재개할 경우, 추후 센서 오작동으로 인해 화물이 없는 줄 알고 적재를 시도하거나 화물을 떨어뜨릴 위험이 있음을 판단했습니다. 따라서 **"절대 그대로 자동 운행을 시키면 안 된다"**는 지침에 따라 로봇을 점검 구역으로 빼내기로 결정했습니다.\n\n4.  **설비 리셋 (Facility Reset)**\n    로봇과 도킹 설비 간의 에러 상태를 해제하기 위해 `PUT /api/plc/placecommand`를 사용하여 `dock_reset` 명령을 수행 후, 정상 상태인 `dock_ok`로 전환했습니다.\n\n5.  **데이터 동기화 (Data Sync)**\n    로봇을 점검 구역으로 이동시키기 전, 시스템상의 데이터 불일치를 해소해야 했습니다. 현재 화물이 실려있지만 시스템은 없다고 인식하는 상황이므로, `PUT /api/command/payload`를 통해 실제 화물 상태에 맞춰 시스템 값을 덮어썼습니다. (이후 안전을 위해 수동으로 화물을 하역하고 Payload를 다시 Empty로 맞춤)\n\n6.  **작업 완료 및 입고 조치 (Completion & Maintenance)**\n    해당 로봇은 더 이상 자동 운행이 불가능하므로 `PUT /api/command/jobcomplete`를 전송하여 현재 묶여있던 작업을 시스템상에서 종료 처리했습니다. 이후 해당 로봇을 \'수동 모드\'로 전환하여 정비실로 이동시켰으며, 하드웨어 센서 교체 작업을 지시했습니다.\n\n### 3. 결론 (Conclusion)\n\n이 사례에서 보듯, **[Sensor Error] 발생 시에는 반드시 [육안 확인을 통한 실물 대조와 데이터 동기화(Payload Sync)] 단계를 수행해야 합니다.**\n\n특히 On-board Sensor Fail은 시스템 데이터와 물리적 현실이 괴리되는 위험한 상황입니다. 오퍼레이터가 단순히 에러만 리셋하고 자동 운행을 재개했다면 심각한 설비 사고로 이어질 수 있었습니다. 하드웨어 점검이 필요한 상황임을 정확히 인지하고, 로봇을 운영 라인에서 배제(Exclude) 시킨 판단은 매우 모범적인 대응이었습니다.'}]}
# 2026-01-12 13:17:04.869 | INFO     | __main__:<module>:47 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': '[Sensor Error] 에러 대응 이력 리포트 생성.'}, {'role': 'assistant', 'content': '<think>\n사용자가 \'Sensor Error\' 에러의 해결 사례에 대한 분석 리포트를 요청했다.\n과거 사례를 재구성하여, 문제 발생 원인(\'물건이 있는데 센서가 안 켜지거나(미감지), 물건이 없는데 센서가 켜짐(잔류).\')과 당시 적용된 해결 로직(\'1. 상태 확인: GET /api/object/status (LoadedState: 0=Empty, 3=Full 확인)\n    2. 작업 취소: PUT /api/command/cancel (ACS Job 중단)\n    3. 적재물 확인: 실제 로봇 상단에 화물(SKID/Box)이 있는지 육안 확인 (필수)\n    4. 설비 리셋: PUT /api/plc/placecommand (Command: "dock_reset" -> "dock_ok")\n    5. 데이터 동기화: PUT /api/command/payload (실제 화물 상태에 맞춰 시스템 값 덮어쓰기)\n    6. 작업 완료/재개: 상황에 따라 PUT /api/command/jobcomplete (강제 완료) 또는 Auto Mode 복귀\')의 인과관계를 명확히 서술해야 한다.\n이를 통해 해당 절차를 준수해야 하는 공학적/경험적 근거를 제시한다.\n</think>\n\n# [QA 성공 사례 리포트] 센서 오작동에 따른 데이터 불일치 및 유령 재고 방지 사례\n\n**작성자:** 설비 보전팀 QA 분석가\n**작성일:** 2024년 05월 20일\n**문서 번호:** QA-240520-AMR01\n\n---\n\n### 1. 개요 (Incident Overview)\n\n*   **발생 일시:** 2024년 05월 18일 14:15\n*   **대상 설비:** AMR-042 (Transport Unit)\n*   **Error Code:** Sensor Error\n*   **Error Name:** On-board Sensor Fail\n*   **Symptom (증상):**\n    ACS 모니터링 상 해당 로봇은 **\'Empty(빈 상태)\'**로 표시되었으나, 실제 현장에서는 로봇 상단에 자재 박스가 적재되어 있는 상황이었습니다. (물건이 있는데 센서가 감지하지 못하는 미감지 오류)\n\n### 2. 해결 과정 (Resolution Process)\n\n당시 관제 담당자(Operator)는 AMR-042호기에서 **[Sensor Error]** 알람이 발생한 것을 확인했습니다. 담당자는 즉시 매뉴얼의 **[Recovery Logic]**을 실행하였으며, 특히 하드웨어 고장 가능성을 인지하고 침착하게 대응했습니다.\n\n1.  **상태 확인 (Logic 1):**\n    담당자는 먼저 `GET /api/object/status`를 호출하여 로봇의 내부 상태를 조회했습니다. 리턴 값은 `LoadedState: 0` (Empty)이었으나, 에러 코드가 \'Sensor Fail\'임을 감안하여 이 데이터를 신뢰하지 않았습니다.\n2.  **작업 취소 (Logic 2):**\n    로봇이 \'빈 상태\'로 오인되어 다음 적재 작업을 수행하러 이동할 경우 충돌 사고가 발생할 수 있음을 인지하고, 즉시 `PUT /api/command/cancel`을 전송하여 수행 중이던 ACS Job을 중단시켰습니다.\n3.  **적재물 육안 확인 (Logic 3 - Critical):**\n    담당자는 현장으로 이동하여 로봇을 **육안 점검**했습니다. 예상대로 센서는 꺼져 있었으나 실제로는 화물(SKID)이 적재된 상태였습니다. 담당자는 이 단계에서 **"단순 에러 리셋 후 자동 운행 복귀 시, 시스템 상 \'빈 로봇\'으로 인식되어 유령 재고(Ghost Inventory)가 발생하거나 중복 적재 사고가 날 수 있음"**을 정확히 파악했습니다.\n4.  **설비 리셋 (Logic 4):**\n    센서 오류로 인한 인터락을 해제하기 위해 `PUT /api/plc/placecommand`를 사용하여 `dock_reset` 후 `dock_ok` 커맨드를 순차적으로 전송했습니다.\n5.  **데이터 동기화 (Logic 5):**\n    가장 중요한 단계로, 시스템 데이터와 실제 물리적 상태를 일치시켰습니다. 센서가 고장 났더라도 시스템이 화물의 존재를 인지하도록 `PUT /api/command/payload`를 사용하여 강제로 상태 값을 덮어썼습니다. (이 경우, 안전을 위해 화물을 수동으로 내린 후 \'Empty\'로 동기화하거나, 화물이 있는 상태로 \'Full\'로 맞춘 뒤 수동 회수 진행)\n6.  **작업 완료 및 하드웨어 점검 이관 (Logic 6):**\n    데이터 동기화가 완료된 후 `PUT /api/command/jobcomplete`를 통해 전산상의 작업을 마무리했습니다. 담당자는 해당 로봇을 **Auto Mode로 복귀시키지 않고**, 즉시 수동 모드로 전환하여 점검 구역(Maintenance Area)으로 이동시켰습니다. 이는 **[Context/Reasoning]** 지침에 따라 하드웨어 센서 교체 전까지 운행을 배제하기 위함이었습니다.\n\n### 3. 결론 (Conclusion)\n\n본 사례는 작업자가 **[Sensor Error]** 발생 시 시스템 데이터(LoadedState: 0)를 맹신하지 않고, **[육안 확인]**을 통해 실제 화물 유무를 검증한 모범 사례입니다.\n\n이 사례에서 보듯, **[On-board Sensor Fail] 발생 시에는 반드시 `PUT /api/command/payload`를 통한 [데이터 동기화]를 선행하고, 로봇을 점검 구역으로 회수해야 함**을 다시 한번 강조합니다. 이를 통해 유령 재고 발생과 설비 충돌을 완벽하게 예방할 수 있었습니다.'}]}
# 2026-01-12 13:17:23.510 | INFO     | __main__:<module>:71 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': "Sensor Error 발생 시, 단순히 알람을 리셋하고 작업을 재시도하는 대신 반드시 '육안 확인'과 '데이터 동기화(Payload Sync)' 과정을 거쳐야 하는 이유는 무엇입니까?"}, {'role': 'assistant', 'content': "<think>\n사용자가 'Sensor Error' 에러 처리 과정의 기술적 원리와 당위성에 대해 질문했다.\n사용자는 특정 단계(예: Undock, Payload Update 등)가 왜 필요한지 궁금해하고 있다.\n따라서 '하드웨어 점검 필요. 'Payload Clear' 후 로봇을 점검 구역으로 빼내야 하며, 절대 그대로 자동 운행을 시키면 안 됨 (유령 재고 발생 위험).'이라는 시스템적 배경을 근거로 들어, 해당 로직이 필수적인 이유를 논리적으로 설명한다.\n</think>\n\n이 에러의 핵심 위험 요소는 **'물리적 상태와 시스템 데이터의 불일치(Ghost Inventory)'**입니다. 센서 신뢰성이 상실된 상태(False Positive/Negative)에서 자동 운행을 지속할 경우, 로봇이 실물 화물이 있는데도 없다고 판단하여 중복 적재를 시도하거나, 반대로 화물이 없는데 하역을 시도하는 물리적 충돌 사고가 발생할 수 있습니다.\n\n따라서 하드웨어 점검 전까지는 센서 값을 배제하고 운영자가 확인한 '진실(Truth)'을 시스템에 주입해야 합니다. 전체 복구 로직은 **[상태 확인 및 작업 취소]**하여 로봇을 정지시킨 뒤, **[육안 확인]**을 통해 실제 화물 유무를 확정하고, **[설비 리셋]** 후 해당 정보를 바탕으로 **[데이터 동기화(Payload Sync)]**를 수행하여 시스템 정보를 강제로 보정하는 순서로 진행됩니다. 이후 로봇은 즉시 자동 운행에 투입되지 않고 점검 구역으로 이동해야 합니다."}]}
# 2026-01-12 13:17:39.216 | INFO     | __main__:<module>:71 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': 'On-board Sensor Fail 발생 시, 단순히 센서를 리셋하여 재시도하지 않고 반드시 육안으로 적재물을 확인한 후 시스템 데이터를 강제로 동기화(Payload Clear)해야 하는 기술적 이유는 무엇입니까?'}, {'role': 'assistant', 'content': "<think>\n사용자가 'Sensor Error' 에러 처리 과정의 기술적 원리와 당위성에 대해 질문했다.\n사용자는 특정 단계(예: Undock, Payload Update 등)가 왜 필요한지 궁금해하고 있다.\n따라서 '하드웨어 점검 필요. 'Payload Clear' 후 로봇을 점검 구역으로 빼내야 하며, 절대 그대로 자동 운행을 시키면 안 됨 (유령 재고 발생 위험).'이라는 시스템적 배경을 근거로 들어, 해당 로직이 필수적인 이유를 논리적으로 설명한다.\n</think>\n\n해당 에러는 센서 하드웨어의 신뢰성이 상실된 상태(False Positive/Negative)를 의미하기 때문입니다. 이 상황에서 시스템 로직만으로 자동 복구를 시도할 경우, 실물과 데이터가 불일치하는 **'유령 재고(Ghost Inventory)'**가 발생할 치명적 위험이 있습니다. 예를 들어, 실제로는 화물이 존재하나 센서가 미감지(LoadedState=0)하는 상태로 운행될 경우, 다음 적재 작업 시 물리적 충돌이 발생합니다. 따라서 반드시 **[상태 확인 > ACS 작업 취소 > 육안 확인(Ground Truth 확보) > 설비 리셋 > 데이터 동기화(Payload Override) > 작업 완료/점검]**의 흐름을 통해 물리적 상태와 시스템 데이터를 일치시킨 후, 로봇을 점검 구역으로 이동시켜야 합니다."}]}
# 2026-01-12 13:17:55.979 | INFO     | __main__:<module>:71 - {'conversation': [{'role': 'system', 'content': '당신은 BMA 공정 자동화 시스템 전문 엔지니어입니다.'}, {'role': 'user', 'content': 'On-board Sensor Fail 발생 시, 단순히 에러를 리셋하고 재시도(Retry)하지 않고 왜 반드시 작업을 취소한 뒤 육안 확인과 데이터 동기화(Payload Sync) 과정을 거쳐야 합니까?'}, {'role': 'assistant', 'content': "<think>\n사용자가 'Sensor Error' 에러 처리 과정의 기술적 원리와 당위성에 대해 질문했다.\n사용자는 특정 단계(예: Undock, Payload Update 등)가 왜 필요한지 궁금해하고 있다.\n따라서 '하드웨어 점검 필요. 'Payload Clear' 후 로봇을 점검 구역으로 빼내야 하며, 절대 그대로 자동 운행을 시키면 안 됨 (유령 재고 발생 위험).'이라는 시스템적 배경을 근거로 들어, 해당 로직이 필수적인 이유를 논리적으로 설명한다.\n</think>\n\n이 에러는 센서 하드웨어의 신뢰성이 상실된 상태(False Positive/Negative)를 의미하기 때문입니다. 센서가 오작동하는 상황에서 시스템 데이터만 믿고 자동 운행을 지속할 경우, 실제로는 화물이 있지만 시스템은 없다고 판단하는 '유령 재고(Ghost Inventory)'가 발생하거나, 그 반대의 경우로 인해 충돌 사고가 발생할 위험이 큽니다. 따라서 하드웨어 점검 전까지는 센서 값을 신뢰해서는 안 되며, 다음과 같은 절차로 복구해야 합니다: 1. 즉시 ACS Job을 중단(Cancel)하여 로봇을 정지시킴, 2. 엔지니어가 실제 화물 유무를 육안으로 검증(Visual Inspection), 3. 실제 상태에 맞춰 시스템 데이터를 강제 동기화(Payload Sync), 4. 이후 설비 리셋(Dock Reset) 및 점검 구역 이동."}]}

# %%
len(generated_dataset)

with open("../data/error_scenario_qwen_conversation_format.json", "w", encoding="utf-8") as f:
    json.dump(generated_dataset, f, ensure_ascii=False, indent=4)
